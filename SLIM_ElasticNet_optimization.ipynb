# %% [markdown]
# # SLIM ElasticNet

# %% [markdown]
# ## Import

# %%
## Allow more than one output for a single code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd
import scipy.sparse as sps
import numpy as np
import os

## Set the numpy random seed
SEED = 42
np.random.seed(SEED)

os.getcwd()
# Out:
# '/home/alessio/Scrivania/RecSysChallenge2021'

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

from Evaluation.Evaluator import EvaluatorHoldout

from Recommenders.Recommender_import_list import *

from Recommenders.DataIO import DataIO
# Out:
# Tensorflow is not available

# %%
## Utility Functions
from Dataset.load_data import load_data

# %% [markdown]
# ## Data Loading and Split

# %%
URM_all, ICM_dict = load_data()

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

URM_aug_train = sps.vstack([URM_train.copy().tocoo(), 
                            ICM_dict['ICM_genre'].T.tocoo(),
                            ICM_dict['ICM_subgenre'].T.tocoo(), 
                            #ICM_dict['ICM_event'].T.tocoo(), 
                            ICM_dict['ICM_channel'].T.tocoo()], format='csr')

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10], exclude_seen = True)
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %% [markdown]
# ## Optimization

# %%
# !ls "./result_experiments/SLIM_elasticNet"
# Out:
# SLIM_elasticNet_AUG_all_no_preprocess
# SLIM_elasticNet_AUG_genre_subgenre_channel
# SLIM_elasticNet_AUG_genre_subgenre_channel_improved_range
# SLIM_elasticNet_AUG_genre_subgenre_channel_improved_range2
# SLIM_elasticNet_AUG_subgenre_channel
# SLIM_elasticNet_AUG_subgenre_channel_improved_range
# SLIM_elasticNet_AUG_subgenre_channel_improved_range2
# SLIM_elasticNet_AUG_subgenre_channel_improved_range3
# SLIM_elasticNet_AUG_subgenre_channel_topK_categorical

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_subgenre_channel/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.24

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK  l1_ratio     alpha       MAP
# 1   163   0.00024  0.249627  0.243175
# 8   198  0.000284   0.40556  0.240926
# 9   673  0.000137  0.242518  0.246201
# 10  595  0.000047  0.014348  0.243584
# Max value for the range:  673
# Min value for the range:  163
# Best MAP:  0.24620129975875174
#   topK  l1_ratio     alpha       MAP
# 9  673  0.000137  0.242518  0.246201

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_subgenre_channel_improved_range/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.23

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK  l1_ratio     alpha       MAP
# 1  2166  0.000074  0.629136  0.240714
# 3  3000  0.000676  0.518743  0.241660
# 4  2296  0.000645  0.921119  0.236437
# Max value for the range:  3000
# Min value for the range:  2166
# Best MAP:  0.24165995209945682
#    topK  l1_ratio     alpha      MAP
# 3  3000  0.000676  0.518743  0.24166

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_subgenre_channel_improved_range2/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.23

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#     topK  l1_ratio     alpha       MAP
# 2   1636  0.000798  0.411405  0.243611
# 3   2250  0.000157  0.167486  0.247697
# 5   1695  0.000467  0.872669  0.237389
# 7   4105  0.007362  0.290221  0.242095
# 9   3208  0.014892  0.513976  0.231000
# 10  1361  0.000125  0.214618  0.247316
# 12  2332  0.002503  0.737477  0.236473
# 14  3808   0.00019  0.491501  0.242699
# 15  5000   0.00001     0.001  0.242395
# 16  1000  0.002144     0.001  0.239454
# 17  1000   0.00001     0.001  0.239262
# 18  1000   0.00001       1.0  0.236160
# 19  5000  0.000846     0.001  0.242399
# Max value for the range:  5000
# Min value for the range:  1000
# Best MAP:  0.24769716516730364
#    topK  l1_ratio     alpha       MAP
# 3  2250  0.000157  0.167486  0.247697

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_subgenre_channel_improved_range3/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.24

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK  l1_ratio     alpha       MAP
# 0   784  0.000755  0.318332  0.244759
# 3   385  0.230848  0.005979  0.245127
# 7   544  0.000496  0.014366  0.243371
# 9   610  0.000037  0.435064  0.242721
# 10  504  0.049056  0.018869  0.246835
# 11  409  0.002514  0.333054  0.243149
# 12  358  0.000176  0.432125  0.242374
# 18  516   0.00096  0.501859  0.241236
# 19  519  0.000105  0.045349  0.247893
# Max value for the range:  784
# Min value for the range:  358
# Best MAP:  0.24789319039942123
#    topK  l1_ratio     alpha       MAP
# 19  519  0.000105  0.045349  0.247893

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_subgenre_channel_topK_categorical/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.248

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK  l1_ratio     alpha       MAP
# 14  504  0.001471  0.053619  0.248362
# 23  504  0.001883  0.117165  0.248218
# 24  519  0.000028  0.112551  0.248314
# 26  504   0.00001  0.117231  0.248188
# 29  504   0.00001  0.114378  0.248238
# 32  673  0.001155  0.073102  0.248808
# 33  673  0.001728  0.071795  0.248701
# 34  673   0.00001  0.057693  0.248567
# Max value for the range:  673
# Min value for the range:  504
# Best MAP:  0.2488081628664942
#    topK  l1_ratio     alpha       MAP
# 32  673  0.001155  0.073102  0.248808

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_genre_subgenre_channel/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.248

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#     topK  l1_ratio     alpha       MAP
# 27  1000  0.000206  0.060559  0.249429
# 37   995  0.000017  0.101755  0.248934
# 46   782  0.000299  0.127645  0.248391
# Max value for the range:  1000
# Min value for the range:  782
# Best MAP:  0.24942902333144856
#     topK  l1_ratio     alpha       MAP
# 27  1000  0.000206  0.060559  0.249429

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_genre_subgenre_channel_improved_range/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.248

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#     topK  l1_ratio     alpha       MAP
# 29  1155  0.000015  0.086246  0.249109
# 39  1200  0.000201  0.141444  0.248205
# 46  1200  0.000029  0.098893  0.249031
# 53   600  0.000503  0.121877  0.248354
# 59  1200  0.000358  0.103771  0.248658
# Max value for the range:  1200
# Min value for the range:  600
# Best MAP:  0.2491089283678688
#     topK  l1_ratio     alpha       MAP
# 29  1155  0.000015  0.086246  0.249109

# %%
output_folder_path = "result_experiments/SLIM_elasticNet/SLIM_elasticNet_AUG_genre_subgenre_channel_improved_range2/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(MultiThreadSLIM_SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.24

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK  l1_ratio     alpha       MAP
# 0   971  0.000036  0.223323  0.246936
# 1   936  0.000578  0.368908  0.244168
# 3   759  0.000087  0.228848  0.246548
# 6   600   0.00001     0.001  0.243272
# 7  1200  0.002694     0.001  0.244545
# 9  1174   0.00019  0.007758  0.247633
# Max value for the range:  1200
# Min value for the range:  600
# Best MAP:  0.24763323864892064
#    topK l1_ratio     alpha       MAP
# 9  1174  0.00019  0.007758  0.247633

# %%
output_folder_path = "result_experiments/SLIM_elasticNet_AUG_subgenre_channel_topK_categorical/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 50  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
from Recommenders.SLIM.SLIMElasticNetRecommender import MultiThreadSLIM_SLIMElasticNetRecommender

runHyperparameterSearch_Collaborative(MultiThreadSLIM_SLIMElasticNetRecommender,
                                      URM_train = URM_aug_train,
                                      URM_train_last_test = None,
                                      metric_to_optimize = metric_to_optimize,
                                      cutoff_to_optimize = cutoff_to_optimize,
                                      n_cases = n_cases,
                                      n_random_starts = n_random_starts,
                                      evaluator_validation_earlystopping = evaluator_validation,
                                      evaluator_validation = evaluator_validation,
                                      evaluator_test = None,
                                      output_folder_path = output_folder_path,
                                      resume_from_saved = True,
                                      similarity_type_list = None,
                                      parallelizeKNN = True)
