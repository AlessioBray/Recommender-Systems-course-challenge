# %% [markdown]
# ## Import

# %%
## Allow more than one output for a single code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd
import scipy.sparse as sps
import numpy as np
import os

from skopt.space import Real, Integer, Categorical

## Set the numpy random seed
SEED = 42
np.random.seed(SEED)

os.getcwd()
# Out:
# '/home/jupyter/RecSysChallenge2021'

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

from Evaluation.Evaluator import EvaluatorHoldout

from Recommenders.Recommender_import_list import *
# Out:
# Tensorflow is not available

# %%
## Utility Functions
from Dataset.load_data import load_data
from Dataset.write_submission import write_submission
from Dataset.load_test_user_array import load_test_user_array

# %% [markdown]
# ## Data Loading and Split

# %%
DATA_FILE_PATH = "./Dataset"

URM_PATH = os.path.join(DATA_FILE_PATH, "data_train.csv")

URM_all_dataframe = pd.read_csv(filepath_or_buffer=URM_PATH, 
                                sep=",",
                                dtype={0:int, 1:int, 2:int},
                                engine='python')

URM_all_dataframe.columns = ["UserID", "ItemID", "Interaction"]


userID_unique = URM_all_dataframe["UserID"].unique()
itemID_unique = URM_all_dataframe["ItemID"].unique()

n_users = len(userID_unique)
n_items = len(itemID_unique)


ICM_event_PATH = os.path.join(DATA_FILE_PATH, "data_ICM_event.csv")

ICM_event_dataframe = pd.read_csv(filepath_or_buffer=ICM_event_PATH, 
                            sep=",", 
                            dtype={0:int, 1:int, 2:int},
                            engine='python')

ICM_event_dataframe.columns = ["ItemID", "EventID", "Feature"]

n_event_features = max(ICM_event_dataframe["EventID"]) + 1 # this must be set to max since it is a processed matrix

ICM_event = sps.csr_matrix((np.ones(len(ICM_event_dataframe["ItemID"].values)), (ICM_event_dataframe["ItemID"].values, ICM_event_dataframe["EventID"].values)),
                            shape = (n_items, n_event_features)
                             )

ICM_event.data = np.ones_like(ICM_event.data)

# %%
URM_all, ICM_dict = load_data()
ICM_dict['ICM_event'] = ICM_event

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

URM_aug_train = sps.vstack([URM_train.copy().tocoo(), 
                            #ICM_dict['ICM_genre'].T.tocoo(),
                            ICM_dict['ICM_subgenre'].T.tocoo(), 
                            #ICM_dict['ICM_event'].T.tocoo(), 
                            ICM_dict['ICM_channel'].T.tocoo()], format='csr')

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10], exclude_seen = True)
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
test_UserID_array = load_test_user_array()

# %% [markdown]
# ## Optimization

# %%
output_folder_path = "result_experiments/ItemCBF_event_noPreprocessed/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 50  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative

runHyperparameterSearch_Collaborative(MultVAERecommender,
                                URM_train = URM_train,
                                URM_train_last_test = None,
                                metric_to_optimize = metric_to_optimize,
                                cutoff_to_optimize = cutoff_to_optimize,
                                evaluator_validation = evaluator_validation,
                                evaluator_test = None,
                                output_folder_path = output_folder_path,
                                parallelizeKNN = True,
                                allow_weighting = True,
                                allow_bias_ICM = True,
                                resume_from_saved = True,
                                similarity_type_list = None,
                                ICM_name = 'ICM_event',
                                ICM_object = ICM_event.copy(),
                                n_cases = n_cases,
                                n_random_starts = n_random_starts
                               )
# Out:
# SearchBayesianSkopt: Resuming 'ItemKNNCBFRecommender_ICM_event_cosine' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 6338, 'shrink': 24, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'none', 'ICM_bias': 48.04236752064873}
# SearchBayesianSkopt: Resuming 'ItemKNNCBFRecommender_ICM_event_jaccard' Failed, no such file exists.
#
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 37, 'shrink': 1060, 'similarity': 'jaccard', 'normalize': False}
# SearchBayesianSkopt: Resuming 'ItemKNNCBFRecommender_ICM_event_asymmetric' Failed, no such file exists.
#
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.Iteration No: 1 started. Evaluating function at random point.
#
# SearchBayesianSkopt: Testing config: {'topK': 5117, 'shrink': 1242, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.6018724983238877, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.22707836073382298}
# SearchBayesianSkopt: Resuming 'ItemKNNCBFRecommender_ICM_event_dice' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 4574, 'shrink': 259, 'similarity': 'dice', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# SearchBayesianSkopt: Resuming 'ItemKNNCBFRecommender_ICM_event_tversky' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 5830, 'shrink': 2995, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.9073122668793414, 'tversky_beta': 0.6973813564750694}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 9485.64 column/sec. Elapsed time 1.90 sec
# Similarity column 18059 (100.0%), 8530.79 column/sec. Elapsed time 2.12 sec
# Similarity column 18059 (100.0%), 9858.93 column/sec. Elapsed time 1.83 sec
# Similarity column 18059 (100.0%), 5240.06 column/sec. Elapsed time 3.45 sec
# Similarity column 18059 (100.0%), 4865.55 column/sec. Elapsed time 3.71 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 8.86 sec. Users per second: 1540
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 37, 'shrink': 1060, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0107211, PRECISION_RECALL_MIN_DEN: 0.0107211, RECALL: 0.0012159, MAP: 0.0033932, MAP_MIN_DEN: 0.0033932, MRR: 0.0313548, NDCG: 0.0109331, F1: 0.0021841, HIT_RATE: 0.0990034, ARHR_ALL_HITS: 0.0326025, NOVELTY: 0.0084258, AVERAGE_POPULARITY: 0.0474067, DIVERSITY_MEAN_INTER_LIST: 0.9781754, DIVERSITY_HERFINDAHL: 0.9978104, COVERAGE_ITEM: 0.2943685, COVERAGE_ITEM_CORRECT: 0.0203223, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0989744, DIVERSITY_GINI: 0.0600301, SHANNON_ENTROPY: 10.2133216, RATIO_DIVERSITY_HERFINDAHL: 0.9981956, RATIO_DIVERSITY_GINI: 0.2421344, RATIO_SHANNON_ENTROPY: 0.8243214, RATIO_AVERAGE_POPULARITY: 0.2326482, RATIO_NOVELTY: 0.0396440,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard_best_model'
# EvaluatorHoldout: Processed 13646 (100.0%) in 8.83 sec. Users per second: 1545ItemKNNCBFRecommender: Saving complete
#
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 6338, 'shrink': 24, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'none', 'ICM_bias': 48.04236752064873} - results: PRECISION: 0.0021178, PRECISION_RECALL_MIN_DEN: 0.0021178, RECALL: 0.0002456, MAP: 0.0005677, MAP_MIN_DEN: 0.0005677, MRR: 0.0054631, NDCG: 0.0020074, F1: 0.0004402, HIT_RATE: 0.0205188, ARHR_ALL_HITS: 0.0055699, NOVELTY: 0.0091860, AVERAGE_POPULARITY: 0.0143135, DIVERSITY_MEAN_INTER_LIST: 0.9628768, DIVERSITY_HERFINDAHL: 0.9962806, COVERAGE_ITEM: 0.2394374, COVERAGE_ITEM_CORRECT: 0.0073094, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0205128, DIVERSITY_GINI: 0.0396366, SHANNON_ENTROPY: 9.4943412, RATIO_DIVERSITY_HERFINDAHL: 0.9966652, RATIO_DIVERSITY_GINI: 0.1598763, RATIO_SHANNON_ENTROPY: 0.7662922, RATIO_AVERAGE_POPULARITY: 0.0702436, RATIO_NOVELTY: 0.0432208,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_cosine
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_cosine_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 11.1539
# Function value obtained: -0.0034
# Current minimum: -0.0034
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 3238, 'shrink': 175, 'similarity': 'jaccard', 'normalize': False}
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 11.3573
# Function value obtained: -0.0006
# Current minimum: -0.0006
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 4612, 'shrink': 2775, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'BM25', 'ICM_bias': 1.6641238411966883}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 8.86 sec. Users per second: 1540
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 5117, 'shrink': 1242, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.6018724983238877, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.22707836073382298} - results: PRECISION: 0.0025575, PRECISION_RECALL_MIN_DEN: 0.0025575, RECALL: 0.0003278, MAP: 0.0006666, MAP_MIN_DEN: 0.0006666, MRR: 0.0065300, NDCG: 0.0023971, F1: 0.0005811, HIT_RATE: 0.0252089, ARHR_ALL_HITS: 0.0065978, NOVELTY: 0.0091653, AVERAGE_POPULARITY: 0.0150533, DIVERSITY_MEAN_INTER_LIST: 0.9646982, DIVERSITY_HERFINDAHL: 0.9964627, COVERAGE_ITEM: 0.1632427, COVERAGE_ITEM_CORRECT: 0.0082507, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0252015, DIVERSITY_GINI: 0.0281493, SHANNON_ENTROPY: 9.2107542, RATIO_DIVERSITY_HERFINDAHL: 0.9968474, RATIO_DIVERSITY_GINI: 0.1135417, RATIO_SHANNON_ENTROPY: 0.7434037, RATIO_AVERAGE_POPULARITY: 0.0738743, RATIO_NOVELTY: 0.0431233,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_asymmetric
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_asymmetric_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 12.8611
# Function value obtained: -0.0007
# Current minimum: -0.0007
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 781, 'shrink': 3150, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.2508402945050346, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.016597903460638254}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.44 sec. Users per second: 1193
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 4574, 'shrink': 259, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0064708, PRECISION_RECALL_MIN_DEN: 0.0064708, RECALL: 0.0007020, MAP: 0.0019345, MAP_MIN_DEN: 0.0019345, MRR: 0.0184802, NDCG: 0.0064699, F1: 0.0012667, HIT_RATE: 0.0621428, ARHR_ALL_HITS: 0.0189053, NOVELTY: 0.0087790, AVERAGE_POPULARITY: 0.0293858, DIVERSITY_MEAN_INTER_LIST: 0.9743360, DIVERSITY_HERFINDAHL: 0.9974265, COVERAGE_ITEM: 0.2904369, COVERAGE_ITEM_CORRECT: 0.0160585, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0621245, DIVERSITY_GINI: 0.0611614, SHANNON_ENTROPY: 10.1428123, RATIO_DIVERSITY_HERFINDAHL: 0.9978115, RATIO_DIVERSITY_GINI: 0.2466975, RATIO_SHANNON_ENTROPY: 0.8186305, RATIO_AVERAGE_POPULARITY: 0.1442108, RATIO_NOVELTY: 0.0413057,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice_best_model'
# ItemKNNCBFRecommender: Saving complete
# Similarity column 18059 (100.0%), 7480.21 column/sec. Elapsed time 2.41 sec
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 13.6517
# Function value obtained: -0.0019
# Current minimum: -0.0019
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1453, 'shrink': 2834, 'similarity': 'dice', 'normalize': False}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 6258.62 column/sec. Elapsed time 2.89 sec
# Similarity column 18059 (100.0%), 7275.05 column/sec. Elapsed time 2.48 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.99 sec. Users per second: 1138
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 5830, 'shrink': 2995, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.9073122668793414, 'tversky_beta': 0.6973813564750694} - results: PRECISION: 0.0203943, PRECISION_RECALL_MIN_DEN: 0.0203943, RECALL: 0.0022465, MAP: 0.0078690, MAP_MIN_DEN: 0.0078690, MRR: 0.0670931, NDCG: 0.0226639, F1: 0.0040472, HIT_RATE: 0.1735307, ARHR_ALL_HITS: 0.0726259, NOVELTY: 0.0080362, AVERAGE_POPULARITY: 0.0851451, DIVERSITY_MEAN_INTER_LIST: 0.9621586, DIVERSITY_HERFINDAHL: 0.9962088, COVERAGE_ITEM: 0.2811894, COVERAGE_ITEM_CORRECT: 0.0177197, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1734799, DIVERSITY_GINI: 0.0486981, SHANNON_ENTROPY: 9.7529413, RATIO_DIVERSITY_HERFINDAHL: 0.9965934, RATIO_DIVERSITY_GINI: 0.1964264, RATIO_SHANNON_ENTROPY: 0.7871639, RATIO_AVERAGE_POPULARITY: 0.4178495, RATIO_NOVELTY: 0.0378108,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_tversky
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_tversky_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 16.1766
# Function value obtained: -0.0079
# Current minimum: -0.0079
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 9994, 'shrink': 1754, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.28364040210698566, 'tversky_beta': 1.2675125921317574}
# Similarity column 18059 (100.0%), 6542.37 column/sec. Elapsed time 2.76 secItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
#
# Similarity column 18059 (100.0%), 4559.77 column/sec. Elapsed time 3.96 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.37 sec. Users per second: 1456
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 4612, 'shrink': 2775, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'BM25', 'ICM_bias': 1.6641238411966883} - results: PRECISION: 0.0022351, PRECISION_RECALL_MIN_DEN: 0.0022351, RECALL: 0.0002624, MAP: 0.0006195, MAP_MIN_DEN: 0.0006195, MRR: 0.0059421, NDCG: 0.0021498, F1: 0.0004697, HIT_RATE: 0.0217646, ARHR_ALL_HITS: 0.0060688, NOVELTY: 0.0091753, AVERAGE_POPULARITY: 0.0146555, DIVERSITY_MEAN_INTER_LIST: 0.9651119, DIVERSITY_HERFINDAHL: 0.9965041, COVERAGE_ITEM: 0.2439781, COVERAGE_ITEM_CORRECT: 0.0078631, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0217582, DIVERSITY_GINI: 0.0421482, SHANNON_ENTROPY: 9.5910002, RATIO_DIVERSITY_HERFINDAHL: 0.9968888, RATIO_DIVERSITY_GINI: 0.1700070, RATIO_SHANNON_ENTROPY: 0.7740935, RATIO_AVERAGE_POPULARITY: 0.0719218, RATIO_NOVELTY: 0.0431707,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_cosine
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_cosine_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 12.1909
# Function value obtained: -0.0006
# Current minimum: -0.0006
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 9808, 'shrink': 583, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'none', 'ICM_bias': 58.25167462182646}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.39 sec. Users per second: 1453
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 3238, 'shrink': 175, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0057306, PRECISION_RECALL_MIN_DEN: 0.0057306, RECALL: 0.0006225, MAP: 0.0017368, MAP_MIN_DEN: 0.0017368, MRR: 0.0166904, NDCG: 0.0057818, F1: 0.0011230, HIT_RATE: 0.0554009, ARHR_ALL_HITS: 0.0170250, NOVELTY: 0.0088771, AVERAGE_POPULARITY: 0.0259369, DIVERSITY_MEAN_INTER_LIST: 0.9732975, DIVERSITY_HERFINDAHL: 0.9973226, COVERAGE_ITEM: 0.2794728, COVERAGE_ITEM_CORRECT: 0.0150064, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0553846, DIVERSITY_GINI: 0.0585254, SHANNON_ENTROPY: 10.0836211, RATIO_DIVERSITY_HERFINDAHL: 0.9977076, RATIO_DIVERSITY_GINI: 0.2360650, RATIO_SHANNON_ENTROPY: 0.8138532, RATIO_AVERAGE_POPULARITY: 0.1272854, RATIO_NOVELTY: 0.0417676,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 12.6186
# Function value obtained: -0.0017
# Current minimum: -0.0034
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 5355, 'shrink': 1644, 'similarity': 'jaccard', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 8.89 sec. Users per second: 1535
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 1453, 'shrink': 2834, 'similarity': 'dice', 'normalize': False} - results: PRECISION: 0.0194856, PRECISION_RECALL_MIN_DEN: 0.0194856, RECALL: 0.0021271, MAP: 0.0073617, MAP_MIN_DEN: 0.0073617, MRR: 0.0630742, NDCG: 0.0214279, F1: 0.0038354, HIT_RATE: 0.1665690, ARHR_ALL_HITS: 0.0681055, NOVELTY: 0.0080456, AVERAGE_POPULARITY: 0.0819658, DIVERSITY_MEAN_INTER_LIST: 0.9643588, DIVERSITY_HERFINDAHL: 0.9964288, COVERAGE_ITEM: 0.2846226, COVERAGE_ITEM_CORRECT: 0.0181073, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1665201, DIVERSITY_GINI: 0.0502917, SHANNON_ENTROPY: 9.8184596, RATIO_DIVERSITY_HERFINDAHL: 0.9968135, RATIO_DIVERSITY_GINI: 0.2028541, RATIO_SHANNON_ENTROPY: 0.7924519, RATIO_AVERAGE_POPULARITY: 0.4022472, RATIO_NOVELTY: 0.0378550,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice_best_model'
# ItemKNNCBFRecommender: Saving complete
# Similarity column 18059 (100.0%), 9255.69 column/sec. Elapsed time 1.95 sec
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 12.0187
# Function value obtained: -0.0074
# Current minimum: -0.0074
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 171, 'shrink': 2572, 'similarity': 'dice', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 6678.00 column/sec. Elapsed time 2.70 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.23 sec. Users per second: 1216
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 781, 'shrink': 3150, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.2508402945050346, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.016597903460638254} - results: PRECISION: 0.0272827, PRECISION_RECALL_MIN_DEN: 0.0272877, RECALL: 0.0031093, MAP: 0.0115580, MAP_MIN_DEN: 0.0115585, MRR: 0.0963008, NDCG: 0.0317591, F1: 0.0055824, HIT_RATE: 0.2265865, ARHR_ALL_HITS: 0.1054079, NOVELTY: 0.0076438, AVERAGE_POPULARITY: 0.1135815, DIVERSITY_MEAN_INTER_LIST: 0.9502609, DIVERSITY_HERFINDAHL: 0.9950191, COVERAGE_ITEM: 0.2611440, COVERAGE_ITEM_CORRECT: 0.0182734, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2265201, DIVERSITY_GINI: 0.0450606, SHANNON_ENTROPY: 9.4902604, RATIO_DIVERSITY_HERFINDAHL: 0.9954032, RATIO_DIVERSITY_GINI: 0.1817540, RATIO_SHANNON_ENTROPY: 0.7659628, RATIO_AVERAGE_POPULARITY: 0.5574010, RATIO_NOVELTY: 0.0359648,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_asymmetric
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_asymmetric_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 14.1198
# Function value obtained: -0.0116
# Current minimum: -0.0116
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 5251, 'shrink': 3511, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.2313449963269012, 'feature_weighting': 'TF-IDF', 'ICM_bias': 4.177830183554939}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 6987.34 column/sec. Elapsed time 2.58 sec
# Similarity column 18059 (100.0%), 9031.43 column/sec. Elapsed time 2.00 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.81 sec. Users per second: 1391
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 9994, 'shrink': 1754, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.28364040210698566, 'tversky_beta': 1.2675125921317574} - results: PRECISION: 0.0289316, PRECISION_RECALL_MIN_DEN: 0.0289334, RECALL: 0.0034642, MAP: 0.0121401, MAP_MIN_DEN: 0.0121407, MRR: 0.1004685, NDCG: 0.0334368, F1: 0.0061875, HIT_RATE: 0.2384582, ARHR_ALL_HITS: 0.1102953, NOVELTY: 0.0075828, AVERAGE_POPULARITY: 0.1209502, DIVERSITY_MEAN_INTER_LIST: 0.9328343, DIVERSITY_HERFINDAHL: 0.9932766, COVERAGE_ITEM: 0.2772025, COVERAGE_ITEM_CORRECT: 0.0176089, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2383883, DIVERSITY_GINI: 0.0428054, SHANNON_ENTROPY: 9.3310748, RATIO_DIVERSITY_HERFINDAHL: 0.9936600, RATIO_DIVERSITY_GINI: 0.1726576, RATIO_SHANNON_ENTROPY: 0.7531149, RATIO_AVERAGE_POPULARITY: 0.5935628, RATIO_NOVELTY: 0.0356778,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_tversky
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_tversky_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 14.1540
# Function value obtained: -0.0121
# Current minimum: -0.0121
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 5353, 'shrink': 4727, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.05530832955401267, 'tversky_beta': 1.0437056011082912}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 4565.67 column/sec. Elapsed time 3.96 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.68 sec. Users per second: 1409
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 9808, 'shrink': 583, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'none', 'ICM_bias': 58.25167462182646} - results: PRECISION: 0.0314305, PRECISION_RECALL_MIN_DEN: 0.0314404, RECALL: 0.0038016, MAP: 0.0147701, MAP_MIN_DEN: 0.0147723, MRR: 0.1217628, NDCG: 0.0387620, F1: 0.0067828, HIT_RATE: 0.2555328, ARHR_ALL_HITS: 0.1339162, NOVELTY: 0.0075886, AVERAGE_POPULARITY: 0.1325779, DIVERSITY_MEAN_INTER_LIST: 0.9058275, DIVERSITY_HERFINDAHL: 0.9905761, COVERAGE_ITEM: 0.2567141, COVERAGE_ITEM_CORRECT: 0.0145634, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2554579, DIVERSITY_GINI: 0.0365544, SHANNON_ENTROPY: 9.0024497, RATIO_DIVERSITY_HERFINDAHL: 0.9909585, RATIO_DIVERSITY_GINI: 0.1474439, RATIO_SHANNON_ENTROPY: 0.7265914, RATIO_AVERAGE_POPULARITY: 0.6506260, RATIO_NOVELTY: 0.0357049,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_cosine
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_cosine_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 12.6984
# Function value obtained: -0.0148
# Current minimum: -0.0148
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 5414, 'shrink': 2176, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'BM25', 'ICM_bias': 1.5435772044132163}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.91 sec. Users per second: 1251
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 5355, 'shrink': 1644, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0146783, PRECISION_RECALL_MIN_DEN: 0.0146783, RECALL: 0.0016326, MAP: 0.0051255, MAP_MIN_DEN: 0.0051255, MRR: 0.0455704, NDCG: 0.0155965, F1: 0.0029383, HIT_RATE: 0.1306610, ARHR_ALL_HITS: 0.0482937, NOVELTY: 0.0082360, AVERAGE_POPULARITY: 0.0637825, DIVERSITY_MEAN_INTER_LIST: 0.9754920, DIVERSITY_HERFINDAHL: 0.9975421, COVERAGE_ITEM: 0.2889418, COVERAGE_ITEM_CORRECT: 0.0197685, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1306227, DIVERSITY_GINI: 0.0556441, SHANNON_ENTROPY: 10.0761834, RATIO_DIVERSITY_HERFINDAHL: 0.9979271, RATIO_DIVERSITY_GINI: 0.2244432, RATIO_SHANNON_ENTROPY: 0.8132529, RATIO_AVERAGE_POPULARITY: 0.3130125, RATIO_NOVELTY: 0.0387509,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 13.1816
# Function value obtained: -0.0051
# Current minimum: -0.0051
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1470, 'shrink': 2689, 'similarity': 'jaccard', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 8477.60 column/sec. Elapsed time 2.13 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.17 sec. Users per second: 1489
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 5251, 'shrink': 3511, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.2313449963269012, 'feature_weighting': 'TF-IDF', 'ICM_bias': 4.177830183554939} - results: PRECISION: 0.0024329, PRECISION_RECALL_MIN_DEN: 0.0024329, RECALL: 0.0003147, MAP: 0.0006213, MAP_MIN_DEN: 0.0006213, MRR: 0.0060613, NDCG: 0.0022566, F1: 0.0005574, HIT_RATE: 0.0238898, ARHR_ALL_HITS: 0.0061371, NOVELTY: 0.0091871, AVERAGE_POPULARITY: 0.0146297, DIVERSITY_MEAN_INTER_LIST: 0.9632044, DIVERSITY_HERFINDAHL: 0.9963134, COVERAGE_ITEM: 0.1619137, COVERAGE_ITEM_CORRECT: 0.0074755, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0238828, DIVERSITY_GINI: 0.0274741, SHANNON_ENTROPY: 9.1670299, RATIO_DIVERSITY_HERFINDAHL: 0.9966980, RATIO_DIVERSITY_GINI: 0.1108183, RATIO_SHANNON_ENTROPY: 0.7398747, RATIO_AVERAGE_POPULARITY: 0.0717952, RATIO_NOVELTY: 0.0432258,
#
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.86 sec. Users per second: 1383
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 171, 'shrink': 2572, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0181812, PRECISION_RECALL_MIN_DEN: 0.0181812, RECALL: 0.0020050, MAP: 0.0067288, MAP_MIN_DEN: 0.0067288, MRR: 0.0581171, NDCG: 0.0197987, F1: 0.0036117, HIT_RATE: 0.1566027, ARHR_ALL_HITS: 0.0624994, NOVELTY: 0.0080854, AVERAGE_POPULARITY: 0.0779311, DIVERSITY_MEAN_INTER_LIST: 0.9673933, DIVERSITY_HERFINDAHL: 0.9967322, COVERAGE_ITEM: 0.2853425, COVERAGE_ITEM_CORRECT: 0.0185503, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1565568, DIVERSITY_GINI: 0.0512825, SHANNON_ENTROPY: 9.8748055, RATIO_DIVERSITY_HERFINDAHL: 0.9971170, RATIO_DIVERSITY_GINI: 0.2068506, RATIO_SHANNON_ENTROPY: 0.7969996, RATIO_AVERAGE_POPULARITY: 0.3824467, RATIO_NOVELTY: 0.0380423,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 11.5292
# Function value obtained: -0.0006
# Current minimum: -0.0116
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 8157, 'shrink': 1522, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.9644173589620764, 'feature_weighting': 'none', 'ICM_bias': 0.15312026074886398}
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 12.7513
# Function value obtained: -0.0067
# Current minimum: -0.0074
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 255, 'shrink': 3522, 'similarity': 'dice', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 5615.90 column/sec. Elapsed time 3.22 sec
# Similarity column 18059 (100.0%), 8979.97 column/sec. Elapsed time 2.01 sec
# Similarity column 18059 (100.0%), 6677.09 column/sec. Elapsed time 2.70 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.62 sec. Users per second: 1418
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 5353, 'shrink': 4727, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.05530832955401267, 'tversky_beta': 1.0437056011082912} - results: PRECISION: 0.0343251, PRECISION_RECALL_MIN_DEN: 0.0343269, RECALL: 0.0042317, MAP: 0.0154412, MAP_MIN_DEN: 0.0154421, MRR: 0.1259016, NDCG: 0.0411063, F1: 0.0075346, HIT_RATE: 0.2770043, ARHR_ALL_HITS: 0.1392489, NOVELTY: 0.0073445, AVERAGE_POPULARITY: 0.1429856, DIVERSITY_MEAN_INTER_LIST: 0.9056428, DIVERSITY_HERFINDAHL: 0.9905576, COVERAGE_ITEM: 0.2593167, COVERAGE_ITEM_CORRECT: 0.0157816, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2769231, DIVERSITY_GINI: 0.0361863, SHANNON_ENTROPY: 8.9554407, RATIO_DIVERSITY_HERFINDAHL: 0.9909400, RATIO_DIVERSITY_GINI: 0.1459592, RATIO_SHANNON_ENTROPY: 0.7227973, RATIO_AVERAGE_POPULARITY: 0.7017017, RATIO_NOVELTY: 0.0345566,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_tversky
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_tversky_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 14.0063
# Function value obtained: -0.0154
# Current minimum: -0.0154
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 7760, 'shrink': 4450, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.6517124806983491, 'tversky_beta': 0.23591157504149957}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 8.93 sec. Users per second: 1528
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 5414, 'shrink': 2176, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'BM25', 'ICM_bias': 1.5435772044132163} - results: PRECISION: 0.0029313, PRECISION_RECALL_MIN_DEN: 0.0029313, RECALL: 0.0003153, MAP: 0.0008696, MAP_MIN_DEN: 0.0008696, MRR: 0.0082766, NDCG: 0.0029149, F1: 0.0005694, HIT_RATE: 0.0282867, ARHR_ALL_HITS: 0.0084863, NOVELTY: 0.0091075, AVERAGE_POPULARITY: 0.0165302, DIVERSITY_MEAN_INTER_LIST: 0.9664367, DIVERSITY_HERFINDAHL: 0.9966366, COVERAGE_ITEM: 0.2516751, COVERAGE_ITEM_CORRECT: 0.0099120, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0282784, DIVERSITY_GINI: 0.0471428, SHANNON_ENTROPY: 9.7496207, RATIO_DIVERSITY_HERFINDAHL: 0.9970213, RATIO_DIVERSITY_GINI: 0.1901530, RATIO_SHANNON_ENTROPY: 0.7868959, RATIO_AVERAGE_POPULARITY: 0.0811219, RATIO_NOVELTY: 0.0428515,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 11.3370
# Function value obtained: -0.0009
# Current minimum: -0.0148
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 5810, 'shrink': 2531, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF', 'ICM_bias': 719.8674960496154}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 4538.18 column/sec. Elapsed time 3.98 sec
# Similarity column 18059 (100.0%), 5986.81 column/sec. Elapsed time 3.02 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.63 sec. Users per second: 1284
# SearchBayesianSkopt: New best config found. Config 3: {'topK': 1470, 'shrink': 2689, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0188040, PRECISION_RECALL_MIN_DEN: 0.0188040, RECALL: 0.0020679, MAP: 0.0070154, MAP_MIN_DEN: 0.0070154, MRR: 0.0603577, NDCG: 0.0205505, F1: 0.0037261, HIT_RATE: 0.1614392, ARHR_ALL_HITS: 0.0650456, NOVELTY: 0.0080662, AVERAGE_POPULARITY: 0.0798652, DIVERSITY_MEAN_INTER_LIST: 0.9658312, DIVERSITY_HERFINDAHL: 0.9965760, COVERAGE_ITEM: 0.2850102, COVERAGE_ITEM_CORRECT: 0.0184949, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1613919, DIVERSITY_GINI: 0.0508468, SHANNON_ENTROPY: 9.8487269, RATIO_DIVERSITY_HERFINDAHL: 0.9969608, RATIO_DIVERSITY_GINI: 0.2050933, RATIO_SHANNON_ENTROPY: 0.7948948, RATIO_AVERAGE_POPULARITY: 0.3919381, RATIO_NOVELTY: 0.0379518,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 14.1904
# Function value obtained: -0.0070
# Current minimum: -0.0070
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 8790, 'shrink': 4711, 'similarity': 'jaccard', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.84 sec. Users per second: 1387
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 8157, 'shrink': 1522, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.9644173589620764, 'feature_weighting': 'none', 'ICM_bias': 0.15312026074886398} - results: PRECISION: 0.0038326, PRECISION_RECALL_MIN_DEN: 0.0038326, RECALL: 0.0004924, MAP: 0.0012786, MAP_MIN_DEN: 0.0012786, MRR: 0.0125570, NDCG: 0.0040824, F1: 0.0008727, HIT_RATE: 0.0376667, ARHR_ALL_HITS: 0.0126716, NOVELTY: 0.0090741, AVERAGE_POPULARITY: 0.0201480, DIVERSITY_MEAN_INTER_LIST: 0.9655181, DIVERSITY_HERFINDAHL: 0.9965447, COVERAGE_ITEM: 0.1844510, COVERAGE_ITEM_CORRECT: 0.0098012, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0376557, DIVERSITY_GINI: 0.0321140, SHANNON_ENTROPY: 9.3557839, RATIO_DIVERSITY_HERFINDAHL: 0.9969294, RATIO_DIVERSITY_GINI: 0.1295334, RATIO_SHANNON_ENTROPY: 0.7551091, RATIO_AVERAGE_POPULARITY: 0.0988765, RATIO_NOVELTY: 0.0426944,
#
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.54 sec. Users per second: 1295
# SearchBayesianSkopt: New best config found. Config 3: {'topK': 255, 'shrink': 3522, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0211637, PRECISION_RECALL_MIN_DEN: 0.0211637, RECALL: 0.0023467, MAP: 0.0082459, MAP_MIN_DEN: 0.0082459, MRR: 0.0700779, NDCG: 0.0236337, F1: 0.0042249, HIT_RATE: 0.1795398, ARHR_ALL_HITS: 0.0759831, NOVELTY: 0.0079798, AVERAGE_POPULARITY: 0.0890242, DIVERSITY_MEAN_INTER_LIST: 0.9601960, DIVERSITY_HERFINDAHL: 0.9960126, COVERAGE_ITEM: 0.2819093, COVERAGE_ITEM_CORRECT: 0.0176643, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1794872, DIVERSITY_GINI: 0.0484784, SHANNON_ENTROPY: 9.7259151, RATIO_DIVERSITY_HERFINDAHL: 0.9963971, RATIO_DIVERSITY_GINI: 0.1955402, RATIO_SHANNON_ENTROPY: 0.7849826, RATIO_AVERAGE_POPULARITY: 0.4368860, RATIO_NOVELTY: 0.0375456,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice_best_model'
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 12.8523
# Function value obtained: -0.0013
# ItemKNNCBFRecommender: Saving complete
# Current minimum: -0.0116
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 3078, 'shrink': 883, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.2246181185065022, 'feature_weighting': 'TF-IDF', 'ICM_bias': 278.92168114997514}
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 12.8780
# Function value obtained: -0.0082
# Current minimum: -0.0082
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 5412, 'shrink': 3751, 'similarity': 'dice', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 9964.84 column/sec. Elapsed time 1.81 sec
# Similarity column 18059 (100.0%), 8888.53 column/sec. Elapsed time 2.03 sec
# Similarity column 18059 (100.0%), 6270.83 column/sec. Elapsed time 2.88 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.72 sec. Users per second: 1404
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 7760, 'shrink': 4450, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.6517124806983491, 'tversky_beta': 0.23591157504149957} - results: PRECISION: 0.0244687, PRECISION_RECALL_MIN_DEN: 0.0244705, RECALL: 0.0027516, MAP: 0.0108008, MAP_MIN_DEN: 0.0108015, MRR: 0.0909840, NDCG: 0.0292758, F1: 0.0049468, HIT_RATE: 0.2038693, ARHR_ALL_HITS: 0.0990222, NOVELTY: 0.0079459, AVERAGE_POPULARITY: 0.1014802, DIVERSITY_MEAN_INTER_LIST: 0.9394401, DIVERSITY_HERFINDAHL: 0.9939371, COVERAGE_ITEM: 0.2713329, COVERAGE_ITEM_CORRECT: 0.0153940, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2038095, DIVERSITY_GINI: 0.0431303, SHANNON_ENTROPY: 9.4083566, RATIO_DIVERSITY_HERFINDAHL: 0.9943208, RATIO_DIVERSITY_GINI: 0.1739684, RATIO_SHANNON_ENTROPY: 0.7593523, RATIO_AVERAGE_POPULARITY: 0.4980139, RATIO_NOVELTY: 0.0373859,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 14.0818
# Function value obtained: -0.0108
# Current minimum: -0.0154
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2662, 'shrink': 4418, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.7911314243178622, 'tversky_beta': 0.5546936861632773}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.32 sec. Users per second: 1205
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 5810, 'shrink': 2531, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF', 'ICM_bias': 719.8674960496154} - results: PRECISION: 0.0021105, PRECISION_RECALL_MIN_DEN: 0.0021105, RECALL: 0.0002429, MAP: 0.0005913, MAP_MIN_DEN: 0.0005913, MRR: 0.0056974, NDCG: 0.0020447, F1: 0.0004357, HIT_RATE: 0.0205188, ARHR_ALL_HITS: 0.0058051, NOVELTY: 0.0091856, AVERAGE_POPULARITY: 0.0143606, DIVERSITY_MEAN_INTER_LIST: 0.9628561, DIVERSITY_HERFINDAHL: 0.9962786, COVERAGE_ITEM: 0.2391605, COVERAGE_ITEM_CORRECT: 0.0072540, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0205128, DIVERSITY_GINI: 0.0395822, SHANNON_ENTROPY: 9.4935923, RATIO_DIVERSITY_HERFINDAHL: 0.9966631, RATIO_DIVERSITY_GINI: 0.1596568, RATIO_SHANNON_ENTROPY: 0.7662317, RATIO_AVERAGE_POPULARITY: 0.0704744, RATIO_NOVELTY: 0.0432188,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 14.6442
# Function value obtained: -0.0006
# Current minimum: -0.0148
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 7724, 'shrink': 1152, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'BM25', 'ICM_bias': 7.203645728086528}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.31 sec. Users per second: 1466
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 3078, 'shrink': 883, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.2246181185065022, 'feature_weighting': 'TF-IDF', 'ICM_bias': 278.92168114997514} - results: PRECISION: 0.0029313, PRECISION_RECALL_MIN_DEN: 0.0029313, RECALL: 0.0003481, MAP: 0.0011159, MAP_MIN_DEN: 0.0011159, MRR: 0.0109396, NDCG: 0.0033613, F1: 0.0006222, HIT_RATE: 0.0287996, ARHR_ALL_HITS: 0.0110493, NOVELTY: 0.0091525, AVERAGE_POPULARITY: 0.0167376, DIVERSITY_MEAN_INTER_LIST: 0.8288275, DIVERSITY_HERFINDAHL: 0.9828767, COVERAGE_ITEM: 0.1051553, COVERAGE_ITEM_CORRECT: 0.0044853, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0287912, DIVERSITY_GINI: 0.0095592, SHANNON_ENTROPY: 7.2613885, RATIO_DIVERSITY_HERFINDAHL: 0.9832561, RATIO_DIVERSITY_GINI: 0.0385575, RATIO_SHANNON_ENTROPY: 0.5860696, RATIO_AVERAGE_POPULARITY: 0.0821396, RATIO_NOVELTY: 0.0430633,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 11.6165
# Function value obtained: -0.0011
# Current minimum: -0.0116
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 7394, 'shrink': 2769, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.3190845694778471, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.9675568179363458}
# Similarity column 18059 (100.0%), 4538.78 column/sec. Elapsed time 3.98 sec
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.77 sec. Users per second: 1396
# SearchBayesianSkopt: New best config found. Config 4: {'topK': 8790, 'shrink': 4711, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0234428, PRECISION_RECALL_MIN_DEN: 0.0234446, RECALL: 0.0026602, MAP: 0.0097463, MAP_MIN_DEN: 0.0097469, MRR: 0.0823314, NDCG: 0.0271053, F1: 0.0047783, HIT_RATE: 0.1971274, ARHR_ALL_HITS: 0.0894892, NOVELTY: 0.0078969, AVERAGE_POPULARITY: 0.0982840, DIVERSITY_MEAN_INTER_LIST: 0.9474633, DIVERSITY_HERFINDAHL: 0.9947394, COVERAGE_ITEM: 0.2786422, COVERAGE_ITEM_CORRECT: 0.0168337, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1970696, DIVERSITY_GINI: 0.0460263, SHANNON_ENTROPY: 9.5634752, RATIO_DIVERSITY_HERFINDAHL: 0.9951234, RATIO_DIVERSITY_GINI: 0.1856495, RATIO_SHANNON_ENTROPY: 0.7718720, RATIO_AVERAGE_POPULARITY: 0.4823286, RATIO_NOVELTY: 0.0371556,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_jaccard_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 12.9934
# Function value obtained: -0.0097
# Current minimum: -0.0097
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 8542, 'shrink': 1098, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 18059 (100.0%), 9628.07 column/sec. Elapsed time 1.88 sec
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.33 sec. Users per second: 1205
# SearchBayesianSkopt: New best config found. Config 4: {'topK': 5412, 'shrink': 3751, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0217060, PRECISION_RECALL_MIN_DEN: 0.0217060, RECALL: 0.0024111, MAP: 0.0085970, MAP_MIN_DEN: 0.0085970, MRR: 0.0727507, NDCG: 0.0244451, F1: 0.0043400, HIT_RATE: 0.1837168, ARHR_ALL_HITS: 0.0790467, NOVELTY: 0.0079596, AVERAGE_POPULARITY: 0.0914521, DIVERSITY_MEAN_INTER_LIST: 0.9580357, DIVERSITY_HERFINDAHL: 0.9957965, COVERAGE_ITEM: 0.2817985, COVERAGE_ITEM_CORRECT: 0.0173321, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1836630, DIVERSITY_GINI: 0.0480732, SHANNON_ENTROPY: 9.6946775, RATIO_DIVERSITY_HERFINDAHL: 0.9961810, RATIO_DIVERSITY_GINI: 0.1939058, RATIO_SHANNON_ENTROPY: 0.7824614, RATIO_AVERAGE_POPULARITY: 0.4488012, RATIO_NOVELTY: 0.0374507,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice
#
# ItemKNNCBFRecommender: Saving model in file 'result_experiments/ItemCBF_event_noPreprocessed/ItemKNNCBFRecommender_ICM_event_dice_best_model'
# ItemKNNCBFRecommender: Saving complete
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 13.4985
# Function value obtained: -0.0086
# Current minimum: -0.0086
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1004, 'shrink': 41, 'similarity': 'dice', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 6394.36 column/sec. Elapsed time 2.82 sec
# Similarity column 18059 (100.0%), 9228.13 column/sec. Elapsed time 1.96 sec
# Similarity column 18059 (100.0%), 5386.56 column/sec. Elapsed time 3.35 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.55 sec. Users per second: 1429
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 2662, 'shrink': 4418, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.7911314243178622, 'tversky_beta': 0.5546936861632773} - results: PRECISION: 0.0241683, PRECISION_RECALL_MIN_DEN: 0.0241701, RECALL: 0.0027301, MAP: 0.0102763, MAP_MIN_DEN: 0.0102770, MRR: 0.0866807, NDCG: 0.0282984, F1: 0.0049060, HIT_RATE: 0.2027700, ARHR_ALL_HITS: 0.0942828, NOVELTY: 0.0079093, AVERAGE_POPULARITY: 0.1000227, DIVERSITY_MEAN_INTER_LIST: 0.9439985, DIVERSITY_HERFINDAHL: 0.9943929, COVERAGE_ITEM: 0.2774794, COVERAGE_ITEM_CORRECT: 0.0161692, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2027106, DIVERSITY_GINI: 0.0449862, SHANNON_ENTROPY: 9.4993597, RATIO_DIVERSITY_HERFINDAHL: 0.9947768, RATIO_DIVERSITY_GINI: 0.1814540, RATIO_SHANNON_ENTROPY: 0.7666972, RATIO_AVERAGE_POPULARITY: 0.4908612, RATIO_NOVELTY: 0.0372140,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 13.8688
# Function value obtained: -0.0103
# Current minimum: -0.0154
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 9597, 'shrink': 2139, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.8886305463587267, 'tversky_beta': 0.37117539065419597}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.52 sec. Users per second: 1434
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 7724, 'shrink': 1152, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'BM25', 'ICM_bias': 7.203645728086528} - results: PRECISION: 0.0051737, PRECISION_RECALL_MIN_DEN: 0.0051737, RECALL: 0.0005478, MAP: 0.0016285, MAP_MIN_DEN: 0.0016285, MRR: 0.0156688, NDCG: 0.0053245, F1: 0.0009907, HIT_RATE: 0.0499047, ARHR_ALL_HITS: 0.0159730, NOVELTY: 0.0088956, AVERAGE_POPULARITY: 0.0246801, DIVERSITY_MEAN_INTER_LIST: 0.9736884, DIVERSITY_HERFINDAHL: 0.9973617, COVERAGE_ITEM: 0.2818539, COVERAGE_ITEM_CORRECT: 0.0142311, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0498901, DIVERSITY_GINI: 0.0600303, SHANNON_ENTROPY: 10.1240510, RATIO_DIVERSITY_HERFINDAHL: 0.9977467, RATIO_DIVERSITY_GINI: 0.2421353, RATIO_SHANNON_ENTROPY: 0.8171163, RATIO_AVERAGE_POPULARITY: 0.1211177, RATIO_NOVELTY: 0.0418546,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 11.6762
# Function value obtained: -0.0016
# Current minimum: -0.0148
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 4368, 'shrink': 304, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'BM25', 'ICM_bias': 0.01453629629451686}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 8.74 sec. Users per second: 1562
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 7394, 'shrink': 2769, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.3190845694778471, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.9675568179363458} - results: PRECISION: 0.0157702, PRECISION_RECALL_MIN_DEN: 0.0157702, RECALL: 0.0015879, MAP: 0.0063535, MAP_MIN_DEN: 0.0063535, MRR: 0.0553558, NDCG: 0.0180727, F1: 0.0028854, HIT_RATE: 0.1374762, ARHR_ALL_HITS: 0.0592566, NOVELTY: 0.0082787, AVERAGE_POPULARITY: 0.0664077, DIVERSITY_MEAN_INTER_LIST: 0.9735230, DIVERSITY_HERFINDAHL: 0.9973452, COVERAGE_ITEM: 0.2647433, COVERAGE_ITEM_CORRECT: 0.0193255, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1374359, DIVERSITY_GINI: 0.0550423, SHANNON_ENTROPY: 10.0112643, RATIO_DIVERSITY_HERFINDAHL: 0.9977302, RATIO_DIVERSITY_GINI: 0.2220161, RATIO_SHANNON_ENTROPY: 0.8080132, RATIO_AVERAGE_POPULARITY: 0.3258956, RATIO_NOVELTY: 0.0389521,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 11.9456
# Function value obtained: -0.0064
# Current minimum: -0.0116
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 3863, 'shrink': 1441, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.929657445185727, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.45209759075550604}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 6746.66 column/sec. Elapsed time 2.68 sec
# Similarity column 18059 (100.0%), 6785.59 column/sec. Elapsed time 2.66 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.49 sec. Users per second: 1300
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 8542, 'shrink': 1098, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0117544, PRECISION_RECALL_MIN_DEN: 0.0117544, RECALL: 0.0013107, MAP: 0.0038168, MAP_MIN_DEN: 0.0038168, MRR: 0.0346002, NDCG: 0.0120856, F1: 0.0023585, HIT_RATE: 0.1067712, ARHR_ALL_HITS: 0.0363113, NOVELTY: 0.0083807, AVERAGE_POPULARITY: 0.0515282, DIVERSITY_MEAN_INTER_LIST: 0.9779153, DIVERSITY_HERFINDAHL: 0.9977844, COVERAGE_ITEM: 0.2937040, COVERAGE_ITEM_CORRECT: 0.0206545, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1067399, DIVERSITY_GINI: 0.0594685, SHANNON_ENTROPY: 10.1954769, RATIO_DIVERSITY_HERFINDAHL: 0.9981695, RATIO_DIVERSITY_GINI: 0.2398691, RATIO_SHANNON_ENTROPY: 0.8228811, RATIO_AVERAGE_POPULARITY: 0.2528745, RATIO_NOVELTY: 0.0394317,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 12.7275
# Function value obtained: -0.0038
# Current minimum: -0.0097
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 8064, 'shrink': 3669, 'similarity': 'jaccard', 'normalize': False}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 6464.43 column/sec. Elapsed time 2.79 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.93 sec. Users per second: 1249
# ...
#
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.24 sec. Users per second: 1214
# SearchBayesianSkopt: Config 47 is suboptimal. Config: {'topK': 6537, 'shrink': 4715, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0234501, PRECISION_RECALL_MIN_DEN: 0.0234519, RECALL: 0.0026608, MAP: 0.0097491, MAP_MIN_DEN: 0.0097497, MRR: 0.0823609, NDCG: 0.0271138, F1: 0.0047793, HIT_RATE: 0.1972006, ARHR_ALL_HITS: 0.0895179, NOVELTY: 0.0078969, AVERAGE_POPULARITY: 0.0982879, DIVERSITY_MEAN_INTER_LIST: 0.9474598, DIVERSITY_HERFINDAHL: 0.9947390, COVERAGE_ITEM: 0.2786422, COVERAGE_ITEM_CORRECT: 0.0168337, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1971429, DIVERSITY_GINI: 0.0460258, SHANNON_ENTROPY: 9.5634065, RATIO_DIVERSITY_HERFINDAHL: 0.9951230, RATIO_DIVERSITY_GINI: 0.1856474, RATIO_SHANNON_ENTROPY: 0.7718664, RATIO_AVERAGE_POPULARITY: 0.4823476, RATIO_NOVELTY: 0.0371554,
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 14.4647
# Function value obtained: -0.0006
# Current minimum: -0.0099
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 2485, 'shrink': 2073, 'similarity': 'dice', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 15.1713
# Function value obtained: -0.0097
# Current minimum: -0.0099
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 2457, 'shrink': 546, 'similarity': 'jaccard', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.31 sec. Users per second: 954
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 6580, 'shrink': 67, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF', 'ICM_bias': 262.82115567717307} - results: PRECISION: 0.0319801, PRECISION_RECALL_MIN_DEN: 0.0319892, RECALL: 0.0038647, MAP: 0.0149476, MAP_MIN_DEN: 0.0149495, MRR: 0.1224879, NDCG: 0.0392471, F1: 0.0068960, HIT_RATE: 0.2597098, ARHR_ALL_HITS: 0.1351168, NOVELTY: 0.0075753, AVERAGE_POPULARITY: 0.1329310, DIVERSITY_MEAN_INTER_LIST: 0.9043389, DIVERSITY_HERFINDAHL: 0.9904273, COVERAGE_ITEM: 0.2546653, COVERAGE_ITEM_CORRECT: 0.0152279, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2596337, DIVERSITY_GINI: 0.0354641, SHANNON_ENTROPY: 8.9482991, RATIO_DIVERSITY_HERFINDAHL: 0.9908096, RATIO_DIVERSITY_GINI: 0.1430464, RATIO_SHANNON_ENTROPY: 0.7222209, RATIO_AVERAGE_POPULARITY: 0.6523586, RATIO_NOVELTY: 0.0356422,
#
# Similarity column 18059 (100.0%), 7102.56 column/sec. Elapsed time 2.54 sec
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 20.0285
# Function value obtained: -0.0149
# Current minimum: -0.0150
# SearchBayesianSkopt: Search complete. Best config is 35: {'topK': 10000, 'shrink': 4960, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF', 'ICM_bias': 0.11357227446548925}
#
# Similarity column 18059 (100.0%), 5361.58 column/sec. Elapsed time 3.37 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.67 sec. Users per second: 1169
# SearchBayesianSkopt: Config 47 is suboptimal. Config: {'topK': 5385, 'shrink': 3319, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.0, 'tversky_beta': 2.0} - results: PRECISION: 0.0378792, PRECISION_RECALL_MIN_DEN: 0.0378860, RECALL: 0.0047863, MAP: 0.0171224, MAP_MIN_DEN: 0.0171243, MRR: 0.1375684, NDCG: 0.0452872, F1: 0.0084987, HIT_RATE: 0.3000879, ARHR_ALL_HITS: 0.1532711, NOVELTY: 0.0071307, AVERAGE_POPULARITY: 0.1614361, DIVERSITY_MEAN_INTER_LIST: 0.8830075, DIVERSITY_HERFINDAHL: 0.9882943, COVERAGE_ITEM: 0.2276981, COVERAGE_ITEM_CORRECT: 0.0145634, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.3000000, DIVERSITY_GINI: 0.0277594, SHANNON_ENTROPY: 8.5233090, RATIO_DIVERSITY_HERFINDAHL: 0.9886758, RATIO_DIVERSITY_GINI: 0.1119691, RATIO_SHANNON_ENTROPY: 0.6879198, RATIO_AVERAGE_POPULARITY: 0.7922477, RATIO_NOVELTY: 0.0335505,
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 16.2585
# Function value obtained: -0.0171
# Current minimum: -0.0172
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 4846, 'shrink': 4422, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.085642619061328, 'tversky_beta': 1.9877312442918178}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.77 sec. Users per second: 1160
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'topK': 1559, 'shrink': 1273, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.011348185593208939, 'feature_weighting': 'none', 'ICM_bias': 785.992826766932} - results: PRECISION: 0.0215741, PRECISION_RECALL_MIN_DEN: 0.0215791, RECALL: 0.0027626, MAP: 0.0076800, MAP_MIN_DEN: 0.0076810, MRR: 0.0662719, NDCG: 0.0229851, F1: 0.0048980, HIT_RATE: 0.1862817, ARHR_ALL_HITS: 0.0712983, NOVELTY: 0.0077889, AVERAGE_POPULARITY: 0.0967840, DIVERSITY_MEAN_INTER_LIST: 0.9580376, DIVERSITY_HERFINDAHL: 0.9957967, COVERAGE_ITEM: 0.2161249, COVERAGE_ITEM_CORRECT: 0.0206545, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1862271, DIVERSITY_GINI: 0.0334734, SHANNON_ENTROPY: 9.2740298, RATIO_DIVERSITY_HERFINDAHL: 0.9961812, RATIO_DIVERSITY_GINI: 0.1350167, RATIO_SHANNON_ENTROPY: 0.7485107, RATIO_AVERAGE_POPULARITY: 0.4749673, RATIO_NOVELTY: 0.0366472,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 16.1379
# Function value obtained: -0.0077
# Current minimum: -0.0173
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 10000, 'shrink': 2324, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'none', 'ICM_bias': 0.01}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 6552.67 column/sec. Elapsed time 2.76 sec
# Similarity column 18059 (100.0%), 9118.65 column/sec. Elapsed time 1.98 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.33 sec. Users per second: 1321
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'topK': 2485, 'shrink': 2073, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0162905, PRECISION_RECALL_MIN_DEN: 0.0162905, RECALL: 0.0017858, MAP: 0.0058436, MAP_MIN_DEN: 0.0058436, MRR: 0.0512474, NDCG: 0.0175025, F1: 0.0032188, HIT_RATE: 0.1426792, ARHR_ALL_HITS: 0.0546709, NOVELTY: 0.0081731, AVERAGE_POPULARITY: 0.0696457, DIVERSITY_MEAN_INTER_LIST: 0.9731883, DIVERSITY_HERFINDAHL: 0.9973117, COVERAGE_ITEM: 0.2879451, COVERAGE_ITEM_CORRECT: 0.0194363, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1426374, DIVERSITY_GINI: 0.0539580, SHANNON_ENTROPY: 10.0043760, RATIO_DIVERSITY_HERFINDAHL: 0.9976967, RATIO_DIVERSITY_GINI: 0.2176425, RATIO_SHANNON_ENTROPY: 0.8074573, RATIO_AVERAGE_POPULARITY: 0.3417862, RATIO_NOVELTY: 0.0384550,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 14.4776
# Function value obtained: -0.0058
# Current minimum: -0.0099
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 38, 'shrink': 4208, 'similarity': 'dice', 'normalize': False}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.08 sec. Users per second: 1354
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'topK': 2457, 'shrink': 546, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0085446, PRECISION_RECALL_MIN_DEN: 0.0085446, RECALL: 0.0009820, MAP: 0.0025425, MAP_MIN_DEN: 0.0025425, MRR: 0.0239354, NDCG: 0.0084896, F1: 0.0017616, HIT_RATE: 0.0807563, ARHR_ALL_HITS: 0.0246570, NOVELTY: 0.0085573, AVERAGE_POPULARITY: 0.0395174, DIVERSITY_MEAN_INTER_LIST: 0.9769852, DIVERSITY_HERFINDAHL: 0.9976914, COVERAGE_ITEM: 0.2968049, COVERAGE_ITEM_CORRECT: 0.0193255, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0807326, DIVERSITY_GINI: 0.0622363, SHANNON_ENTROPY: 10.2237309, RATIO_DIVERSITY_HERFINDAHL: 0.9980765, RATIO_DIVERSITY_GINI: 0.2510334, RATIO_SHANNON_ENTROPY: 0.8251615, RATIO_AVERAGE_POPULARITY: 0.1939317, RATIO_NOVELTY: 0.0402628,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 14.9725
# Function value obtained: -0.0025
# Current minimum: -0.0099
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 3523, 'shrink': 445, 'similarity': 'jaccard', 'normalize': True}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# Similarity column 18059 (100.0%), 7364.59 column/sec. Elapsed time 2.45 sec
# Similarity column 18059 (100.0%), 9632.72 column/sec. Elapsed time 1.87 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.75 sec. Users per second: 1400
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'topK': 4846, 'shrink': 4422, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.085642619061328, 'tversky_beta': 1.9877312442918178} - results: PRECISION: 0.0239484, PRECISION_RECALL_MIN_DEN: 0.0239484, RECALL: 0.0027392, MAP: 0.0096269, MAP_MIN_DEN: 0.0096269, MRR: 0.0808203, NDCG: 0.0271177, F1: 0.0049161, HIT_RATE: 0.2007182, ARHR_ALL_HITS: 0.0881361, NOVELTY: 0.0078338, AVERAGE_POPULARITY: 0.1000725, DIVERSITY_MEAN_INTER_LIST: 0.9523121, DIVERSITY_HERFINDAHL: 0.9952242, COVERAGE_ITEM: 0.2819093, COVERAGE_ITEM_CORRECT: 0.0179966, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2006593, DIVERSITY_GINI: 0.0470260, SHANNON_ENTROPY: 9.6131042, RATIO_DIVERSITY_HERFINDAHL: 0.9956084, RATIO_DIVERSITY_GINI: 0.1896817, RATIO_SHANNON_ENTROPY: 0.7758776, RATIO_AVERAGE_POPULARITY: 0.4911056, RATIO_NOVELTY: 0.0368585,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 13.7383
# Function value obtained: -0.0096
# Current minimum: -0.0172
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 893, 'shrink': 133, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.9061601433393065, 'tversky_beta': 1.927152319866257}
# ItemKNNCBFRecommender: ICM Detected 92 ( 0.5%) items with no features.
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.27 sec. Users per second: 1328
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 10000, 'shrink': 2324, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'none', 'ICM_bias': 0.01} - results: PRECISION: 0.0377473, PRECISION_RECALL_MIN_DEN: 0.0377541, RECALL: 0.0047626, MAP: 0.0170530, MAP_MIN_DEN: 0.0170549, MRR: 0.1370872, NDCG: 0.0451236, F1: 0.0084581, HIT_RATE: 0.2989887, ARHR_ALL_HITS: 0.1526985, NOVELTY: 0.0071397, AVERAGE_POPULARITY: 0.1608798, DIVERSITY_MEAN_INTER_LIST: 0.8833292, DIVERSITY_HERFINDAHL: 0.9883264, COVERAGE_ITEM: 0.2272551, COVERAGE_ITEM_CORRECT: 0.0145080, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2989011, DIVERSITY_GINI: 0.0278225, SHANNON_ENTROPY: 8.5305651, RATIO_DIVERSITY_HERFINDAHL: 0.9887080, RATIO_DIVERSITY_GINI: 0.1122234, RATIO_SHANNON_ENTROPY: 0.6885054, RATIO_AVERAGE_POPULARITY: 0.7895173, RATIO_NOVELTY: 0.0335930,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 14.0598
# Function value obtained: -0.0171
# Current minimum: -0.0173
# SearchBayesianSkopt: Search complete. Best config is 29: {'topK': 10000, 'shrink': 545, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'none', 'ICM_bias': 0.01}
#
# Similarity column 18059 (100.0%), 6342.82 column/sec. Elapsed time 2.85 sec
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.57 sec. Users per second: 1427
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 38, 'shrink': 4208, 'similarity': 'dice', 'normalize': False} - results: PRECISION: 0.0139308, PRECISION_RECALL_MIN_DEN: 0.0139308, RECALL: 0.0015284, MAP: 0.0050319, MAP_MIN_DEN: 0.0050319, MRR: 0.0452451, NDCG: 0.0151333, F1: 0.0027545, HIT_RATE: 0.1250183, ARHR_ALL_HITS: 0.0476890, NOVELTY: 0.0082563, AVERAGE_POPULARITY: 0.0592737, DIVERSITY_MEAN_INTER_LIST: 0.9766080, DIVERSITY_HERFINDAHL: 0.9976536, COVERAGE_ITEM: 0.2886096, COVERAGE_ITEM_CORRECT: 0.0197685, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.1249817, DIVERSITY_GINI: 0.0554296, SHANNON_ENTROPY: 10.0870254, RATIO_DIVERSITY_HERFINDAHL: 0.9980388, RATIO_DIVERSITY_GINI: 0.2235780, RATIO_SHANNON_ENTROPY: 0.8141279, RATIO_AVERAGE_POPULARITY: 0.2908857, RATIO_NOVELTY: 0.0388465,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 13.4018
# Function value obtained: -0.0050
# Current minimum: -0.0099
# SearchBayesianSkopt: Search complete. Best config is 18: {'topK': 10000, 'shrink': 5000, 'similarity': 'dice', 'normalize': True}
#
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.01 sec. Users per second: 1363
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 3523, 'shrink': 445, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0079291, PRECISION_RECALL_MIN_DEN: 0.0079291, RECALL: 0.0008975, MAP: 0.0023259, MAP_MIN_DEN: 0.0023259, MRR: 0.0220150, NDCG: 0.0078331, F1: 0.0016125, HIT_RATE: 0.0752601, ARHR_ALL_HITS: 0.0226330, NOVELTY: 0.0086248, AVERAGE_POPULARITY: 0.0361741, DIVERSITY_MEAN_INTER_LIST: 0.9764701, DIVERSITY_HERFINDAHL: 0.9976399, COVERAGE_ITEM: 0.2959189, COVERAGE_ITEM_CORRECT: 0.0187718, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0752381, DIVERSITY_GINI: 0.0626241, SHANNON_ENTROPY: 10.2185836, RATIO_DIVERSITY_HERFINDAHL: 0.9980250, RATIO_DIVERSITY_GINI: 0.2525976, RATIO_SHANNON_ENTROPY: 0.8247461, RATIO_AVERAGE_POPULARITY: 0.1775245, RATIO_NOVELTY: 0.0405801,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 13.1587
# Function value obtained: -0.0023
# Current minimum: -0.0099
# SearchBayesianSkopt: Search complete. Best config is 18: {'topK': 7873, 'shrink': 5000, 'similarity': 'jaccard', 'normalize': False}
#
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.19 sec. Users per second: 1486
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 893, 'shrink': 133, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.9061601433393065, 'tversky_beta': 1.927152319866257} - results: PRECISION: 0.0032830, PRECISION_RECALL_MIN_DEN: 0.0032830, RECALL: 0.0003482, MAP: 0.0010166, MAP_MIN_DEN: 0.0010166, MRR: 0.0097444, NDCG: 0.0033465, F1: 0.0006297, HIT_RATE: 0.0318042, ARHR_ALL_HITS: 0.0099550, NOVELTY: 0.0090707, AVERAGE_POPULARITY: 0.0174325, DIVERSITY_MEAN_INTER_LIST: 0.9663360, DIVERSITY_HERFINDAHL: 0.9966265, COVERAGE_ITEM: 0.2538347, COVERAGE_ITEM_CORRECT: 0.0112409, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.0317949, DIVERSITY_GINI: 0.0478174, SHANNON_ENTROPY: 9.7549396, RATIO_DIVERSITY_HERFINDAHL: 0.9970112, RATIO_DIVERSITY_GINI: 0.1928740, RATIO_SHANNON_ENTROPY: 0.7873252, RATIO_AVERAGE_POPULARITY: 0.0855498, RATIO_NOVELTY: 0.0426783,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 13.2020
# Function value obtained: -0.0010
# Current minimum: -0.0172
# SearchBayesianSkopt: Search complete. Best config is 40: {'topK': 4987, 'shrink': 2231, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.0, 'tversky_beta': 2.0}

# %%
from Recommenders.DataIO import DataIO

recommender_class = ItemKNNCBFRecommender

data_loader = DataIO(folder_path = output_folder_path)

search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_ICM_event_asymmetric_metadata.zip")
result_on_validation_df = search_metadata["result_on_validation_df"]
print('Best asymmetric MAP: ', max(result_on_validation_df.MAP))

search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_ICM_event_cosine_metadata.zip")
result_on_validation_df = search_metadata["result_on_validation_df"]
print('Best cosine MAP: ', max(result_on_validation_df.MAP))

search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_ICM_event_dice_metadata.zip")
result_on_validation_df = search_metadata["result_on_validation_df"]
print('Best dice MAP: ', max(result_on_validation_df.MAP))

search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_ICM_event_jaccard_metadata.zip")
result_on_validation_df = search_metadata["result_on_validation_df"]
print('Best jaccard MAP: ', max(result_on_validation_df.MAP))

search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_ICM_event_tversky_metadata.zip")
result_on_validation_df = search_metadata["result_on_validation_df"]
print('Best tversky MAP: ', max(result_on_validation_df.MAP))
# Out:
# Best asymmetric MAP:  0.01728293831089527
# Best cosine MAP:  0.014957613022247365
# Best dice MAP:  0.00992955375027038
# Best jaccard MAP:  0.009929196066525621
# Best tversky MAP:  0.01718384246561002
