# %% [markdown]
# # RP3beta

# %% [markdown]
# ## Import

# %%
## Allow more than one output for a single code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd
import scipy.sparse as sps
import numpy as np
import os

from skopt.space import Real, Integer, Categorical

## Set the numpy random seed
SEED = 42
np.random.seed(SEED)

os.getcwd()
# Out:
# '/home/alessio/Scrivania/RecSysChallenge2021'

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

from Evaluation.Evaluator import EvaluatorHoldout

from Recommenders.Recommender_import_list import *
# Out:
# Tensorflow is not available

# %%
## Utility Functions
from Dataset.load_data import load_data
from Dataset.write_submission import write_submission
from Dataset.load_test_user_array import load_test_user_array

# %% [markdown]
# ## Data Loading and Split

# %%
URM_all, ICM_dict = load_data()

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

URM_aug_train = sps.vstack([URM_train.tocoo(), 
                            ICM_dict['ICM_genre'].T.tocoo(),
                            ICM_dict['ICM_subgenre'].T.tocoo(), 
                            #ICM_dict['ICM_event'].T.tocoo(), 
                            ICM_dict['ICM_channel'].T.tocoo()], format='csr')

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10], exclude_seen = True)
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
test_UserID_array = load_test_user_array()

# %% [markdown]
# ## Optimization

# %%
output_folder_path = "result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 100  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender

runHyperparameterSearch_Collaborative(RP3betaRecommender,
                                      URM_train = URM_aug_train,
                                      URM_train_last_test = None,
                                      metric_to_optimize = metric_to_optimize,
                                      cutoff_to_optimize = cutoff_to_optimize,
                                      n_cases = n_cases,
                                      n_random_starts = n_random_starts,
                                      evaluator_validation_earlystopping = evaluator_validation,
                                      evaluator_validation = evaluator_validation,
                                      evaluator_test = None,
                                      output_folder_path = output_folder_path,
                                      resume_from_saved = True,
                                      similarity_type_list = None,
                                      parallelizeKNN = True)
# Out:
# SearchBayesianSkopt: Extending previous number of cases from 50 to 100.
#
# SearchBayesianSkopt: Resuming 'RP3betaRecommender'... Loaded 50 configurations.
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 1.3059
# Function value obtained: -0.1390
# Current minimum: -0.2264
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.5181509793978214, 'beta': 0.3580157120684137, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.05 sec. Users per second: 1235
# SearchBayesianSkopt: Config 50 is suboptimal. Config: {'topK': 70, 'alpha': 0.5181509793978214, 'beta': 0.3580157120684137, 'normalize_similarity': True} - results: PRECISION: 0.3631101, PRECISION_RECALL_MIN_DEN: 0.3645224, RECALL: 0.0637845, MAP: 0.2215760, MAP_MIN_DEN: 0.2221982, MRR: 0.6311031, NDCG: 0.3815157, F1: 0.1085082, HIT_RATE: 0.9620402, ARHR_ALL_HITS: 1.1622943, NOVELTY: 0.0059455, AVERAGE_POPULARITY: 0.4288118, DIVERSITY_MEAN_INTER_LIST: 0.9146586, DIVERSITY_HERFINDAHL: 0.9914592, COVERAGE_ITEM: 0.1551581, COVERAGE_ITEM_CORRECT: 0.0905366, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9617582, DIVERSITY_GINI: 0.0201096, SHANNON_ENTROPY: 8.4516891, RATIO_DIVERSITY_HERFINDAHL: 0.9918328, RATIO_DIVERSITY_GINI: 0.0778918, RATIO_SHANNON_ENTROPY: 0.6794702, RATIO_AVERAGE_POPULARITY: 2.1504350, RATIO_NOVELTY: 0.0281433,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 44.8995
# Function value obtained: -0.2216
# Current minimum: -0.2264
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.4360414197508163, 'beta': 0.4749135615490282, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.47 sec. Users per second: 1190
# SearchBayesianSkopt: Config 51 is suboptimal. Config: {'topK': 50, 'alpha': 0.4360414197508163, 'beta': 0.4749135615490282, 'normalize_similarity': True} - results: PRECISION: 0.3673384, PRECISION_RECALL_MIN_DEN: 0.3687571, RECALL: 0.0645114, MAP: 0.2244264, MAP_MIN_DEN: 0.2250595, MRR: 0.6326581, NDCG: 0.3851435, F1: 0.1097489, HIT_RATE: 0.9619669, ARHR_ALL_HITS: 1.1712739, NOVELTY: 0.0059221, AVERAGE_POPULARITY: 0.4418273, DIVERSITY_MEAN_INTER_LIST: 0.9110519, DIVERSITY_HERFINDAHL: 0.9910985, COVERAGE_ITEM: 0.1769201, COVERAGE_ITEM_CORRECT: 0.1029404, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9616850, DIVERSITY_GINI: 0.0225187, SHANNON_ENTROPY: 8.5014480, RATIO_DIVERSITY_HERFINDAHL: 0.9914721, RATIO_DIVERSITY_GINI: 0.0872231, RATIO_SHANNON_ENTROPY: 0.6834705, RATIO_AVERAGE_POPULARITY: 2.2157061, RATIO_NOVELTY: 0.0280325,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 44.2584
# Function value obtained: -0.2244
# Current minimum: -0.2264
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.0, 'beta': 0.5709733707621545, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.53 sec. Users per second: 1009
# SearchBayesianSkopt: Config 52 is suboptimal. Config: {'topK': 50, 'alpha': 0.0, 'beta': 0.5709733707621545, 'normalize_similarity': True} - results: PRECISION: 0.3692437, PRECISION_RECALL_MIN_DEN: 0.3705953, RECALL: 0.0641794, MAP: 0.2252421, MAP_MIN_DEN: 0.2258136, MRR: 0.6272191, NDCG: 0.3854852, F1: 0.1093519, HIT_RATE: 0.9612341, ARHR_ALL_HITS: 1.1684067, NOVELTY: 0.0057975, AVERAGE_POPULARITY: 0.4864597, DIVERSITY_MEAN_INTER_LIST: 0.9001963, DIVERSITY_HERFINDAHL: 0.9900130, COVERAGE_ITEM: 0.1680049, COVERAGE_ITEM_CORRECT: 0.1015560, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9609524, DIVERSITY_GINI: 0.0201311, SHANNON_ENTROPY: 8.2506979, RATIO_DIVERSITY_HERFINDAHL: 0.9903862, RATIO_DIVERSITY_GINI: 0.0779754, RATIO_SHANNON_ENTROPY: 0.6633116, RATIO_AVERAGE_POPULARITY: 2.4395319, RATIO_NOVELTY: 0.0274429,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 51.6353
# Function value obtained: -0.2252
# Current minimum: -0.2264
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 1.0, 'beta': 0.0, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.12 sec. Users per second: 1348
# SearchBayesianSkopt: Config 53 is suboptimal. Config: {'topK': 50, 'alpha': 1.0, 'beta': 0.0, 'normalize_similarity': True} - results: PRECISION: 0.1958962, PRECISION_RECALL_MIN_DEN: 0.1961658, RECALL: 0.0303299, MAP: 0.1113124, MAP_MIN_DEN: 0.1114465, MRR: 0.4532365, NDCG: 0.2180596, F1: 0.0525272, HIT_RATE: 0.7686502, ARHR_ALL_HITS: 0.6983217, NOVELTY: 0.0068443, AVERAGE_POPULARITY: 0.1642250, DIVERSITY_MEAN_INTER_LIST: 0.9781698, DIVERSITY_HERFINDAHL: 0.9978098, COVERAGE_ITEM: 0.2500138, COVERAGE_ITEM_CORRECT: 0.0670026, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.7684249, DIVERSITY_GINI: 0.0495516, SHANNON_ENTROPY: 9.9978343, RATIO_DIVERSITY_HERFINDAHL: 0.9981859, RATIO_DIVERSITY_GINI: 0.1919319, RATIO_SHANNON_ENTROPY: 0.8037719, RATIO_AVERAGE_POPULARITY: 0.8235670, RATIO_NOVELTY: 0.0323975,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 42.2814
# Function value obtained: -0.1113
# Current minimum: -0.2264
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.003363169137183484, 'beta': 0.16015149226854034, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.68 sec. Users per second: 1278
# SearchBayesianSkopt: Config 54 is suboptimal. Config: {'topK': 50, 'alpha': 0.003363169137183484, 'beta': 0.16015149226854034, 'normalize_similarity': True} - results: PRECISION: 0.2815697, PRECISION_RECALL_MIN_DEN: 0.2819362, RECALL: 0.0448786, MAP: 0.1636734, MAP_MIN_DEN: 0.1638369, MRR: 0.5485860, NDCG: 0.3009806, F1: 0.0774178, HIT_RATE: 0.8940349, ARHR_ALL_HITS: 0.9329138, NOVELTY: 0.0065364, AVERAGE_POPULARITY: 0.2032144, DIVERSITY_MEAN_INTER_LIST: 0.9729651, DIVERSITY_HERFINDAHL: 0.9972894, COVERAGE_ITEM: 0.2339554, COVERAGE_ITEM_CORRECT: 0.0873249, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8937729, DIVERSITY_GINI: 0.0341798, SHANNON_ENTROPY: 9.4912127, RATIO_DIVERSITY_HERFINDAHL: 0.9976653, RATIO_DIVERSITY_GINI: 0.1323912, RATIO_SHANNON_ENTROPY: 0.7630422, RATIO_AVERAGE_POPULARITY: 1.0190938, RATIO_NOVELTY: 0.0309402,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 44.0279
# Function value obtained: -0.1637
# Current minimum: -0.2264
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.0, 'beta': 0.7032252244934684, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.96 sec. Users per second: 912
# SearchBayesianSkopt: Config 55 is suboptimal. Config: {'topK': 70, 'alpha': 0.0, 'beta': 0.7032252244934684, 'normalize_similarity': True} - results: PRECISION: 0.3566247, PRECISION_RECALL_MIN_DEN: 0.3578414, RECALL: 0.0607760, MAP: 0.2138631, MAP_MIN_DEN: 0.2143838, MRR: 0.6055573, NDCG: 0.3706106, F1: 0.1038533, HIT_RATE: 0.9529532, ARHR_ALL_HITS: 1.1188615, NOVELTY: 0.0056617, AVERAGE_POPULARITY: 0.5268199, DIVERSITY_MEAN_INTER_LIST: 0.9057602, DIVERSITY_HERFINDAHL: 0.9905694, COVERAGE_ITEM: 0.1511712, COVERAGE_ITEM_CORRECT: 0.0840024, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9526740, DIVERSITY_GINI: 0.0148874, SHANNON_ENTROPY: 7.9390871, RATIO_DIVERSITY_HERFINDAHL: 0.9909427, RATIO_DIVERSITY_GINI: 0.0576643, RATIO_SHANNON_ENTROPY: 0.6382597, RATIO_AVERAGE_POPULARITY: 2.6419331, RATIO_NOVELTY: 0.0268000,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 49.1705
# Function value obtained: -0.2139
# Current minimum: -0.2264
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 59, 'alpha': 0.014035509586266873, 'beta': 0.37505112479480907, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.66 sec. Users per second: 1170
# SearchBayesianSkopt: Config 56 is suboptimal. Config: {'topK': 59, 'alpha': 0.014035509586266873, 'beta': 0.37505112479480907, 'normalize_similarity': True} - results: PRECISION: 0.3633959, PRECISION_RECALL_MIN_DEN: 0.3647715, RECALL: 0.0636991, MAP: 0.2212655, MAP_MIN_DEN: 0.2218950, MRR: 0.6280615, NDCG: 0.3811359, F1: 0.1083974, HIT_RATE: 0.9612341, ARHR_ALL_HITS: 1.1593523, NOVELTY: 0.0059495, AVERAGE_POPULARITY: 0.4295512, DIVERSITY_MEAN_INTER_LIST: 0.9158201, DIVERSITY_HERFINDAHL: 0.9915753, COVERAGE_ITEM: 0.1649039, COVERAGE_ITEM_CORRECT: 0.0942466, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9609524, DIVERSITY_GINI: 0.0214339, SHANNON_ENTROPY: 8.5121412, RATIO_DIVERSITY_HERFINDAHL: 0.9919490, RATIO_DIVERSITY_GINI: 0.0830216, RATIO_SHANNON_ENTROPY: 0.6843302, RATIO_AVERAGE_POPULARITY: 2.1541431, RATIO_NOVELTY: 0.0281620,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 45.2790
# Function value obtained: -0.2213
# Current minimum: -0.2264
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 55, 'alpha': 0.8855468389894778, 'beta': 0.5474048275169753, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.73 sec. Users per second: 994
# SearchBayesianSkopt: New best config found. Config 57: {'topK': 55, 'alpha': 0.8855468389894778, 'beta': 0.5474048275169753, 'normalize_similarity': True} - results: PRECISION: 0.3701378, PRECISION_RECALL_MIN_DEN: 0.3716320, RECALL: 0.0649084, MAP: 0.2264439, MAP_MIN_DEN: 0.2270767, MRR: 0.6321807, NDCG: 0.3873327, F1: 0.1104483, HIT_RATE: 0.9613073, ARHR_ALL_HITS: 1.1760152, NOVELTY: 0.0058745, AVERAGE_POPULARITY: 0.4645616, DIVERSITY_MEAN_INTER_LIST: 0.9034912, DIVERSITY_HERFINDAHL: 0.9903425, COVERAGE_ITEM: 0.1768093, COVERAGE_ITEM_CORRECT: 0.0980121, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9610256, DIVERSITY_GINI: 0.0213015, SHANNON_ENTROPY: 8.3710493, RATIO_DIVERSITY_HERFINDAHL: 0.9907158, RATIO_DIVERSITY_GINI: 0.0825087, RATIO_SHANNON_ENTROPY: 0.6729872, RATIO_AVERAGE_POPULARITY: 2.3297158, RATIO_NOVELTY: 0.0278071,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 51.7177
# Function value obtained: -0.2264
# Current minimum: -0.2264
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 1.0, 'beta': 0.6544982790234605, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.12 sec. Users per second: 1040
# SearchBayesianSkopt: Config 58 is suboptimal. Config: {'topK': 70, 'alpha': 1.0, 'beta': 0.6544982790234605, 'normalize_similarity': True} - results: PRECISION: 0.3642533, PRECISION_RECALL_MIN_DEN: 0.3655901, RECALL: 0.0631327, MAP: 0.2219737, MAP_MIN_DEN: 0.2225957, MRR: 0.6249983, NDCG: 0.3812367, F1: 0.1076138, HIT_RATE: 0.9585226, ARHR_ALL_HITS: 1.1577564, NOVELTY: 0.0057475, AVERAGE_POPULARITY: 0.5167668, DIVERSITY_MEAN_INTER_LIST: 0.8911693, DIVERSITY_HERFINDAHL: 0.9891104, COVERAGE_ITEM: 0.1637964, COVERAGE_ITEM_CORRECT: 0.0775237, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9582418, DIVERSITY_GINI: 0.0163976, SHANNON_ENTROPY: 7.9633926, RATIO_DIVERSITY_HERFINDAHL: 0.9894832, RATIO_DIVERSITY_GINI: 0.0635139, RATIO_SHANNON_ENTROPY: 0.6402138, RATIO_AVERAGE_POPULARITY: 2.5915181, RATIO_NOVELTY: 0.0272061,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 50.5006
# Function value obtained: -0.2220
# Current minimum: -0.2264
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 53, 'alpha': 0.9983032649294943, 'beta': 0.7135002612471414, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.99 sec. Users per second: 911
# SearchBayesianSkopt: Config 59 is suboptimal. Config: {'topK': 53, 'alpha': 0.9983032649294943, 'beta': 0.7135002612471414, 'normalize_similarity': True} - results: PRECISION: 0.3576433, PRECISION_RECALL_MIN_DEN: 0.3589675, RECALL: 0.0619351, MAP: 0.2159312, MAP_MIN_DEN: 0.2165197, MRR: 0.6108169, NDCG: 0.3732348, F1: 0.1055853, HIT_RATE: 0.9552250, ARHR_ALL_HITS: 1.1302685, NOVELTY: 0.0057677, AVERAGE_POPULARITY: 0.5106746, DIVERSITY_MEAN_INTER_LIST: 0.9044121, DIVERSITY_HERFINDAHL: 0.9904346, COVERAGE_ITEM: 0.1601418, COVERAGE_ITEM_CORRECT: 0.0724846, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9549451, DIVERSITY_GINI: 0.0161856, SHANNON_ENTROPY: 8.0365910, RATIO_DIVERSITY_HERFINDAHL: 0.9908079, RATIO_DIVERSITY_GINI: 0.0626927, RATIO_SHANNON_ENTROPY: 0.6460985, RATIO_AVERAGE_POPULARITY: 2.5609663, RATIO_NOVELTY: 0.0273017,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 49.7932
# Function value obtained: -0.2159
# Current minimum: -0.2264
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 59, 'alpha': 0.581571728092294, 'beta': 0.5403916343159995, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.54 sec. Users per second: 1088
# SearchBayesianSkopt: New best config found. Config 60: {'topK': 59, 'alpha': 0.581571728092294, 'beta': 0.5403916343159995, 'normalize_similarity': True} - results: PRECISION: 0.3698080, PRECISION_RECALL_MIN_DEN: 0.3712994, RECALL: 0.0646765, MAP: 0.2265351, MAP_MIN_DEN: 0.2272359, MRR: 0.6345859, NDCG: 0.3875953, F1: 0.1100977, HIT_RATE: 0.9619669, ARHR_ALL_HITS: 1.1782829, NOVELTY: 0.0058352, AVERAGE_POPULARITY: 0.4747416, DIVERSITY_MEAN_INTER_LIST: 0.8987358, DIVERSITY_HERFINDAHL: 0.9898670, COVERAGE_ITEM: 0.1701645, COVERAGE_ITEM_CORRECT: 0.1018329, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9616850, DIVERSITY_GINI: 0.0202662, SHANNON_ENTROPY: 8.2762763, RATIO_DIVERSITY_HERFINDAHL: 0.9902401, RATIO_DIVERSITY_GINI: 0.0784987, RATIO_SHANNON_ENTROPY: 0.6653679, RATIO_AVERAGE_POPULARITY: 2.3807672, RATIO_NOVELTY: 0.0276213,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 51.6996
# Function value obtained: -0.2265
# Current minimum: -0.2265
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.6909086087840585, 'beta': 0.5696183723229574, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.06 sec. Users per second: 970
# SearchBayesianSkopt: New best config found. Config 61: {'topK': 50, 'alpha': 0.6909086087840585, 'beta': 0.5696183723229574, 'normalize_similarity': True} - results: PRECISION: 0.3704529, PRECISION_RECALL_MIN_DEN: 0.3718796, RECALL: 0.0648829, MAP: 0.2267752, MAP_MIN_DEN: 0.2274152, MRR: 0.6323787, NDCG: 0.3877055, F1: 0.1104254, HIT_RATE: 0.9634325, ARHR_ALL_HITS: 1.1772925, NOVELTY: 0.0058571, AVERAGE_POPULARITY: 0.4681931, DIVERSITY_MEAN_INTER_LIST: 0.9039504, DIVERSITY_HERFINDAHL: 0.9903884, COVERAGE_ITEM: 0.1773077, COVERAGE_ITEM_CORRECT: 0.1054322, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9631502, DIVERSITY_GINI: 0.0217870, SHANNON_ENTROPY: 8.3837012, RATIO_DIVERSITY_HERFINDAHL: 0.9907617, RATIO_DIVERSITY_GINI: 0.0843890, RATIO_SHANNON_ENTROPY: 0.6740043, RATIO_AVERAGE_POPULARITY: 2.3479273, RATIO_NOVELTY: 0.0277250,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 51.4341
# Function value obtained: -0.2268
# Current minimum: -0.2268
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.6396128709224748, 'beta': 0.5778890935970639, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 17.12 sec. Users per second: 797
# SearchBayesianSkopt: Config 62 is suboptimal. Config: {'topK': 56, 'alpha': 0.6396128709224748, 'beta': 0.5778890935970639, 'normalize_similarity': True} - results: PRECISION: 0.3699912, PRECISION_RECALL_MIN_DEN: 0.3713976, RECALL: 0.0645095, MAP: 0.2267222, MAP_MIN_DEN: 0.2274431, MRR: 0.6322268, NDCG: 0.3875426, F1: 0.1098638, HIT_RATE: 0.9613073, ARHR_ALL_HITS: 1.1773332, NOVELTY: 0.0058274, AVERAGE_POPULARITY: 0.4783351, DIVERSITY_MEAN_INTER_LIST: 0.9004273, DIVERSITY_HERFINDAHL: 0.9900361, COVERAGE_ITEM: 0.1730439, COVERAGE_ITEM_CORRECT: 0.1024974, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9610256, DIVERSITY_GINI: 0.0206476, SHANNON_ENTROPY: 8.2954464, RATIO_DIVERSITY_HERFINDAHL: 0.9904093, RATIO_DIVERSITY_GINI: 0.0799758, RATIO_SHANNON_ENTROPY: 0.6669091, RATIO_AVERAGE_POPULARITY: 2.3987882, RATIO_NOVELTY: 0.0275841,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 56.8554
# Function value obtained: -0.2267
# Current minimum: -0.2268
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.984682589094437, 'beta': 0.39773057811031665, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.96 sec. Users per second: 1245
# SearchBayesianSkopt: Config 63 is suboptimal. Config: {'topK': 50, 'alpha': 0.984682589094437, 'beta': 0.39773057811031665, 'normalize_similarity': True} - results: PRECISION: 0.3545288, PRECISION_RECALL_MIN_DEN: 0.3557885, RECALL: 0.0617540, MAP: 0.2153308, MAP_MIN_DEN: 0.2158649, MRR: 0.6210541, NDCG: 0.3728324, F1: 0.1051860, HIT_RATE: 0.9554448, ARHR_ALL_HITS: 1.1371977, NOVELTY: 0.0060915, AVERAGE_POPULARITY: 0.3857336, DIVERSITY_MEAN_INTER_LIST: 0.9302845, DIVERSITY_HERFINDAHL: 0.9930216, COVERAGE_ITEM: 0.1909297, COVERAGE_ITEM_CORRECT: 0.0933607, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9551648, DIVERSITY_GINI: 0.0258638, SHANNON_ENTROPY: 8.8057791, RATIO_DIVERSITY_HERFINDAHL: 0.9933959, RATIO_DIVERSITY_GINI: 0.1001800, RATIO_SHANNON_ENTROPY: 0.7079371, RATIO_AVERAGE_POPULARITY: 1.9344034, RATIO_NOVELTY: 0.0288344,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 47.6718
# Function value obtained: -0.2153
# Current minimum: -0.2268
# Iteration No: 16 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 65, 'alpha': 0.5340596612877432, 'beta': 0.576047232632624, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.68 sec. Users per second: 1076
# SearchBayesianSkopt: Config 64 is suboptimal. Config: {'topK': 65, 'alpha': 0.5340596612877432, 'beta': 0.576047232632624, 'normalize_similarity': True} - results: PRECISION: 0.3694563, PRECISION_RECALL_MIN_DEN: 0.3708513, RECALL: 0.0643042, MAP: 0.2263138, MAP_MIN_DEN: 0.2270121, MRR: 0.6336501, NDCG: 0.3870650, F1: 0.1095424, HIT_RATE: 0.9609409, ARHR_ALL_HITS: 1.1765002, NOVELTY: 0.0057855, AVERAGE_POPULARITY: 0.4932037, DIVERSITY_MEAN_INTER_LIST: 0.8938487, DIVERSITY_HERFINDAHL: 0.9893783, COVERAGE_ITEM: 0.1678941, COVERAGE_ITEM_CORRECT: 0.1001163, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9606593, DIVERSITY_GINI: 0.0190353, SHANNON_ENTROPY: 8.1538712, RATIO_DIVERSITY_HERFINDAHL: 0.9897512, RATIO_DIVERSITY_GINI: 0.0737307, RATIO_SHANNON_ENTROPY: 0.6555272, RATIO_AVERAGE_POPULARITY: 2.4733519, RATIO_NOVELTY: 0.0273858,
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 46.6574
# Function value obtained: -0.2263
# Current minimum: -0.2268
# Iteration No: 17 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.6474273385451582, 'beta': 0.723015422770903, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.83 sec. Users per second: 987
# SearchBayesianSkopt: Config 65 is suboptimal. Config: {'topK': 70, 'alpha': 0.6474273385451582, 'beta': 0.723015422770903, 'normalize_similarity': True} - results: PRECISION: 0.3601495, PRECISION_RECALL_MIN_DEN: 0.3615143, RECALL: 0.0621199, MAP: 0.2176818, MAP_MIN_DEN: 0.2183324, MRR: 0.6165079, NDCG: 0.3760019, F1: 0.1059629, HIT_RATE: 0.9572769, ARHR_ALL_HITS: 1.1392317, NOVELTY: 0.0056844, AVERAGE_POPULARITY: 0.5288024, DIVERSITY_MEAN_INTER_LIST: 0.8962784, DIVERSITY_HERFINDAHL: 0.9896213, COVERAGE_ITEM: 0.1599756, COVERAGE_ITEM_CORRECT: 0.0840024, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9569963, DIVERSITY_GINI: 0.0154036, SHANNON_ENTROPY: 7.9121692, RATIO_DIVERSITY_HERFINDAHL: 0.9899943, RATIO_DIVERSITY_GINI: 0.0596639, RATIO_SHANNON_ENTROPY: 0.6360957, RATIO_AVERAGE_POPULARITY: 2.6518751, RATIO_NOVELTY: 0.0269074,
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 48.1300
# Function value obtained: -0.2177
# Current minimum: -0.2268
# Iteration No: 18 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 69, 'alpha': 0.011555794826539236, 'beta': 0.06781036097091143, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.05 sec. Users per second: 1357
# SearchBayesianSkopt: Config 66 is suboptimal. Config: {'topK': 69, 'alpha': 0.011555794826539236, 'beta': 0.06781036097091143, 'normalize_similarity': True} - results: PRECISION: 0.2463872, PRECISION_RECALL_MIN_DEN: 0.2467562, RECALL: 0.0384528, MAP: 0.1423333, MAP_MIN_DEN: 0.1425091, MRR: 0.5147334, NDCG: 0.2680629, F1: 0.0665236, HIT_RATE: 0.8511652, ARHR_ALL_HITS: 0.8426607, NOVELTY: 0.0065511, AVERAGE_POPULARITY: 0.1843639, DIVERSITY_MEAN_INTER_LIST: 0.9683434, DIVERSITY_HERFINDAHL: 0.9968272, COVERAGE_ITEM: 0.1846171, COVERAGE_ITEM_CORRECT: 0.0711003, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8509158, DIVERSITY_GINI: 0.0284389, SHANNON_ENTROPY: 9.2599132, RATIO_DIVERSITY_HERFINDAHL: 0.9972030, RATIO_DIVERSITY_GINI: 0.1101545, RATIO_SHANNON_ENTROPY: 0.7444470, RATIO_AVERAGE_POPULARITY: 0.9245609, RATIO_NOVELTY: 0.0310097,
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 44.0810
# Function value obtained: -0.1423
# Current minimum: -0.2268
# Iteration No: 19 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.3063677253667481, 'beta': 0.4533810982972715, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.99 sec. Users per second: 1138
# SearchBayesianSkopt: Config 67 is suboptimal. Config: {'topK': 70, 'alpha': 0.3063677253667481, 'beta': 0.4533810982972715, 'normalize_similarity': True} - results: PRECISION: 0.3684743, PRECISION_RECALL_MIN_DEN: 0.3698631, RECALL: 0.0644388, MAP: 0.2249492, MAP_MIN_DEN: 0.2256060, MRR: 0.6317305, NDCG: 0.3856695, F1: 0.1096943, HIT_RATE: 0.9622600, ARHR_ALL_HITS: 1.1711560, NOVELTY: 0.0058505, AVERAGE_POPULARITY: 0.4670354, DIVERSITY_MEAN_INTER_LIST: 0.9002354, DIVERSITY_HERFINDAHL: 0.9900169, COVERAGE_ITEM: 0.1554350, COVERAGE_ITEM_CORRECT: 0.0938590, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9619780, DIVERSITY_GINI: 0.0189388, SHANNON_ENTROPY: 8.2479222, RATIO_DIVERSITY_HERFINDAHL: 0.9903901, RATIO_DIVERSITY_GINI: 0.0733569, RATIO_SHANNON_ENTROPY: 0.6630884, RATIO_AVERAGE_POPULARITY: 2.3421217, RATIO_NOVELTY: 0.0276934,
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 46.3002
# Function value obtained: -0.2249
# Current minimum: -0.2268
# Iteration No: 20 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.5908642769802794, 'beta': 0.5197979499186438, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.54 sec. Users per second: 1183
# SearchBayesianSkopt: Config 68 is suboptimal. Config: {'topK': 50, 'alpha': 0.5908642769802794, 'beta': 0.5197979499186438, 'normalize_similarity': True} - results: PRECISION: 0.3679686, PRECISION_RECALL_MIN_DEN: 0.3693845, RECALL: 0.0645506, MAP: 0.2251819, MAP_MIN_DEN: 0.2258426, MRR: 0.6327921, NDCG: 0.3858844, F1: 0.1098337, HIT_RATE: 0.9623333, ARHR_ALL_HITS: 1.1736138, NOVELTY: 0.0058929, AVERAGE_POPULARITY: 0.4539846, DIVERSITY_MEAN_INTER_LIST: 0.9060119, DIVERSITY_HERFINDAHL: 0.9905945, COVERAGE_ITEM: 0.1773631, COVERAGE_ITEM_CORRECT: 0.1037710, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9620513, DIVERSITY_GINI: 0.0222559, SHANNON_ENTROPY: 8.4436709, RATIO_DIVERSITY_HERFINDAHL: 0.9909679, RATIO_DIVERSITY_GINI: 0.0862056, RATIO_SHANNON_ENTROPY: 0.6788255, RATIO_AVERAGE_POPULARITY: 2.2766733, RATIO_NOVELTY: 0.0278943,
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 45.8049
# Function value obtained: -0.2252
# Current minimum: -0.2268
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 69, 'alpha': 0.02169792183313302, 'beta': 0.22426166263782937, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.47 sec. Users per second: 1304
# SearchBayesianSkopt: Config 69 is suboptimal. Config: {'topK': 69, 'alpha': 0.02169792183313302, 'beta': 0.22426166263782937, 'normalize_similarity': True} - results: PRECISION: 0.3267185, PRECISION_RECALL_MIN_DEN: 0.3277722, RECALL: 0.0566184, MAP: 0.1925288, MAP_MIN_DEN: 0.1930195, MRR: 0.5950422, NDCG: 0.3446977, F1: 0.0965118, HIT_RATE: 0.9459915, ARHR_ALL_HITS: 1.0547785, NOVELTY: 0.0062285, AVERAGE_POPULARITY: 0.3061429, DIVERSITY_MEAN_INTER_LIST: 0.9624190, DIVERSITY_HERFINDAHL: 0.9962349, COVERAGE_ITEM: 0.1705521, COVERAGE_ITEM_CORRECT: 0.0861620, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9457143, DIVERSITY_GINI: 0.0254892, SHANNON_ENTROPY: 9.0902983, RATIO_DIVERSITY_HERFINDAHL: 0.9966103, RATIO_DIVERSITY_GINI: 0.0987291, RATIO_SHANNON_ENTROPY: 0.7308109, RATIO_AVERAGE_POPULARITY: 1.5352669, RATIO_NOVELTY: 0.0294829,
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 43.2918
# Function value obtained: -0.1925
# Current minimum: -0.2268
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.004449069716675359, 'beta': 0.6726975589215134, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.64 sec. Users per second: 1080
# SearchBayesianSkopt: Config 70 is suboptimal. Config: {'topK': 50, 'alpha': 0.004449069716675359, 'beta': 0.6726975589215134, 'normalize_similarity': True} - results: PRECISION: 0.3624139, PRECISION_RECALL_MIN_DEN: 0.3636663, RECALL: 0.0622806, MAP: 0.2183936, MAP_MIN_DEN: 0.2189211, MRR: 0.6108284, NDCG: 0.3766733, F1: 0.1062946, HIT_RATE: 0.9577165, ARHR_ALL_HITS: 1.1368401, NOVELTY: 0.0057037, AVERAGE_POPULARITY: 0.5141347, DIVERSITY_MEAN_INTER_LIST: 0.9067459, DIVERSITY_HERFINDAHL: 0.9906679, COVERAGE_ITEM: 0.1610277, COVERAGE_ITEM_CORRECT: 0.0947450, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9574359, DIVERSITY_GINI: 0.0172855, SHANNON_ENTROPY: 8.0930824, RATIO_DIVERSITY_HERFINDAHL: 0.9910413, RATIO_DIVERSITY_GINI: 0.0669530, RATIO_SHANNON_ENTROPY: 0.6506401, RATIO_AVERAGE_POPULARITY: 2.5783186, RATIO_NOVELTY: 0.0269986,
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 45.0134
# Function value obtained: -0.2184
# Current minimum: -0.2268
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.986066825346864, 'beta': 0.48288362527871764, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.59 sec. Users per second: 1084
# SearchBayesianSkopt: Config 71 is suboptimal. Config: {'topK': 70, 'alpha': 0.986066825346864, 'beta': 0.48288362527871764, 'normalize_similarity': True} - results: PRECISION: 0.3652206, PRECISION_RECALL_MIN_DEN: 0.3666311, RECALL: 0.0639430, MAP: 0.2221095, MAP_MIN_DEN: 0.2227017, MRR: 0.6248814, NDCG: 0.3818707, F1: 0.1088318, HIT_RATE: 0.9597684, ARHR_ALL_HITS: 1.1586193, NOVELTY: 0.0059067, AVERAGE_POPULARITY: 0.4510268, DIVERSITY_MEAN_INTER_LIST: 0.9081210, DIVERSITY_HERFINDAHL: 0.9908054, COVERAGE_ITEM: 0.1727670, COVERAGE_ITEM_CORRECT: 0.0890415, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9594872, DIVERSITY_GINI: 0.0205778, SHANNON_ENTROPY: 8.3806290, RATIO_DIVERSITY_HERFINDAHL: 0.9911789, RATIO_DIVERSITY_GINI: 0.0797054, RATIO_SHANNON_ENTROPY: 0.6737573, RATIO_AVERAGE_POPULARITY: 2.2618407, RATIO_NOVELTY: 0.0279594,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 46.4941
# Function value obtained: -0.2221
# Current minimum: -0.2268
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 68, 'alpha': 0.9969233224514603, 'beta': 0.685633880377396, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.57 sec. Users per second: 1006
# SearchBayesianSkopt: Config 72 is suboptimal. Config: {'topK': 68, 'alpha': 0.9969233224514603, 'beta': 0.685633880377396, 'normalize_similarity': True} - results: PRECISION: 0.3630075, PRECISION_RECALL_MIN_DEN: 0.3643524, RECALL: 0.0628651, MAP: 0.2205932, MAP_MIN_DEN: 0.2211830, MRR: 0.6207185, NDCG: 0.3793054, F1: 0.1071706, HIT_RATE: 0.9577165, ARHR_ALL_HITS: 1.1502544, NOVELTY: 0.0057324, AVERAGE_POPULARITY: 0.5230373, DIVERSITY_MEAN_INTER_LIST: 0.8925669, DIVERSITY_HERFINDAHL: 0.9892501, COVERAGE_ITEM: 0.1608062, COVERAGE_ITEM_CORRECT: 0.0732045, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9574359, DIVERSITY_GINI: 0.0156865, SHANNON_ENTROPY: 7.9234760, RATIO_DIVERSITY_HERFINDAHL: 0.9896230, RATIO_DIVERSITY_GINI: 0.0607596, RATIO_SHANNON_ENTROPY: 0.6370047, RATIO_AVERAGE_POPULARITY: 2.6229637, RATIO_NOVELTY: 0.0271346,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 49.5521
# Function value obtained: -0.2206
# Current minimum: -0.2268
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.5941854449185462, 'beta': 0.6087828816599469, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.69 sec. Users per second: 1075
# SearchBayesianSkopt: Config 73 is suboptimal. Config: {'topK': 70, 'alpha': 0.5941854449185462, 'beta': 0.6087828816599469, 'normalize_similarity': True} - results: PRECISION: 0.3679027, PRECISION_RECALL_MIN_DEN: 0.3693145, RECALL: 0.0638496, MAP: 0.2253240, MAP_MIN_DEN: 0.2260102, MRR: 0.6332079, NDCG: 0.3858709, F1: 0.1088144, HIT_RATE: 0.9605745, ARHR_ALL_HITS: 1.1739849, NOVELTY: 0.0057458, AVERAGE_POPULARITY: 0.5076320, DIVERSITY_MEAN_INTER_LIST: 0.8896451, DIVERSITY_HERFINDAHL: 0.9889580, COVERAGE_ITEM: 0.1640179, COVERAGE_ITEM_CORRECT: 0.0954649, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9602930, DIVERSITY_GINI: 0.0176727, SHANNON_ENTROPY: 8.0353386, RATIO_DIVERSITY_HERFINDAHL: 0.9893307, RATIO_DIVERSITY_GINI: 0.0684529, RATIO_SHANNON_ENTROPY: 0.6459978, RATIO_AVERAGE_POPULARITY: 2.5457081, RATIO_NOVELTY: 0.0271982,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 47.1227
# Function value obtained: -0.2253
# Current minimum: -0.2268
# Iteration No: 26 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.7675813111121186, 'beta': 0.3386347912927609, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.16 sec. Users per second: 1223
# SearchBayesianSkopt: Config 74 is suboptimal. Config: {'topK': 50, 'alpha': 0.7675813111121186, 'beta': 0.3386347912927609, 'normalize_similarity': True} - results: PRECISION: 0.3462113, PRECISION_RECALL_MIN_DEN: 0.3473753, RECALL: 0.0603676, MAP: 0.2085821, MAP_MIN_DEN: 0.2091458, MRR: 0.6158999, NDCG: 0.3649359, F1: 0.1028089, HIT_RATE: 0.9547853, ARHR_ALL_HITS: 1.1153077, NOVELTY: 0.0061606, AVERAGE_POPULARITY: 0.3503908, DIVERSITY_MEAN_INTER_LIST: 0.9442663, DIVERSITY_HERFINDAHL: 0.9944197, COVERAGE_ITEM: 0.1936984, COVERAGE_ITEM_CORRECT: 0.0976245, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9545055, DIVERSITY_GINI: 0.0270014, SHANNON_ENTROPY: 8.9808421, RATIO_DIVERSITY_HERFINDAHL: 0.9947945, RATIO_DIVERSITY_GINI: 0.1045864, RATIO_SHANNON_ENTROPY: 0.7220112, RATIO_AVERAGE_POPULARITY: 1.7571641, RATIO_NOVELTY: 0.0291613,
#
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 44.6144
# Function value obtained: -0.2086
# Current minimum: -0.2268
# Iteration No: 27 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 69, 'alpha': 0.9801995799142661, 'beta': 0.8167419245875541, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.10 sec. Users per second: 968
# SearchBayesianSkopt: Config 75 is suboptimal. Config: {'topK': 69, 'alpha': 0.9801995799142661, 'beta': 0.8167419245875541, 'normalize_similarity': True} - results: PRECISION: 0.3312399, PRECISION_RECALL_MIN_DEN: 0.3322248, RECALL: 0.0558077, MAP: 0.1944792, MAP_MIN_DEN: 0.1949013, MRR: 0.5692664, NDCG: 0.3437054, F1: 0.0955218, HIT_RATE: 0.9350725, ARHR_ALL_HITS: 1.0361177, NOVELTY: 0.0057616, AVERAGE_POPULARITY: 0.5371433, DIVERSITY_MEAN_INTER_LIST: 0.8962933, DIVERSITY_HERFINDAHL: 0.9896228, COVERAGE_ITEM: 0.1543275, COVERAGE_ITEM_CORRECT: 0.0499474, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9347985, DIVERSITY_GINI: 0.0118205, SHANNON_ENTROPY: 7.6015408, RATIO_DIVERSITY_HERFINDAHL: 0.9899958, RATIO_DIVERSITY_GINI: 0.0457853, RATIO_SHANNON_ENTROPY: 0.6111228, RATIO_AVERAGE_POPULARITY: 2.6937034, RATIO_NOVELTY: 0.0272727,
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 47.7886
# Function value obtained: -0.1945
# Current minimum: -0.2268
# Iteration No: 28 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 69, 'alpha': 0.4058325510457491, 'beta': 0.6773261166450103, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.80 sec. Users per second: 989
# SearchBayesianSkopt: Config 76 is suboptimal. Config: {'topK': 69, 'alpha': 0.4058325510457491, 'beta': 0.6773261166450103, 'normalize_similarity': True} - results: PRECISION: 0.3643852, PRECISION_RECALL_MIN_DEN: 0.3657065, RECALL: 0.0628266, MAP: 0.2212409, MAP_MIN_DEN: 0.2218783, MRR: 0.6215598, NDCG: 0.3804168, F1: 0.1071745, HIT_RATE: 0.9579364, ARHR_ALL_HITS: 1.1527967, NOVELTY: 0.0056870, AVERAGE_POPULARITY: 0.5265122, DIVERSITY_MEAN_INTER_LIST: 0.8919138, DIVERSITY_HERFINDAHL: 0.9891848, COVERAGE_ITEM: 0.1626890, COVERAGE_ITEM_CORRECT: 0.0929177, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9576557, DIVERSITY_GINI: 0.0163446, SHANNON_ENTROPY: 7.9322730, RATIO_DIVERSITY_HERFINDAHL: 0.9895577, RATIO_DIVERSITY_GINI: 0.0633087, RATIO_SHANNON_ENTROPY: 0.6377119, RATIO_AVERAGE_POPULARITY: 2.6403900, RATIO_NOVELTY: 0.0269197,
#
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 47.2768
# Function value obtained: -0.2212
# Current minimum: -0.2268
# Iteration No: 29 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 54, 'alpha': 0.016357382431280713, 'beta': 0.8908711361729424, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.79 sec. Users per second: 1067
# SearchBayesianSkopt: Config 77 is suboptimal. Config: {'topK': 54, 'alpha': 0.016357382431280713, 'beta': 0.8908711361729424, 'normalize_similarity': True} - results: PRECISION: 0.1428550, PRECISION_RECALL_MIN_DEN: 0.1433359, RECALL: 0.0240184, MAP: 0.0651144, MAP_MIN_DEN: 0.0652883, MRR: 0.3204307, NDCG: 0.1489064, F1: 0.0411228, HIT_RATE: 0.7128829, ARHR_ALL_HITS: 0.4511986, NOVELTY: 0.0067618, AVERAGE_POPULARITY: 0.1768047, DIVERSITY_MEAN_INTER_LIST: 0.9469720, DIVERSITY_HERFINDAHL: 0.9946903, COVERAGE_ITEM: 0.2089263, COVERAGE_ITEM_CORRECT: 0.0841686, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.7126740, DIVERSITY_GINI: 0.0265413, SHANNON_ENTROPY: 8.8673424, RATIO_DIVERSITY_HERFINDAHL: 0.9950652, RATIO_DIVERSITY_GINI: 0.1028044, RATIO_SHANNON_ENTROPY: 0.7128864, RATIO_AVERAGE_POPULARITY: 0.8866523, RATIO_NOVELTY: 0.0320071,
#
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 46.0745
# Function value obtained: -0.0651
# Current minimum: -0.2268
# Iteration No: 30 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.7633536357475784, 'beta': 0.5391642734750557, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.48 sec. Users per second: 1189
# SearchBayesianSkopt: Config 78 is suboptimal. Config: {'topK': 50, 'alpha': 0.7633536357475784, 'beta': 0.5391642734750557, 'normalize_similarity': True} - results: PRECISION: 0.3680566, PRECISION_RECALL_MIN_DEN: 0.3694761, RECALL: 0.0645247, MAP: 0.2249781, MAP_MIN_DEN: 0.2256344, MRR: 0.6319561, NDCG: 0.3857407, F1: 0.1098002, HIT_RATE: 0.9618203, ARHR_ALL_HITS: 1.1725974, NOVELTY: 0.0058918, AVERAGE_POPULARITY: 0.4564947, DIVERSITY_MEAN_INTER_LIST: 0.9057177, DIVERSITY_HERFINDAHL: 0.9905651, COVERAGE_ITEM: 0.1782491, COVERAGE_ITEM_CORRECT: 0.1020544, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9615385, DIVERSITY_GINI: 0.0222220, SHANNON_ENTROPY: 8.4359109, RATIO_DIVERSITY_HERFINDAHL: 0.9909385, RATIO_DIVERSITY_GINI: 0.0860740, RATIO_SHANNON_ENTROPY: 0.6782017, RATIO_AVERAGE_POPULARITY: 2.2892613, RATIO_NOVELTY: 0.0278888,
#
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 44.2384
# Function value obtained: -0.2250
# Current minimum: -0.2268
# Iteration No: 31 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 1.0, 'beta': 0.5661058529626954, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.69 sec. Users per second: 1168
# SearchBayesianSkopt: Config 79 is suboptimal. Config: {'topK': 50, 'alpha': 1.0, 'beta': 0.5661058529626954, 'normalize_similarity': True} - results: PRECISION: 0.3676242, PRECISION_RECALL_MIN_DEN: 0.3690218, RECALL: 0.0642937, MAP: 0.2244221, MAP_MIN_DEN: 0.2250162, MRR: 0.6282537, NDCG: 0.3846090, F1: 0.1094464, HIT_RATE: 0.9611608, ARHR_ALL_HITS: 1.1677666, NOVELTY: 0.0059042, AVERAGE_POPULARITY: 0.4587359, DIVERSITY_MEAN_INTER_LIST: 0.9085734, DIVERSITY_HERFINDAHL: 0.9908507, COVERAGE_ITEM: 0.1801872, COVERAGE_ITEM_CORRECT: 0.0929177, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9608791, DIVERSITY_GINI: 0.0220778, SHANNON_ENTROPY: 8.4378494, RATIO_DIVERSITY_HERFINDAHL: 0.9912241, RATIO_DIVERSITY_GINI: 0.0855157, RATIO_SHANNON_ENTROPY: 0.6783575, RATIO_AVERAGE_POPULARITY: 2.3005005, RATIO_NOVELTY: 0.0279476,
#
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 43.8318
# Function value obtained: -0.2244
# Current minimum: -0.2268
# Iteration No: 32 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.43463209495585553, 'beta': 0.399102059033436, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.16 sec. Users per second: 1223
# SearchBayesianSkopt: Config 80 is suboptimal. Config: {'topK': 70, 'alpha': 0.43463209495585553, 'beta': 0.399102059033436, 'normalize_similarity': True} - results: PRECISION: 0.3657189, PRECISION_RECALL_MIN_DEN: 0.3671562, RECALL: 0.0641298, MAP: 0.2233396, MAP_MIN_DEN: 0.2240288, MRR: 0.6325119, NDCG: 0.3838651, F1: 0.1091243, HIT_RATE: 0.9621134, ARHR_ALL_HITS: 1.1681572, NOVELTY: 0.0058893, AVERAGE_POPULARITY: 0.4518894, DIVERSITY_MEAN_INTER_LIST: 0.9045485, DIVERSITY_HERFINDAHL: 0.9904482, COVERAGE_ITEM: 0.1538845, COVERAGE_ITEM_CORRECT: 0.0904812, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9618315, DIVERSITY_GINI: 0.0191976, SHANNON_ENTROPY: 8.3194509, RATIO_DIVERSITY_HERFINDAHL: 0.9908215, RATIO_DIVERSITY_GINI: 0.0743594, RATIO_SHANNON_ENTROPY: 0.6688389, RATIO_AVERAGE_POPULARITY: 2.2661664, RATIO_NOVELTY: 0.0278771,
#
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 44.1603
# Function value obtained: -0.2233
# Current minimum: -0.2268
# Iteration No: 33 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.7408640129963959, 'beta': 0.5596241677997111, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.79 sec. Users per second: 1158
# SearchBayesianSkopt: New best config found. Config 81: {'topK': 60, 'alpha': 0.7408640129963959, 'beta': 0.5596241677997111, 'normalize_similarity': True} - results: PRECISION: 0.3700425, PRECISION_RECALL_MIN_DEN: 0.3715182, RECALL: 0.0647020, MAP: 0.2268955, MAP_MIN_DEN: 0.2275927, MRR: 0.6346242, NDCG: 0.3878508, F1: 0.1101451, HIT_RATE: 0.9618936, ARHR_ALL_HITS: 1.1792190, NOVELTY: 0.0058302, AVERAGE_POPULARITY: 0.4783079, DIVERSITY_MEAN_INTER_LIST: 0.8977000, DIVERSITY_HERFINDAHL: 0.9897634, COVERAGE_ITEM: 0.1711612, COVERAGE_ITEM_CORRECT: 0.1000609, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9616117, DIVERSITY_GINI: 0.0201456, SHANNON_ENTROPY: 8.2600302, RATIO_DIVERSITY_HERFINDAHL: 0.9901365, RATIO_DIVERSITY_GINI: 0.0780312, RATIO_SHANNON_ENTROPY: 0.6640618, RATIO_AVERAGE_POPULARITY: 2.3986515, RATIO_NOVELTY: 0.0275976,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 46.3122
# Function value obtained: -0.2269
# Current minimum: -0.2269
# Iteration No: 34 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.6604570390079625, 'beta': 0.6314083282630033, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.94 sec. Users per second: 1142
# SearchBayesianSkopt: Config 82 is suboptimal. Config: {'topK': 50, 'alpha': 0.6604570390079625, 'beta': 0.6314083282630033, 'normalize_similarity': True} - results: PRECISION: 0.3672065, PRECISION_RECALL_MIN_DEN: 0.3686333, RECALL: 0.0641432, MAP: 0.2241723, MAP_MIN_DEN: 0.2248200, MRR: 0.6291985, NDCG: 0.3846691, F1: 0.1092098, HIT_RATE: 0.9632127, ARHR_ALL_HITS: 1.1687617, NOVELTY: 0.0058015, AVERAGE_POPULARITY: 0.4869631, DIVERSITY_MEAN_INTER_LIST: 0.9021492, DIVERSITY_HERFINDAHL: 0.9902083, COVERAGE_ITEM: 0.1739299, COVERAGE_ITEM_CORRECT: 0.1003378, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9629304, DIVERSITY_GINI: 0.0203710, SHANNON_ENTROPY: 8.2696412, RATIO_DIVERSITY_HERFINDAHL: 0.9905815, RATIO_DIVERSITY_GINI: 0.0789045, RATIO_SHANNON_ENTROPY: 0.6648345, RATIO_AVERAGE_POPULARITY: 2.4420562, RATIO_NOVELTY: 0.0274614,
#
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 44.6177
# Function value obtained: -0.2242
# Current minimum: -0.2269
# Iteration No: 35 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 1.0, 'beta': 0.5430440575529217, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.32 sec. Users per second: 1108
# SearchBayesianSkopt: Config 83 is suboptimal. Config: {'topK': 70, 'alpha': 1.0, 'beta': 0.5430440575529217, 'normalize_similarity': True} - results: PRECISION: 0.3679979, PRECISION_RECALL_MIN_DEN: 0.3694066, RECALL: 0.0641934, MAP: 0.2249100, MAP_MIN_DEN: 0.2254995, MRR: 0.6291117, NDCG: 0.3851602, F1: 0.1093175, HIT_RATE: 0.9624798, ARHR_ALL_HITS: 1.1697771, NOVELTY: 0.0058413, AVERAGE_POPULARITY: 0.4797330, DIVERSITY_MEAN_INTER_LIST: 0.8977035, DIVERSITY_HERFINDAHL: 0.9897638, COVERAGE_ITEM: 0.1698322, COVERAGE_ITEM_CORRECT: 0.0869373, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9621978, DIVERSITY_GINI: 0.0191993, SHANNON_ENTROPY: 8.2153057, RATIO_DIVERSITY_HERFINDAHL: 0.9901368, RATIO_DIVERSITY_GINI: 0.0743661, RATIO_SHANNON_ENTROPY: 0.6604662, RATIO_AVERAGE_POPULARITY: 2.4057981, RATIO_NOVELTY: 0.0276499,
#
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 44.8527
# Function value obtained: -0.2249
# Current minimum: -0.2269
# Iteration No: 36 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.329617591667842, 'beta': 0.5182167497714305, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.58 sec. Users per second: 1178
# SearchBayesianSkopt: Config 84 is suboptimal. Config: {'topK': 61, 'alpha': 0.329617591667842, 'beta': 0.5182167497714305, 'normalize_similarity': True} - results: PRECISION: 0.3688627, PRECISION_RECALL_MIN_DEN: 0.3702689, RECALL: 0.0643994, MAP: 0.2252782, MAP_MIN_DEN: 0.2259545, MRR: 0.6305107, NDCG: 0.3859997, F1: 0.1096543, HIT_RATE: 0.9605745, ARHR_ALL_HITS: 1.1717923, NOVELTY: 0.0058330, AVERAGE_POPULARITY: 0.4743474, DIVERSITY_MEAN_INTER_LIST: 0.8989850, DIVERSITY_HERFINDAHL: 0.9898919, COVERAGE_ITEM: 0.1658453, COVERAGE_ITEM_CORRECT: 0.1003932, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9602930, DIVERSITY_GINI: 0.0198803, SHANNON_ENTROPY: 8.2600346, RATIO_DIVERSITY_HERFINDAHL: 0.9902650, RATIO_DIVERSITY_GINI: 0.0770038, RATIO_SHANNON_ENTROPY: 0.6640622, RATIO_AVERAGE_POPULARITY: 2.3787900, RATIO_NOVELTY: 0.0276109,
#
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 44.2839
# Function value obtained: -0.2253
# Current minimum: -0.2269
# Iteration No: 37 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 55, 'alpha': 0.5336979605467275, 'beta': 0.5627870234178236, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.74 sec. Users per second: 1162
# SearchBayesianSkopt: Config 85 is suboptimal. Config: {'topK': 55, 'alpha': 0.5336979605467275, 'beta': 0.5627870234178236, 'normalize_similarity': True} - results: PRECISION: 0.3702550, PRECISION_RECALL_MIN_DEN: 0.3716921, RECALL: 0.0646446, MAP: 0.2266009, MAP_MIN_DEN: 0.2272780, MRR: 0.6333301, NDCG: 0.3876625, F1: 0.1100714, HIT_RATE: 0.9622600, ARHR_ALL_HITS: 1.1774903, NOVELTY: 0.0058317, AVERAGE_POPULARITY: 0.4761852, DIVERSITY_MEAN_INTER_LIST: 0.8999165, DIVERSITY_HERFINDAHL: 0.9899851, COVERAGE_ITEM: 0.1716596, COVERAGE_ITEM_CORRECT: 0.1033834, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9619780, DIVERSITY_GINI: 0.0207576, SHANNON_ENTROPY: 8.2998292, RATIO_DIVERSITY_HERFINDAHL: 0.9903582, RATIO_DIVERSITY_GINI: 0.0804018, RATIO_SHANNON_ENTROPY: 0.6672614, RATIO_AVERAGE_POPULARITY: 2.3880068, RATIO_NOVELTY: 0.0276046,
#
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 44.2522
# Function value obtained: -0.2266
# Current minimum: -0.2269
# Iteration No: 38 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'alpha': 0.03170503109781054, 'beta': 0.5738589116211202, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.25 sec. Users per second: 958
# SearchBayesianSkopt: Config 86 is suboptimal. Config: {'topK': 70, 'alpha': 0.03170503109781054, 'beta': 0.5738589116211202, 'normalize_similarity': True} - results: PRECISION: 0.3679247, PRECISION_RECALL_MIN_DEN: 0.3693045, RECALL: 0.0636811, MAP: 0.2245168, MAP_MIN_DEN: 0.2251250, MRR: 0.6280276, NDCG: 0.3846003, F1: 0.1085706, HIT_RATE: 0.9596219, ARHR_ALL_HITS: 1.1670095, NOVELTY: 0.0057424, AVERAGE_POPULARITY: 0.5072185, DIVERSITY_MEAN_INTER_LIST: 0.8895486, DIVERSITY_HERFINDAHL: 0.9889483, COVERAGE_ITEM: 0.1559887, COVERAGE_ITEM_CORRECT: 0.0966277, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9593407, DIVERSITY_GINI: 0.0175817, SHANNON_ENTROPY: 8.0327170, RATIO_DIVERSITY_HERFINDAHL: 0.9893211, RATIO_DIVERSITY_GINI: 0.0681004, RATIO_SHANNON_ENTROPY: 0.6457871, RATIO_AVERAGE_POPULARITY: 2.5436346, RATIO_NOVELTY: 0.0271818,
#
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 48.6876
# Function value obtained: -0.2245
# Current minimum: -0.2269
# ...
#
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 49.3569
# Function value obtained: -0.2260
# Current minimum: -0.2269
# Iteration No: 40 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.04557135654251555, 'beta': 0.408800886023456, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.74 sec. Users per second: 1163
# SearchBayesianSkopt: Config 88 is suboptimal. Config: {'topK': 50, 'alpha': 0.04557135654251555, 'beta': 0.408800886023456, 'normalize_similarity': True} - results: PRECISION: 0.3645317, PRECISION_RECALL_MIN_DEN: 0.3659008, RECALL: 0.0638787, MAP: 0.2223746, MAP_MIN_DEN: 0.2230002, MRR: 0.6300002, NDCG: 0.3823270, F1: 0.1087080, HIT_RATE: 0.9613806, ARHR_ALL_HITS: 1.1631974, NOVELTY: 0.0059597, AVERAGE_POPULARITY: 0.4272646, DIVERSITY_MEAN_INTER_LIST: 0.9177852, DIVERSITY_HERFINDAHL: 0.9917718, COVERAGE_ITEM: 0.1757019, COVERAGE_ITEM_CORRECT: 0.0981228, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9610989, DIVERSITY_GINI: 0.0228833, SHANNON_ENTROPY: 8.5812570, RATIO_DIVERSITY_HERFINDAHL: 0.9921456, RATIO_DIVERSITY_GINI: 0.0886354, RATIO_SHANNON_ENTROPY: 0.6898867, RATIO_AVERAGE_POPULARITY: 2.1426759, RATIO_NOVELTY: 0.0282106,
#
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 45.5134
# Function value obtained: -0.2224
# Current minimum: -0.2269
# Iteration No: 41 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.6022015658572655, 'beta': 0.4928753971929123, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.73 sec. Users per second: 1164
# SearchBayesianSkopt: Config 89 is suboptimal. Config: {'topK': 61, 'alpha': 0.6022015658572655, 'beta': 0.4928753971929123, 'normalize_similarity': True} - results: PRECISION: 0.3682105, PRECISION_RECALL_MIN_DEN: 0.3695817, RECALL: 0.0644062, MAP: 0.2256115, MAP_MIN_DEN: 0.2263200, MRR: 0.6339576, NDCG: 0.3863767, F1: 0.1096354, HIT_RATE: 0.9618203, ARHR_ALL_HITS: 1.1756006, NOVELTY: 0.0058740, AVERAGE_POPULARITY: 0.4602675, DIVERSITY_MEAN_INTER_LIST: 0.9031519, DIVERSITY_HERFINDAHL: 0.9903086, COVERAGE_ITEM: 0.1683925, COVERAGE_ITEM_CORRECT: 0.0992857, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9615385, DIVERSITY_GINI: 0.0206145, SHANNON_ENTROPY: 8.3462660, RATIO_DIVERSITY_HERFINDAHL: 0.9906818, RATIO_DIVERSITY_GINI: 0.0798475, RATIO_SHANNON_ENTROPY: 0.6709947, RATIO_AVERAGE_POPULARITY: 2.3081814, RATIO_NOVELTY: 0.0278047,
#
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 47.2561
# Function value obtained: -0.2256
# Current minimum: -0.2269
# Iteration No: 42 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.7883237332492624, 'beta': 0.5511475820173782, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.28 sec. Users per second: 1111
# SearchBayesianSkopt: Config 90 is suboptimal. Config: {'topK': 60, 'alpha': 0.7883237332492624, 'beta': 0.5511475820173782, 'normalize_similarity': True} - results: PRECISION: 0.3698227, PRECISION_RECALL_MIN_DEN: 0.3712660, RECALL: 0.0647714, MAP: 0.2266151, MAP_MIN_DEN: 0.2272849, MRR: 0.6331955, NDCG: 0.3875333, F1: 0.1102358, HIT_RATE: 0.9616005, ARHR_ALL_HITS: 1.1779147, NOVELTY: 0.0058390, AVERAGE_POPULARITY: 0.4756205, DIVERSITY_MEAN_INTER_LIST: 0.8984458, DIVERSITY_HERFINDAHL: 0.9898380, COVERAGE_ITEM: 0.1714934, COVERAGE_ITEM_CORRECT: 0.0984551, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9613187, DIVERSITY_GINI: 0.0201419, SHANNON_ENTROPY: 8.2714635, RATIO_DIVERSITY_HERFINDAHL: 0.9902111, RATIO_DIVERSITY_GINI: 0.0780170, RATIO_SHANNON_ENTROPY: 0.6649810, RATIO_AVERAGE_POPULARITY: 2.3851746, RATIO_NOVELTY: 0.0276390,
#
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 45.9913
# Function value obtained: -0.2266
# Current minimum: -0.2269
# Iteration No: 43 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.02329168351449729, 'beta': 0.6059650263222859, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.02 sec. Users per second: 1135
# SearchBayesianSkopt: Config 91 is suboptimal. Config: {'topK': 50, 'alpha': 0.02329168351449729, 'beta': 0.6059650263222859, 'normalize_similarity': True} - results: PRECISION: 0.3679540, PRECISION_RECALL_MIN_DEN: 0.3693225, RECALL: 0.0638857, MAP: 0.2245623, MAP_MIN_DEN: 0.2251381, MRR: 0.6263046, NDCG: 0.3845219, F1: 0.1088691, HIT_RATE: 0.9612341, ARHR_ALL_HITS: 1.1662199, NOVELTY: 0.0057586, AVERAGE_POPULARITY: 0.4995920, DIVERSITY_MEAN_INTER_LIST: 0.8993553, DIVERSITY_HERFINDAHL: 0.9899289, COVERAGE_ITEM: 0.1670081, COVERAGE_ITEM_CORRECT: 0.0997840, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9609524, DIVERSITY_GINI: 0.0192284, SHANNON_ENTROPY: 8.1756699, RATIO_DIVERSITY_HERFINDAHL: 0.9903021, RATIO_DIVERSITY_GINI: 0.0744786, RATIO_SHANNON_ENTROPY: 0.6572797, RATIO_AVERAGE_POPULARITY: 2.5053884, RATIO_NOVELTY: 0.0272588,
#
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 45.1747
# Function value obtained: -0.2246
# Current minimum: -0.2269
# Iteration No: 44 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 51, 'alpha': 0.027374313140432045, 'beta': 0.25551951967582415, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.16 sec. Users per second: 1343
# SearchBayesianSkopt: Config 92 is suboptimal. Config: {'topK': 51, 'alpha': 0.027374313140432045, 'beta': 0.25551951967582415, 'normalize_similarity': True} - results: PRECISION: 0.3356808, PRECISION_RECALL_MIN_DEN: 0.3366728, RECALL: 0.0581370, MAP: 0.2000090, MAP_MIN_DEN: 0.2005077, MRR: 0.6091184, NDCG: 0.3546505, F1: 0.0991092, HIT_RATE: 0.9504617, ARHR_ALL_HITS: 1.0868999, NOVELTY: 0.0061914, AVERAGE_POPULARITY: 0.3340914, DIVERSITY_MEAN_INTER_LIST: 0.9527223, DIVERSITY_HERFINDAHL: 0.9952652, COVERAGE_ITEM: 0.1890470, COVERAGE_ITEM_CORRECT: 0.0925854, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9501832, DIVERSITY_GINI: 0.0264702, SHANNON_ENTROPY: 9.0291552, RATIO_DIVERSITY_HERFINDAHL: 0.9956404, RATIO_DIVERSITY_GINI: 0.1025290, RATIO_SHANNON_ENTROPY: 0.7258953, RATIO_AVERAGE_POPULARITY: 1.6754245, RATIO_NOVELTY: 0.0293072,
#
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 42.9928
# Function value obtained: -0.2000
# Current minimum: -0.2269
# Iteration No: 45 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.44028387000039493, 'beta': 0.8157985568051423, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.71 sec. Users per second: 1074
# SearchBayesianSkopt: Config 93 is suboptimal. Config: {'topK': 50, 'alpha': 0.44028387000039493, 'beta': 0.8157985568051423, 'normalize_similarity': True} - results: PRECISION: 0.3243368, PRECISION_RECALL_MIN_DEN: 0.3254458, RECALL: 0.0545449, MAP: 0.1882456, MAP_MIN_DEN: 0.1887247, MRR: 0.5685260, NDCG: 0.3373163, F1: 0.0933849, HIT_RATE: 0.9380771, ARHR_ALL_HITS: 1.0187933, NOVELTY: 0.0057506, AVERAGE_POPULARITY: 0.4980981, DIVERSITY_MEAN_INTER_LIST: 0.9146045, DIVERSITY_HERFINDAHL: 0.9914537, COVERAGE_ITEM: 0.1618584, COVERAGE_ITEM_CORRECT: 0.0751426, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9378022, DIVERSITY_GINI: 0.0145505, SHANNON_ENTROPY: 7.9493381, RATIO_DIVERSITY_HERFINDAHL: 0.9918274, RATIO_DIVERSITY_GINI: 0.0563594, RATIO_SHANNON_ENTROPY: 0.6390839, RATIO_AVERAGE_POPULARITY: 2.4978968, RATIO_NOVELTY: 0.0272205,
#
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 45.6535
# Function value obtained: -0.1882
# Current minimum: -0.2269
# Iteration No: 46 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.9706094198698128, 'beta': 0.17278235244513387, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.89 sec. Users per second: 1379
# SearchBayesianSkopt: Config 94 is suboptimal. Config: {'topK': 50, 'alpha': 0.9706094198698128, 'beta': 0.17278235244513387, 'normalize_similarity': True} - results: PRECISION: 0.2542723, PRECISION_RECALL_MIN_DEN: 0.2546646, RECALL: 0.0404004, MAP: 0.1463464, MAP_MIN_DEN: 0.1465350, MRR: 0.5219556, NDCG: 0.2750231, F1: 0.0697228, HIT_RATE: 0.8660413, ARHR_ALL_HITS: 0.8605866, NOVELTY: 0.0068864, AVERAGE_POPULARITY: 0.1598968, DIVERSITY_MEAN_INTER_LIST: 0.9753621, DIVERSITY_HERFINDAHL: 0.9975291, COVERAGE_ITEM: 0.2996844, COVERAGE_ITEM_CORRECT: 0.0889861, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8657875, DIVERSITY_GINI: 0.0515374, SHANNON_ENTROPY: 9.9327626, RATIO_DIVERSITY_HERFINDAHL: 0.9979050, RATIO_DIVERSITY_GINI: 0.1996237, RATIO_SHANNON_ENTROPY: 0.7985405, RATIO_AVERAGE_POPULARITY: 0.8018618, RATIO_NOVELTY: 0.0325972,
#
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 43.2285
# Function value obtained: -0.1463
# Current minimum: -0.2269
# Iteration No: 47 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 58, 'alpha': 0.7371306326293727, 'beta': 0.5686834174958042, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.71 sec. Users per second: 1165
# SearchBayesianSkopt: Config 95 is suboptimal. Config: {'topK': 58, 'alpha': 0.7371306326293727, 'beta': 0.5686834174958042, 'normalize_similarity': True} - results: PRECISION: 0.3697127, PRECISION_RECALL_MIN_DEN: 0.3711814, RECALL: 0.0646399, MAP: 0.2266116, MAP_MIN_DEN: 0.2273114, MRR: 0.6331603, NDCG: 0.3874549, F1: 0.1100406, HIT_RATE: 0.9616005, ARHR_ALL_HITS: 1.1776614, NOVELTY: 0.0058317, AVERAGE_POPULARITY: 0.4777151, DIVERSITY_MEAN_INTER_LIST: 0.8992248, DIVERSITY_HERFINDAHL: 0.9899159, COVERAGE_ITEM: 0.1719364, COVERAGE_ITEM_CORRECT: 0.1011130, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9613187, DIVERSITY_GINI: 0.0203759, SHANNON_ENTROPY: 8.2800509, RATIO_DIVERSITY_HERFINDAHL: 0.9902890, RATIO_DIVERSITY_GINI: 0.0789236, RATIO_SHANNON_ENTROPY: 0.6656714, RATIO_AVERAGE_POPULARITY: 2.3956789, RATIO_NOVELTY: 0.0276045,
#
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 44.8547
# Function value obtained: -0.2266
# Current minimum: -0.2269
# Iteration No: 48 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 69, 'alpha': 0.9796505833234846, 'beta': 0.6150518210421486, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.59 sec. Users per second: 1084
# SearchBayesianSkopt: Config 96 is suboptimal. Config: {'topK': 69, 'alpha': 0.9796505833234846, 'beta': 0.6150518210421486, 'normalize_similarity': True} - results: PRECISION: 0.3660120, PRECISION_RECALL_MIN_DEN: 0.3674030, RECALL: 0.0635580, MAP: 0.2238809, MAP_MIN_DEN: 0.2244825, MRR: 0.6318705, NDCG: 0.3840466, F1: 0.1083082, HIT_RATE: 0.9599883, ARHR_ALL_HITS: 1.1690852, NOVELTY: 0.0057757, AVERAGE_POPULARITY: 0.5042132, DIVERSITY_MEAN_INTER_LIST: 0.8921117, DIVERSITY_HERFINDAHL: 0.9892046, COVERAGE_ITEM: 0.1679495, COVERAGE_ITEM_CORRECT: 0.0846116, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9597070, DIVERSITY_GINI: 0.0176496, SHANNON_ENTROPY: 8.0584796, RATIO_DIVERSITY_HERFINDAHL: 0.9895775, RATIO_DIVERSITY_GINI: 0.0683636, RATIO_SHANNON_ENTROPY: 0.6478582, RATIO_AVERAGE_POPULARITY: 2.5285633, RATIO_NOVELTY: 0.0273397,
#
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 46.1375
# Function value obtained: -0.2239
# Current minimum: -0.2269
# Iteration No: 49 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.6921491040166957, 'beta': 0.5592722970194465, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.88 sec. Users per second: 1149
# SearchBayesianSkopt: Config 97 is suboptimal. Config: {'topK': 56, 'alpha': 0.6921491040166957, 'beta': 0.5592722970194465, 'normalize_similarity': True} - results: PRECISION: 0.3700498, PRECISION_RECALL_MIN_DEN: 0.3714438, RECALL: 0.0645815, MAP: 0.2268157, MAP_MIN_DEN: 0.2274965, MRR: 0.6340229, NDCG: 0.3877499, F1: 0.1099707, HIT_RATE: 0.9618936, ARHR_ALL_HITS: 1.1786238, NOVELTY: 0.0058380, AVERAGE_POPULARITY: 0.4751938, DIVERSITY_MEAN_INTER_LIST: 0.8994041, DIVERSITY_HERFINDAHL: 0.9899338, COVERAGE_ITEM: 0.1729332, COVERAGE_ITEM_CORRECT: 0.1024974, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9616117, DIVERSITY_GINI: 0.0206352, SHANNON_ENTROPY: 8.2958466, RATIO_DIVERSITY_HERFINDAHL: 0.9903069, RATIO_DIVERSITY_GINI: 0.0799278, RATIO_SHANNON_ENTROPY: 0.6669413, RATIO_AVERAGE_POPULARITY: 2.3830347, RATIO_NOVELTY: 0.0276345,
#
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 45.1650
# Function value obtained: -0.2268
# Current minimum: -0.2269
# Iteration No: 50 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.624694330676126, 'beta': 0.5684622077543231, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.84 sec. Users per second: 1153
# SearchBayesianSkopt: New best config found. Config 98: {'topK': 56, 'alpha': 0.624694330676126, 'beta': 0.5684622077543231, 'normalize_similarity': True} - results: PRECISION: 0.3704675, PRECISION_RECALL_MIN_DEN: 0.3718735, RECALL: 0.0646153, MAP: 0.2271450, MAP_MIN_DEN: 0.2278471, MRR: 0.6337651, NDCG: 0.3880923, F1: 0.1100382, HIT_RATE: 0.9614539, ARHR_ALL_HITS: 1.1794330, NOVELTY: 0.0058300, AVERAGE_POPULARITY: 0.4774199, DIVERSITY_MEAN_INTER_LIST: 0.8994589, DIVERSITY_HERFINDAHL: 0.9899393, COVERAGE_ITEM: 0.1729332, COVERAGE_ITEM_CORRECT: 0.1031065, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9611722, DIVERSITY_GINI: 0.0206402, SHANNON_ENTROPY: 8.2902670, RATIO_DIVERSITY_HERFINDAHL: 0.9903124, RATIO_DIVERSITY_GINI: 0.0799471, RATIO_SHANNON_ENTROPY: 0.6664927, RATIO_AVERAGE_POPULARITY: 2.3941983, RATIO_NOVELTY: 0.0275966,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 46.6083
# Function value obtained: -0.2271
# Current minimum: -0.2271
# SearchBayesianSkopt: Testing config: {'topK': 55, 'alpha': 0.5760980092475169, 'beta': 0.571242657285991, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.10 sec. Users per second: 1128
# SearchBayesianSkopt: Config 99 is suboptimal. Config: {'topK': 55, 'alpha': 0.5760980092475169, 'beta': 0.571242657285991, 'normalize_similarity': True} - results: PRECISION: 0.3697714, PRECISION_RECALL_MIN_DEN: 0.3711732, RECALL: 0.0645464, MAP: 0.2266099, MAP_MIN_DEN: 0.2272763, MRR: 0.6327235, NDCG: 0.3874083, F1: 0.1099077, HIT_RATE: 0.9612341, ARHR_ALL_HITS: 1.1773872, NOVELTY: 0.0058278, AVERAGE_POPULARITY: 0.4779965, DIVERSITY_MEAN_INTER_LIST: 0.9001326, DIVERSITY_HERFINDAHL: 0.9900067, COVERAGE_ITEM: 0.1739853, COVERAGE_ITEM_CORRECT: 0.1043801, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9609524, DIVERSITY_GINI: 0.0207706, SHANNON_ENTROPY: 8.2966332, RATIO_DIVERSITY_HERFINDAHL: 0.9903798, RATIO_DIVERSITY_GINI: 0.0804524, RATIO_SHANNON_ENTROPY: 0.6670045, RATIO_AVERAGE_POPULARITY: 2.3970900, RATIO_NOVELTY: 0.0275860,
#
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 92.3856
# Function value obtained: -0.2266
# Current minimum: -0.2271
# SearchBayesianSkopt: Search complete. Best config is 98: {'topK': 56, 'alpha': 0.624694330676126, 'beta': 0.5684622077543231, 'normalize_similarity': True}

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.22

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_47567/83441945.py in <module>
#       4
#       5 data_loader = DataIO(folder_path = output_folder_path)
# ----> 6 search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#       7 #search_metadata.keys()
#       8
#
# ~/Scrivania/RecSysChallenge2021/Recommenders/DataIO.py in load_data(self, file_name)
#     207             file_name += ".zip"
#     208
# --> 209         dataFile = zipfile.ZipFile(self.folder_path + file_name)
#     210
#     211         dataFile.testzip()
#
# ~/anaconda3/envs/RecSysFramework/lib/python3.8/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'result_experiments/RP3beta_augmented_all/RP3betaRecommender_metadata.zip'

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_event_preprocessed/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.219

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK     alpha      beta normalize_similarity       MAP
# 13  122  0.449787  0.395651                 True  0.220561
# 38   93   0.20678  0.380367                 True  0.219950
# 46   94       0.0  0.390115                 True  0.219409
# Max value for the range:  122
# Min value for the range:  93
# Best MAP:  0.2205607899518212
#    topK     alpha      beta normalize_similarity       MAP
# 13  122  0.449787  0.395651                 True  0.220561

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_no_event/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.224

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK    alpha      beta normalize_similarity       MAP
# 30   62      0.0  0.533488                 True  0.224454
# 34   85      1.0  0.543791                 True  0.224019
# 40   56  0.48885  0.543524                 True  0.226386
# 44   37      0.0  0.536916                 True  0.224072
# Max value for the range:  85
# Min value for the range:  37
# Best MAP:  0.22638588201903473
#    topK    alpha      beta normalize_similarity       MAP
# 40   56  0.48885  0.543524                 True  0.226386

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_no_event_improved_range/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.226

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK     alpha      beta normalize_similarity       MAP
# 47   61  0.297542  0.563447                 True  0.226389
# 57   55  0.885547  0.547405                 True  0.226444
# 60   59  0.581572  0.540392                 True  0.226535
# 61   50  0.690909  0.569618                 True  0.226775
# 62   56  0.639613  0.577889                 True  0.226722
# 64   65   0.53406  0.576047                 True  0.226314
# 81   60  0.740864  0.559624                 True  0.226896
# 85   55  0.533698  0.562787                 True  0.226601
# 90   60  0.788324  0.551148                 True  0.226615
# 95   58  0.737131  0.568683                 True  0.226612
# 97   56  0.692149  0.559272                 True  0.226816
# 98   56  0.624694  0.568462                 True  0.227145
# 99   55  0.576098  0.571243                 True  0.226610
# Max value for the range:  65
# Min value for the range:  50
# Best MAP:  0.22714496253335392
#    topK     alpha      beta normalize_similarity       MAP
# 98   56  0.624694  0.568462                 True  0.227145

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_no_event_topK_categorical/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.226

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK     alpha      beta normalize_similarity       MAP
# 25   66  0.667368  0.555375                 True  0.226365
# 30   51  0.478767  0.574051                 True  0.226439
# 34   51  0.531833   0.54934                 True  0.226300
# 36   51  0.743044  0.563758                 True  0.226602
# 37   51  0.650132   0.57081                 True  0.226861
# 38   51  0.651618  0.575714                 True  0.227280
# 41   51  0.642757   0.58423                 True  0.226830
# 45   51  0.582075    0.5893                 True  0.226184
# 48   66  0.614196   0.52372                 True  0.226039
# Max value for the range:  66
# Min value for the range:  51
# Best MAP:  0.227279727881186
#    topK     alpha      beta normalize_similarity      MAP
# 38   51  0.651618  0.575714                 True  0.22728
