# %% [markdown]
# # RP3beta

# %% [markdown]
# ## Import

# %%
## Allow more than one output for a single code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd
import scipy.sparse as sps
import numpy as np
import os

from skopt.space import Real, Integer, Categorical

## Set the numpy random seed
SEED = 42
np.random.seed(SEED)

os.getcwd()
# Out:
# '/home/alessio/Scrivania/RecSysChallenge2021'

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

from Evaluation.Evaluator import EvaluatorHoldout

from Recommenders.Recommender_import_list import *
# Out:
# Tensorflow is not available

# %%
## Utility Functions
from Dataset.load_data import load_data
from Dataset.write_submission import write_submission
from Dataset.load_test_user_array import load_test_user_array

# %% [markdown]
# ## Data Loading and Split

# %%
URM_all, ICM_dict = load_data()

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

URM_aug_train = sps.vstack([URM_train.tocoo(), 
                            ICM_dict['ICM_genre'].T.tocoo(),
                            ICM_dict['ICM_subgenre'].T.tocoo(), 
                            #ICM_dict['ICM_event'].T.tocoo(), 
                            ICM_dict['ICM_channel'].T.tocoo()], format='csr')

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10], exclude_seen = True)
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
test_UserID_array = load_test_user_array()

# %% [markdown]
# ## Optimization

# %%
output_folder_path = "result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 100  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender

runHyperparameterSearch_Collaborative(RP3betaRecommender,
                                      URM_train = URM_aug_train,
                                      URM_train_last_test = None,
                                      metric_to_optimize = metric_to_optimize,
                                      cutoff_to_optimize = cutoff_to_optimize,
                                      n_cases = n_cases,
                                      n_random_starts = n_random_starts,
                                      evaluator_validation_earlystopping = evaluator_validation,
                                      evaluator_validation = evaluator_validation,
                                      evaluator_test = None,
                                      output_folder_path = output_folder_path,
                                      resume_from_saved = True,
                                      similarity_type_list = None,
                                      parallelizeKNN = True)
# Out:
# SearchBayesianSkopt: Resuming 'RP3betaRecommender' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 51, 'alpha': 0.8892004746256345, 'beta': 0.7686587124882853, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.54 sec. Users per second: 1008
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 51, 'alpha': 0.8892004746256345, 'beta': 0.7686587124882853, 'normalize_similarity': True} - results: PRECISION: 0.3467683, PRECISION_RECALL_MIN_DEN: 0.3480191, RECALL: 0.0595108, MAP: 0.2066228, MAP_MIN_DEN: 0.2071249, MRR: 0.5969829, NDCG: 0.3613776, F1: 0.1015876, HIT_RATE: 0.9514143, ARHR_ALL_HITS: 1.0933855, NOVELTY: 0.0057378, AVERAGE_POPULARITY: 0.5156573, DIVERSITY_MEAN_INTER_LIST: 0.9115770, DIVERSITY_HERFINDAHL: 0.9911510, COVERAGE_ITEM: 0.1570962, COVERAGE_ITEM_CORRECT: 0.0663381, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9511355, DIVERSITY_GINI: 0.0143952, SHANNON_ENTROPY: 7.9571968, RATIO_DIVERSITY_HERFINDAHL: 0.9915246, RATIO_DIVERSITY_GINI: 0.0557582, RATIO_SHANNON_ENTROPY: 0.6397157, RATIO_AVERAGE_POPULARITY: 2.5859541, RATIO_NOVELTY: 0.0271599,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 47.7129
# Function value obtained: -0.2066
# Current minimum: -0.2066
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.39293129695495665, 'beta': 0.7512320687837937, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.27 sec. Users per second: 1029
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 60, 'alpha': 0.39293129695495665, 'beta': 0.7512320687837937, 'normalize_similarity': True} - results: PRECISION: 0.3527554, PRECISION_RECALL_MIN_DEN: 0.3540311, RECALL: 0.0603035, MAP: 0.2103942, MAP_MIN_DEN: 0.2109156, MRR: 0.6003384, NDCG: 0.3664747, F1: 0.1029993, HIT_RATE: 0.9544922, ARHR_ALL_HITS: 1.1058805, NOVELTY: 0.0056841, AVERAGE_POPULARITY: 0.5217666, DIVERSITY_MEAN_INTER_LIST: 0.9097960, DIVERSITY_HERFINDAHL: 0.9909729, COVERAGE_ITEM: 0.1582590, COVERAGE_ITEM_CORRECT: 0.0854422, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9542125, DIVERSITY_GINI: 0.0152559, SHANNON_ENTROPY: 7.9847014, RATIO_DIVERSITY_HERFINDAHL: 0.9913464, RATIO_DIVERSITY_GINI: 0.0590918, RATIO_SHANNON_ENTROPY: 0.6419269, RATIO_AVERAGE_POPULARITY: 2.6165912, RATIO_NOVELTY: 0.0269057,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 47.8400
# Function value obtained: -0.2104
# Current minimum: -0.2104
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 65, 'alpha': 0.8042807828177057, 'beta': 0.06694328455005728, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.04 sec. Users per second: 1359
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 65, 'alpha': 0.8042807828177057, 'beta': 0.06694328455005728, 'normalize_similarity': True} - results: PRECISION: 0.2397039, PRECISION_RECALL_MIN_DEN: 0.2400212, RECALL: 0.0377354, MAP: 0.1372996, MAP_MIN_DEN: 0.1374814, MRR: 0.5032257, NDCG: 0.2605541, F1: 0.0652057, HIT_RATE: 0.8449362, ARHR_ALL_HITS: 0.8182215, NOVELTY: 0.0067055, AVERAGE_POPULARITY: 0.1657971, DIVERSITY_MEAN_INTER_LIST: 0.9711790, DIVERSITY_HERFINDAHL: 0.9971108, COVERAGE_ITEM: 0.2443103, COVERAGE_ITEM_CORRECT: 0.0750318, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8446886, DIVERSITY_GINI: 0.0368980, SHANNON_ENTROPY: 9.5245942, RATIO_DIVERSITY_HERFINDAHL: 0.9974866, RATIO_DIVERSITY_GINI: 0.1429195, RATIO_SHANNON_ENTROPY: 0.7657259, RATIO_AVERAGE_POPULARITY: 0.8314510, RATIO_NOVELTY: 0.0317405,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 44.1445
# Function value obtained: -0.1373
# Current minimum: -0.2104
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 55, 'alpha': 0.019516531689971698, 'beta': 0.08590541685641785, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.95 sec. Users per second: 1371
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 55, 'alpha': 0.019516531689971698, 'beta': 0.08590541685641785, 'normalize_similarity': True} - results: PRECISION: 0.2456764, PRECISION_RECALL_MIN_DEN: 0.2459914, RECALL: 0.0380677, MAP: 0.1422362, MAP_MIN_DEN: 0.1423867, MRR: 0.5133364, NDCG: 0.2673777, F1: 0.0659209, HIT_RATE: 0.8466217, ARHR_ALL_HITS: 0.8408988, NOVELTY: 0.0066122, AVERAGE_POPULARITY: 0.1814960, DIVERSITY_MEAN_INTER_LIST: 0.9703759, DIVERSITY_HERFINDAHL: 0.9970305, COVERAGE_ITEM: 0.2175646, COVERAGE_ITEM_CORRECT: 0.0753641, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8463736, DIVERSITY_GINI: 0.0328488, SHANNON_ENTROPY: 9.4204779, RATIO_DIVERSITY_HERFINDAHL: 0.9974063, RATIO_DIVERSITY_GINI: 0.1272357, RATIO_SHANNON_ENTROPY: 0.7573555, RATIO_AVERAGE_POPULARITY: 0.9101789, RATIO_NOVELTY: 0.0312992,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 41.6705
# Function value obtained: -0.1422
# Current minimum: -0.2104
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.8439169274506522, 'beta': 0.28705003515631605, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.87 sec. Users per second: 1149
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 61, 'alpha': 0.8439169274506522, 'beta': 0.28705003515631605, 'normalize_similarity': True} - results: PRECISION: 0.3279056, PRECISION_RECALL_MIN_DEN: 0.3289382, RECALL: 0.0565172, MAP: 0.1945681, MAP_MIN_DEN: 0.1950901, MRR: 0.5991988, NDCG: 0.3466796, F1: 0.0964163, HIT_RATE: 0.9451854, ARHR_ALL_HITS: 1.0626420, NOVELTY: 0.0063177, AVERAGE_POPULARITY: 0.2863086, DIVERSITY_MEAN_INTER_LIST: 0.9654626, DIVERSITY_HERFINDAHL: 0.9965392, COVERAGE_ITEM: 0.2070436, COVERAGE_ITEM_CORRECT: 0.0957971, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9449084, DIVERSITY_GINI: 0.0306525, SHANNON_ENTROPY: 9.3066746, RATIO_DIVERSITY_HERFINDAHL: 0.9969148, RATIO_DIVERSITY_GINI: 0.1187284, RATIO_SHANNON_ENTROPY: 0.7482064, RATIO_AVERAGE_POPULARITY: 1.4358005, RATIO_NOVELTY: 0.0299052,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 43.4901
# Function value obtained: -0.1946
# Current minimum: -0.2104
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.5695258298159999, 'beta': 0.48585737365893056, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.71 sec. Users per second: 1165
# SearchBayesianSkopt: New best config found. Config 5: {'topK': 61, 'alpha': 0.5695258298159999, 'beta': 0.48585737365893056, 'normalize_similarity': True} - results: PRECISION: 0.3678880, PRECISION_RECALL_MIN_DEN: 0.3692855, RECALL: 0.0643946, MAP: 0.2253592, MAP_MIN_DEN: 0.2260722, MRR: 0.6337450, NDCG: 0.3861045, F1: 0.1096043, HIT_RATE: 0.9618203, ARHR_ALL_HITS: 1.1748459, NOVELTY: 0.0058785, AVERAGE_POPULARITY: 0.4581904, DIVERSITY_MEAN_INTER_LIST: 0.9038966, DIVERSITY_HERFINDAHL: 0.9903830, COVERAGE_ITEM: 0.1687801, COVERAGE_ITEM_CORRECT: 0.0981228, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9615385, DIVERSITY_GINI: 0.0206987, SHANNON_ENTROPY: 8.3576982, RATIO_DIVERSITY_HERFINDAHL: 0.9907563, RATIO_DIVERSITY_GINI: 0.0801739, RATIO_SHANNON_ENTROPY: 0.6719138, RATIO_AVERAGE_POPULARITY: 2.2977651, RATIO_NOVELTY: 0.0278259,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 44.9260
# Function value obtained: -0.2254
# Current minimum: -0.2254
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.21729888759113763, 'beta': 0.8679597325256949, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.47 sec. Users per second: 1013
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 60, 'alpha': 0.21729888759113763, 'beta': 0.8679597325256949, 'normalize_similarity': True} - results: PRECISION: 0.1991646, PRECISION_RECALL_MIN_DEN: 0.1999450, RECALL: 0.0339991, MAP: 0.0989437, MAP_MIN_DEN: 0.0992562, MRR: 0.4150194, NDCG: 0.2085884, F1: 0.0580830, HIT_RATE: 0.8296204, ARHR_ALL_HITS: 0.6340087, NOVELTY: 0.0063803, AVERAGE_POPULARITY: 0.2665278, DIVERSITY_MEAN_INTER_LIST: 0.9477731, DIVERSITY_HERFINDAHL: 0.9947704, COVERAGE_ITEM: 0.2009524, COVERAGE_ITEM_CORRECT: 0.0873803, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8293773, DIVERSITY_GINI: 0.0236949, SHANNON_ENTROPY: 8.7456555, RATIO_DIVERSITY_HERFINDAHL: 0.9951453, RATIO_DIVERSITY_GINI: 0.0917790, RATIO_SHANNON_ENTROPY: 0.7031035, RATIO_AVERAGE_POPULARITY: 1.3366021, RATIO_NOVELTY: 0.0302014,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 45.6341
# Function value obtained: -0.0989
# Current minimum: -0.2254
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 65, 'alpha': 0.6503575199067979, 'beta': 0.4104545186296278, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.29 sec. Users per second: 1208
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 65, 'alpha': 0.6503575199067979, 'beta': 0.4104545186296278, 'normalize_similarity': True} - results: PRECISION: 0.3652865, PRECISION_RECALL_MIN_DEN: 0.3667929, RECALL: 0.0642780, MAP: 0.2229225, MAP_MIN_DEN: 0.2236229, MRR: 0.6329164, NDCG: 0.3835418, F1: 0.1093195, HIT_RATE: 0.9636524, ARHR_ALL_HITS: 1.1674352, NOVELTY: 0.0059217, AVERAGE_POPULARITY: 0.4403965, DIVERSITY_MEAN_INTER_LIST: 0.9086793, DIVERSITY_HERFINDAHL: 0.9908613, COVERAGE_ITEM: 0.1628551, COVERAGE_ITEM_CORRECT: 0.0925854, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9633700, DIVERSITY_GINI: 0.0204327, SHANNON_ENTROPY: 8.4090960, RATIO_DIVERSITY_HERFINDAHL: 0.9912347, RATIO_DIVERSITY_GINI: 0.0791434, RATIO_SHANNON_ENTROPY: 0.6760459, RATIO_AVERAGE_POPULARITY: 2.2085311, RATIO_NOVELTY: 0.0280307,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 43.1964
# Function value obtained: -0.2229
# Current minimum: -0.2254
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 55, 'alpha': 0.9294783221227146, 'beta': 0.35161696738967346, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.89 sec. Users per second: 982
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 55, 'alpha': 0.9294783221227146, 'beta': 0.35161696738967346, 'normalize_similarity': True} - results: PRECISION: 0.3509380, PRECISION_RECALL_MIN_DEN: 0.3521075, RECALL: 0.0609537, MAP: 0.2125430, MAP_MIN_DEN: 0.2130867, MRR: 0.6183017, NDCG: 0.3693868, F1: 0.1038670, HIT_RATE: 0.9537593, ARHR_ALL_HITS: 1.1276331, NOVELTY: 0.0061265, AVERAGE_POPULARITY: 0.3688574, DIVERSITY_MEAN_INTER_LIST: 0.9371097, DIVERSITY_HERFINDAHL: 0.9937041, COVERAGE_ITEM: 0.1937538, COVERAGE_ITEM_CORRECT: 0.0941359, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9534799, DIVERSITY_GINI: 0.0260616, SHANNON_ENTROPY: 8.8724883, RATIO_DIVERSITY_HERFINDAHL: 0.9940786, RATIO_DIVERSITY_GINI: 0.1009463, RATIO_SHANNON_ENTROPY: 0.7133001, RATIO_AVERAGE_POPULARITY: 1.8497718, RATIO_NOVELTY: 0.0290001,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 45.8524
# Function value obtained: -0.2125
# Current minimum: -0.2254
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 51, 'alpha': 0.8140142545998793, 'beta': 0.9558482490568551, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.46 sec. Users per second: 944
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 51, 'alpha': 0.8140142545998793, 'beta': 0.9558482490568551, 'normalize_similarity': True} - results: PRECISION: 0.0318408, PRECISION_RECALL_MIN_DEN: 0.0319460, RECALL: 0.0055157, MAP: 0.0108428, MAP_MIN_DEN: 0.0108750, MRR: 0.0784374, NDCG: 0.0316307, F1: 0.0094026, HIT_RATE: 0.2394841, ARHR_ALL_HITS: 0.0917324, NOVELTY: 0.0091753, AVERAGE_POPULARITY: 0.0161339, DIVERSITY_MEAN_INTER_LIST: 0.9628280, DIVERSITY_HERFINDAHL: 0.9962757, COVERAGE_ITEM: 0.2313528, COVERAGE_ITEM_CORRECT: 0.0556509, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.2394139, DIVERSITY_GINI: 0.0374746, SHANNON_ENTROPY: 9.4823829, RATIO_DIVERSITY_HERFINDAHL: 0.9966512, RATIO_DIVERSITY_GINI: 0.1451529, RATIO_SHANNON_ENTROPY: 0.7623324, RATIO_AVERAGE_POPULARITY: 0.0809096, RATIO_NOVELTY: 0.0434318,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 49.4642
# Function value obtained: -0.0108
# Current minimum: -0.2254
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.7556472591869856, 'beta': 0.8236336394282383, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.33 sec. Users per second: 952
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'topK': 61, 'alpha': 0.7556472591869856, 'beta': 0.8236336394282383, 'normalize_similarity': True} - results: PRECISION: 0.3294812, PRECISION_RECALL_MIN_DEN: 0.3305879, RECALL: 0.0557032, MAP: 0.1927959, MAP_MIN_DEN: 0.1932740, MRR: 0.5765808, NDCG: 0.3431066, F1: 0.0952954, HIT_RATE: 0.9395427, ARHR_ALL_HITS: 1.0377545, NOVELTY: 0.0057235, AVERAGE_POPULARITY: 0.5242139, DIVERSITY_MEAN_INTER_LIST: 0.9063319, DIVERSITY_HERFINDAHL: 0.9906266, COVERAGE_ITEM: 0.1519464, COVERAGE_ITEM_CORRECT: 0.0612437, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9392674, DIVERSITY_GINI: 0.0124177, SHANNON_ENTROPY: 7.7454694, RATIO_DIVERSITY_HERFINDAHL: 0.9909999, RATIO_DIVERSITY_GINI: 0.0480984, RATIO_SHANNON_ENTROPY: 0.6226939, RATIO_AVERAGE_POPULARITY: 2.6288645, RATIO_NOVELTY: 0.0270925,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 49.7338
# Function value obtained: -0.1928
# Current minimum: -0.2254
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.35098926156215254, 'beta': 0.5583117030224621, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.16 sec. Users per second: 1222
# SearchBayesianSkopt: New best config found. Config 11: {'topK': 56, 'alpha': 0.35098926156215254, 'beta': 0.5583117030224621, 'normalize_similarity': True} - results: PRECISION: 0.3700498, PRECISION_RECALL_MIN_DEN: 0.3714394, RECALL: 0.0644377, MAP: 0.2267042, MAP_MIN_DEN: 0.2273442, MRR: 0.6331907, NDCG: 0.3875291, F1: 0.1097623, HIT_RATE: 0.9604280, ARHR_ALL_HITS: 1.1776522, NOVELTY: 0.0058193, AVERAGE_POPULARITY: 0.4799414, DIVERSITY_MEAN_INTER_LIST: 0.9001976, DIVERSITY_HERFINDAHL: 0.9900132, COVERAGE_ITEM: 0.1727117, COVERAGE_ITEM_CORRECT: 0.1036049, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9601465, DIVERSITY_GINI: 0.0204379, SHANNON_ENTROPY: 8.2764518, RATIO_DIVERSITY_HERFINDAHL: 0.9903863, RATIO_DIVERSITY_GINI: 0.0791634, RATIO_SHANNON_ENTROPY: 0.6653820, RATIO_AVERAGE_POPULARITY: 2.4068435, RATIO_NOVELTY: 0.0275461,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 45.5165
# Function value obtained: -0.2267
# Current minimum: -0.2267
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 66, 'alpha': 0.14589052800299954, 'beta': 0.5432272831812962, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.44 sec. Users per second: 1193
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'topK': 66, 'alpha': 0.14589052800299954, 'beta': 0.5432272831812962, 'normalize_similarity': True} - results: PRECISION: 0.3684523, PRECISION_RECALL_MIN_DEN: 0.3698217, RECALL: 0.0640452, MAP: 0.2251192, MAP_MIN_DEN: 0.2257590, MRR: 0.6275093, NDCG: 0.3852326, F1: 0.1091225, HIT_RATE: 0.9596219, ARHR_ALL_HITS: 1.1686912, NOVELTY: 0.0057904, AVERAGE_POPULARITY: 0.4897054, DIVERSITY_MEAN_INTER_LIST: 0.8953555, DIVERSITY_HERFINDAHL: 0.9895290, COVERAGE_ITEM: 0.1627443, COVERAGE_ITEM_CORRECT: 0.0988427, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9593407, DIVERSITY_GINI: 0.0188715, SHANNON_ENTROPY: 8.1612072, RATIO_DIVERSITY_HERFINDAHL: 0.9899019, RATIO_DIVERSITY_GINI: 0.0730964, RATIO_SHANNON_ENTROPY: 0.6561170, RATIO_AVERAGE_POPULARITY: 2.4558087, RATIO_NOVELTY: 0.0274091,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 41.7181
# Function value obtained: -0.2251
# Current minimum: -0.2267
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.32649805652674274, 'beta': 0.6000742842308181, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.54 sec. Users per second: 1183
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'topK': 60, 'alpha': 0.32649805652674274, 'beta': 0.6000742842308181, 'normalize_similarity': True} - results: PRECISION: 0.3683424, PRECISION_RECALL_MIN_DEN: 0.3697344, RECALL: 0.0639057, MAP: 0.2248040, MAP_MIN_DEN: 0.2254404, MRR: 0.6282323, NDCG: 0.3850779, F1: 0.1089151, HIT_RATE: 0.9615272, ARHR_ALL_HITS: 1.1682745, NOVELTY: 0.0057593, AVERAGE_POPULARITY: 0.5015403, DIVERSITY_MEAN_INTER_LIST: 0.8935903, DIVERSITY_HERFINDAHL: 0.9893525, COVERAGE_ITEM: 0.1683925, COVERAGE_ITEM_CORRECT: 0.1013345, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9612454, DIVERSITY_GINI: 0.0187446, SHANNON_ENTROPY: 8.1124861, RATIO_DIVERSITY_HERFINDAHL: 0.9897254, RATIO_DIVERSITY_GINI: 0.0726047, RATIO_SHANNON_ENTROPY: 0.6522001, RATIO_AVERAGE_POPULARITY: 2.5151591, RATIO_NOVELTY: 0.0272619,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 42.2793
# Function value obtained: -0.2248
# Current minimum: -0.2267
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.24220568864231623, 'beta': 0.19354560153598704, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.62 sec. Users per second: 1418
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'topK': 56, 'alpha': 0.24220568864231623, 'beta': 0.19354560153598704, 'normalize_similarity': True} - results: PRECISION: 0.2929063, PRECISION_RECALL_MIN_DEN: 0.2933658, RECALL: 0.0479275, MAP: 0.1700031, MAP_MIN_DEN: 0.1702482, MRR: 0.5600663, NDCG: 0.3113913, F1: 0.0823760, HIT_RATE: 0.9117690, ARHR_ALL_HITS: 0.9607174, NOVELTY: 0.0064823, AVERAGE_POPULARITY: 0.2138242, DIVERSITY_MEAN_INTER_LIST: 0.9728310, DIVERSITY_HERFINDAHL: 0.9972760, COVERAGE_ITEM: 0.2152943, COVERAGE_ITEM_CORRECT: 0.0901490, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9115018, DIVERSITY_GINI: 0.0319636, SHANNON_ENTROPY: 9.4326741, RATIO_DIVERSITY_HERFINDAHL: 0.9976518, RATIO_DIVERSITY_GINI: 0.1238070, RATIO_SHANNON_ENTROPY: 0.7583361, RATIO_AVERAGE_POPULARITY: 1.0723002, RATIO_NOVELTY: 0.0306841,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 39.5566
# Function value obtained: -0.1700
# Current minimum: -0.2267
# Iteration No: 16 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.25560265489115214, 'beta': 0.9407345126885377, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.16 sec. Users per second: 1123
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'topK': 50, 'alpha': 0.25560265489115214, 'beta': 0.9407345126885377, 'normalize_similarity': True} - results: PRECISION: 0.0888099, PRECISION_RECALL_MIN_DEN: 0.0892632, RECALL: 0.0156088, MAP: 0.0371313, MAP_MIN_DEN: 0.0372699, MRR: 0.2234591, NDCG: 0.0936320, F1: 0.0265511, HIT_RATE: 0.5446285, ARHR_ALL_HITS: 0.2860550, NOVELTY: 0.0073243, AVERAGE_POPULARITY: 0.1032360, DIVERSITY_MEAN_INTER_LIST: 0.9421252, DIVERSITY_HERFINDAHL: 0.9942056, COVERAGE_ITEM: 0.2230467, COVERAGE_ITEM_CORRECT: 0.0832826, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.5444689, DIVERSITY_GINI: 0.0300898, SHANNON_ENTROPY: 8.9995911, RATIO_DIVERSITY_HERFINDAHL: 0.9945803, RATIO_DIVERSITY_GINI: 0.1165489, RATIO_SHANNON_ENTROPY: 0.7235185, RATIO_AVERAGE_POPULARITY: 0.5177148, RATIO_NOVELTY: 0.0346697,
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 41.7989
# Function value obtained: -0.0371
# Current minimum: -0.2267
# Iteration No: 17 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.8067029040263461, 'beta': 0.16905947396523893, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.12 sec. Users per second: 1348
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'topK': 60, 'alpha': 0.8067029040263461, 'beta': 0.16905947396523893, 'normalize_similarity': True} - results: PRECISION: 0.2659607, PRECISION_RECALL_MIN_DEN: 0.2663565, RECALL: 0.0425364, MAP: 0.1540411, MAP_MIN_DEN: 0.1542236, MRR: 0.5365979, NDCG: 0.2867649, F1: 0.0733427, HIT_RATE: 0.8816503, ARHR_ALL_HITS: 0.8952806, NOVELTY: 0.0067051, AVERAGE_POPULARITY: 0.1715597, DIVERSITY_MEAN_INTER_LIST: 0.9739544, DIVERSITY_HERFINDAHL: 0.9973883, COVERAGE_ITEM: 0.2722742, COVERAGE_ITEM_CORRECT: 0.0895952, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8813919, DIVERSITY_GINI: 0.0412067, SHANNON_ENTROPY: 9.6786397, RATIO_DIVERSITY_HERFINDAHL: 0.9977642, RATIO_DIVERSITY_GINI: 0.1596089, RATIO_SHANNON_ENTROPY: 0.7781104, RATIO_AVERAGE_POPULARITY: 0.8603497, RATIO_NOVELTY: 0.0317387,
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 40.2492
# Function value obtained: -0.1540
# Current minimum: -0.2267
# Iteration No: 18 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.6231005214350529, 'beta': 0.1442089385313218, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.47 sec. Users per second: 1441
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'topK': 56, 'alpha': 0.6231005214350529, 'beta': 0.1442089385313218, 'normalize_similarity': True} - results: PRECISION: 0.2616811, PRECISION_RECALL_MIN_DEN: 0.2620897, RECALL: 0.0416497, MAP: 0.1510287, MAP_MIN_DEN: 0.1512173, MRR: 0.5311192, NDCG: 0.2823010, F1: 0.0718618, HIT_RATE: 0.8774000, ARHR_ALL_HITS: 0.8814960, NOVELTY: 0.0066584, AVERAGE_POPULARITY: 0.1729138, DIVERSITY_MEAN_INTER_LIST: 0.9719505, DIVERSITY_HERFINDAHL: 0.9971879, COVERAGE_ITEM: 0.2571571, COVERAGE_ITEM_CORRECT: 0.0865496, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8771429, DIVERSITY_GINI: 0.0368195, SHANNON_ENTROPY: 9.5374123, RATIO_DIVERSITY_HERFINDAHL: 0.9975638, RATIO_DIVERSITY_GINI: 0.1426156, RATIO_SHANNON_ENTROPY: 0.7667564, RATIO_AVERAGE_POPULARITY: 0.8671400, RATIO_NOVELTY: 0.0315178,
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 40.4679
# Function value obtained: -0.1510
# Current minimum: -0.2267
# Iteration No: 19 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 65, 'alpha': 0.5103958806120827, 'beta': 0.431604595431197, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.65 sec. Users per second: 1282
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'topK': 65, 'alpha': 0.5103958806120827, 'beta': 0.431604595431197, 'normalize_similarity': True} - results: PRECISION: 0.3667448, PRECISION_RECALL_MIN_DEN: 0.3682037, RECALL: 0.0643667, MAP: 0.2240122, MAP_MIN_DEN: 0.2247097, MRR: 0.6332818, NDCG: 0.3846919, F1: 0.1095130, HIT_RATE: 0.9626264, ARHR_ALL_HITS: 1.1701149, NOVELTY: 0.0058937, AVERAGE_POPULARITY: 0.4509288, DIVERSITY_MEAN_INTER_LIST: 0.9057311, DIVERSITY_HERFINDAHL: 0.9905665, COVERAGE_ITEM: 0.1604740, COVERAGE_ITEM_CORRECT: 0.0935821, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9623443, DIVERSITY_GINI: 0.0199559, SHANNON_ENTROPY: 8.3536395, RATIO_DIVERSITY_HERFINDAHL: 0.9909398, RATIO_DIVERSITY_GINI: 0.0772967, RATIO_SHANNON_ENTROPY: 0.6715875, RATIO_AVERAGE_POPULARITY: 2.2613491, RATIO_NOVELTY: 0.0278980,
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 41.2210
# Function value obtained: -0.2240
# Current minimum: -0.2267
# Iteration No: 20 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 51, 'alpha': 0.8542150255356403, 'beta': 0.04870328648198664, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.34 sec. Users per second: 1461
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'topK': 51, 'alpha': 0.8542150255356403, 'beta': 0.04870328648198664, 'normalize_similarity': True} - results: PRECISION: 0.2225854, PRECISION_RECALL_MIN_DEN: 0.2229000, RECALL: 0.0346941, MAP: 0.1277641, MAP_MIN_DEN: 0.1279443, MRR: 0.4885280, NDCG: 0.2449159, F1: 0.0600312, HIT_RATE: 0.8163564, ARHR_ALL_HITS: 0.7770073, NOVELTY: 0.0068017, AVERAGE_POPULARITY: 0.1627266, DIVERSITY_MEAN_INTER_LIST: 0.9738365, DIVERSITY_HERFINDAHL: 0.9973765, COVERAGE_ITEM: 0.2646880, COVERAGE_ITEM_CORRECT: 0.0709895, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8161172, DIVERSITY_GINI: 0.0443273, SHANNON_ENTROPY: 9.7581717, RATIO_DIVERSITY_HERFINDAHL: 0.9977524, RATIO_DIVERSITY_GINI: 0.1716960, RATIO_SHANNON_ENTROPY: 0.7845043, RATIO_AVERAGE_POPULARITY: 0.8160526, RATIO_NOVELTY: 0.0321960,
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 41.1031
# Function value obtained: -0.1278
# Current minimum: -0.2267
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 55, 'alpha': 0.32697860553875197, 'beta': 0.8178322422691375, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.37 sec. Users per second: 1103
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'topK': 55, 'alpha': 0.32697860553875197, 'beta': 0.8178322422691375, 'normalize_similarity': True} - results: PRECISION: 0.3062876, PRECISION_RECALL_MIN_DEN: 0.3072758, RECALL: 0.0512542, MAP: 0.1733450, MAP_MIN_DEN: 0.1737520, MRR: 0.5462169, NDCG: 0.3179803, F1: 0.0878137, HIT_RATE: 0.9289169, ARHR_ALL_HITS: 0.9594050, NOVELTY: 0.0058174, AVERAGE_POPULARITY: 0.4602526, DIVERSITY_MEAN_INTER_LIST: 0.9228740, DIVERSITY_HERFINDAHL: 0.9922806, COVERAGE_ITEM: 0.1677834, COVERAGE_ITEM_CORRECT: 0.0784097, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9286447, DIVERSITY_GINI: 0.0157534, SHANNON_ENTROPY: 8.1046759, RATIO_DIVERSITY_HERFINDAHL: 0.9926546, RATIO_DIVERSITY_GINI: 0.0610187, RATIO_SHANNON_ENTROPY: 0.6515722, RATIO_AVERAGE_POPULARITY: 2.3081065, RATIO_NOVELTY: 0.0275370,
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 42.7731
# Function value obtained: -0.1733
# Current minimum: -0.2267
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.736057793464704, 'beta': 0.18251918967447314, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.66 sec. Users per second: 1413
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'topK': 60, 'alpha': 0.736057793464704, 'beta': 0.18251918967447314, 'normalize_similarity': True} - results: PRECISION: 0.2738385, PRECISION_RECALL_MIN_DEN: 0.2742593, RECALL: 0.0442366, MAP: 0.1586841, MAP_MIN_DEN: 0.1588867, MRR: 0.5433855, NDCG: 0.2940308, F1: 0.0761687, HIT_RATE: 0.8933753, ARHR_ALL_HITS: 0.9147349, NOVELTY: 0.0066443, AVERAGE_POPULARITY: 0.1794161, DIVERSITY_MEAN_INTER_LIST: 0.9741189, DIVERSITY_HERFINDAHL: 0.9974047, COVERAGE_ITEM: 0.2599812, COVERAGE_ITEM_CORRECT: 0.0903151, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8931136, DIVERSITY_GINI: 0.0383839, SHANNON_ENTROPY: 9.6198588, RATIO_DIVERSITY_HERFINDAHL: 0.9977807, RATIO_DIVERSITY_GINI: 0.1486750, RATIO_SHANNON_ENTROPY: 0.7733847, RATIO_AVERAGE_POPULARITY: 0.8997482, RATIO_NOVELTY: 0.0314511,
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 39.5714
# Function value obtained: -0.1587
# Current minimum: -0.2267
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.9535067977677266, 'beta': 0.741019617188522, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.52 sec. Users per second: 1090
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 60, 'alpha': 0.9535067977677266, 'beta': 0.741019617188522, 'normalize_similarity': True} - results: PRECISION: 0.3547706, PRECISION_RECALL_MIN_DEN: 0.3561034, RECALL: 0.0611989, MAP: 0.2132286, MAP_MIN_DEN: 0.2138225, MRR: 0.6075271, NDCG: 0.3700014, F1: 0.1043902, HIT_RATE: 0.9541258, ARHR_ALL_HITS: 1.1199557, NOVELTY: 0.0057277, AVERAGE_POPULARITY: 0.5224080, DIVERSITY_MEAN_INTER_LIST: 0.9041163, DIVERSITY_HERFINDAHL: 0.9904050, COVERAGE_ITEM: 0.1577053, COVERAGE_ITEM_CORRECT: 0.0682208, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9538462, DIVERSITY_GINI: 0.0146818, SHANNON_ENTROPY: 7.9278437, RATIO_DIVERSITY_HERFINDAHL: 0.9907783, RATIO_DIVERSITY_GINI: 0.0568681, RATIO_SHANNON_ENTROPY: 0.6373558, RATIO_AVERAGE_POPULARITY: 2.6198076, RATIO_NOVELTY: 0.0271121,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 42.5787
# Function value obtained: -0.2132
# Current minimum: -0.2267
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.8803684591664868, 'beta': 0.40798074206988966, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.62 sec. Users per second: 1285
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'topK': 61, 'alpha': 0.8803684591664868, 'beta': 0.40798074206988966, 'normalize_similarity': True} - results: PRECISION: 0.3609556, PRECISION_RECALL_MIN_DEN: 0.3624074, RECALL: 0.0634568, MAP: 0.2199254, MAP_MIN_DEN: 0.2205294, MRR: 0.6259748, NDCG: 0.3790630, F1: 0.1079379, HIT_RATE: 0.9597684, ARHR_ALL_HITS: 1.1541775, NOVELTY: 0.0059981, AVERAGE_POPULARITY: 0.4128681, DIVERSITY_MEAN_INTER_LIST: 0.9218654, DIVERSITY_HERFINDAHL: 0.9921798, COVERAGE_ITEM: 0.1790797, COVERAGE_ITEM_CORRECT: 0.0929730, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9594872, DIVERSITY_GINI: 0.0228166, SHANNON_ENTROPY: 8.6104232, RATIO_DIVERSITY_HERFINDAHL: 0.9925537, RATIO_DIVERSITY_GINI: 0.0883770, RATIO_SHANNON_ENTROPY: 0.6922315, RATIO_AVERAGE_POPULARITY: 2.0704796, RATIO_NOVELTY: 0.0283923,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 41.1842
# Function value obtained: -0.2199
# Current minimum: -0.2267
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 65, 'alpha': 0.43259582853948053, 'beta': 0.2505580155332668, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.88 sec. Users per second: 1381
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 65, 'alpha': 0.43259582853948053, 'beta': 0.2505580155332668, 'normalize_similarity': True} - results: PRECISION: 0.3204895, PRECISION_RECALL_MIN_DEN: 0.3214151, RECALL: 0.0553878, MAP: 0.1886961, MAP_MIN_DEN: 0.1891576, MRR: 0.5917552, NDCG: 0.3390536, F1: 0.0944521, HIT_RATE: 0.9419610, ARHR_ALL_HITS: 1.0402268, NOVELTY: 0.0063112, AVERAGE_POPULARITY: 0.2726871, DIVERSITY_MEAN_INTER_LIST: 0.9693707, DIVERSITY_HERFINDAHL: 0.9969300, COVERAGE_ITEM: 0.1832327, COVERAGE_ITEM_CORRECT: 0.0939144, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9416850, DIVERSITY_GINI: 0.0284316, SHANNON_ENTROPY: 9.2839544, RATIO_DIVERSITY_HERFINDAHL: 0.9973057, RATIO_DIVERSITY_GINI: 0.1101261, RATIO_SHANNON_ENTROPY: 0.7463798, RATIO_AVERAGE_POPULARITY: 1.3674901, RATIO_NOVELTY: 0.0298743,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 40.0189
# Function value obtained: -0.1887
# Current minimum: -0.2267
# Iteration No: 26 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.11159108503842866, 'beta': 0.4831077684647668, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.83 sec. Users per second: 1260
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'topK': 56, 'alpha': 0.11159108503842866, 'beta': 0.4831077684647668, 'normalize_similarity': True} - results: PRECISION: 0.3686282, PRECISION_RECALL_MIN_DEN: 0.3699640, RECALL: 0.0642610, MAP: 0.2248198, MAP_MIN_DEN: 0.2254134, MRR: 0.6294716, NDCG: 0.3854935, F1: 0.1094433, HIT_RATE: 0.9607211, ARHR_ALL_HITS: 1.1701396, NOVELTY: 0.0058682, AVERAGE_POPULARITY: 0.4612121, DIVERSITY_MEAN_INTER_LIST: 0.9038928, DIVERSITY_HERFINDAHL: 0.9903827, COVERAGE_ITEM: 0.1669528, COVERAGE_ITEM_CORRECT: 0.0999502, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9604396, DIVERSITY_GINI: 0.0207832, SHANNON_ENTROPY: 8.3558716, RATIO_DIVERSITY_HERFINDAHL: 0.9907559, RATIO_DIVERSITY_GINI: 0.0805012, RATIO_SHANNON_ENTROPY: 0.6717670, RATIO_AVERAGE_POPULARITY: 2.3129187, RATIO_NOVELTY: 0.0277775,
#
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 40.9428
# Function value obtained: -0.2248
# Current minimum: -0.2267
# Iteration No: 27 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.9250710421586982, 'beta': 0.6945137381434542, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.13 sec. Users per second: 1125
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'topK': 56, 'alpha': 0.9250710421586982, 'beta': 0.6945137381434542, 'normalize_similarity': True} - results: PRECISION: 0.3616518, PRECISION_RECALL_MIN_DEN: 0.3630008, RECALL: 0.0626872, MAP: 0.2194364, MAP_MIN_DEN: 0.2200416, MRR: 0.6196776, NDCG: 0.3780378, F1: 0.1068529, HIT_RATE: 0.9580830, ARHR_ALL_HITS: 1.1466526, NOVELTY: 0.0057497, AVERAGE_POPULARITY: 0.5112115, DIVERSITY_MEAN_INTER_LIST: 0.8991007, DIVERSITY_HERFINDAHL: 0.9899035, COVERAGE_ITEM: 0.1620245, COVERAGE_ITEM_CORRECT: 0.0798494, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9578022, DIVERSITY_GINI: 0.0167898, SHANNON_ENTROPY: 8.0399873, RATIO_DIVERSITY_HERFINDAHL: 0.9902766, RATIO_DIVERSITY_GINI: 0.0650333, RATIO_SHANNON_ENTROPY: 0.6463716, RATIO_AVERAGE_POPULARITY: 2.5636589, RATIO_NOVELTY: 0.0272163,
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 42.5298
# Function value obtained: -0.2194
# Current minimum: -0.2267
# Iteration No: 28 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 51, 'alpha': 0.5881195526380723, 'beta': 0.5495572171567521, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.24 sec. Users per second: 1214
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'topK': 51, 'alpha': 0.5881195526380723, 'beta': 0.5495572171567521, 'normalize_similarity': True} - results: PRECISION: 0.3695149, PRECISION_RECALL_MIN_DEN: 0.3709136, RECALL: 0.0646401, MAP: 0.2264740, MAP_MIN_DEN: 0.2271262, MRR: 0.6339512, NDCG: 0.3873872, F1: 0.1100321, HIT_RATE: 0.9617470, ARHR_ALL_HITS: 1.1781267, NOVELTY: 0.0058620, AVERAGE_POPULARITY: 0.4656681, DIVERSITY_MEAN_INTER_LIST: 0.9042497, DIVERSITY_HERFINDAHL: 0.9904183, COVERAGE_ITEM: 0.1778061, COVERAGE_ITEM_CORRECT: 0.1057644, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9614652, DIVERSITY_GINI: 0.0218314, SHANNON_ENTROPY: 8.3919032, RATIO_DIVERSITY_HERFINDAHL: 0.9907916, RATIO_DIVERSITY_GINI: 0.0845611, RATIO_SHANNON_ENTROPY: 0.6746637, RATIO_AVERAGE_POPULARITY: 2.3352645, RATIO_NOVELTY: 0.0277480,
#
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 41.1390
# Function value obtained: -0.2265
# Current minimum: -0.2267
# Iteration No: 29 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 65, 'alpha': 0.0885670134755261, 'beta': 0.527394386568812, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.04 sec. Users per second: 1133
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'topK': 65, 'alpha': 0.0885670134755261, 'beta': 0.527394386568812, 'normalize_similarity': True} - results: PRECISION: 0.3687601, PRECISION_RECALL_MIN_DEN: 0.3701714, RECALL: 0.0640978, MAP: 0.2252276, MAP_MIN_DEN: 0.2258558, MRR: 0.6285424, NDCG: 0.3855889, F1: 0.1092124, HIT_RATE: 0.9606478, ARHR_ALL_HITS: 1.1699560, NOVELTY: 0.0058036, AVERAGE_POPULARITY: 0.4848399, DIVERSITY_MEAN_INTER_LIST: 0.8961663, DIVERSITY_HERFINDAHL: 0.9896101, COVERAGE_ITEM: 0.1622460, COVERAGE_ITEM_CORRECT: 0.0988981, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9603663, DIVERSITY_GINI: 0.0190518, SHANNON_ENTROPY: 8.1851417, RATIO_DIVERSITY_HERFINDAHL: 0.9899831, RATIO_DIVERSITY_GINI: 0.0737947, RATIO_SHANNON_ENTROPY: 0.6580412, RATIO_AVERAGE_POPULARITY: 2.4314089, RATIO_NOVELTY: 0.0274715,
#
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 42.8013
# Function value obtained: -0.2252
# Current minimum: -0.2267
# Iteration No: 30 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 56, 'alpha': 0.9554721739776058, 'beta': 0.5356482570953874, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.26 sec. Users per second: 1212
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'topK': 56, 'alpha': 0.9554721739776058, 'beta': 0.5356482570953874, 'normalize_similarity': True} - results: PRECISION: 0.3683790, PRECISION_RECALL_MIN_DEN: 0.3698378, RECALL: 0.0644991, MAP: 0.2249935, MAP_MIN_DEN: 0.2256106, MRR: 0.6303271, NDCG: 0.3855278, F1: 0.1097773, HIT_RATE: 0.9606478, ARHR_ALL_HITS: 1.1707038, NOVELTY: 0.0058958, AVERAGE_POPULARITY: 0.4586797, DIVERSITY_MEAN_INTER_LIST: 0.9059557, DIVERSITY_HERFINDAHL: 0.9905889, COVERAGE_ITEM: 0.1761449, COVERAGE_ITEM_CORRECT: 0.0941913, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9603663, DIVERSITY_GINI: 0.0214959, SHANNON_ENTROPY: 8.4027883, RATIO_DIVERSITY_HERFINDAHL: 0.9909623, RATIO_DIVERSITY_GINI: 0.0832616, RATIO_SHANNON_ENTROPY: 0.6755388, RATIO_AVERAGE_POPULARITY: 2.3002189, RATIO_NOVELTY: 0.0279081,
#
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 42.5413
# Function value obtained: -0.2250
# Current minimum: -0.2267
# Iteration No: 31 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 66, 'alpha': 1.0, 'beta': 0.7801618433888122, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.05 sec. Users per second: 1045
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'topK': 66, 'alpha': 1.0, 'beta': 0.7801618433888122, 'normalize_similarity': True} - results: PRECISION: 0.3443866, PRECISION_RECALL_MIN_DEN: 0.3455204, RECALL: 0.0586654, MAP: 0.2047488, MAP_MIN_DEN: 0.2052321, MRR: 0.5884591, NDCG: 0.3580431, F1: 0.1002529, HIT_RATE: 0.9476770, ARHR_ALL_HITS: 1.0809248, NOVELTY: 0.0057293, AVERAGE_POPULARITY: 0.5341490, DIVERSITY_MEAN_INTER_LIST: 0.9020336, DIVERSITY_HERFINDAHL: 0.9901967, COVERAGE_ITEM: 0.1509497, COVERAGE_ITEM_CORRECT: 0.0548203, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9473993, DIVERSITY_GINI: 0.0126582, SHANNON_ENTROPY: 7.7535092, RATIO_DIVERSITY_HERFINDAHL: 0.9905700, RATIO_DIVERSITY_GINI: 0.0490299, RATIO_SHANNON_ENTROPY: 0.6233403, RATIO_AVERAGE_POPULARITY: 2.6786876, RATIO_NOVELTY: 0.0271199,
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 43.7326
# Function value obtained: -0.2047
# Current minimum: -0.2267
# Iteration No: 32 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 1.0, 'beta': 0.6358060189754955, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.92 sec. Users per second: 1145
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'topK': 50, 'alpha': 1.0, 'beta': 0.6358060189754955, 'normalize_similarity': True} - results: PRECISION: 0.3648322, PRECISION_RECALL_MIN_DEN: 0.3661723, RECALL: 0.0636317, MAP: 0.2224360, MAP_MIN_DEN: 0.2230254, MRR: 0.6267833, NDCG: 0.3821213, F1: 0.1083633, HIT_RATE: 0.9620402, ARHR_ALL_HITS: 1.1612154, NOVELTY: 0.0058355, AVERAGE_POPULARITY: 0.4839930, DIVERSITY_MEAN_INTER_LIST: 0.9049357, DIVERSITY_HERFINDAHL: 0.9904869, COVERAGE_ITEM: 0.1703860, COVERAGE_ITEM_CORRECT: 0.0857190, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9617582, DIVERSITY_GINI: 0.0196530, SHANNON_ENTROPY: 8.2663211, RATIO_DIVERSITY_HERFINDAHL: 0.9908603, RATIO_DIVERSITY_GINI: 0.0761233, RATIO_SHANNON_ENTROPY: 0.6645676, RATIO_AVERAGE_POPULARITY: 2.4271616, RATIO_NOVELTY: 0.0276224,
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 43.0194
# Function value obtained: -0.2224
# Current minimum: -0.2267
# Iteration No: 33 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.0, 'beta': 0.4270534489589333, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.42 sec. Users per second: 1310
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'topK': 50, 'alpha': 0.0, 'beta': 0.4270534489589333, 'normalize_similarity': True} - results: PRECISION: 0.3656163, PRECISION_RECALL_MIN_DEN: 0.3670626, RECALL: 0.0642261, MAP: 0.2227488, MAP_MIN_DEN: 0.2233739, MRR: 0.6287142, NDCG: 0.3828435, F1: 0.1092591, HIT_RATE: 0.9618203, ARHR_ALL_HITS: 1.1629810, NOVELTY: 0.0059466, AVERAGE_POPULARITY: 0.4317539, DIVERSITY_MEAN_INTER_LIST: 0.9161568, DIVERSITY_HERFINDAHL: 0.9916090, COVERAGE_ITEM: 0.1737638, COVERAGE_ITEM_CORRECT: 0.1006147, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9615385, DIVERSITY_GINI: 0.0227399, SHANNON_ENTROPY: 8.5585930, RATIO_DIVERSITY_HERFINDAHL: 0.9919827, RATIO_DIVERSITY_GINI: 0.0880799, RATIO_SHANNON_ENTROPY: 0.6880647, RATIO_AVERAGE_POPULARITY: 2.1651895, RATIO_NOVELTY: 0.0281486,
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 40.9928
# Function value obtained: -0.2227
# Current minimum: -0.2267
# Iteration No: 34 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.0, 'beta': 0.49655109910902384, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.80 sec. Users per second: 1264
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'topK': 50, 'alpha': 0.0, 'beta': 0.49655109910902384, 'normalize_similarity': True} - results: PRECISION: 0.3678367, PRECISION_RECALL_MIN_DEN: 0.3691840, RECALL: 0.0642539, MAP: 0.2239416, MAP_MIN_DEN: 0.2245025, MRR: 0.6273100, NDCG: 0.3843304, F1: 0.1093981, HIT_RATE: 0.9603547, ARHR_ALL_HITS: 1.1656999, NOVELTY: 0.0058820, AVERAGE_POPULARITY: 0.4559681, DIVERSITY_MEAN_INTER_LIST: 0.9076382, DIVERSITY_HERFINDAHL: 0.9907572, COVERAGE_ITEM: 0.1728224, COVERAGE_ITEM_CORRECT: 0.1019436, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9600733, DIVERSITY_GINI: 0.0218489, SHANNON_ENTROPY: 8.4305044, RATIO_DIVERSITY_HERFINDAHL: 0.9911306, RATIO_DIVERSITY_GINI: 0.0846290, RATIO_SHANNON_ENTROPY: 0.6777670, RATIO_AVERAGE_POPULARITY: 2.2866205, RATIO_NOVELTY: 0.0278425,
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 40.8585
# Function value obtained: -0.2239
# Current minimum: -0.2267
# Iteration No: 35 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 50, 'alpha': 0.0, 'beta': 0.2905687456079028, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.54 sec. Users per second: 1295
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'topK': 50, 'alpha': 0.0, 'beta': 0.2905687456079028, 'normalize_similarity': True} - results: PRECISION: 0.3467243, PRECISION_RECALL_MIN_DEN: 0.3478720, RECALL: 0.0604436, MAP: 0.2088969, MAP_MIN_DEN: 0.2095008, MRR: 0.6160638, NDCG: 0.3654841, F1: 0.1029417, HIT_RATE: 0.9547853, ARHR_ALL_HITS: 1.1168044, NOVELTY: 0.0060941, AVERAGE_POPULARITY: 0.3751402, DIVERSITY_MEAN_INTER_LIST: 0.9335857, DIVERSITY_HERFINDAHL: 0.9933517, COVERAGE_ITEM: 0.1801318, COVERAGE_ITEM_CORRECT: 0.0920870, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9545055, DIVERSITY_GINI: 0.0247150, SHANNON_ENTROPY: 8.8181610, RATIO_DIVERSITY_HERFINDAHL: 0.9937261, RATIO_DIVERSITY_GINI: 0.0957304, RATIO_SHANNON_ENTROPY: 0.7089325, RATIO_AVERAGE_POPULARITY: 1.8812791, RATIO_NOVELTY: 0.0288465,
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 40.7902
# Function value obtained: -0.2089
# Current minimum: -0.2267
# Iteration No: 36 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 66, 'alpha': 1.0, 'beta': 0.6331286115495369, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.14 sec. Users per second: 1124
# SearchBayesianSkopt: Config 35 is suboptimal. Config: {'topK': 66, 'alpha': 1.0, 'beta': 0.6331286115495369, 'normalize_similarity': True} - results: PRECISION: 0.3651693, PRECISION_RECALL_MIN_DEN: 0.3665072, RECALL: 0.0633465, MAP: 0.2229948, MAP_MIN_DEN: 0.2236021, MRR: 0.6296687, NDCG: 0.3828208, F1: 0.1079643, HIT_RATE: 0.9597684, ARHR_ALL_HITS: 1.1644848, NOVELTY: 0.0057731, AVERAGE_POPULARITY: 0.5068227, DIVERSITY_MEAN_INTER_LIST: 0.8927599, DIVERSITY_HERFINDAHL: 0.9892694, COVERAGE_ITEM: 0.1660114, COVERAGE_ITEM_CORRECT: 0.0807907, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9594872, DIVERSITY_GINI: 0.0174014, SHANNON_ENTROPY: 8.0452855, RATIO_DIVERSITY_HERFINDAHL: 0.9896423, RATIO_DIVERSITY_GINI: 0.0674020, RATIO_SHANNON_ENTROPY: 0.6467975, RATIO_AVERAGE_POPULARITY: 2.5416494, RATIO_NOVELTY: 0.0273271,
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 43.5400
# Function value obtained: -0.2230
# Current minimum: -0.2267
# Iteration No: 37 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.0, 'beta': 0.7219853989054117, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.17 sec. Users per second: 1121
# SearchBayesianSkopt: Config 36 is suboptimal. Config: {'topK': 61, 'alpha': 0.0, 'beta': 0.7219853989054117, 'normalize_similarity': True} - results: PRECISION: 0.3506156, PRECISION_RECALL_MIN_DEN: 0.3517641, RECALL: 0.0594882, MAP: 0.2089678, MAP_MIN_DEN: 0.2094660, MRR: 0.5984060, NDCG: 0.3643578, F1: 0.1017181, HIT_RATE: 0.9505350, ARHR_ALL_HITS: 1.1000301, NOVELTY: 0.0056798, AVERAGE_POPULARITY: 0.5152276, DIVERSITY_MEAN_INTER_LIST: 0.9126747, DIVERSITY_HERFINDAHL: 0.9912608, COVERAGE_ITEM: 0.1527216, COVERAGE_ITEM_CORRECT: 0.0836702, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9502564, DIVERSITY_GINI: 0.0151656, SHANNON_ENTROPY: 8.0079132, RATIO_DIVERSITY_HERFINDAHL: 0.9916344, RATIO_DIVERSITY_GINI: 0.0587420, RATIO_SHANNON_ENTROPY: 0.6437930, RATIO_AVERAGE_POPULARITY: 2.5837989, RATIO_NOVELTY: 0.0268858,
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 42.9881
# Function value obtained: -0.2090
# Current minimum: -0.2267
# ...
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.18 sec. Users per second: 1120
# SearchBayesianSkopt: Config 88 is suboptimal. Config: {'topK': 50, 'alpha': 0.7178670944221012, 'beta': 0.6627362287212518, 'normalize_similarity': True} - results: PRECISION: 0.3637036, PRECISION_RECALL_MIN_DEN: 0.3650877, RECALL: 0.0633938, MAP: 0.2211807, MAP_MIN_DEN: 0.2218158, MRR: 0.6247702, NDCG: 0.3808987, F1: 0.1079686, HIT_RATE: 0.9615272, ARHR_ALL_HITS: 1.1571244, NOVELTY: 0.0057739, AVERAGE_POPULARITY: 0.4972103, DIVERSITY_MEAN_INTER_LIST: 0.9004781, DIVERSITY_HERFINDAHL: 0.9900412, COVERAGE_ITEM: 0.1695000, COVERAGE_ITEM_CORRECT: 0.0958525, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9612454, DIVERSITY_GINI: 0.0191577, SHANNON_ENTROPY: 8.1805739, RATIO_DIVERSITY_HERFINDAHL: 0.9904144, RATIO_DIVERSITY_GINI: 0.0742049, RATIO_SHANNON_ENTROPY: 0.6576740, RATIO_AVERAGE_POPULARITY: 2.4934447, RATIO_NOVELTY: 0.0273310,
#
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 45.3694
# Function value obtained: -0.2212
# Current minimum: -0.2269
# Iteration No: 90 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 66, 'alpha': 0.026064606879101178, 'beta': 0.24140056925507264, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.29 sec. Users per second: 1326
# SearchBayesianSkopt: Config 89 is suboptimal. Config: {'topK': 66, 'alpha': 0.026064606879101178, 'beta': 0.24140056925507264, 'normalize_similarity': True} - results: PRECISION: 0.3342958, PRECISION_RECALL_MIN_DEN: 0.3353644, RECALL: 0.0581289, MAP: 0.1990912, MAP_MIN_DEN: 0.1996328, MRR: 0.6069188, NDCG: 0.3533625, F1: 0.0990369, HIT_RATE: 0.9495090, ARHR_ALL_HITS: 1.0829608, NOVELTY: 0.0061765, AVERAGE_POPULARITY: 0.3309542, DIVERSITY_MEAN_INTER_LIST: 0.9556326, DIVERSITY_HERFINDAHL: 0.9955563, COVERAGE_ITEM: 0.1705521, COVERAGE_ITEM_CORRECT: 0.0877125, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9492308, DIVERSITY_GINI: 0.0248649, SHANNON_ENTROPY: 8.9987610, RATIO_DIVERSITY_HERFINDAHL: 0.9959315, RATIO_DIVERSITY_GINI: 0.0963108, RATIO_SHANNON_ENTROPY: 0.7234518, RATIO_AVERAGE_POPULARITY: 1.6596923, RATIO_NOVELTY: 0.0292365,
#
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 43.7163
# Function value obtained: -0.1991
# Current minimum: -0.2269
# Iteration No: 91 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'alpha': 0.6249724404613112, 'beta': 0.5435236510127593, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.80 sec. Users per second: 1156
# SearchBayesianSkopt: Config 90 is suboptimal. Config: {'topK': 61, 'alpha': 0.6249724404613112, 'beta': 0.5435236510127593, 'normalize_similarity': True} - results: PRECISION: 0.3698227, PRECISION_RECALL_MIN_DEN: 0.3712689, RECALL: 0.0646359, MAP: 0.2265808, MAP_MIN_DEN: 0.2272695, MRR: 0.6346202, NDCG: 0.3876429, F1: 0.1100395, HIT_RATE: 0.9617470, ARHR_ALL_HITS: 1.1786042, NOVELTY: 0.0058295, AVERAGE_POPULARITY: 0.4774323, DIVERSITY_MEAN_INTER_LIST: 0.8973134, DIVERSITY_HERFINDAHL: 0.9897248, COVERAGE_ITEM: 0.1694446, COVERAGE_ITEM_CORRECT: 0.1004485, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9614652, DIVERSITY_GINI: 0.0199462, SHANNON_ENTROPY: 8.2505398, RATIO_DIVERSITY_HERFINDAHL: 0.9900978, RATIO_DIVERSITY_GINI: 0.0772590, RATIO_SHANNON_ENTROPY: 0.6632988, RATIO_AVERAGE_POPULARITY: 2.3942605, RATIO_NOVELTY: 0.0275944,
#
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 45.3895
# Function value obtained: -0.2266
# Current minimum: -0.2269
# Iteration No: 92 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 66, 'alpha': 0.9975537053753768, 'beta': 0.36958202125126544, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.00 sec. Users per second: 1241
# SearchBayesianSkopt: Config 91 is suboptimal. Config: {'topK': 66, 'alpha': 0.9975537053753768, 'beta': 0.36958202125126544, 'normalize_similarity': True} - results: PRECISION: 0.3547633, PRECISION_RECALL_MIN_DEN: 0.3560808, RECALL: 0.0616525, MAP: 0.2159309, MAP_MIN_DEN: 0.2164758, MRR: 0.6223189, NDCG: 0.3733801, F1: 0.1050491, HIT_RATE: 0.9560311, ARHR_ALL_HITS: 1.1394330, NOVELTY: 0.0060521, AVERAGE_POPULARITY: 0.3964387, DIVERSITY_MEAN_INTER_LIST: 0.9259643, DIVERSITY_HERFINDAHL: 0.9925896, COVERAGE_ITEM: 0.1833435, COVERAGE_ITEM_CORRECT: 0.0873803, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9557509, DIVERSITY_GINI: 0.0235098, SHANNON_ENTROPY: 8.6735342, RATIO_DIVERSITY_HERFINDAHL: 0.9929638, RATIO_DIVERSITY_GINI: 0.0910621, RATIO_SHANNON_ENTROPY: 0.6973053, RATIO_AVERAGE_POPULARITY: 1.9880883, RATIO_NOVELTY: 0.0286477,
#
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 44.1252
# Function value obtained: -0.2159
# Current minimum: -0.2269
# Iteration No: 93 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.6071059270715014, 'beta': 0.553718330482973, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.05 sec. Users per second: 1132
# SearchBayesianSkopt: New best config found. Config 92: {'topK': 60, 'alpha': 0.6071059270715014, 'beta': 0.553718330482973, 'normalize_similarity': True} - results: PRECISION: 0.3703136, PRECISION_RECALL_MIN_DEN: 0.3717670, RECALL: 0.0647321, MAP: 0.2269787, MAP_MIN_DEN: 0.2276781, MRR: 0.6351583, NDCG: 0.3881356, F1: 0.1102007, HIT_RATE: 0.9621867, ARHR_ALL_HITS: 1.1800192, NOVELTY: 0.0058279, AVERAGE_POPULARITY: 0.4777839, DIVERSITY_MEAN_INTER_LIST: 0.8984756, DIVERSITY_HERFINDAHL: 0.9898410, COVERAGE_ITEM: 0.1693339, COVERAGE_ITEM_CORRECT: 0.1016668, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9619048, DIVERSITY_GINI: 0.0201608, SHANNON_ENTROPY: 8.2648582, RATIO_DIVERSITY_HERFINDAHL: 0.9902141, RATIO_DIVERSITY_GINI: 0.0780904, RATIO_SHANNON_ENTROPY: 0.6644500, RATIO_AVERAGE_POPULARITY: 2.3960239, RATIO_NOVELTY: 0.0275866,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 46.3839
# Function value obtained: -0.2270
# Current minimum: -0.2270
# Iteration No: 94 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 66, 'alpha': 0.0024200590876060084, 'beta': 0.14937653517696017, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 9.88 sec. Users per second: 1381
# SearchBayesianSkopt: Config 93 is suboptimal. Config: {'topK': 66, 'alpha': 0.0024200590876060084, 'beta': 0.14937653517696017, 'normalize_similarity': True} - results: PRECISION: 0.2830207, PRECISION_RECALL_MIN_DEN: 0.2834142, RECALL: 0.0454717, MAP: 0.1641164, MAP_MIN_DEN: 0.1643056, MRR: 0.5481442, NDCG: 0.3019298, F1: 0.0783546, HIT_RATE: 0.8981386, ARHR_ALL_HITS: 0.9343866, NOVELTY: 0.0064938, AVERAGE_POPULARITY: 0.2043465, DIVERSITY_MEAN_INTER_LIST: 0.9717128, DIVERSITY_HERFINDAHL: 0.9971642, COVERAGE_ITEM: 0.2036104, COVERAGE_ITEM_CORRECT: 0.0827842, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8978755, DIVERSITY_GINI: 0.0302758, SHANNON_ENTROPY: 9.3621676, RATIO_DIVERSITY_HERFINDAHL: 0.9975400, RATIO_DIVERSITY_GINI: 0.1172695, RATIO_SHANNON_ENTROPY: 0.7526677, RATIO_AVERAGE_POPULARITY: 1.0247711, RATIO_NOVELTY: 0.0307388,
#
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 43.0158
# Function value obtained: -0.1641
# Current minimum: -0.2270
# Iteration No: 95 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.628054418553635, 'beta': 0.5540706492564426, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.10 sec. Users per second: 1127
# SearchBayesianSkopt: New best config found. Config 94: {'topK': 60, 'alpha': 0.628054418553635, 'beta': 0.5540706492564426, 'normalize_similarity': True} - results: PRECISION: 0.3703723, PRECISION_RECALL_MIN_DEN: 0.3717977, RECALL: 0.0646802, MAP: 0.2270953, MAP_MIN_DEN: 0.2277845, MRR: 0.6348586, NDCG: 0.3881649, F1: 0.1101281, HIT_RATE: 0.9620402, ARHR_ALL_HITS: 1.1801116, NOVELTY: 0.0058278, AVERAGE_POPULARITY: 0.4781174, DIVERSITY_MEAN_INTER_LIST: 0.8981181, DIVERSITY_HERFINDAHL: 0.9898052, COVERAGE_ITEM: 0.1706628, COVERAGE_ITEM_CORRECT: 0.1017221, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9617582, DIVERSITY_GINI: 0.0201473, SHANNON_ENTROPY: 8.2607462, RATIO_DIVERSITY_HERFINDAHL: 0.9901783, RATIO_DIVERSITY_GINI: 0.0780381, RATIO_SHANNON_ENTROPY: 0.6641194, RATIO_AVERAGE_POPULARITY: 2.3976964, RATIO_NOVELTY: 0.0275862,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3beta_augmented_all_no_event_improved_range_topK_categorical/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 46.9249
# Function value obtained: -0.2271
# Current minimum: -0.2271
# Iteration No: 96 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.6788265555367597, 'beta': 0.5547342689234718, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 13.98 sec. Users per second: 976
# SearchBayesianSkopt: Config 95 is suboptimal. Config: {'topK': 60, 'alpha': 0.6788265555367597, 'beta': 0.5547342689234718, 'normalize_similarity': True} - results: PRECISION: 0.3698740, PRECISION_RECALL_MIN_DEN: 0.3713363, RECALL: 0.0646051, MAP: 0.2267176, MAP_MIN_DEN: 0.2274240, MRR: 0.6344215, NDCG: 0.3877329, F1: 0.1099972, HIT_RATE: 0.9616005, ARHR_ALL_HITS: 1.1788867, NOVELTY: 0.0058314, AVERAGE_POPULARITY: 0.4773314, DIVERSITY_MEAN_INTER_LIST: 0.8983535, DIVERSITY_HERFINDAHL: 0.9898288, COVERAGE_ITEM: 0.1702198, COVERAGE_ITEM_CORRECT: 0.1006700, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9613187, DIVERSITY_GINI: 0.0202225, SHANNON_ENTROPY: 8.2688799, RATIO_DIVERSITY_HERFINDAHL: 0.9902018, RATIO_DIVERSITY_GINI: 0.0783293, RATIO_SHANNON_ENTROPY: 0.6647733, RATIO_AVERAGE_POPULARITY: 2.3937546, RATIO_NOVELTY: 0.0276029,
#
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 49.2130
# Function value obtained: -0.2267
# Current minimum: -0.2271
# Iteration No: 97 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.6060939560841812, 'beta': 0.5543455055033387, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.74 sec. Users per second: 1163
# SearchBayesianSkopt: Config 96 is suboptimal. Config: {'topK': 60, 'alpha': 0.6060939560841812, 'beta': 0.5543455055033387, 'normalize_similarity': True} - results: PRECISION: 0.3704895, PRECISION_RECALL_MIN_DEN: 0.3719372, RECALL: 0.0647362, MAP: 0.2269741, MAP_MIN_DEN: 0.2276724, MRR: 0.6347782, NDCG: 0.3881595, F1: 0.1102145, HIT_RATE: 0.9623333, ARHR_ALL_HITS: 1.1796978, NOVELTY: 0.0058280, AVERAGE_POPULARITY: 0.4777280, DIVERSITY_MEAN_INTER_LIST: 0.8986940, DIVERSITY_HERFINDAHL: 0.9898628, COVERAGE_ITEM: 0.1691124, COVERAGE_ITEM_CORRECT: 0.1019436, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9620513, DIVERSITY_GINI: 0.0201676, SHANNON_ENTROPY: 8.2668200, RATIO_DIVERSITY_HERFINDAHL: 0.9902359, RATIO_DIVERSITY_GINI: 0.0781168, RATIO_SHANNON_ENTROPY: 0.6646077, RATIO_AVERAGE_POPULARITY: 2.3957436, RATIO_NOVELTY: 0.0275869,
#
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 47.3288
# Function value obtained: -0.2270
# Current minimum: -0.2271
# Iteration No: 98 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 66, 'alpha': 0.6831816023612254, 'beta': 0.32948529821146094, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 10.78 sec. Users per second: 1266
# SearchBayesianSkopt: Config 97 is suboptimal. Config: {'topK': 66, 'alpha': 0.6831816023612254, 'beta': 0.32948529821146094, 'normalize_similarity': True} - results: PRECISION: 0.3537667, PRECISION_RECALL_MIN_DEN: 0.3550094, RECALL: 0.0620900, MAP: 0.2144773, MAP_MIN_DEN: 0.2150618, MRR: 0.6239891, NDCG: 0.3726981, F1: 0.1056392, HIT_RATE: 0.9577165, ARHR_ALL_HITS: 1.1383486, NOVELTY: 0.0060641, AVERAGE_POPULARITY: 0.3812515, DIVERSITY_MEAN_INTER_LIST: 0.9350293, DIVERSITY_HERFINDAHL: 0.9934961, COVERAGE_ITEM: 0.1713273, COVERAGE_ITEM_CORRECT: 0.0926408, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9574359, DIVERSITY_GINI: 0.0231323, SHANNON_ENTROPY: 8.7489754, RATIO_DIVERSITY_HERFINDAHL: 0.9938705, RATIO_DIVERSITY_GINI: 0.0896000, RATIO_SHANNON_ENTROPY: 0.7033704, RATIO_AVERAGE_POPULARITY: 1.9119264, RATIO_NOVELTY: 0.0287047,
#
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 44.3468
# Function value obtained: -0.2145
# Current minimum: -0.2271
# Iteration No: 99 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 51, 'alpha': 0.011117568417680858, 'beta': 0.6880529690594752, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.20 sec. Users per second: 1119
# SearchBayesianSkopt: Config 98 is suboptimal. Config: {'topK': 51, 'alpha': 0.011117568417680858, 'beta': 0.6880529690594752, 'normalize_similarity': True} - results: PRECISION: 0.3614612, PRECISION_RECALL_MIN_DEN: 0.3627535, RECALL: 0.0620432, MAP: 0.2167270, MAP_MIN_DEN: 0.2172706, MRR: 0.6069549, NDCG: 0.3747324, F1: 0.1059078, HIT_RATE: 0.9563975, ARHR_ALL_HITS: 1.1285171, NOVELTY: 0.0056904, AVERAGE_POPULARITY: 0.5180002, DIVERSITY_MEAN_INTER_LIST: 0.9065355, DIVERSITY_HERFINDAHL: 0.9906469, COVERAGE_ITEM: 0.1595326, COVERAGE_ITEM_CORRECT: 0.0928623, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9561172, DIVERSITY_GINI: 0.0166344, SHANNON_ENTROPY: 8.0481886, RATIO_DIVERSITY_HERFINDAHL: 0.9910203, RATIO_DIVERSITY_GINI: 0.0644311, RATIO_SHANNON_ENTROPY: 0.6470309, RATIO_AVERAGE_POPULARITY: 2.5977032, RATIO_NOVELTY: 0.0269356,
#
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 44.9578
# Function value obtained: -0.2167
# Current minimum: -0.2271
# Iteration No: 100 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 60, 'alpha': 0.6062106308408592, 'beta': 0.5545212862971027, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 13646 (100.0%) in 11.72 sec. Users per second: 1165
# SearchBayesianSkopt: Config 99 is suboptimal. Config: {'topK': 60, 'alpha': 0.6062106308408592, 'beta': 0.5545212862971027, 'normalize_similarity': True} - results: PRECISION: 0.3704162, PRECISION_RECALL_MIN_DEN: 0.3718639, RECALL: 0.0647235, MAP: 0.2269718, MAP_MIN_DEN: 0.2276701, MRR: 0.6348330, NDCG: 0.3881319, F1: 0.1101927, HIT_RATE: 0.9623333, ARHR_ALL_HITS: 1.1797282, NOVELTY: 0.0058283, AVERAGE_POPULARITY: 0.4776188, DIVERSITY_MEAN_INTER_LIST: 0.8987625, DIVERSITY_HERFINDAHL: 0.9898697, COVERAGE_ITEM: 0.1692231, COVERAGE_ITEM_CORRECT: 0.1018329, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9620513, DIVERSITY_GINI: 0.0201895, SHANNON_ENTROPY: 8.2683324, RATIO_DIVERSITY_HERFINDAHL: 0.9902428, RATIO_DIVERSITY_GINI: 0.0782016, RATIO_SHANNON_ENTROPY: 0.6647293, RATIO_AVERAGE_POPULARITY: 2.3951961, RATIO_NOVELTY: 0.0275884,
#
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 44.8074
# Function value obtained: -0.2270
# Current minimum: -0.2271
# SearchBayesianSkopt: Search complete. Best config is 94: {'topK': 60, 'alpha': 0.628054418553635, 'beta': 0.5540706492564426, 'normalize_similarity': True}

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.22

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_47567/83441945.py in <module>
#       4
#       5 data_loader = DataIO(folder_path = output_folder_path)
# ----> 6 search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#       7 #search_metadata.keys()
#       8
#
# ~/Scrivania/RecSysChallenge2021/Recommenders/DataIO.py in load_data(self, file_name)
#     207             file_name += ".zip"
#     208
# --> 209         dataFile = zipfile.ZipFile(self.folder_path + file_name)
#     210
#     211         dataFile.testzip()
#
# ~/anaconda3/envs/RecSysFramework/lib/python3.8/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'result_experiments/RP3beta_augmented_all/RP3betaRecommender_metadata.zip'

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_event_preprocessed/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.219

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK     alpha      beta normalize_similarity       MAP
# 13  122  0.449787  0.395651                 True  0.220561
# 38   93   0.20678  0.380367                 True  0.219950
# 46   94       0.0  0.390115                 True  0.219409
# Max value for the range:  122
# Min value for the range:  93
# Best MAP:  0.2205607899518212
#    topK     alpha      beta normalize_similarity       MAP
# 13  122  0.449787  0.395651                 True  0.220561

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_no_event/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.224

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK    alpha      beta normalize_similarity       MAP
# 30   62      0.0  0.533488                 True  0.224454
# 34   85      1.0  0.543791                 True  0.224019
# 40   56  0.48885  0.543524                 True  0.226386
# 44   37      0.0  0.536916                 True  0.224072
# Max value for the range:  85
# Min value for the range:  37
# Best MAP:  0.22638588201903473
#    topK    alpha      beta normalize_similarity       MAP
# 40   56  0.48885  0.543524                 True  0.226386

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_no_event_improved_range/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.226

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK     alpha      beta normalize_similarity       MAP
# 47   61  0.297542  0.563447                 True  0.226389
# 57   55  0.885547  0.547405                 True  0.226444
# 60   59  0.581572  0.540392                 True  0.226535
# 61   50  0.690909  0.569618                 True  0.226775
# 62   56  0.639613  0.577889                 True  0.226722
# 64   65   0.53406  0.576047                 True  0.226314
# 81   60  0.740864  0.559624                 True  0.226896
# 85   55  0.533698  0.562787                 True  0.226601
# 90   60  0.788324  0.551148                 True  0.226615
# 95   58  0.737131  0.568683                 True  0.226612
# 97   56  0.692149  0.559272                 True  0.226816
# 98   56  0.624694  0.568462                 True  0.227145
# 99   55  0.576098  0.571243                 True  0.226610
# Max value for the range:  65
# Min value for the range:  50
# Best MAP:  0.22714496253335392
#    topK     alpha      beta normalize_similarity       MAP
# 98   56  0.624694  0.568462                 True  0.227145

# %%
from Recommenders.DataIO import DataIO

output_folder_path = "result_experiments/RP3beta_augmented_all_no_event_topK_categorical/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.226

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].topK))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    topK     alpha      beta normalize_similarity       MAP
# 25   66  0.667368  0.555375                 True  0.226365
# 30   51  0.478767  0.574051                 True  0.226439
# 34   51  0.531833   0.54934                 True  0.226300
# 36   51  0.743044  0.563758                 True  0.226602
# 37   51  0.650132   0.57081                 True  0.226861
# 38   51  0.651618  0.575714                 True  0.227280
# 41   51  0.642757   0.58423                 True  0.226830
# 45   51  0.582075    0.5893                 True  0.226184
# 48   66  0.614196   0.52372                 True  0.226039
# Max value for the range:  66
# Min value for the range:  51
# Best MAP:  0.227279727881186
#    topK     alpha      beta normalize_similarity      MAP
# 38   51  0.651618  0.575714                 True  0.22728
