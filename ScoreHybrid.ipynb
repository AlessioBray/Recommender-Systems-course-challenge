# %% [markdown]
# # Hybrid

# %%
## Allow more than one output for a single code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd
import scipy.sparse as sps
import numpy as np
import os

from skopt.space import Real, Integer, Categorical

## Set the numpy random seed
SEED = 42
np.random.seed(SEED)

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

from Evaluation.Evaluator import EvaluatorHoldout

from Recommenders.Recommender_import_list import *
from Recommenders.Hybrid.DifferentLossScoresHybridRecommender import DifferentLossScoresHybridRecommender

from Recommenders.DataIO import DataIO

# %%
## Utility Functions
from Dataset.load_data import load_data
from Dataset.write_submission import write_submission
from Dataset.load_test_user_array import load_test_user_array

# %%
URM_all, ICM_dict = load_data()

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

URM_aug_train = sps.vstack([URM_train.copy().tocoo(), 
                            #ICM_dict['genre'].T.tocoo(),
                            ICM_dict['ICM_subgenre'].T.tocoo(), 
                            #ICM_dict['event'].T.tocoo(), 
                            ICM_dict['ICM_channel'].T.tocoo()], format='csr')
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items

# %%
evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10], exclude_seen = True)
# Out:
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
test_UserID_array = load_test_user_array()

# %%
output_folder_path = "result_experiments/ScoresHybrid_RP3beta_SLIMElasticNet/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("RP3betaRecommender_SLIMElasticNetRecommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2492

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#        alpha       MAP
# 1   0.179126  0.249305
# 3   0.097846  0.249249
# 4   0.085722  0.249238
# 6   0.093221  0.249264
# 12  0.058649  0.249263
# 19  0.068366  0.249322
# 20  0.090797  0.249294
# 23   0.10836  0.249229
# 24  0.169875  0.249370
# 25  0.160786  0.249360
# 26  0.165214  0.249295
# 27   0.15583  0.249292
# 29   0.12072  0.249326
# 30  0.131851  0.249352
# 32  0.140437  0.249325
# 33  0.116893  0.249266
# 36  0.173987  0.249287
# 38  0.126547  0.249389
# 39  0.162094  0.249333
# 42  0.136249  0.249338
# 43  0.072869  0.249288
# 49  0.184595  0.249208
# Max value for the range:  0.18459510477167498
# Min value for the range:  0.05864858110109953
# Best MAP:  0.2493893873197331
#        alpha       MAP
# 38  0.126547  0.249389

# %%
output_folder_path = "result_experiments/ScoresHybrid_RP3beta_IALS/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("RP3betaRecommender_IALSRecommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.242

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#        alpha       MAP
# 15       0.3  0.242100
# 17       0.3  0.242100
# 19       0.3  0.242100
# 22       0.3  0.242100
# 25       0.3  0.242100
# 27       0.3  0.242100
# 29       0.3  0.242100
# 30       0.3  0.242100
# 39  0.296169  0.242097
# 44  0.298094  0.242135
# 45  0.298079  0.242135
# 46  0.298078  0.242132
# Max value for the range:  0.3
# Min value for the range:  0.29616943093704623
# Best MAP:  0.2421349590204923
#        alpha       MAP
# 44  0.298094  0.242135

# %%
output_folder_path = "result_experiments/ScoresHybrid_RP3beta_IALS_separate_weights/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("RP3betaRecommender_IALSRecommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2432

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#        alpha      beta gamma delta       MAP
# 4    0.54826  0.559405     0     0  0.243257
# 30       1.0       1.0     0     0  0.243406
# 38  0.996756   0.92316     0     0  0.243237
# 78  0.855813  0.887564     0     0  0.243212
# 83  0.345041  0.320944     0     0  0.243259
# 87       1.0  0.963778     0     0  0.243264
# Max value for the range:  1.0
# Min value for the range:  0.34504058756186956
# Best MAP:  0.24340612633738892
#    alpha beta gamma delta       MAP
# 30   1.0  1.0     0     0  0.243406

# %%
output_folder_path = "result_experiments/ScoresHybrid_DifferentLossSLIM_RP3beta/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("DifferentLossScoresHybridRecommender_RP3betaRecommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.0

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#       alpha       MAP
# 0  0.653104  0.227285
# 1  0.254516  0.227149
# 2  0.116613  0.227141
# 3  0.899746  0.227913
# 4  0.756824  0.227376
# 5  0.012251  0.227149
# Max value for the range:  0.8997460478162632
# Min value for the range:  0.012250596716553989
# Best MAP:  0.22791306365723676
#       alpha       MAP
# 3  0.899746  0.227913

# %%
output_folder_path = "result_experiments/ScoresHybrid_SLIMElasticNet_IALS/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("SLIMElasticNetRecommender_IALSRecommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2501

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#        alpha       MAP
# 35  0.759515  0.250106
# 43   0.79719  0.250127
# 44  0.789777  0.250129
# 55  0.793885  0.250101
# 58  0.785876  0.250173
# 60  0.783476  0.250139
# 64  0.784601  0.250165
# 67  0.784386  0.250169
# 68  0.784194  0.250169
# 70  0.784073  0.250167
# 71  0.784007  0.250172
# 76  0.783795  0.250164
# 77  0.783854  0.250159
# 80   0.78409  0.250167
# 81  0.784043  0.250174
# 85  0.783801  0.250165
# 86  0.783923  0.250164
# 87  0.784417  0.250172
# 88  0.784515  0.250175
# 89  0.784636  0.250169
# 93  0.784975  0.250166
# 94  0.783231  0.250116
# 95  0.785802  0.250161
# 96  0.785745  0.250158
# Max value for the range:  0.7971900785890443
# Min value for the range:  0.7595145328142148
# Best MAP:  0.25017529411491135
#        alpha       MAP
# 88  0.784515  0.250175

# %% [markdown]
# ## PRovare varie combinazioni diff loss e altri

# %%
output_folder_path = "result_experiments/ScoresHybrid_DiffLossSLIM_IALS/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 100  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
print('Fitting ...')

RP3beta = RP3betaRecommender(URM_aug_train)
RP3beta.fit(topK = 51, alpha = 0.620106, beta =	0.566617, normalize_similarity = True)

#Top = TopPop(URM_train)
#Top.fit()

#UserKNNCF = UserKNNCFRecommender(URM_train)
#UserKNNCF.fit(topK= 777, shrink = 0, similarity = 'tversky', normalize = True, tversky_alpha = 2.0, tversky_beta = 1.2531451455933782)

SLIMElasticNet = MultiThreadSLIM_SLIMElasticNetRecommender(URM_aug_train)
SLIMElasticNet.load_model(folder_path = 'result_experiments/SLIM_elasticNet_AUG_subgenre_channel_topK_categorical/', file_name = 'SLIMElasticNetRecommender_best_model.zip')
#SLIMElasticNet.fit(topK = 673, l1_ratio = 0.001155, alpha = 0.073102)

earlystopping_keywargs = {"validation_every_n": 1,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 20,
                          "validation_metric": metric_to_optimize,
                         }

SLIM_BPR = SLIM_BPR_Cython(URM_aug_train)
SLIM_BPR.load_model(folder_path = 'result_experiments/SLIM_BPR_AUG_subgenre_channel/', file_name = 'SLIM_BPR_Recommender_best_model.zip')

DiffLoss = DifferentLossScoresHybridRecommender(URM_aug_train, [SLIMElasticNet, SLIM_BPR])
DiffLoss.fit(norm = np.inf, alpha = 0.826909)

IALS = IALSRecommender(URM_aug_train)
IALS.load_model(folder_path = 'result_experiments/IALS_NO_AUG/', file_name = 'IALSRecommender_best_model.zip')
#IALS.fit(num_factors = 52, epochs = 300, confidence_scaling = 'linear', alpha = 1.3346069348060516, epsilon = 0.17158990394166584, reg = 0.0005841170332713697, **earlystopping_keywargs)

print('Fitting Ended')
# Out:
# Fitting ...
# SLIMElasticNetRecommender: Loading model from file 'result_experiments/SLIM_elasticNet_AUG_subgenre_channel_topK_categorical/SLIMElasticNetRecommender_best_model.zip'
# SLIMElasticNetRecommender: Loading complete
# SLIM_BPR_Recommender: Loading model from file 'result_experiments/SLIM_BPR_AUG_subgenre_channel/SLIM_BPR_Recommender_best_model.zip'
# SLIM_BPR_Recommender: Loading complete
# IALSRecommender: Loading model from file 'result_experiments/IALS_NO_AUG/IALSRecommender_best_model.zip'
# IALSRecommender: Loading complete
# Fitting Ended

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search_ScoresHybrid import runHyperparameterSearch_ScoresHybrid

runHyperparameterSearch_ScoresHybrid([DiffLoss, IALS],
                                      URM_train = URM_aug_train,
                                      ICM_object = None,
                                      ICM_name = '',
                                      URM_train_last_test = None,
                                      metric_to_optimize = metric_to_optimize,
                                      cutoff_to_optimize = cutoff_to_optimize,
                                      n_cases = n_cases,
                                      n_random_starts = n_random_starts,
                                      evaluator_validation_earlystopping = evaluator_validation,
                                      evaluator_validation = evaluator_validation,
                                      evaluator_test = None,
                                      output_folder_path = output_folder_path,
                                      resume_from_saved = False,
                                      similarity_type_list = None,
                                      parallelizeKNN = True)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.1446018485160938}
# EvaluatorHoldout: Processed 13646 (100.0%) in 37.80 sec. Users per second: 361
# SearchBayesianSkopt: New best config found. Config 0: {'alpha': 0.1446018485160938} - results: PRECISION: 0.3833358, PRECISION_RECALL_MIN_DEN: 0.3848390, RECALL: 0.0681410, MAP: 0.2339243, MAP_MIN_DEN: 0.2346333, MRR: 0.6343746, NDCG: 0.3975659, F1: 0.1157131, HIT_RATE: 0.9659241, ARHR_ALL_HITS: 1.1975065, NOVELTY: 0.0056407, AVERAGE_POPULARITY: 0.4756843, DIVERSITY_MEAN_INTER_LIST: 0.9515626, DIVERSITY_HERFINDAHL: 0.9951493, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0610222, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9656410, DIVERSITY_GINI: 0.0163044, SHANNON_ENTROPY: 8.5454943, RATIO_DIVERSITY_HERFINDAHL: 0.9955271, RATIO_DIVERSITY_GINI: 0.0639261, RATIO_SHANNON_ENTROPY: 0.6878146, RATIO_AVERAGE_POPULARITY: 2.3854442, RATIO_NOVELTY: 0.0268287,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 38.0009
# Function value obtained: -0.2339
# Current minimum: -0.2339
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.8459356334008694}
# EvaluatorHoldout: Processed 13646 (100.0%) in 37.30 sec. Users per second: 366
# SearchBayesianSkopt: New best config found. Config 1: {'alpha': 0.8459356334008694} - results: PRECISION: 0.3834310, PRECISION_RECALL_MIN_DEN: 0.3849343, RECALL: 0.0681593, MAP: 0.2339966, MAP_MIN_DEN: 0.2347056, MRR: 0.6343456, NDCG: 0.3976473, F1: 0.1157439, HIT_RATE: 0.9658508, ARHR_ALL_HITS: 1.1976899, NOVELTY: 0.0056403, AVERAGE_POPULARITY: 0.4758775, DIVERSITY_MEAN_INTER_LIST: 0.9514837, DIVERSITY_HERFINDAHL: 0.9951414, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0609668, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9655678, DIVERSITY_GINI: 0.0162849, SHANNON_ENTROPY: 8.5435932, RATIO_DIVERSITY_HERFINDAHL: 0.9955192, RATIO_DIVERSITY_GINI: 0.0638496, RATIO_SHANNON_ENTROPY: 0.6876616, RATIO_AVERAGE_POPULARITY: 2.3864133, RATIO_NOVELTY: 0.0268271,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 37.4917
# Function value obtained: -0.2340
# Current minimum: -0.2340
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7163847161770754}
# EvaluatorHoldout: Processed 13646 (100.0%) in 37.32 sec. Users per second: 366
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'alpha': 0.7163847161770754} - results: PRECISION: 0.3833651, PRECISION_RECALL_MIN_DEN: 0.3848683, RECALL: 0.0681383, MAP: 0.2339928, MAP_MIN_DEN: 0.2347017, MRR: 0.6345491, NDCG: 0.3976357, F1: 0.1157106, HIT_RATE: 0.9659241, ARHR_ALL_HITS: 1.1978174, NOVELTY: 0.0056405, AVERAGE_POPULARITY: 0.4757676, DIVERSITY_MEAN_INTER_LIST: 0.9515275, DIVERSITY_HERFINDAHL: 0.9951458, COVERAGE_ITEM: 0.0734814, COVERAGE_ITEM_CORRECT: 0.0610222, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9656410, DIVERSITY_GINI: 0.0162960, SHANNON_ENTROPY: 8.5446796, RATIO_DIVERSITY_HERFINDAHL: 0.9955236, RATIO_DIVERSITY_GINI: 0.0638931, RATIO_SHANNON_ENTROPY: 0.6877490, RATIO_AVERAGE_POPULARITY: 2.3858624, RATIO_NOVELTY: 0.0268280,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 37.6396
# Function value obtained: -0.2340
# Current minimum: -0.2340
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6059325199683158}
# EvaluatorHoldout: Processed 13646 (100.0%) in 36.42 sec. Users per second: 375
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'alpha': 0.6059325199683158} - results: PRECISION: 0.3833724, PRECISION_RECALL_MIN_DEN: 0.3848756, RECALL: 0.0681446, MAP: 0.2339738, MAP_MIN_DEN: 0.2346828, MRR: 0.6344809, NDCG: 0.3976187, F1: 0.1157199, HIT_RATE: 0.9659241, ARHR_ALL_HITS: 1.1977077, NOVELTY: 0.0056406, AVERAGE_POPULARITY: 0.4757394, DIVERSITY_MEAN_INTER_LIST: 0.9515342, DIVERSITY_HERFINDAHL: 0.9951465, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0610222, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9656410, DIVERSITY_GINI: 0.0162995, SHANNON_ENTROPY: 8.5449578, RATIO_DIVERSITY_HERFINDAHL: 0.9955242, RATIO_DIVERSITY_GINI: 0.0639067, RATIO_SHANNON_ENTROPY: 0.6877714, RATIO_AVERAGE_POPULARITY: 2.3857209, RATIO_NOVELTY: 0.0268284,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 36.6018
# Function value obtained: -0.2340
# Current minimum: -0.2340
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7906248445206222}
# EvaluatorHoldout: Processed 13646 (100.0%) in 36.54 sec. Users per second: 373
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'alpha': 0.7906248445206222} - results: PRECISION: 0.3833504, PRECISION_RECALL_MIN_DEN: 0.3848537, RECALL: 0.0681357, MAP: 0.2339785, MAP_MIN_DEN: 0.2346875, MRR: 0.6343793, NDCG: 0.3976014, F1: 0.1157061, HIT_RATE: 0.9658508, ARHR_ALL_HITS: 1.1976461, NOVELTY: 0.0056404, AVERAGE_POPULARITY: 0.4758132, DIVERSITY_MEAN_INTER_LIST: 0.9515105, DIVERSITY_HERFINDAHL: 0.9951441, COVERAGE_ITEM: 0.0734814, COVERAGE_ITEM_CORRECT: 0.0610222, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9655678, DIVERSITY_GINI: 0.0162928, SHANNON_ENTROPY: 8.5443307, RATIO_DIVERSITY_HERFINDAHL: 0.9955219, RATIO_DIVERSITY_GINI: 0.0638806, RATIO_SHANNON_ENTROPY: 0.6877209, RATIO_AVERAGE_POPULARITY: 2.3860908, RATIO_NOVELTY: 0.0268277,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 36.7316
# Function value obtained: -0.2340
# Current minimum: -0.2340
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.8243351366730706}
# EvaluatorHoldout: Processed 13646 (100.0%) in 36.52 sec. Users per second: 374
# SearchBayesianSkopt: New best config found. Config 5: {'alpha': 0.8243351366730706} - results: PRECISION: 0.3834017, PRECISION_RECALL_MIN_DEN: 0.3849050, RECALL: 0.0681482, MAP: 0.2339985, MAP_MIN_DEN: 0.2347074, MRR: 0.6343376, NDCG: 0.3976308, F1: 0.1157264, HIT_RATE: 0.9658508, ARHR_ALL_HITS: 1.1976699, NOVELTY: 0.0056404, AVERAGE_POPULARITY: 0.4758407, DIVERSITY_MEAN_INTER_LIST: 0.9514995, DIVERSITY_HERFINDAHL: 0.9951430, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0609668, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9655678, DIVERSITY_GINI: 0.0162897, SHANNON_ENTROPY: 8.5440257, RATIO_DIVERSITY_HERFINDAHL: 0.9955207, RATIO_DIVERSITY_GINI: 0.0638685, RATIO_SHANNON_ENTROPY: 0.6876964, RATIO_AVERAGE_POPULARITY: 2.3862289, RATIO_NOVELTY: 0.0268274,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 36.7047
# Function value obtained: -0.2340
# Current minimum: -0.2340
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.13939272943321912}
# EvaluatorHoldout: Processed 13646 (100.0%) in 36.38 sec. Users per second: 375
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'alpha': 0.13939272943321912} - results: PRECISION: 0.3833358, PRECISION_RECALL_MIN_DEN: 0.3848390, RECALL: 0.0681410, MAP: 0.2339243, MAP_MIN_DEN: 0.2346333, MRR: 0.6343746, NDCG: 0.3975659, F1: 0.1157131, HIT_RATE: 0.9659241, ARHR_ALL_HITS: 1.1975065, NOVELTY: 0.0056407, AVERAGE_POPULARITY: 0.4756843, DIVERSITY_MEAN_INTER_LIST: 0.9515626, DIVERSITY_HERFINDAHL: 0.9951493, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0610222, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9656410, DIVERSITY_GINI: 0.0163044, SHANNON_ENTROPY: 8.5454943, RATIO_DIVERSITY_HERFINDAHL: 0.9955271, RATIO_DIVERSITY_GINI: 0.0639261, RATIO_SHANNON_ENTROPY: 0.6878146, RATIO_AVERAGE_POPULARITY: 2.3854442, RATIO_NOVELTY: 0.0268287,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 36.5604
# Function value obtained: -0.2339
# Current minimum: -0.2340
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.833340700621555}
# EvaluatorHoldout: Processed 13646 (100.0%) in 36.52 sec. Users per second: 374
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'alpha': 0.833340700621555} - results: PRECISION: 0.3834017, PRECISION_RECALL_MIN_DEN: 0.3849050, RECALL: 0.0681501, MAP: 0.2339876, MAP_MIN_DEN: 0.2346966, MRR: 0.6343498, NDCG: 0.3976287, F1: 0.1157293, HIT_RATE: 0.9658508, ARHR_ALL_HITS: 1.1976618, NOVELTY: 0.0056404, AVERAGE_POPULARITY: 0.4758558, DIVERSITY_MEAN_INTER_LIST: 0.9514948, DIVERSITY_HERFINDAHL: 0.9951425, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0609668, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9655678, DIVERSITY_GINI: 0.0162881, SHANNON_ENTROPY: 8.5438845, RATIO_DIVERSITY_HERFINDAHL: 0.9955203, RATIO_DIVERSITY_GINI: 0.0638622, RATIO_SHANNON_ENTROPY: 0.6876850, RATIO_AVERAGE_POPULARITY: 2.3863046, RATIO_NOVELTY: 0.0268273,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 36.7009
# Function value obtained: -0.2340
# Current minimum: -0.2340
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.31742425982597894}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2648/3552071390.py in <module>
#       4 from HyperparameterTuning.run_hyperparameter_search_ScoresHybrid import runHyperparameterSearch_ScoresHybrid
#       5
# ----> 6 runHyperparameterSearch_ScoresHybrid([DiffLoss, IALS],
#       7                                       URM_train = URM_aug_train,
#       8                                       ICM_object = None,
#
# ~/RecSysChallenge2021/HyperparameterTuning/run_hyperparameter_search_ScoresHybrid.py in runHyperparameterSearch_ScoresHybrid(recommenders, URM_train, ICM_object, ICM_name, URM_train_last_test, n_cases, n_random_starts, resume_from_saved, save_model, evaluate_on_test, max_total_time, evaluator_validation_earlystopping, evaluator_validation, evaluator_test, metric_to_optimize, cutoff_to_optimize, output_folder_path, parallelizeKNN, allow_weighting, similarity_type_list, user_id_array)
#     149
#     150
# --> 151         hyperparameterSearch.search(recommender_input_args,
#     152                                     hyperparameter_search_space = hyperparameters_range_dictionary,
#     153                                     n_cases = n_cases,
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchBayesianSkopt.py in search(self, recommender_input_args, hyperparameter_search_space, metric_to_optimize, cutoff_to_optimize, n_cases, n_random_starts, output_folder_path, output_file_name_root, save_model, save_metadata, resume_from_saved, recommender_input_args_last_test, evaluate_on_test, max_total_time)
#     336                 # of "Searching for the next optimal point". This may be due to a bug in the print rather than the underlying process
#     337                 # https://github.com/scikit-optimize/scikit-optimize/issues/949
# --> 338                 self.result = gp_minimize(self._objective_function_list_input,
#     339                                           self.hyperparams_values,
#     340                                           base_estimator=None,
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     257             noise=noise)
#     258
# --> 259     return base_minimize(
#     260         func, space, base_estimator=base_estimator,
#     261         acq_func=acq_func,
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     299     for n in range(n_calls):
#     300         next_x = optimizer.ask()
# --> 301         next_y = func(next_x)
#     302         result = optimizer.tell(next_x, next_y)
#     303         result.specs = specs
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchBayesianSkopt.py in _objective_function_list_input(self, current_fit_hyperparameters_list_of_values)
#     410
#     411         current_fit_hyperparameters_dict = dict(zip(self.hyperparams_names, current_fit_hyperparameters_list_of_values))
# --> 412         result = self._objective_function(current_fit_hyperparameters_dict)
#     413
#     414         # The search can only progress if there is at least a valid config in the initial random start
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     533         except (KeyboardInterrupt, SystemExit) as e:
#     534             # If getting a interrupt, terminate without saving the exception
# --> 535             raise e
#     536
#     537         except:
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     462
#     463             was_already_evaluated_flag, was_already_evaluated_index = self._was_already_evaluated_check(current_fit_hyperparameters_dict)
# --> 464             result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#     465
#     466             result_series = result_df.loc[self.metadata_dict["cutoff_to_optimize"]]
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py in _evaluate_on_validation(self, current_fit_hyperparameters, was_already_evaluated_flag, was_already_evaluated_index)
#     334
#     335             # Evaluate recommender and get results for the first cutoff
# --> 336             result_df, _ = self.evaluator_validation.evaluateRecommender(recommender_instance)
#     337
#     338             evaluation_time = time.time() - start_time
#
# ~/RecSysChallenge2021/Evaluation/Evaluator.py in evaluateRecommender(self, recommender_object)
#     269         self._n_users_evaluated = 0
#     270
# --> 271         results_dict = self._run_evaluation_on_selected_users(recommender_object, self.users_to_evaluate)
#     272
#     273
#
# ~/RecSysChallenge2021/Evaluation/Evaluator.py in _run_evaluation_on_selected_users(self, recommender_object, users_to_evaluate, block_size)
#     479
#     480             # Compute predictions for a batch of users using vectorization, much more efficient than computing it one at a time
# --> 481             recommended_items_batch_list, scores_batch = recommender_object.recommend(test_user_batch_array,
#     482                                                                       remove_seen_flag=self.exclude_seen,
#     483                                                                       cutoff = self.max_cutoff,
#
# ~/RecSysChallenge2021/Recommenders/BaseRecommender.py in recommend(self, user_id_array, cutoff, remove_seen_flag, items_to_compute, remove_top_pop_flag, remove_custom_items_flag, return_scores)
#     145         # Compute the scores using the model-specific function
#     146         # Vectorize over all users in user_id_array
# --> 147         scores_batch = self._compute_item_score(user_id_array, items_to_compute=items_to_compute)
#     148
#     149
#
# ~/RecSysChallenge2021/Recommenders/Hybrid/ScoresHybridRecommender.py in _compute_item_score(self, user_id_array, items_to_compute)
#      34
#      35         # In a simple extension this could be a loop over a list of pretrained recommender objects
# ---> 36         item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
#      37         item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
#      38
#
# ~/RecSysChallenge2021/Recommenders/Hybrid/DifferentLossScoresHybridRecommender.py in _compute_item_score(self, user_id_array, items_to_compute)
#      45
#      46         norm_item_weights_1 = LA.norm(item_weights_1, self.norm)
# ---> 47         norm_item_weights_2 = LA.norm(item_weights_2, self.norm)
#      48
#      49
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/numpy/linalg/linalg.py in norm(x, ord, axis, keepdims)
#    2586             if row_axis > col_axis:
#    2587                 row_axis -= 1
# -> 2588             ret = add.reduce(abs(x), axis=col_axis).max(axis=row_axis)
#    2589         elif ord == -1:
#    2590             if col_axis > row_axis:
#
# KeyboardInterrupt:
