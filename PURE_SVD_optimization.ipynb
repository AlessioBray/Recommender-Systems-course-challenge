# %% [markdown]
# # Pure SVD

# %% [markdown]
# ## Import

# %%
## Allow more than one output for a single code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd
import scipy.sparse as sps
import numpy as np
import os

from skopt.space import Real, Integer, Categorical

## Set the numpy random seed
SEED = 42
np.random.seed(SEED)

os.getcwd()
# Out:
# '/home/jupyter/RecSysChallenge2021'

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

from Evaluation.Evaluator import EvaluatorHoldout

from Recommenders.Recommender_import_list import *

from Recommenders.DataIO import DataIO

# %%
## Utility Functions
from Dataset.load_data import load_data
from Dataset.write_submission import write_submission
from Dataset.load_test_user_array import load_test_user_array

# %% [markdown]
# ## Data Loading and Split

# %%
URM_all, ICM_dict = load_data()

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

URM_aug_train = sps.vstack([URM_train.copy().tocoo(), 
                            #ICM_dict['ICM_genre'].T.tocoo(),
                            ICM_dict['ICM_subgenre'].T.tocoo(), 
                            #ICM_dict['ICM_event'].T.tocoo(), 
                            ICM_dict['ICM_channel'].T.tocoo()], format='csr')

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10], exclude_seen = True)
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
test_UserID_array = load_test_user_array()

# %% [markdown]
# ## Optimization

# %%
output_folder_path = "result_experiments/PureSVD_AUG_subgenre_channel/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(PureSVDRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.23

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].num_factors))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].num_factors))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    num_factors       MAP
# 15          34  0.231957
# 18          25  0.232404
# 22          21  0.231231
# 26          29  0.232360
# 28          27  0.231184
# 29          31  0.231435
# 30          38  0.230926
# 32          23  0.231512
# 34          36  0.230165
# 40          33  0.231404
# 41          30  0.231996
# 43          24  0.232603
# 44          24  0.232603
# 45          24  0.232603
# 47          24  0.232603
# 48          24  0.232603
# 49          24  0.232603
# Max value for the range:  38
# Min value for the range:  21
# Best MAP:  0.23260277155466252
#    num_factors       MAP
# 43          24  0.232603
# 44          24  0.232603
# 45          24  0.232603
# 47          24  0.232603
# 48          24  0.232603
# 49          24  0.232603

# %%
output_folder_path = "result_experiments/PureSVD_AUG_subgenre_channel_improved_range/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(PureSVDRecommender.RECOMMENDER_NAME + "_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.23

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].num_factors))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].num_factors))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    num_factors       MAP
# 1           28  0.232788
# 2           26  0.232011
# 4           27  0.232152
# 5           37  0.230875
# 6           39  0.231174
# 8           35  0.231914
# 10          34  0.231389
# 11          24  0.232529
# 12          29  0.232367
# 14          21  0.231277
# 16          23  0.232224
# 18          31  0.231438
# 20          25  0.232356
# 22          28  0.232788
# 23          28  0.232788
# 25          32  0.231695
# 30          28  0.232788
# 34          23  0.232224
# 36          20  0.230006
# 37          28  0.232788
# 38          28  0.232788
# 39          36  0.231192
# 40          22  0.231879
# 42          27  0.232152
# 43          21  0.231277
# 45          28  0.232788
# 47          24  0.232529
# 49          28  0.232788
# Max value for the range:  39
# Min value for the range:  20
# Best MAP:  0.23278767951071105
#    num_factors       MAP
# 1           28  0.232788
# 22          28  0.232788
# 23          28  0.232788
# 30          28  0.232788
# 37          28  0.232788
# 38          28  0.232788
# 45          28  0.232788
# 49          28  0.232788

# %%
output_folder_path = "result_experiments/PureSVD_AUG_subgenre_channel_improved_range/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 50  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative

runHyperparameterSearch_Collaborative(PureSVDRecommender,
                                      URM_train = URM_aug_train,
                                      URM_train_last_test = None,
                                      metric_to_optimize = metric_to_optimize,
                                      cutoff_to_optimize = cutoff_to_optimize,
                                      n_cases = n_cases,
                                      n_random_starts = n_random_starts,
                                      evaluator_validation_earlystopping = evaluator_validation,
                                      evaluator_validation = evaluator_validation,
                                      evaluator_test = None,
                                      output_folder_path = output_folder_path,
                                      resume_from_saved = True,
                                      similarity_type_list = None,
                                      parallelizeKNN = True)

# %%
output_folder_path = "result_experiments/PureSVD_Item_AUG_subgenre_channel/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 50  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
from Recommenders.MatrixFactorization.PureSVDRecommender import PureSVDRecommender, PureSVDItemRecommender

runHyperparameterSearch_Collaborative(PureSVDItemRecommender,
                                      URM_train = URM_aug_train,
                                      URM_train_last_test = None,
                                      metric_to_optimize = metric_to_optimize,
                                      cutoff_to_optimize = cutoff_to_optimize,
                                      n_cases = n_cases,
                                      n_random_starts = n_random_starts,
                                      evaluator_validation_earlystopping = evaluator_validation,
                                      evaluator_validation = evaluator_validation,
                                      evaluator_test = None,
                                      output_folder_path = output_folder_path,
                                      resume_from_saved = True,
                                      similarity_type_list = None,
                                      parallelizeKNN = True)
# Out:
# SearchBayesianSkopt: Resuming 'PureSVDItemRecommender' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 215, 'topK': 87}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.17 sec. Users per second: 484
# SearchBayesianSkopt: New best config found. Config 0: {'num_factors': 215, 'topK': 87} - results: PRECISION: 0.2727906, PRECISION_RECALL_MIN_DEN: 0.2736618, RECALL: 0.0469139, MAP: 0.1525421, MAP_MIN_DEN: 0.1529007, MRR: 0.5432545, NDCG: 0.2911290, F1: 0.0800593, HIT_RATE: 0.9150667, ARHR_ALL_HITS: 0.9000972, NOVELTY: 0.0058064, AVERAGE_POPULARITY: 0.3487272, DIVERSITY_MEAN_INTER_LIST: 0.9481612, DIVERSITY_HERFINDAHL: 0.9948092, COVERAGE_ITEM: 0.0566477, COVERAGE_ITEM_CORRECT: 0.0402569, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9147985, DIVERSITY_GINI: 0.0114977, SHANNON_ENTROPY: 8.1229975, RATIO_DIVERSITY_HERFINDAHL: 0.9951868, RATIO_DIVERSITY_GINI: 0.0450801, RATIO_SHANNON_ENTROPY: 0.6538084, RATIO_AVERAGE_POPULARITY: 1.7487848, RATIO_NOVELTY: 0.0276169,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender
#
# PureSVDItemRecommender: Saving model in file 'result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender_best_model'
# PureSVDItemRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 58.4028
# Function value obtained: -0.1525
# Current minimum: -0.1525
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 246, 'topK': 380}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 44.22 sec. Users per second: 309
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'num_factors': 246, 'topK': 380} - results: PRECISION: 0.2656310, PRECISION_RECALL_MIN_DEN: 0.2664155, RECALL: 0.0457598, MAP: 0.1482904, MAP_MIN_DEN: 0.1486627, MRR: 0.5361620, NDCG: 0.2844441, F1: 0.0780705, HIT_RATE: 0.9092774, ARHR_ALL_HITS: 0.8815152, NOVELTY: 0.0058229, AVERAGE_POPULARITY: 0.3374685, DIVERSITY_MEAN_INTER_LIST: 0.9473174, DIVERSITY_HERFINDAHL: 0.9947248, COVERAGE_ITEM: 0.0548757, COVERAGE_ITEM_CORRECT: 0.0401462, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9090110, DIVERSITY_GINI: 0.0111327, SHANNON_ENTROPY: 8.0771086, RATIO_DIVERSITY_HERFINDAHL: 0.9951024, RATIO_DIVERSITY_GINI: 0.0436489, RATIO_SHANNON_ENTROPY: 0.6501149, RATIO_AVERAGE_POPULARITY: 1.6923251, RATIO_NOVELTY: 0.0276955,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 80.4119
# Function value obtained: -0.1483
# Current minimum: -0.1525
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 178, 'topK': 809}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 56.38 sec. Users per second: 242
# SearchBayesianSkopt: New best config found. Config 2: {'num_factors': 178, 'topK': 809} - results: PRECISION: 0.2791954, PRECISION_RECALL_MIN_DEN: 0.2801708, RECALL: 0.0482680, MAP: 0.1561840, MAP_MIN_DEN: 0.1566152, MRR: 0.5493284, NDCG: 0.2971015, F1: 0.0823066, HIT_RATE: 0.9231277, ARHR_ALL_HITS: 0.9155973, NOVELTY: 0.0056303, AVERAGE_POPULARITY: 0.4274740, DIVERSITY_MEAN_INTER_LIST: 0.9295259, DIVERSITY_HERFINDAHL: 0.9929458, COVERAGE_ITEM: 0.0459605, COVERAGE_ITEM_CORRECT: 0.0330583, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9228571, DIVERSITY_GINI: 0.0082388, SHANNON_ENTROPY: 7.6395280, RATIO_DIVERSITY_HERFINDAHL: 0.9933227, RATIO_DIVERSITY_GINI: 0.0323025, RATIO_SHANNON_ENTROPY: 0.6148947, RATIO_AVERAGE_POPULARITY: 2.1436810, RATIO_NOVELTY: 0.0267795,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender
#
# PureSVDItemRecommender: Saving model in file 'result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender_best_model'
# PureSVDItemRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 107.5356
# Function value obtained: -0.1562
# Current minimum: -0.1562
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 178, 'topK': 101}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 29.26 sec. Users per second: 466
# SearchBayesianSkopt: New best config found. Config 3: {'num_factors': 178, 'topK': 101} - results: PRECISION: 0.2820900, PRECISION_RECALL_MIN_DEN: 0.2829830, RECALL: 0.0484812, MAP: 0.1581368, MAP_MIN_DEN: 0.1584993, MRR: 0.5467482, NDCG: 0.2988681, F1: 0.0827421, HIT_RATE: 0.9193903, ARHR_ALL_HITS: 0.9182088, NOVELTY: 0.0056917, AVERAGE_POPULARITY: 0.4008718, DIVERSITY_MEAN_INTER_LIST: 0.9371532, DIVERSITY_HERFINDAHL: 0.9937084, COVERAGE_ITEM: 0.0506119, COVERAGE_ITEM_CORRECT: 0.0364915, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9191209, DIVERSITY_GINI: 0.0095074, SHANNON_ENTROPY: 7.8447781, RATIO_DIVERSITY_HERFINDAHL: 0.9940857, RATIO_DIVERSITY_GINI: 0.0372765, RATIO_SHANNON_ENTROPY: 0.6314150, RATIO_AVERAGE_POPULARITY: 2.0102774, RATIO_NOVELTY: 0.0270714,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender
#
# PureSVDItemRecommender: Saving model in file 'result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender_best_model'
# PureSVDItemRecommender: Saving complete
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 56.6366
# Function value obtained: -0.1581
# Current minimum: -0.1581
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 304, 'topK': 68}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 26.00 sec. Users per second: 525
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'num_factors': 304, 'topK': 68} - results: PRECISION: 0.2601275, PRECISION_RECALL_MIN_DEN: 0.2609524, RECALL: 0.0446024, MAP: 0.1435021, MAP_MIN_DEN: 0.1438342, MRR: 0.5233221, NDCG: 0.2772680, F1: 0.0761482, HIT_RATE: 0.9015096, ARHR_ALL_HITS: 0.8561942, NOVELTY: 0.0060179, AVERAGE_POPULARITY: 0.2704777, DIVERSITY_MEAN_INTER_LIST: 0.9615118, DIVERSITY_HERFINDAHL: 0.9961441, COVERAGE_ITEM: 0.0695498, COVERAGE_ITEM_CORRECT: 0.0501689, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9012454, DIVERSITY_GINI: 0.0161244, SHANNON_ENTROPY: 8.6043348, RATIO_DIVERSITY_HERFINDAHL: 0.9965223, RATIO_DIVERSITY_GINI: 0.0632202, RATIO_SHANNON_ENTROPY: 0.6925506, RATIO_AVERAGE_POPULARITY: 1.3563816, RATIO_NOVELTY: 0.0286232,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 60.5283
# Function value obtained: -0.1435
# Current minimum: -0.1581
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 28, 'topK': 982}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 55.19 sec. Users per second: 247
# SearchBayesianSkopt: New best config found. Config 5: {'num_factors': 28, 'topK': 982} - results: PRECISION: 0.3738678, PRECISION_RECALL_MIN_DEN: 0.3752490, RECALL: 0.0652807, MAP: 0.2291963, MAP_MIN_DEN: 0.2299121, MRR: 0.6387625, NDCG: 0.3914592, F1: 0.1111531, HIT_RATE: 0.9635058, ARHR_ALL_HITS: 1.1891354, NOVELTY: 0.0054303, AVERAGE_POPULARITY: 0.5802115, DIVERSITY_MEAN_INTER_LIST: 0.8809396, DIVERSITY_HERFINDAHL: 0.9880875, COVERAGE_ITEM: 0.0350518, COVERAGE_ITEM_CORRECT: 0.0287945, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9632234, DIVERSITY_GINI: 0.0064910, SHANNON_ENTROPY: 7.2128773, RATIO_DIVERSITY_HERFINDAHL: 0.9884626, RATIO_DIVERSITY_GINI: 0.0254499, RATIO_SHANNON_ENTROPY: 0.5805542, RATIO_AVERAGE_POPULARITY: 2.9096237, RATIO_NOVELTY: 0.0258284,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender
#
# PureSVDItemRecommender: Saving model in file 'result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender_best_model'
# PureSVDItemRecommender: Saving complete
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 99.7963
# Function value obtained: -0.2292
# Current minimum: -0.2292
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 162, 'topK': 579}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 50.15 sec. Users per second: 272
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'num_factors': 162, 'topK': 579} - results: PRECISION: 0.2872783, PRECISION_RECALL_MIN_DEN: 0.2882221, RECALL: 0.0495461, MAP: 0.1607213, MAP_MIN_DEN: 0.1611165, MRR: 0.5542105, NDCG: 0.3039124, F1: 0.0845160, HIT_RATE: 0.9280375, ARHR_ALL_HITS: 0.9322980, NOVELTY: 0.0055876, AVERAGE_POPULARITY: 0.4514999, DIVERSITY_MEAN_INTER_LIST: 0.9276349, DIVERSITY_HERFINDAHL: 0.9927567, COVERAGE_ITEM: 0.0452406, COVERAGE_ITEM_CORRECT: 0.0323384, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9277656, DIVERSITY_GINI: 0.0079091, SHANNON_ENTROPY: 7.5762251, RATIO_DIVERSITY_HERFINDAHL: 0.9931336, RATIO_DIVERSITY_GINI: 0.0310101, RATIO_SHANNON_ENTROPY: 0.6097995, RATIO_AVERAGE_POPULARITY: 2.2641653, RATIO_NOVELTY: 0.0265763,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 82.8765
# Function value obtained: -0.1607
# Current minimum: -0.2292
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 6, 'topK': 86}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 23.36 sec. Users per second: 584
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'num_factors': 6, 'topK': 86} - results: PRECISION: 0.3386560, PRECISION_RECALL_MIN_DEN: 0.3397201, RECALL: 0.0566890, MAP: 0.2036318, MAP_MIN_DEN: 0.2041221, MRR: 0.6034753, NDCG: 0.3566345, F1: 0.0971205, HIT_RATE: 0.9424740, ARHR_ALL_HITS: 1.0895916, NOVELTY: 0.0053547, AVERAGE_POPULARITY: 0.6191321, DIVERSITY_MEAN_INTER_LIST: 0.8518476, DIVERSITY_HERFINDAHL: 0.9851785, COVERAGE_ITEM: 0.0202115, COVERAGE_ITEM_CORRECT: 0.0129022, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9421978, DIVERSITY_GINI: 0.0037931, SHANNON_ENTROPY: 6.5135595, RATIO_DIVERSITY_HERFINDAHL: 0.9855525, RATIO_DIVERSITY_GINI: 0.0148721, RATIO_SHANNON_ENTROPY: 0.5242671, RATIO_AVERAGE_POPULARITY: 3.1048012, RATIO_NOVELTY: 0.0254686,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 35.8649
# Function value obtained: -0.2036
# Current minimum: -0.2292
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 161, 'topK': 149}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 32.27 sec. Users per second: 423
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'num_factors': 161, 'topK': 149} - results: PRECISION: 0.2919097, PRECISION_RECALL_MIN_DEN: 0.2928211, RECALL: 0.0504391, MAP: 0.1649600, MAP_MIN_DEN: 0.1653693, MRR: 0.5581051, NDCG: 0.3089230, F1: 0.0860156, HIT_RATE: 0.9297963, ARHR_ALL_HITS: 0.9479273, NOVELTY: 0.0056214, AVERAGE_POPULARITY: 0.4363301, DIVERSITY_MEAN_INTER_LIST: 0.9322586, DIVERSITY_HERFINDAHL: 0.9932190, COVERAGE_ITEM: 0.0477878, COVERAGE_ITEM_CORRECT: 0.0337228, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9295238, DIVERSITY_GINI: 0.0086819, SHANNON_ENTROPY: 7.7152018, RATIO_DIVERSITY_HERFINDAHL: 0.9935961, RATIO_DIVERSITY_GINI: 0.0340398, RATIO_SHANNON_ENTROPY: 0.6209855, RATIO_AVERAGE_POPULARITY: 2.1880925, RATIO_NOVELTY: 0.0267369,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 58.6476
# Function value obtained: -0.1650
# Current minimum: -0.2292
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 200, 'topK': 251}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 37.82 sec. Users per second: 361
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'num_factors': 200, 'topK': 251} - results: PRECISION: 0.2773047, PRECISION_RECALL_MIN_DEN: 0.2781835, RECALL: 0.0478826, MAP: 0.1553326, MAP_MIN_DEN: 0.1556968, MRR: 0.5428095, NDCG: 0.2947983, F1: 0.0816642, HIT_RATE: 0.9199033, ARHR_ALL_HITS: 0.9077403, NOVELTY: 0.0057268, AVERAGE_POPULARITY: 0.3811925, DIVERSITY_MEAN_INTER_LIST: 0.9402768, DIVERSITY_HERFINDAHL: 0.9940208, COVERAGE_ITEM: 0.0502243, COVERAGE_ITEM_CORRECT: 0.0366022, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9196337, DIVERSITY_GINI: 0.0097686, SHANNON_ENTROPY: 7.8851546, RATIO_DIVERSITY_HERFINDAHL: 0.9943981, RATIO_DIVERSITY_GINI: 0.0383007, RATIO_SHANNON_ENTROPY: 0.6346648, RATIO_AVERAGE_POPULARITY: 1.9115904, RATIO_NOVELTY: 0.0272385,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 68.1736
# Function value obtained: -0.1553
# Current minimum: -0.2292
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 112, 'topK': 904}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 57.44 sec. Users per second: 238
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'num_factors': 112, 'topK': 904} - results: PRECISION: 0.3071156, PRECISION_RECALL_MIN_DEN: 0.3081289, RECALL: 0.0529419, MAP: 0.1745954, MAP_MIN_DEN: 0.1750157, MRR: 0.5674760, NDCG: 0.3224300, F1: 0.0903150, HIT_RATE: 0.9391763, ARHR_ALL_HITS: 0.9828370, NOVELTY: 0.0054151, AVERAGE_POPULARITY: 0.5571192, DIVERSITY_MEAN_INTER_LIST: 0.8938336, DIVERSITY_HERFINDAHL: 0.9893768, COVERAGE_ITEM: 0.0374329, COVERAGE_ITEM_CORRECT: 0.0259151, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9389011, DIVERSITY_GINI: 0.0054268, SHANNON_ENTROPY: 7.0062906, RATIO_DIVERSITY_HERFINDAHL: 0.9897524, RATIO_DIVERSITY_GINI: 0.0212772, RATIO_SHANNON_ENTROPY: 0.5639263, RATIO_AVERAGE_POPULARITY: 2.7938212, RATIO_NOVELTY: 0.0257560,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 91.3401
# Function value obtained: -0.1746
# Current minimum: -0.2292
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 349, 'topK': 12}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 17.75 sec. Users per second: 769
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'num_factors': 349, 'topK': 12} - results: PRECISION: 0.2435732, PRECISION_RECALL_MIN_DEN: 0.2443213, RECALL: 0.0417572, MAP: 0.1300754, MAP_MIN_DEN: 0.1304032, MRR: 0.4971803, NDCG: 0.2587880, F1: 0.0712923, HIT_RATE: 0.8933753, ARHR_ALL_HITS: 0.7968943, NOVELTY: 0.0061262, AVERAGE_POPULARITY: 0.2390767, DIVERSITY_MEAN_INTER_LIST: 0.9579358, DIVERSITY_HERFINDAHL: 0.9957866, COVERAGE_ITEM: 0.0776344, COVERAGE_ITEM_CORRECT: 0.0513871, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8931136, DIVERSITY_GINI: 0.0166396, SHANNON_ENTROPY: 8.6146835, RATIO_DIVERSITY_HERFINDAHL: 0.9961646, RATIO_DIVERSITY_GINI: 0.0652406, RATIO_SHANNON_ENTROPY: 0.6933835, RATIO_AVERAGE_POPULARITY: 1.1989134, RATIO_NOVELTY: 0.0291381,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 53.5362
# Function value obtained: -0.1301
# Current minimum: -0.2292
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 197, 'topK': 139}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.92 sec. Users per second: 427
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'num_factors': 197, 'topK': 139} - results: PRECISION: 0.2786311, PRECISION_RECALL_MIN_DEN: 0.2794630, RECALL: 0.0479262, MAP: 0.1559190, MAP_MIN_DEN: 0.1562722, MRR: 0.5457481, NDCG: 0.2960101, F1: 0.0817850, HIT_RATE: 0.9194636, ARHR_ALL_HITS: 0.9116336, NOVELTY: 0.0057378, AVERAGE_POPULARITY: 0.3781089, DIVERSITY_MEAN_INTER_LIST: 0.9434112, DIVERSITY_HERFINDAHL: 0.9943342, COVERAGE_ITEM: 0.0518301, COVERAGE_ITEM_CORRECT: 0.0373775, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9191941, DIVERSITY_GINI: 0.0103098, SHANNON_ENTROPY: 7.9660430, RATIO_DIVERSITY_HERFINDAHL: 0.9947117, RATIO_DIVERSITY_GINI: 0.0404225, RATIO_SHANNON_ENTROPY: 0.6411754, RATIO_AVERAGE_POPULARITY: 1.8961269, RATIO_NOVELTY: 0.0272906,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 60.4697
# Function value obtained: -0.1559
# Current minimum: -0.2292
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 157, 'topK': 155}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 32.82 sec. Users per second: 416
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'num_factors': 157, 'topK': 155} - results: PRECISION: 0.2930969, PRECISION_RECALL_MIN_DEN: 0.2940899, RECALL: 0.0504244, MAP: 0.1661544, MAP_MIN_DEN: 0.1665741, MRR: 0.5573996, NDCG: 0.3098887, F1: 0.0860455, HIT_RATE: 0.9289169, ARHR_ALL_HITS: 0.9500379, NOVELTY: 0.0056039, AVERAGE_POPULARITY: 0.4455314, DIVERSITY_MEAN_INTER_LIST: 0.9302797, DIVERSITY_HERFINDAHL: 0.9930212, COVERAGE_ITEM: 0.0472894, COVERAGE_ITEM_CORRECT: 0.0331691, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9286447, DIVERSITY_GINI: 0.0083393, SHANNON_ENTROPY: 7.6540676, RATIO_DIVERSITY_HERFINDAHL: 0.9933981, RATIO_DIVERSITY_GINI: 0.0326968, RATIO_SHANNON_ENTROPY: 0.6160649, RATIO_AVERAGE_POPULARITY: 2.2342350, RATIO_NOVELTY: 0.0266541,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 58.4756
# Function value obtained: -0.1662
# Current minimum: -0.2292
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 102, 'topK': 816}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 55.36 sec. Users per second: 246
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'num_factors': 102, 'topK': 816} - results: PRECISION: 0.3146270, PRECISION_RECALL_MIN_DEN: 0.3155983, RECALL: 0.0540620, MAP: 0.1792892, MAP_MIN_DEN: 0.1797309, MRR: 0.5729031, NDCG: 0.3290230, F1: 0.0922694, HIT_RATE: 0.9448190, ARHR_ALL_HITS: 0.9996901, NOVELTY: 0.0053821, AVERAGE_POPULARITY: 0.5804396, DIVERSITY_MEAN_INTER_LIST: 0.8800522, DIVERSITY_HERFINDAHL: 0.9879988, COVERAGE_ITEM: 0.0364915, COVERAGE_ITEM_CORRECT: 0.0249737, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9445421, DIVERSITY_GINI: 0.0049079, SHANNON_ENTROPY: 6.8563019, RATIO_DIVERSITY_HERFINDAHL: 0.9883738, RATIO_DIVERSITY_GINI: 0.0192430, RATIO_SHANNON_ENTROPY: 0.5518539, RATIO_AVERAGE_POPULARITY: 2.9107674, RATIO_NOVELTY: 0.0255988,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 87.1595
# Function value obtained: -0.1793
# Current minimum: -0.2292
# Iteration No: 16 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 6, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 59.72 sec. Users per second: 228
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'num_factors': 6, 'topK': 1000} - results: PRECISION: 0.3410303, PRECISION_RECALL_MIN_DEN: 0.3421585, RECALL: 0.0572839, MAP: 0.2063364, MAP_MIN_DEN: 0.2069089, MRR: 0.6110513, NDCG: 0.3602775, F1: 0.0980912, HIT_RATE: 0.9439396, ARHR_ALL_HITS: 1.1031758, NOVELTY: 0.0053285, AVERAGE_POPULARITY: 0.6355037, DIVERSITY_MEAN_INTER_LIST: 0.8364290, DIVERSITY_HERFINDAHL: 0.9836368, COVERAGE_ITEM: 0.0141758, COVERAGE_ITEM_CORRECT: 0.0122930, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9436630, DIVERSITY_GINI: 0.0035225, SHANNON_ENTROPY: 6.4056593, RATIO_DIVERSITY_HERFINDAHL: 0.9840102, RATIO_DIVERSITY_GINI: 0.0138112, RATIO_SHANNON_ENTROPY: 0.5155823, RATIO_AVERAGE_POPULARITY: 3.1869008, RATIO_NOVELTY: 0.0253440,
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 87.4940
# Function value obtained: -0.2063
# Current minimum: -0.2292
# Iteration No: 17 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 46, 'topK': 5}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.16 sec. Users per second: 964
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'num_factors': 46, 'topK': 5} - results: PRECISION: 0.2916239, PRECISION_RECALL_MIN_DEN: 0.2927434, RECALL: 0.0510266, MAP: 0.1646507, MAP_MIN_DEN: 0.1651789, MRR: 0.5628870, NDCG: 0.3091792, F1: 0.0868557, HIT_RATE: 0.9310421, ARHR_ALL_HITS: 0.9502369, NOVELTY: 0.0054551, AVERAGE_POPULARITY: 0.5566977, DIVERSITY_MEAN_INTER_LIST: 0.8708260, DIVERSITY_HERFINDAHL: 0.9870762, COVERAGE_ITEM: 0.0384850, COVERAGE_ITEM_CORRECT: 0.0186057, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9307692, DIVERSITY_GINI: 0.0048912, SHANNON_ENTROPY: 6.8588828, RATIO_DIVERSITY_HERFINDAHL: 0.9874509, RATIO_DIVERSITY_GINI: 0.0191775, RATIO_SHANNON_ENTROPY: 0.5520616, RATIO_AVERAGE_POPULARITY: 2.7917075, RATIO_NOVELTY: 0.0259462,
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 28.4272
# Function value obtained: -0.1647
# Current minimum: -0.2292
# Iteration No: 18 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 49, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 56.96 sec. Users per second: 240
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'num_factors': 49, 'topK': 1000} - results: PRECISION: 0.3689726, PRECISION_RECALL_MIN_DEN: 0.3704141, RECALL: 0.0648998, MAP: 0.2242263, MAP_MIN_DEN: 0.2248415, MRR: 0.6321184, NDCG: 0.3859564, F1: 0.1103839, HIT_RATE: 0.9628463, ARHR_ALL_HITS: 1.1716801, NOVELTY: 0.0053474, AVERAGE_POPULARITY: 0.6209447, DIVERSITY_MEAN_INTER_LIST: 0.8620405, DIVERSITY_HERFINDAHL: 0.9861977, COVERAGE_ITEM: 0.0360485, COVERAGE_ITEM_CORRECT: 0.0278531, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9625641, DIVERSITY_GINI: 0.0049892, SHANNON_ENTROPY: 6.8499299, RATIO_DIVERSITY_HERFINDAHL: 0.9865721, RATIO_DIVERSITY_GINI: 0.0195618, RATIO_SHANNON_ENTROPY: 0.5513410, RATIO_AVERAGE_POPULARITY: 3.1138913, RATIO_NOVELTY: 0.0254339,
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 87.5752
# Function value obtained: -0.2242
# Current minimum: -0.2292
# Iteration No: 19 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 30, 'topK': 730}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 48.45 sec. Users per second: 282
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'num_factors': 30, 'topK': 730} - results: PRECISION: 0.3726587, PRECISION_RECALL_MIN_DEN: 0.3740533, RECALL: 0.0649449, MAP: 0.2274893, MAP_MIN_DEN: 0.2280820, MRR: 0.6306732, NDCG: 0.3888978, F1: 0.1106128, HIT_RATE: 0.9616005, ARHR_ALL_HITS: 1.1781023, NOVELTY: 0.0054090, AVERAGE_POPULARITY: 0.5901876, DIVERSITY_MEAN_INTER_LIST: 0.8750830, DIVERSITY_HERFINDAHL: 0.9875019, COVERAGE_ITEM: 0.0347749, COVERAGE_ITEM_CORRECT: 0.0283515, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9613187, DIVERSITY_GINI: 0.0060141, SHANNON_ENTROPY: 7.1070475, RATIO_DIVERSITY_HERFINDAHL: 0.9878768, RATIO_DIVERSITY_GINI: 0.0235800, RATIO_SHANNON_ENTROPY: 0.5720361, RATIO_AVERAGE_POPULARITY: 2.9596515, RATIO_NOVELTY: 0.0257271,
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 73.2706
# Function value obtained: -0.2275
# Current minimum: -0.2292
# Iteration No: 20 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 349, 'topK': 993}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.02 min. Users per second: 223
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'num_factors': 349, 'topK': 993} - results: PRECISION: 0.2464898, PRECISION_RECALL_MIN_DEN: 0.2472908, RECALL: 0.0426057, MAP: 0.1344274, MAP_MIN_DEN: 0.1347743, MRR: 0.5115119, NDCG: 0.2645394, F1: 0.0726533, HIT_RATE: 0.8935952, ARHR_ALL_HITS: 0.8211821, NOVELTY: 0.0059957, AVERAGE_POPULARITY: 0.2708976, DIVERSITY_MEAN_INTER_LIST: 0.9602763, DIVERSITY_HERFINDAHL: 0.9960206, COVERAGE_ITEM: 0.0605238, COVERAGE_ITEM_CORRECT: 0.0450745, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8933333, DIVERSITY_GINI: 0.0145133, SHANNON_ENTROPY: 8.4655929, RATIO_DIVERSITY_HERFINDAHL: 0.9963987, RATIO_DIVERSITY_GINI: 0.0569035, RATIO_SHANNON_ENTROPY: 0.6813834, RATIO_AVERAGE_POPULARITY: 1.3584876, RATIO_NOVELTY: 0.0285173,
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 112.7745
# Function value obtained: -0.1344
# Current minimum: -0.2292
# Iteration No: 21 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 1, 'topK': 487}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.27 min. Users per second: 179
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'num_factors': 1, 'topK': 487} - results: PRECISION: 0.2837462, PRECISION_RECALL_MIN_DEN: 0.2847388, RECALL: 0.0456583, MAP: 0.1684940, MAP_MIN_DEN: 0.1690876, MRR: 0.5766992, NDCG: 0.3084543, F1: 0.0786593, HIT_RATE: 0.9061263, ARHR_ALL_HITS: 0.9676629, NOVELTY: 0.0051667, AVERAGE_POPULARITY: 0.7434318, DIVERSITY_MEAN_INTER_LIST: 0.6052057, DIVERSITY_HERFINDAHL: 0.9605161, COVERAGE_ITEM: 0.0040977, COVERAGE_ITEM_CORRECT: 0.0029902, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9058608, DIVERSITY_GINI: 0.0013211, SHANNON_ENTROPY: 4.8326895, RATIO_DIVERSITY_HERFINDAHL: 0.9608808, RATIO_DIVERSITY_GINI: 0.0051797, RATIO_SHANNON_ENTROPY: 0.3889763, RATIO_AVERAGE_POPULARITY: 3.7281347, RATIO_NOVELTY: 0.0245742,
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 96.4454
# Function value obtained: -0.1685
# Current minimum: -0.2292
# Iteration No: 22 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 42, 'topK': 843}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 52.77 sec. Users per second: 259
# SearchBayesianSkopt: New best config found. Config 21: {'num_factors': 42, 'topK': 843} - results: PRECISION: 0.3753334, PRECISION_RECALL_MIN_DEN: 0.3767854, RECALL: 0.0660566, MAP: 0.2295136, MAP_MIN_DEN: 0.2301522, MRR: 0.6375058, NDCG: 0.3922078, F1: 0.1123417, HIT_RATE: 0.9660706, ARHR_ALL_HITS: 1.1896696, NOVELTY: 0.0053700, AVERAGE_POPULARITY: 0.6107853, DIVERSITY_MEAN_INTER_LIST: 0.8693817, DIVERSITY_HERFINDAHL: 0.9869318, COVERAGE_ITEM: 0.0364915, COVERAGE_ITEM_CORRECT: 0.0290714, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9657875, DIVERSITY_GINI: 0.0056142, SHANNON_ENTROPY: 7.0126212, RATIO_DIVERSITY_HERFINDAHL: 0.9873065, RATIO_DIVERSITY_GINI: 0.0220121, RATIO_SHANNON_ENTROPY: 0.5644358, RATIO_AVERAGE_POPULARITY: 3.0629443, RATIO_NOVELTY: 0.0255415,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender
#
# PureSVDItemRecommender: Saving model in file 'result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender_best_model'
# PureSVDItemRecommender: Saving complete
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 94.8040
# Function value obtained: -0.2295
# Current minimum: -0.2295
# Iteration No: 23 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 49, 'topK': 589}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 46.49 sec. Users per second: 294
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'num_factors': 49, 'topK': 589} - results: PRECISION: 0.3717573, PRECISION_RECALL_MIN_DEN: 0.3732266, RECALL: 0.0655746, MAP: 0.2260316, MAP_MIN_DEN: 0.2266361, MRR: 0.6309817, NDCG: 0.3880730, F1: 0.1114844, HIT_RATE: 0.9650447, ARHR_ALL_HITS: 1.1757341, NOVELTY: 0.0053486, AVERAGE_POPULARITY: 0.6223277, DIVERSITY_MEAN_INTER_LIST: 0.8574483, DIVERSITY_HERFINDAHL: 0.9857385, COVERAGE_ITEM: 0.0356609, COVERAGE_ITEM_CORRECT: 0.0277424, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9647619, DIVERSITY_GINI: 0.0050713, SHANNON_ENTROPY: 6.8638509, RATIO_DIVERSITY_HERFINDAHL: 0.9861128, RATIO_DIVERSITY_GINI: 0.0198834, RATIO_SHANNON_ENTROPY: 0.5524615, RATIO_AVERAGE_POPULARITY: 3.1208264, RATIO_NOVELTY: 0.0254397,
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 71.8398
# Function value obtained: -0.2260
# Current minimum: -0.2295
# Iteration No: 24 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 261, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.02 min. Users per second: 224
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'num_factors': 261, 'topK': 1000} - results: PRECISION: 0.2564268, PRECISION_RECALL_MIN_DEN: 0.2572513, RECALL: 0.0442374, MAP: 0.1414411, MAP_MIN_DEN: 0.1418020, MRR: 0.5278701, NDCG: 0.2754421, F1: 0.0754573, HIT_RATE: 0.9044409, ARHR_ALL_HITS: 0.8556463, NOVELTY: 0.0058268, AVERAGE_POPULARITY: 0.3338080, DIVERSITY_MEAN_INTER_LIST: 0.9467487, DIVERSITY_HERFINDAHL: 0.9946679, COVERAGE_ITEM: 0.0532698, COVERAGE_ITEM_CORRECT: 0.0387065, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9041758, DIVERSITY_GINI: 0.0108634, SHANNON_ENTROPY: 8.0388614, RATIO_DIVERSITY_HERFINDAHL: 0.9950455, RATIO_DIVERSITY_GINI: 0.0425930, RATIO_SHANNON_ENTROPY: 0.6470364, RATIO_AVERAGE_POPULARITY: 1.6739684, RATIO_NOVELTY: 0.0277139,
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 107.4636
# Function value obtained: -0.1414
# Current minimum: -0.2295
# Iteration No: 25 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 42, 'topK': 705}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 49.14 sec. Users per second: 278
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'num_factors': 42, 'topK': 705} - results: PRECISION: 0.3734941, PRECISION_RECALL_MIN_DEN: 0.3748759, RECALL: 0.0655565, MAP: 0.2284900, MAP_MIN_DEN: 0.2291141, MRR: 0.6357348, NDCG: 0.3904696, F1: 0.1115360, HIT_RATE: 0.9643119, ARHR_ALL_HITS: 1.1847814, NOVELTY: 0.0053763, AVERAGE_POPULARITY: 0.6051736, DIVERSITY_MEAN_INTER_LIST: 0.8778277, DIVERSITY_HERFINDAHL: 0.9877763, COVERAGE_ITEM: 0.0363808, COVERAGE_ITEM_CORRECT: 0.0287945, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9640293, DIVERSITY_GINI: 0.0056756, SHANNON_ENTROPY: 7.0493669, RATIO_DIVERSITY_HERFINDAHL: 0.9881513, RATIO_DIVERSITY_GINI: 0.0222527, RATIO_SHANNON_ENTROPY: 0.5673934, RATIO_AVERAGE_POPULARITY: 3.0348025, RATIO_NOVELTY: 0.0255713,
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 74.3718
# Function value obtained: -0.2285
# Current minimum: -0.2295
# Iteration No: 26 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 79, 'topK': 402}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 42.43 sec. Users per second: 322
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'num_factors': 79, 'topK': 402} - results: PRECISION: 0.3427451, PRECISION_RECALL_MIN_DEN: 0.3440104, RECALL: 0.0595815, MAP: 0.2017586, MAP_MIN_DEN: 0.2023179, MRR: 0.6009073, NDCG: 0.3579845, F1: 0.1015159, HIT_RATE: 0.9541258, ARHR_ALL_HITS: 1.0852738, NOVELTY: 0.0053215, AVERAGE_POPULARITY: 0.6309395, DIVERSITY_MEAN_INTER_LIST: 0.8521859, DIVERSITY_HERFINDAHL: 0.9852123, COVERAGE_ITEM: 0.0352179, COVERAGE_ITEM_CORRECT: 0.0243646, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9538462, DIVERSITY_GINI: 0.0042639, SHANNON_ENTROPY: 6.6363620, RATIO_DIVERSITY_HERFINDAHL: 0.9855864, RATIO_DIVERSITY_GINI: 0.0167178, RATIO_SHANNON_ENTROPY: 0.5341513, RATIO_AVERAGE_POPULARITY: 3.1640127, RATIO_NOVELTY: 0.0253105,
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 65.9375
# Function value obtained: -0.2018
# Current minimum: -0.2295
# Iteration No: 27 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 39, 'topK': 402}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.62 sec. Users per second: 353
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'num_factors': 39, 'topK': 402} - results: PRECISION: 0.3736993, PRECISION_RECALL_MIN_DEN: 0.3750972, RECALL: 0.0655103, MAP: 0.2281617, MAP_MIN_DEN: 0.2287633, MRR: 0.6335681, NDCG: 0.3902142, F1: 0.1114783, HIT_RATE: 0.9651913, ARHR_ALL_HITS: 1.1830276, NOVELTY: 0.0053791, AVERAGE_POPULARITY: 0.6061546, DIVERSITY_MEAN_INTER_LIST: 0.8698733, DIVERSITY_HERFINDAHL: 0.9869810, COVERAGE_ITEM: 0.0364915, COVERAGE_ITEM_CORRECT: 0.0284623, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9649084, DIVERSITY_GINI: 0.0056239, SHANNON_ENTROPY: 7.0161458, RATIO_DIVERSITY_HERFINDAHL: 0.9873556, RATIO_DIVERSITY_GINI: 0.0220501, RATIO_SHANNON_ENTROPY: 0.5647195, RATIO_AVERAGE_POPULARITY: 3.0397224, RATIO_NOVELTY: 0.0255846,
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 58.9772
# Function value obtained: -0.2282
# Current minimum: -0.2295
# Iteration No: 28 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 35, 'topK': 533}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 43.31 sec. Users per second: 315
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'num_factors': 35, 'topK': 533} - results: PRECISION: 0.3735014, PRECISION_RECALL_MIN_DEN: 0.3748783, RECALL: 0.0653957, MAP: 0.2276925, MAP_MIN_DEN: 0.2283114, MRR: 0.6324725, NDCG: 0.3896205, F1: 0.1113034, HIT_RATE: 0.9629928, ARHR_ALL_HITS: 1.1799680, NOVELTY: 0.0054033, AVERAGE_POPULARITY: 0.5923166, DIVERSITY_MEAN_INTER_LIST: 0.8771879, DIVERSITY_HERFINDAHL: 0.9877124, COVERAGE_ITEM: 0.0370452, COVERAGE_ITEM_CORRECT: 0.0293482, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9627106, DIVERSITY_GINI: 0.0060191, SHANNON_ENTROPY: 7.1149625, RATIO_DIVERSITY_HERFINDAHL: 0.9880873, RATIO_DIVERSITY_GINI: 0.0235998, RATIO_SHANNON_ENTROPY: 0.5726731, RATIO_AVERAGE_POPULARITY: 2.9703277, RATIO_NOVELTY: 0.0257000,
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 65.3939
# Function value obtained: -0.2277
# Current minimum: -0.2295
# Iteration No: 29 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 106, 'topK': 5}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 16.16 sec. Users per second: 845
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'num_factors': 106, 'topK': 5} - results: PRECISION: 0.2674190, PRECISION_RECALL_MIN_DEN: 0.2685793, RECALL: 0.0459236, MAP: 0.1426948, MAP_MIN_DEN: 0.1432203, MRR: 0.5105832, NDCG: 0.2787666, F1: 0.0783860, HIT_RATE: 0.9128682, ARHR_ALL_HITS: 0.8438001, NOVELTY: 0.0055486, AVERAGE_POPULARITY: 0.4810343, DIVERSITY_MEAN_INTER_LIST: 0.9172960, DIVERSITY_HERFINDAHL: 0.9917229, COVERAGE_ITEM: 0.0415305, COVERAGE_ITEM_CORRECT: 0.0190487, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9126007, DIVERSITY_GINI: 0.0067246, SHANNON_ENTROPY: 7.3427980, RATIO_DIVERSITY_HERFINDAHL: 0.9920994, RATIO_DIVERSITY_GINI: 0.0263656, RATIO_SHANNON_ENTROPY: 0.5910113, RATIO_AVERAGE_POPULARITY: 2.4122732, RATIO_NOVELTY: 0.0263907,
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 35.7772
# Function value obtained: -0.1427
# Current minimum: -0.2295
# Iteration No: 30 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 75, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 58.48 sec. Users per second: 233
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'num_factors': 75, 'topK': 1000} - results: PRECISION: 0.3397699, PRECISION_RECALL_MIN_DEN: 0.3409120, RECALL: 0.0588227, MAP: 0.1983391, MAP_MIN_DEN: 0.1988347, MRR: 0.5923706, NDCG: 0.3535622, F1: 0.1002838, HIT_RATE: 0.9525868, ARHR_ALL_HITS: 1.0688320, NOVELTY: 0.0053119, AVERAGE_POPULARITY: 0.6372060, DIVERSITY_MEAN_INTER_LIST: 0.8434973, DIVERSITY_HERFINDAHL: 0.9843435, COVERAGE_ITEM: 0.0344980, COVERAGE_ITEM_CORRECT: 0.0235893, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9523077, DIVERSITY_GINI: 0.0040420, SHANNON_ENTROPY: 6.5543135, RATIO_DIVERSITY_HERFINDAHL: 0.9847172, RATIO_DIVERSITY_GINI: 0.0158479, RATIO_SHANNON_ENTROPY: 0.5275473, RATIO_AVERAGE_POPULARITY: 3.1954376, RATIO_NOVELTY: 0.0252653,
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 92.7447
# Function value obtained: -0.1983
# Current minimum: -0.2295
# Iteration No: 31 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 33, 'topK': 890}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 53.27 sec. Users per second: 256
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'num_factors': 33, 'topK': 890} - results: PRECISION: 0.3736699, PRECISION_RECALL_MIN_DEN: 0.3751088, RECALL: 0.0655567, MAP: 0.2278390, MAP_MIN_DEN: 0.2284454, MRR: 0.6321073, NDCG: 0.3898224, F1: 0.1115440, HIT_RATE: 0.9639455, ARHR_ALL_HITS: 1.1805355, NOVELTY: 0.0054160, AVERAGE_POPULARITY: 0.5847099, DIVERSITY_MEAN_INTER_LIST: 0.8827786, DIVERSITY_HERFINDAHL: 0.9882714, COVERAGE_ITEM: 0.0363254, COVERAGE_ITEM_CORRECT: 0.0300681, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9636630, DIVERSITY_GINI: 0.0062840, SHANNON_ENTROPY: 7.1794351, RATIO_DIVERSITY_HERFINDAHL: 0.9886466, RATIO_DIVERSITY_GINI: 0.0246383, RATIO_SHANNON_ENTROPY: 0.5778624, RATIO_AVERAGE_POPULARITY: 2.9321819, RATIO_NOVELTY: 0.0257603,
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 81.0128
# Function value obtained: -0.2278
# Current minimum: -0.2295
# Iteration No: 32 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 47, 'topK': 453}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 41.77 sec. Users per second: 327
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'num_factors': 47, 'topK': 453} - results: PRECISION: 0.3714055, PRECISION_RECALL_MIN_DEN: 0.3728244, RECALL: 0.0655096, MAP: 0.2262019, MAP_MIN_DEN: 0.2268350, MRR: 0.6341507, NDCG: 0.3883342, F1: 0.1113747, HIT_RATE: 0.9636524, ARHR_ALL_HITS: 1.1784877, NOVELTY: 0.0053565, AVERAGE_POPULARITY: 0.6174484, DIVERSITY_MEAN_INTER_LIST: 0.8651839, DIVERSITY_HERFINDAHL: 0.9865120, COVERAGE_ITEM: 0.0358824, COVERAGE_ITEM_CORRECT: 0.0277978, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9633700, DIVERSITY_GINI: 0.0051803, SHANNON_ENTROPY: 6.9086747, RATIO_DIVERSITY_HERFINDAHL: 0.9868865, RATIO_DIVERSITY_GINI: 0.0203108, RATIO_SHANNON_ENTROPY: 0.5560693, RATIO_AVERAGE_POPULARITY: 3.0963580, RATIO_NOVELTY: 0.0254771,
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 63.5724
# Function value obtained: -0.2262
# Current minimum: -0.2295
# Iteration No: 33 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 35, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 55.58 sec. Users per second: 246
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'num_factors': 35, 'topK': 1000} - results: PRECISION: 0.3735234, PRECISION_RECALL_MIN_DEN: 0.3748802, RECALL: 0.0654154, MAP: 0.2279564, MAP_MIN_DEN: 0.2285764, MRR: 0.6344080, NDCG: 0.3898723, F1: 0.1113329, HIT_RATE: 0.9639455, ARHR_ALL_HITS: 1.1816011, NOVELTY: 0.0054060, AVERAGE_POPULARITY: 0.5902920, DIVERSITY_MEAN_INTER_LIST: 0.8781880, DIVERSITY_HERFINDAHL: 0.9878124, COVERAGE_ITEM: 0.0359378, COVERAGE_ITEM_CORRECT: 0.0295697, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9636630, DIVERSITY_GINI: 0.0061722, SHANNON_ENTROPY: 7.1466800, RATIO_DIVERSITY_HERFINDAHL: 0.9881874, RATIO_DIVERSITY_GINI: 0.0241997, RATIO_SHANNON_ENTROPY: 0.5752260, RATIO_AVERAGE_POPULARITY: 2.9601751, RATIO_NOVELTY: 0.0257126,
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 85.0880
# Function value obtained: -0.2280
# Current minimum: -0.2295
# Iteration No: 34 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 53, 'topK': 802}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 53.34 sec. Users per second: 256
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'num_factors': 53, 'topK': 802} - results: PRECISION: 0.3672944, PRECISION_RECALL_MIN_DEN: 0.3686695, RECALL: 0.0644390, MAP: 0.2212852, MAP_MIN_DEN: 0.2219093, MRR: 0.6234969, NDCG: 0.3825698, F1: 0.1096422, HIT_RATE: 0.9627730, ARHR_ALL_HITS: 1.1567207, NOVELTY: 0.0053311, AVERAGE_POPULARITY: 0.6318639, DIVERSITY_MEAN_INTER_LIST: 0.8508839, DIVERSITY_HERFINDAHL: 0.9850822, COVERAGE_ITEM: 0.0356609, COVERAGE_ITEM_CORRECT: 0.0269118, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9624908, DIVERSITY_GINI: 0.0047110, SHANNON_ENTROPY: 6.7590680, RATIO_DIVERSITY_HERFINDAHL: 0.9854561, RATIO_DIVERSITY_GINI: 0.0184710, RATIO_SHANNON_ENTROPY: 0.5440277, RATIO_AVERAGE_POPULARITY: 3.1686481, RATIO_NOVELTY: 0.0253565,
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 81.9911
# Function value obtained: -0.2213
# Current minimum: -0.2295
# Iteration No: 35 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 218, 'topK': 993}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.01 min. Users per second: 224
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'num_factors': 218, 'topK': 993} - results: PRECISION: 0.2675436, PRECISION_RECALL_MIN_DEN: 0.2684476, RECALL: 0.0464516, MAP: 0.1482484, MAP_MIN_DEN: 0.1486063, MRR: 0.5333203, NDCG: 0.2851979, F1: 0.0791594, HIT_RATE: 0.9112560, ARHR_ALL_HITS: 0.8802707, NOVELTY: 0.0057362, AVERAGE_POPULARITY: 0.3737472, DIVERSITY_MEAN_INTER_LIST: 0.9391504, DIVERSITY_HERFINDAHL: 0.9939082, COVERAGE_ITEM: 0.0497259, COVERAGE_ITEM_CORRECT: 0.0359378, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9109890, DIVERSITY_GINI: 0.0094193, SHANNON_ENTROPY: 7.8326121, RATIO_DIVERSITY_HERFINDAHL: 0.9942855, RATIO_DIVERSITY_GINI: 0.0369310, RATIO_SHANNON_ENTROPY: 0.6304357, RATIO_AVERAGE_POPULARITY: 1.8742538, RATIO_NOVELTY: 0.0272831,
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 103.1355
# Function value obtained: -0.1482
# Current minimum: -0.2295
# Iteration No: 36 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 37, 'topK': 782}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 50.52 sec. Users per second: 270
# SearchBayesianSkopt: New best config found. Config 35: {'num_factors': 37, 'topK': 782} - results: PRECISION: 0.3759050, PRECISION_RECALL_MIN_DEN: 0.3773216, RECALL: 0.0659887, MAP: 0.2295448, MAP_MIN_DEN: 0.2301941, MRR: 0.6354080, NDCG: 0.3920842, F1: 0.1122689, HIT_RATE: 0.9653378, ARHR_ALL_HITS: 1.1873201, NOVELTY: 0.0053971, AVERAGE_POPULARITY: 0.5947937, DIVERSITY_MEAN_INTER_LIST: 0.8798040, DIVERSITY_HERFINDAHL: 0.9879740, COVERAGE_ITEM: 0.0364915, COVERAGE_ITEM_CORRECT: 0.0300681, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9650549, DIVERSITY_GINI: 0.0060512, SHANNON_ENTROPY: 7.1294125, RATIO_DIVERSITY_HERFINDAHL: 0.9883490, RATIO_DIVERSITY_GINI: 0.0237257, RATIO_SHANNON_ENTROPY: 0.5738362, RATIO_AVERAGE_POPULARITY: 2.9827499, RATIO_NOVELTY: 0.0256702,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender
#
# PureSVDItemRecommender: Saving model in file 'result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender_best_model'
# PureSVDItemRecommender: Saving complete
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 90.6621
# Function value obtained: -0.2295
# Current minimum: -0.2295
# Iteration No: 37 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 24, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 55.58 sec. Users per second: 245
# SearchBayesianSkopt: New best config found. Config 36: {'num_factors': 24, 'topK': 1000} - results: PRECISION: 0.3747545, PRECISION_RECALL_MIN_DEN: 0.3761471, RECALL: 0.0650300, MAP: 0.2304729, MAP_MIN_DEN: 0.2312110, MRR: 0.6380316, NDCG: 0.3921154, F1: 0.1108283, HIT_RATE: 0.9621134, ARHR_ALL_HITS: 1.1903790, NOVELTY: 0.0054099, AVERAGE_POPULARITY: 0.5936168, DIVERSITY_MEAN_INTER_LIST: 0.8683776, DIVERSITY_HERFINDAHL: 0.9868314, COVERAGE_ITEM: 0.0339997, COVERAGE_ITEM_CORRECT: 0.0280193, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9618315, DIVERSITY_GINI: 0.0061664, SHANNON_ENTROPY: 7.1142863, RATIO_DIVERSITY_HERFINDAHL: 0.9872060, RATIO_DIVERSITY_GINI: 0.0241772, RATIO_SHANNON_ENTROPY: 0.5726187, RATIO_AVERAGE_POPULARITY: 2.9768483, RATIO_NOVELTY: 0.0257312,
#
# ...
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 111.2147
# Function value obtained: -0.1395
# Current minimum: -0.2305
# Iteration No: 39 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 22, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 54.79 sec. Users per second: 249
# SearchBayesianSkopt: Config 38 is suboptimal. Config: {'num_factors': 22, 'topK': 1000} - results: PRECISION: 0.3728492, PRECISION_RECALL_MIN_DEN: 0.3742390, RECALL: 0.0643745, MAP: 0.2293331, MAP_MIN_DEN: 0.2300594, MRR: 0.6363295, NDCG: 0.3904441, F1: 0.1097926, HIT_RATE: 0.9602081, ARHR_ALL_HITS: 1.1861445, NOVELTY: 0.0054036, AVERAGE_POPULARITY: 0.5994081, DIVERSITY_MEAN_INTER_LIST: 0.8575027, DIVERSITY_HERFINDAHL: 0.9857440, COVERAGE_ITEM: 0.0323384, COVERAGE_ITEM_CORRECT: 0.0274655, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9599267, DIVERSITY_GINI: 0.0058770, SHANNON_ENTROPY: 7.0267846, RATIO_DIVERSITY_HERFINDAHL: 0.9861182, RATIO_DIVERSITY_GINI: 0.0230427, RATIO_SHANNON_ENTROPY: 0.5655758, RATIO_AVERAGE_POPULARITY: 3.0058901, RATIO_NOVELTY: 0.0257013,
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 83.7652
# Function value obtained: -0.2293
# Current minimum: -0.2305
# Iteration No: 40 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 26, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 55.30 sec. Users per second: 247
# SearchBayesianSkopt: Config 39 is suboptimal. Config: {'num_factors': 26, 'topK': 1000} - results: PRECISION: 0.3731936, PRECISION_RECALL_MIN_DEN: 0.3745776, RECALL: 0.0650143, MAP: 0.2289505, MAP_MIN_DEN: 0.2296379, MRR: 0.6385763, NDCG: 0.3908959, F1: 0.1107370, HIT_RATE: 0.9626997, ARHR_ALL_HITS: 1.1880752, NOVELTY: 0.0054221, AVERAGE_POPULARITY: 0.5851798, DIVERSITY_MEAN_INTER_LIST: 0.8759560, DIVERSITY_HERFINDAHL: 0.9875892, COVERAGE_ITEM: 0.0343873, COVERAGE_ITEM_CORRECT: 0.0287391, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9624176, DIVERSITY_GINI: 0.0063624, SHANNON_ENTROPY: 7.1739677, RATIO_DIVERSITY_HERFINDAHL: 0.9879641, RATIO_DIVERSITY_GINI: 0.0249455, RATIO_SHANNON_ENTROPY: 0.5774224, RATIO_AVERAGE_POPULARITY: 2.9345386, RATIO_NOVELTY: 0.0257891,
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 84.4953
# Function value obtained: -0.2290
# Current minimum: -0.2305
# Iteration No: 41 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 21, 'topK': 5}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 12.68 sec. Users per second: 1076
# SearchBayesianSkopt: Config 40 is suboptimal. Config: {'num_factors': 21, 'topK': 5} - results: PRECISION: 0.2693830, PRECISION_RECALL_MIN_DEN: 0.2702822, RECALL: 0.0461778, MAP: 0.1538212, MAP_MIN_DEN: 0.1542503, MRR: 0.5608036, NDCG: 0.2925491, F1: 0.0788407, HIT_RATE: 0.9165323, ARHR_ALL_HITS: 0.9173585, NOVELTY: 0.0055306, AVERAGE_POPULARITY: 0.5413011, DIVERSITY_MEAN_INTER_LIST: 0.8553562, DIVERSITY_HERFINDAHL: 0.9855294, COVERAGE_ITEM: 0.0402569, COVERAGE_ITEM_CORRECT: 0.0222604, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9162637, DIVERSITY_GINI: 0.0052402, SHANNON_ENTROPY: 6.8961617, RATIO_DIVERSITY_HERFINDAHL: 0.9859035, RATIO_DIVERSITY_GINI: 0.0205456, RATIO_SHANNON_ENTROPY: 0.5550622, RATIO_AVERAGE_POPULARITY: 2.7144970, RATIO_NOVELTY: 0.0263053,
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 26.0033
# Function value obtained: -0.1538
# Current minimum: -0.2305
# Iteration No: 42 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 23, 'topK': 843}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 51.54 sec. Users per second: 265
# SearchBayesianSkopt: Config 41 is suboptimal. Config: {'num_factors': 23, 'topK': 843} - results: PRECISION: 0.3743881, PRECISION_RECALL_MIN_DEN: 0.3757572, RECALL: 0.0647317, MAP: 0.2300994, MAP_MIN_DEN: 0.2308341, MRR: 0.6376105, NDCG: 0.3916641, F1: 0.1103790, HIT_RATE: 0.9616005, ARHR_ALL_HITS: 1.1889323, NOVELTY: 0.0054015, AVERAGE_POPULARITY: 0.6000395, DIVERSITY_MEAN_INTER_LIST: 0.8591723, DIVERSITY_HERFINDAHL: 0.9859109, COVERAGE_ITEM: 0.0328368, COVERAGE_ITEM_CORRECT: 0.0276317, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9613187, DIVERSITY_GINI: 0.0058780, SHANNON_ENTROPY: 7.0330553, RATIO_DIVERSITY_HERFINDAHL: 0.9862852, RATIO_DIVERSITY_GINI: 0.0230463, RATIO_SHANNON_ENTROPY: 0.5660805, RATIO_AVERAGE_POPULARITY: 3.0090566, RATIO_NOVELTY: 0.0256913,
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 77.9812
# Function value obtained: -0.2301
# Current minimum: -0.2305
# Iteration No: 43 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 63, 'topK': 516}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 45.54 sec. Users per second: 300
# SearchBayesianSkopt: Config 42 is suboptimal. Config: {'num_factors': 63, 'topK': 516} - results: PRECISION: 0.3550344, PRECISION_RECALL_MIN_DEN: 0.3563490, RECALL: 0.0618507, MAP: 0.2108399, MAP_MIN_DEN: 0.2114371, MRR: 0.6064925, NDCG: 0.3692693, F1: 0.1053486, HIT_RATE: 0.9574234, ARHR_ALL_HITS: 1.1152778, NOVELTY: 0.0053091, AVERAGE_POPULARITY: 0.6446971, DIVERSITY_MEAN_INTER_LIST: 0.8342435, DIVERSITY_HERFINDAHL: 0.9834182, COVERAGE_ITEM: 0.0350518, COVERAGE_ITEM_CORRECT: 0.0250291, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9571429, DIVERSITY_GINI: 0.0041784, SHANNON_ENTROPY: 6.5828081, RATIO_DIVERSITY_HERFINDAHL: 0.9837916, RATIO_DIVERSITY_GINI: 0.0163827, RATIO_SHANNON_ENTROPY: 0.5298408, RATIO_AVERAGE_POPULARITY: 3.2330035, RATIO_NOVELTY: 0.0252515,
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 70.3540
# Function value obtained: -0.2108
# Current minimum: -0.2305
# Iteration No: 44 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 41, 'topK': 517}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 43.52 sec. Users per second: 314
# SearchBayesianSkopt: Config 43 is suboptimal. Config: {'num_factors': 41, 'topK': 517} - results: PRECISION: 0.3707240, PRECISION_RECALL_MIN_DEN: 0.3721112, RECALL: 0.0651360, MAP: 0.2251966, MAP_MIN_DEN: 0.2258286, MRR: 0.6319236, NDCG: 0.3869699, F1: 0.1108038, HIT_RATE: 0.9637989, ARHR_ALL_HITS: 1.1727061, NOVELTY: 0.0053708, AVERAGE_POPULARITY: 0.6092290, DIVERSITY_MEAN_INTER_LIST: 0.8689932, DIVERSITY_HERFINDAHL: 0.9868929, COVERAGE_ITEM: 0.0363254, COVERAGE_ITEM_CORRECT: 0.0280746, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9635165, DIVERSITY_GINI: 0.0053663, SHANNON_ENTROPY: 6.9579275, RATIO_DIVERSITY_HERFINDAHL: 0.9872676, RATIO_DIVERSITY_GINI: 0.0210403, RATIO_SHANNON_ENTROPY: 0.5600336, RATIO_AVERAGE_POPULARITY: 3.0551395, RATIO_NOVELTY: 0.0255451,
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 66.5616
# Function value obtained: -0.2252
# Current minimum: -0.2305
# Iteration No: 45 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 26, 'topK': 452}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 39.65 sec. Users per second: 344
# SearchBayesianSkopt: Config 44 is suboptimal. Config: {'num_factors': 26, 'topK': 452} - results: PRECISION: 0.3721017, PRECISION_RECALL_MIN_DEN: 0.3735162, RECALL: 0.0647127, MAP: 0.2281363, MAP_MIN_DEN: 0.2288217, MRR: 0.6365060, NDCG: 0.3895819, F1: 0.1102515, HIT_RATE: 0.9618203, ARHR_ALL_HITS: 1.1834870, NOVELTY: 0.0054045, AVERAGE_POPULARITY: 0.5972913, DIVERSITY_MEAN_INTER_LIST: 0.8626777, DIVERSITY_HERFINDAHL: 0.9862615, COVERAGE_ITEM: 0.0342212, COVERAGE_ITEM_CORRECT: 0.0277978, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9615385, DIVERSITY_GINI: 0.0058451, SHANNON_ENTROPY: 7.0400596, RATIO_DIVERSITY_HERFINDAHL: 0.9866359, RATIO_DIVERSITY_GINI: 0.0229176, RATIO_SHANNON_ENTROPY: 0.5666443, RATIO_AVERAGE_POPULARITY: 2.9952750, RATIO_NOVELTY: 0.0257055,
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 59.8748
# Function value obtained: -0.2281
# Current minimum: -0.2305
# Iteration No: 46 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 24, 'topK': 925}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 53.79 sec. Users per second: 254
# SearchBayesianSkopt: New best config found. Config 45: {'num_factors': 24, 'topK': 925} - results: PRECISION: 0.3748864, PRECISION_RECALL_MIN_DEN: 0.3762832, RECALL: 0.0649201, MAP: 0.2305191, MAP_MIN_DEN: 0.2312471, MRR: 0.6379821, NDCG: 0.3921173, F1: 0.1106744, HIT_RATE: 0.9616738, ARHR_ALL_HITS: 1.1901029, NOVELTY: 0.0054062, AVERAGE_POPULARITY: 0.5958104, DIVERSITY_MEAN_INTER_LIST: 0.8657960, DIVERSITY_HERFINDAHL: 0.9865733, COVERAGE_ITEM: 0.0337228, COVERAGE_ITEM_CORRECT: 0.0281854, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9613919, DIVERSITY_GINI: 0.0060857, SHANNON_ENTROPY: 7.0917312, RATIO_DIVERSITY_HERFINDAHL: 0.9869478, RATIO_DIVERSITY_GINI: 0.0238608, RATIO_SHANNON_ENTROPY: 0.5708033, RATIO_AVERAGE_POPULARITY: 2.9878486, RATIO_NOVELTY: 0.0257135,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender
#
# PureSVDItemRecommender: Saving model in file 'result_experiments/PureSVD_Item_AUG_subgenre_channel/PureSVDItemRecommender_best_model'
# PureSVDItemRecommender: Saving complete
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 97.4979
# Function value obtained: -0.2305
# Current minimum: -0.2305
# Iteration No: 47 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 141, 'topK': 1000}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.00 min. Users per second: 227
# SearchBayesianSkopt: Config 46 is suboptimal. Config: {'num_factors': 141, 'topK': 1000} - results: PRECISION: 0.2948776, PRECISION_RECALL_MIN_DEN: 0.2958555, RECALL: 0.0506486, MAP: 0.1657787, MAP_MIN_DEN: 0.1661998, MRR: 0.5570311, NDCG: 0.3104965, F1: 0.0864486, HIT_RATE: 0.9329474, ARHR_ALL_HITS: 0.9486541, NOVELTY: 0.0055053, AVERAGE_POPULARITY: 0.4982920, DIVERSITY_MEAN_INTER_LIST: 0.9124888, DIVERSITY_HERFINDAHL: 0.9912422, COVERAGE_ITEM: 0.0410322, COVERAGE_ITEM_CORRECT: 0.0290714, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9326740, DIVERSITY_GINI: 0.0066128, SHANNON_ENTROPY: 7.3112936, RATIO_DIVERSITY_HERFINDAHL: 0.9916185, RATIO_DIVERSITY_GINI: 0.0259276, RATIO_SHANNON_ENTROPY: 0.5884755, RATIO_AVERAGE_POPULARITY: 2.4988167, RATIO_NOVELTY: 0.0261851,
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 98.9959
# Function value obtained: -0.1658
# Current minimum: -0.2305
# Iteration No: 48 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 21, 'topK': 609}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 44.98 sec. Users per second: 303
# SearchBayesianSkopt: Config 47 is suboptimal. Config: {'num_factors': 21, 'topK': 609} - results: PRECISION: 0.3713396, PRECISION_RECALL_MIN_DEN: 0.3727071, RECALL: 0.0640805, MAP: 0.2285056, MAP_MIN_DEN: 0.2292259, MRR: 0.6365367, NDCG: 0.3893360, F1: 0.1092996, HIT_RATE: 0.9596219, ARHR_ALL_HITS: 1.1840126, NOVELTY: 0.0053815, AVERAGE_POPULARITY: 0.6127258, DIVERSITY_MEAN_INTER_LIST: 0.8439451, DIVERSITY_HERFINDAHL: 0.9843883, COVERAGE_ITEM: 0.0315632, COVERAGE_ITEM_CORRECT: 0.0261366, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9593407, DIVERSITY_GINI: 0.0053072, SHANNON_ENTROPY: 6.8768462, RATIO_DIVERSITY_HERFINDAHL: 0.9847620, RATIO_DIVERSITY_GINI: 0.0208084, RATIO_SHANNON_ENTROPY: 0.5535075, RATIO_AVERAGE_POPULARITY: 3.0726751, RATIO_NOVELTY: 0.0255961,
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 68.0615
# Function value obtained: -0.2285
# Current minimum: -0.2305
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 26, 'topK': 583}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 44.58 sec. Users per second: 306
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'num_factors': 26, 'topK': 583} - results: PRECISION: 0.3726513, PRECISION_RECALL_MIN_DEN: 0.3740347, RECALL: 0.0647785, MAP: 0.2286090, MAP_MIN_DEN: 0.2292896, MRR: 0.6372914, NDCG: 0.3902515, F1: 0.1103711, HIT_RATE: 0.9611608, ARHR_ALL_HITS: 1.1858450, NOVELTY: 0.0054106, AVERAGE_POPULARITY: 0.5929728, DIVERSITY_MEAN_INTER_LIST: 0.8687905, DIVERSITY_HERFINDAHL: 0.9868727, COVERAGE_ITEM: 0.0344980, COVERAGE_ITEM_CORRECT: 0.0285730, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9608791, DIVERSITY_GINI: 0.0060585, SHANNON_ENTROPY: 7.0985570, RATIO_DIVERSITY_HERFINDAHL: 0.9872473, RATIO_DIVERSITY_GINI: 0.0237540, RATIO_SHANNON_ENTROPY: 0.5713527, RATIO_AVERAGE_POPULARITY: 2.9736185, RATIO_NOVELTY: 0.0257343,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 66.9648
# Function value obtained: -0.2286
# Current minimum: -0.2305
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'num_factors': 271, 'topK': 5}
# PureSVDItemRecommender: Computing SVD decomposition...
# PureSVDItemRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 13646 (100.0%) in 15.09 sec. Users per second: 904
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'num_factors': 271, 'topK': 5} - results: PRECISION: 0.2279789, PRECISION_RECALL_MIN_DEN: 0.2286933, RECALL: 0.0390345, MAP: 0.1183678, MAP_MIN_DEN: 0.1186895, MRR: 0.4795939, NDCG: 0.2424064, F1: 0.0666562, HIT_RATE: 0.8806244, ARHR_ALL_HITS: 0.7472332, NOVELTY: 0.0059576, AVERAGE_POPULARITY: 0.2913300, DIVERSITY_MEAN_INTER_LIST: 0.9393966, DIVERSITY_HERFINDAHL: 0.9939328, COVERAGE_ITEM: 0.0679440, COVERAGE_ITEM_CORRECT: 0.0353840, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.8803663, DIVERSITY_GINI: 0.0110916, SHANNON_ENTROPY: 8.0313235, RATIO_DIVERSITY_HERFINDAHL: 0.9943101, RATIO_DIVERSITY_GINI: 0.0434879, RATIO_SHANNON_ENTROPY: 0.6464297, RATIO_AVERAGE_POPULARITY: 1.4609513, RATIO_NOVELTY: 0.0283362,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 46.5114
# Function value obtained: -0.1184
# Current minimum: -0.2305
# SearchBayesianSkopt: Search complete. Best config is 45: {'num_factors': 24, 'topK': 925}

# %%
output_folder_path = "result_experiments/NMF_AUG_subgenre_channel/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 50  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative

runHyperparameterSearch_Collaborative(NMFRecommender,
                                      URM_train = URM_aug_train,
                                      URM_train_last_test = None,
                                      metric_to_optimize = metric_to_optimize,
                                      cutoff_to_optimize = cutoff_to_optimize,
                                      n_cases = n_cases,
                                      n_random_starts = n_random_starts,
                                      evaluator_validation_earlystopping = evaluator_validation,
                                      evaluator_validation = evaluator_validation,
                                      evaluator_test = None,
                                      output_folder_path = output_folder_path,
                                      resume_from_saved = True,
                                      similarity_type_list = None,
                                      parallelizeKNN = True)
# Out:
# SearchBayesianSkopt: Resuming 'NMFRecommender' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 205, 'solver': 'coordinate_descent', 'init_type': 'nndsvda', 'beta_loss': 'kullback-leibler'}
# NMFRecommender: Computing NMF decomposition...
# SearchBayesianSkopt: Config 0 Exception. Config: {'num_factors': 205, 'solver': 'coordinate_descent', 'init_type': 'nndsvda', 'beta_loss': 'kullback-leibler'} - Exception: Traceback (most recent call last):
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 464, in _objective_function
#     result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 332, in _evaluate_on_validation
#     recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 304, in _fit_model
#     recommender_instance.fit(*self.recommender_input_args.FIT_POSITIONAL_ARGS,
#   File "/home/jupyter/RecSysChallenge2021/Recommenders/MatrixFactorization/NMFRecommender.py", line 70, in fit
#     nmf_solver.fit(self.URM_train)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1342, in fit
#     self.fit_transform(X, **params)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1311, in fit_transform
#     W, H, n_iter_ = non_negative_factorization(
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1025, in non_negative_factorization
#     beta_loss = _check_string_param(solver, regularization, beta_loss, init)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 221, in _check_string_param
#     raise ValueError(
# ValueError: Invalid beta_loss parameter: solver 'cd' does not handle beta_loss = 'kullback-leibler'
# Traceback (most recent call last):
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 464, in _objective_function
#     result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 332, in _evaluate_on_validation
#     recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 304, in _fit_model
#     recommender_instance.fit(*self.recommender_input_args.FIT_POSITIONAL_ARGS,
#   File "/home/jupyter/RecSysChallenge2021/Recommenders/MatrixFactorization/NMFRecommender.py", line 70, in fit
#     nmf_solver.fit(self.URM_train)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1342, in fit
#     self.fit_transform(X, **params)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1311, in fit_transform
#     W, H, n_iter_ = non_negative_factorization(
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1025, in non_negative_factorization
#     beta_loss = _check_string_param(solver, regularization, beta_loss, init)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 221, in _check_string_param
#     raise ValueError(
# ValueError: Invalid beta_loss parameter: solver 'cd' does not handle beta_loss = 'kullback-leibler'
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.1894
# Function value obtained: 65504.0000
# Current minimum: 65504.0000
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 135, 'solver': 'multiplicative_update', 'init_type': 'nndsvda', 'beta_loss': 'frobenius'}
# NMFRecommender: Computing NMF decomposition...
# NMFRecommender: Computing NMF decomposition... done in 7.97 min
# EvaluatorHoldout: Processed 13646 (100.0%) in 36.81 sec. Users per second: 371
# SearchBayesianSkopt: New best config found. Config 1: {'num_factors': 135, 'solver': 'multiplicative_update', 'init_type': 'nndsvda', 'beta_loss': 'frobenius'} - results: PRECISION: 0.3111241, PRECISION_RECALL_MIN_DEN: 0.3119430, RECALL: 0.0513443, MAP: 0.1794743, MAP_MIN_DEN: 0.1798385, MRR: 0.5628120, NDCG: 0.3256668, F1: 0.0881425, HIT_RATE: 0.9284772, ARHR_ALL_HITS: 0.9902430, NOVELTY: 0.0058836, AVERAGE_POPULARITY: 0.3435591, DIVERSITY_MEAN_INTER_LIST: 0.9655399, DIVERSITY_HERFINDAHL: 0.9965469, COVERAGE_ITEM: 0.0662274, COVERAGE_ITEM_CORRECT: 0.0554848, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9282051, DIVERSITY_GINI: 0.0181453, SHANNON_ENTROPY: 8.7690463, RATIO_DIVERSITY_HERFINDAHL: 0.9969252, RATIO_DIVERSITY_GINI: 0.0711439, RATIO_SHANNON_ENTROPY: 0.7058080, RATIO_AVERAGE_POPULARITY: 1.7228677, RATIO_NOVELTY: 0.0279842,
#
# SearchBayesianSkopt: Saving model in result_experiments/NMF_AUG_subgenre_channel/NMFRecommender
#
# NMFRecommender: Saving model in file 'result_experiments/NMF_AUG_subgenre_channel/NMFRecommender_best_model'
# NMFRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 516.1167
# Function value obtained: -0.1795
# Current minimum: -0.1795
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 46, 'solver': 'coordinate_descent', 'init_type': 'random', 'beta_loss': 'kullback-leibler'}
# NMFRecommender: Computing NMF decomposition...
# SearchBayesianSkopt: Config 2 Exception. Config: {'num_factors': 46, 'solver': 'coordinate_descent', 'init_type': 'random', 'beta_loss': 'kullback-leibler'} - Exception: Traceback (most recent call last):
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 464, in _objective_function
#     result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 332, in _evaluate_on_validation
#     recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 304, in _fit_model
#     recommender_instance.fit(*self.recommender_input_args.FIT_POSITIONAL_ARGS,
#   File "/home/jupyter/RecSysChallenge2021/Recommenders/MatrixFactorization/NMFRecommender.py", line 70, in fit
#     nmf_solver.fit(self.URM_train)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1342, in fit
#     self.fit_transform(X, **params)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1311, in fit_transform
#     W, H, n_iter_ = non_negative_factorization(
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1025, in non_negative_factorization
#     beta_loss = _check_string_param(solver, regularization, beta_loss, init)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 221, in _check_string_param
#     raise ValueError(
# ValueError: Invalid beta_loss parameter: solver 'cd' does not handle beta_loss = 'kullback-leibler'
#
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.2186
# Function value obtained: 65504.0000
# Current minimum: -0.1795
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 154, 'solver': 'coordinate_descent', 'init_type': 'nndsvda', 'beta_loss': 'frobenius'}
# Traceback (most recent call last):
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 464, in _objective_function
#     result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 332, in _evaluate_on_validation
#     recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#   File "/home/jupyter/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py", line 304, in _fit_model
#     recommender_instance.fit(*self.recommender_input_args.FIT_POSITIONAL_ARGS,
#   File "/home/jupyter/RecSysChallenge2021/Recommenders/MatrixFactorization/NMFRecommender.py", line 70, in fit
#     nmf_solver.fit(self.URM_train)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1342, in fit
#     self.fit_transform(X, **params)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1311, in fit_transform
#     W, H, n_iter_ = non_negative_factorization(
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 1025, in non_negative_factorization
#     beta_loss = _check_string_param(solver, regularization, beta_loss, init)
#   File "/opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py", line 221, in _check_string_param
#     raise ValueError(
# ValueError: Invalid beta_loss parameter: solver 'cd' does not handle beta_loss = 'kullback-leibler'
# NMFRecommender: Computing NMF decomposition...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1509/1393514818.py in <module>
#       4 from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
#       5
# ----> 6 runHyperparameterSearch_Collaborative(NMFRecommender,
#       7                                       URM_train = URM_aug_train,
#       8                                       URM_train_last_test = None,
#
# ~/RecSysChallenge2021/HyperparameterTuning/run_hyperparameter_search.py in runHyperparameterSearch_Collaborative(recommender_class, URM_train, URM_train_last_test, n_cases, n_random_starts, resume_from_saved, save_model, evaluate_on_test, max_total_time, evaluator_validation, evaluator_test, evaluator_validation_earlystopping, metric_to_optimize, cutoff_to_optimize, output_folder_path, parallelizeKNN, allow_weighting, allow_bias_URM, allow_dropout_MF, similarity_type_list)
#    1059
#    1060         ## Final step, after the hyperparameter range has been defined for each type of algorithm
# -> 1061         hyperparameterSearch.search(recommender_input_args,
#    1062                                hyperparameter_search_space= hyperparameters_range_dictionary,
#    1063                                n_cases = n_cases,
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchBayesianSkopt.py in search(self, recommender_input_args, hyperparameter_search_space, metric_to_optimize, cutoff_to_optimize, n_cases, n_random_starts, output_folder_path, output_file_name_root, save_model, save_metadata, resume_from_saved, recommender_input_args_last_test, evaluate_on_test, max_total_time)
#     336                 # of "Searching for the next optimal point". This may be due to a bug in the print rather than the underlying process
#     337                 # https://github.com/scikit-optimize/scikit-optimize/issues/949
# --> 338                 self.result = gp_minimize(self._objective_function_list_input,
#     339                                           self.hyperparams_values,
#     340                                           base_estimator=None,
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     257             noise=noise)
#     258
# --> 259     return base_minimize(
#     260         func, space, base_estimator=base_estimator,
#     261         acq_func=acq_func,
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     299     for n in range(n_calls):
#     300         next_x = optimizer.ask()
# --> 301         next_y = func(next_x)
#     302         result = optimizer.tell(next_x, next_y)
#     303         result.specs = specs
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchBayesianSkopt.py in _objective_function_list_input(self, current_fit_hyperparameters_list_of_values)
#     410
#     411         current_fit_hyperparameters_dict = dict(zip(self.hyperparams_names, current_fit_hyperparameters_list_of_values))
# --> 412         result = self._objective_function(current_fit_hyperparameters_dict)
#     413
#     414         # The search can only progress if there is at least a valid config in the initial random start
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     533         except (KeyboardInterrupt, SystemExit) as e:
#     534             # If getting a interrupt, terminate without saving the exception
# --> 535             raise e
#     536
#     537         except:
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     462
#     463             was_already_evaluated_flag, was_already_evaluated_index = self._was_already_evaluated_check(current_fit_hyperparameters_dict)
# --> 464             result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#     465
#     466             result_series = result_df.loc[self.metadata_dict["cutoff_to_optimize"]]
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py in _evaluate_on_validation(self, current_fit_hyperparameters, was_already_evaluated_flag, was_already_evaluated_index)
#     330                 self.metadata_dict["hyperparameters_df"].loc[self.model_counter,key] = current_fit_hyperparameters[key]
#     331
# --> 332             recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#     333             start_time = time.time()
#     334
#
# ~/RecSysChallenge2021/HyperparameterTuning/SearchAbstractClass.py in _fit_model(self, current_fit_hyperparameters)
#     302                                                       **self.recommender_input_args.CONSTRUCTOR_KEYWORD_ARGS)
#     303
# --> 304         recommender_instance.fit(*self.recommender_input_args.FIT_POSITIONAL_ARGS,
#     305                                  **self.recommender_input_args.FIT_KEYWORD_ARGS,
#     306                                  **current_fit_hyperparameters)
#
# ~/RecSysChallenge2021/Recommenders/MatrixFactorization/NMFRecommender.py in fit(self, num_factors, l1_ratio, solver, init_type, beta_loss, verbose, random_seed)
#      68                          max_iter = 500)
#      69
# ---> 70         nmf_solver.fit(self.URM_train)
#      71
#      72         self.ITEM_factors = nmf_solver.components_.copy().T
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py in fit(self, X, y, **params)
#    1340         self
#    1341         """
# -> 1342         self.fit_transform(X, **params)
#    1343         return self
#    1344
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py in fit_transform(self, X, y, W, H)
#    1309
#    1310         with config_context(assume_finite=True):
# -> 1311             W, H, n_iter_ = non_negative_factorization(
#    1312                 X=X, W=W, H=H, n_components=self.n_components, init=self.init,
#    1313                 update_H=True, solver=self.solver, beta_loss=self.beta_loss,
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py in non_negative_factorization(X, W, H, n_components, init, update_H, solver, beta_loss, tol, max_iter, alpha, l1_ratio, regularization, random_state, verbose, shuffle)
#    1071
#    1072     if solver == 'cd':
# -> 1073         W, H, n_iter = _fit_coordinate_descent(X, W, H, tol, max_iter,
#    1074                                                l1_reg_W, l1_reg_H,
#    1075                                                l2_reg_W, l2_reg_H,
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py in _fit_coordinate_descent(X, W, H, tol, max_iter, l1_reg_W, l1_reg_H, l2_reg_W, l2_reg_H, update_H, verbose, shuffle, random_state)
#     519         # Update H
#     520         if update_H:
# --> 521             violation += _update_coordinate_descent(X.T, Ht, W, l1_reg_H,
#     522                                                     l2_reg_H, shuffle, rng)
#     523
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py in _update_coordinate_descent(X, W, Ht, l1_reg, l2_reg, shuffle, random_state)
#     414
#     415     HHt = np.dot(Ht.T, Ht)
# --> 416     XHt = safe_sparse_dot(X, Ht)
#     417
#     418     # L2 regularization corresponds to increase of the diagonal of HHt
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     150             ret = np.dot(a, b)
#     151     else:
# --> 152         ret = a @ b
#     153
#     154     if (sparse.issparse(a) and sparse.issparse(b)
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/scipy/sparse/base.py in __matmul__(self, other)
#     558             raise ValueError("Scalar operands are not allowed, "
#     559                              "use '*' instead")
# --> 560         return self.__mul__(other)
#     561
#     562     def __rmatmul__(self, other):
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     469                 return self._mul_vector(other.ravel()).reshape(M, 1)
#     470             elif other.ndim == 2 and other.shape[0] == N:
# --> 471                 return self._mul_multivector(other)
#     472
#     473         if isscalarlike(other):
#
# /opt/conda/envs/RecSysFramework/lib/python3.8/site-packages/scipy/sparse/compressed.py in _mul_multivector(self, other)
#     489         # csr_matvecs or csc_matvecs
#     490         fn = getattr(_sparsetools, self.format + '_matvecs')
# --> 491         fn(M, N, n_vecs, self.indptr, self.indices, self.data,
#     492            other.ravel(), result.ravel())
#     493
#
# KeyboardInterrupt:
