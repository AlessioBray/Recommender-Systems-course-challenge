# %% [markdown]
# # Different Loss Score Hybrid

# %%
## Allow more than one output for a single code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd
import scipy.sparse as sps
import numpy as np
import os

from skopt.space import Real, Integer, Categorical

## Set the numpy random seed
SEED = 42
np.random.seed(SEED)

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

from Evaluation.Evaluator import EvaluatorHoldout

from Recommenders.Recommender_import_list import *
from Recommenders.Hybrid.DifferentLossScoresHybridRecommender import DifferentLossScoresHybridRecommender

from Recommenders.DataIO import DataIO

# %%
## Utility Functions
from Dataset.load_data import load_data
from Dataset.write_submission import write_submission
from Dataset.load_test_user_array import load_test_user_array

# %%
URM_all, ICM_dict = load_data()

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

URM_aug_train = sps.vstack([URM_train.copy().tocoo(), 
                            #ICM_dict['genre'].T.tocoo(),
                            ICM_dict['ICM_subgenre'].T.tocoo(), 
                            #ICM_dict['event'].T.tocoo(), 
                            ICM_dict['ICM_channel'].T.tocoo()], format='csr')
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items

# %%
evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10], exclude_seen = True)
# Out:
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
test_UserID_array = load_test_user_array()

# %% [markdown]
# ## Optimization

# %%
output_folder_path = "result_experiments/DifferentLossScoresHybrid_SLIMElasticNet_SLIMBPR/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("SLIMElasticNetRecommender_SLIM_BPR_Recommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2505

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    norm     alpha       MAP
# 0   1.0  0.689094  0.250504
# 31  inf  0.829324  0.250559
# 43  inf  0.813892  0.250533
# 64  inf  0.812183  0.250529
# 67  inf  0.810747  0.250502
# 73  inf  0.810928  0.250510
# 82  inf  0.809496  0.250501
# 91  1.0  0.714934  0.250584
# Max value for the range:  0.8293235105898995
# Min value for the range:  0.6890941949275555
# Best MAP:  0.25058410337118475
#    norm     alpha       MAP
# 91  1.0  0.714934  0.250584

# %%
output_folder_path = "result_experiments/DifferentLossScoresHybrid_SLIMElasticNet_SLIMBPR_separate_weights/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("SLIMElasticNetRecommender_SLIM_BPR_Recommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2505

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    norm     alpha      beta gamma delta       MAP
# 3   2.0  0.479011  0.104115     0     0  0.250566
# 22  2.0  0.923438  0.191761     0     0  0.250551
# 28  inf   0.33118  0.068812     0     0  0.250583
# 80  inf   0.99593  0.257393     0     0  0.250507
# 86  2.0     0.999  0.290241     0     0  0.250527
# Max value for the range:  0.999
# Min value for the range:  0.3311796359004038
# Best MAP:  0.25058295471200487
#    norm    alpha      beta gamma delta       MAP
# 28  inf  0.33118  0.068812     0     0  0.250583

# %%
output_folder_path = "result_experiments/DifferentLossScoresHybrid_SLIMElasticNet_SLIMBPR_separate_weights_load/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("SLIMElasticNetRecommender_SLIM_BPR_Recommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2505

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    norm     alpha      beta gamma delta       MAP
# 74  1.0     0.999  0.438261     0     0  0.250502
# 75  inf     0.999   0.26941     0     0  0.250532
# 81  1.0  0.276294  0.124128     0     0  0.250522
# 84 -inf  0.831087  0.217555     0     0  0.250524
# Max value for the range:  0.999
# Min value for the range:  0.27629417607486695
# Best MAP:  0.2505315820206637
#    norm  alpha     beta gamma delta       MAP
# 75  inf  0.999  0.26941     0     0  0.250532

# %%
output_folder_path = "result_experiments/DifferentLossScoresHybrid_SLIMElasticNet_SLIMBPR_load/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("SLIMElasticNetRecommender_SLIM_BPR_Recommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2505

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    norm     alpha       MAP
# 17  1.0  0.667851  0.250510
# 27  2.0  0.785279  0.250510
# 33  inf  0.827963  0.250583
# 35  inf  0.787912  0.250509
# 68  inf  0.811425  0.250508
# 69  inf  0.812357  0.250525
# 70  inf  0.811928  0.250513
# 77  inf  0.826667  0.250575
# 79  inf  0.826739  0.250572
# 83  inf  0.826909  0.250588
# 88  inf  0.828083  0.250563
# 89  inf  0.824471  0.250526
# 90  inf  0.825419  0.250533
# 93  inf  0.826161  0.250562
# Max value for the range:  0.8280829208840986
# Min value for the range:  0.6678510490224594
# Best MAP:  0.25058841302410984
#    norm     alpha       MAP
# 83  inf  0.826909  0.250588

# %%
output_folder_path = "result_experiments/DifferentLossScoresHybrid_SLIMElasticNet_IALS/"

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data("SLIMElasticNetRecommender_IALSRecommender_metadata.zip")
#search_metadata.keys()

hyperparameters_df = search_metadata["hyperparameters_df"]
result_on_validation_df = search_metadata["result_on_validation_df"]

hyperparameters_df['MAP'] = result_on_validation_df['MAP'].values.tolist()

threshold = 0.2502

hyperparameters_df[hyperparameters_df['MAP'] > threshold]
print('Max value for the range: ', max(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Min value for the range: ', min(hyperparameters_df[hyperparameters_df['MAP'] > threshold].alpha))
print('Best MAP: ', max(hyperparameters_df['MAP']))
hyperparameters_df[max(hyperparameters_df['MAP']) == hyperparameters_df['MAP']]
# Out:
#    norm     alpha       MAP
# 87  inf  0.712836  0.250207
# 91  inf  0.712971  0.250202
# 93  inf  0.713169  0.250212
# 94  inf  0.713247  0.250212
# 97  inf  0.713347  0.250210
# 98  inf  0.713387  0.250210
# Max value for the range:  0.7133869818889053
# Min value for the range:  0.7128361826446833
# Best MAP:  0.25021211227663814
#    norm     alpha       MAP
# 93  inf  0.713169  0.250212

# %%
output_folder_path = "result_experiments/DifferentLossScoresHybrid_DiffLoss_IALS/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 50  # 50 with 30% random is a good number
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
print('Fitting ...')

#RP3beta = RP3betaRecommender(URM_aug_train)
#RP3beta.fit(topK = 51, alpha = 0.620106, beta = 0.566617, normalize_similarity = True)

#Top = TopPop(URM_train)
#Top.fit()

#UserKNNCF = UserKNNCFRecommender(URM_train)
#UserKNNCF.fit(topK= 777, shrink = 0, similarity = 'tversky', normalize = True, tversky_alpha = 2.0, tversky_beta = 1.2531451455933782)

SLIMElasticNet = MultiThreadSLIM_SLIMElasticNetRecommender(URM_aug_train)
SLIMElasticNet.load_model(folder_path = 'result_experiments/SLIM_elasticNet_AUG_subgenre_channel_topK_categorical/', file_name = 'SLIMElasticNetRecommender_best_model.zip')
#SLIMElasticNet.fit(topK = 673, l1_ratio = 0.001155, alpha = 0.073102)

earlystopping_keywargs = {"validation_every_n": 1,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 20,
                          "validation_metric": metric_to_optimize,
                         }

SLIM_BPR = SLIM_BPR_Cython(URM_aug_train)
SLIM_BPR.load_model(folder_path = 'result_experiments/SLIM_BPR_AUG_subgenre_channel/', file_name = 'SLIM_BPR_Recommender_best_model.zip')
"""
SLIM_BPR.fit(topK = 262, epochs = 315, symmetric = True, lambda_i = 0.000022, lambda_j = 0.000333, learning_rate = 0.037189, sgd_mode='adagrad',
             positive_threshold_BPR = None,
             train_with_sparse_weights = None,
             allow_train_with_sparse_weights = False,
             **earlystopping_keywargs)
"""
IALS = IALSRecommender(URM_aug_train)
IALS.load_model(folder_path = 'result_experiments/IALS_NO_AUG/', file_name = 'IALSRecommender_best_model.zip')
#IALS.fit(num_factors = 52, epochs = 300, confidence_scaling = 'linear', alpha = 1.3346069348060516, epsilon = 0.17158990394166584, reg = 0.0005841170332713697, **earlystopping_keywargs)

DiffLoss = DifferentLossScoresHybridRecommender(URM_aug_train, [SLIMElasticNet, SLIM_BPR])
DiffLoss.fit(norm = np.inf, alpha = 0.826909)

print('Fitting Ended')
# Out:
# Fitting ...
# SLIMElasticNetRecommender: Loading model from file 'result_experiments/SLIM_elasticNet_AUG_subgenre_channel_topK_categorical/SLIMElasticNetRecommender_best_model.zip'
# SLIMElasticNetRecommender: Loading complete
# SLIM_BPR_Recommender: Loading model from file 'result_experiments/SLIM_BPR_AUG_subgenre_channel/SLIM_BPR_Recommender_best_model.zip'
# SLIM_BPR_Recommender: Loading complete
# "\nSLIM_BPR.fit(topK = 262, epochs = 315, symmetric = True, lambda_i = 0.000022, lambda_j = 0.000333, learning_rate = 0.037189, sgd_mode='adagrad',\n             positive_threshold_BPR = None,\n             train_with_sparse_weights = None,\n             allow_train_with_sparse_weights = False,\n             **earlystopping_keywargs)\n"
# IALSRecommender: Loading model from file 'result_experiments/IALS_NO_AUG/IALSRecommender_best_model.zip'
# IALSRecommender: Loading complete
# Fitting Ended

# %%
from functools import partial
import os, multiprocessing

from HyperparameterTuning.run_hyperparameter_search_DifferentLossScoresHybrid import runHyperparameterSearch_DifferentLossScoresHybrid

runHyperparameterSearch_DifferentLossScoresHybrid([DiffLoss, IALS],
                                                    URM_train = URM_aug_train,
                                                    ICM_object = None,
                                                    ICM_name = '',
                                                    URM_train_last_test = None,
                                                    metric_to_optimize = metric_to_optimize,
                                                    cutoff_to_optimize = cutoff_to_optimize,
                                                    n_cases = n_cases,
                                                    n_random_starts = n_random_starts,
                                                    evaluator_validation_earlystopping = evaluator_validation,
                                                    evaluator_validation = evaluator_validation,
                                                    evaluator_test = None,
                                                    output_folder_path = output_folder_path,
                                                    resume_from_saved = False,
                                                    similarity_type_list = None,
                                                    parallelizeKNN = True)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.21574855997490533}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.96 min. Users per second: 116
# SearchBayesianSkopt: New best config found. Config 0: {'norm': 2.0, 'alpha': 0.21574855997490533} - results: PRECISION: 0.3939836, PRECISION_RECALL_MIN_DEN: 0.3955222, RECALL: 0.0701882, MAP: 0.2431386, MAP_MIN_DEN: 0.2438800, MRR: 0.6449510, NDCG: 0.4085909, F1: 0.1191498, HIT_RATE: 0.9699546, ARHR_ALL_HITS: 1.2306057, NOVELTY: 0.0055998, AVERAGE_POPULARITY: 0.4990493, DIVERSITY_MEAN_INTER_LIST: 0.9399903, DIVERSITY_HERFINDAHL: 0.9939921, COVERAGE_ITEM: 0.0695498, COVERAGE_ITEM_CORRECT: 0.0563154, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9696703, DIVERSITY_GINI: 0.0141399, SHANNON_ENTROPY: 8.3111915, RATIO_DIVERSITY_HERFINDAHL: 0.9943695, RATIO_DIVERSITY_GINI: 0.0554394, RATIO_SHANNON_ENTROPY: 0.6689559, RATIO_AVERAGE_POPULARITY: 2.5026142, RATIO_NOVELTY: 0.0266342,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 117.6101
# Function value obtained: -0.2431
# Current minimum: -0.2431
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.9099922673449817}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.95 min. Users per second: 117
# SearchBayesianSkopt: New best config found. Config 1: {'norm': 2.0, 'alpha': 0.9099922673449817} - results: PRECISION: 0.4046021, PRECISION_RECALL_MIN_DEN: 0.4063712, RECALL: 0.0725649, MAP: 0.2510144, MAP_MIN_DEN: 0.2517865, MRR: 0.6532206, NDCG: 0.4184025, F1: 0.1230593, HIT_RATE: 0.9739851, ARHR_ALL_HITS: 1.2567522, NOVELTY: 0.0055254, AVERAGE_POPULARITY: 0.5457852, DIVERSITY_MEAN_INTER_LIST: 0.9072514, DIVERSITY_HERFINDAHL: 0.9907185, COVERAGE_ITEM: 0.0714325, COVERAGE_ITEM_CORRECT: 0.0519962, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9736996, DIVERSITY_GINI: 0.0103987, SHANNON_ENTROPY: 7.7937224, RATIO_DIVERSITY_HERFINDAHL: 0.9910946, RATIO_DIVERSITY_GINI: 0.0407713, RATIO_SHANNON_ENTROPY: 0.6273056, RATIO_AVERAGE_POPULARITY: 2.7369841, RATIO_NOVELTY: 0.0262807,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 117.0397
# Function value obtained: -0.2510
# Current minimum: -0.2510
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.9085404342278435}
# EvaluatorHoldout: Processed 13646 (100.0%) in 39.04 sec. Users per second: 350
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'norm': -inf, 'alpha': 0.9085404342278435} - results: PRECISION: 0.4043603, PRECISION_RECALL_MIN_DEN: 0.4061286, RECALL: 0.0725661, MAP: 0.2508018, MAP_MIN_DEN: 0.2515731, MRR: 0.6532936, NDCG: 0.4181815, F1: 0.1230498, HIT_RATE: 0.9740583, ARHR_ALL_HITS: 1.2561755, NOVELTY: 0.0055237, AVERAGE_POPULARITY: 0.5471851, DIVERSITY_MEAN_INTER_LIST: 0.9059782, DIVERSITY_HERFINDAHL: 0.9905912, COVERAGE_ITEM: 0.0724293, COVERAGE_ITEM_CORRECT: 0.0515532, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9737729, DIVERSITY_GINI: 0.0102957, SHANNON_ENTROPY: 7.7757484, RATIO_DIVERSITY_HERFINDAHL: 0.9909672, RATIO_DIVERSITY_GINI: 0.0403671, RATIO_SHANNON_ENTROPY: 0.6258588, RATIO_AVERAGE_POPULARITY: 2.7440041, RATIO_NOVELTY: 0.0262723,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 39.2309
# Function value obtained: -0.2508
# Current minimum: -0.2510
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.7466570825712733}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.87 min. Users per second: 121
# SearchBayesianSkopt: New best config found. Config 3: {'norm': 2.0, 'alpha': 0.7466570825712733} - results: PRECISION: 0.4050564, PRECISION_RECALL_MIN_DEN: 0.4068194, RECALL: 0.0726221, MAP: 0.2513866, MAP_MIN_DEN: 0.2521652, MRR: 0.6536002, NDCG: 0.4188683, F1: 0.1231626, HIT_RATE: 0.9739118, ARHR_ALL_HITS: 1.2581580, NOVELTY: 0.0055331, AVERAGE_POPULARITY: 0.5402353, DIVERSITY_MEAN_INTER_LIST: 0.9120513, DIVERSITY_HERFINDAHL: 0.9911984, COVERAGE_ITEM: 0.0696052, COVERAGE_ITEM_CORRECT: 0.0517194, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9736264, DIVERSITY_GINI: 0.0108127, SHANNON_ENTROPY: 7.8619656, RATIO_DIVERSITY_HERFINDAHL: 0.9915747, RATIO_DIVERSITY_GINI: 0.0423945, RATIO_SHANNON_ENTROPY: 0.6327983, RATIO_AVERAGE_POPULARITY: 2.7091526, RATIO_NOVELTY: 0.0263172,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 112.5147
# Function value obtained: -0.2514
# Current minimum: -0.2514
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.5231089703188495}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.55 sec. Users per second: 354
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.5231089703188495} - results: PRECISION: 0.4017661, PRECISION_RECALL_MIN_DEN: 0.4034409, RECALL: 0.0718073, MAP: 0.2493065, MAP_MIN_DEN: 0.2500762, MRR: 0.6506811, NDCG: 0.4160321, F1: 0.1218385, HIT_RATE: 0.9720064, ARHR_ALL_HITS: 1.2512211, NOVELTY: 0.0055617, AVERAGE_POPULARITY: 0.5218851, DIVERSITY_MEAN_INTER_LIST: 0.9257871, DIVERSITY_HERFINDAHL: 0.9925719, COVERAGE_ITEM: 0.0677225, COVERAGE_ITEM_CORRECT: 0.0539343, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9717216, DIVERSITY_GINI: 0.0122427, SHANNON_ENTROPY: 8.0706401, RATIO_DIVERSITY_HERFINDAHL: 0.9929487, RATIO_DIVERSITY_GINI: 0.0480012, RATIO_SHANNON_ENTROPY: 0.6495943, RATIO_AVERAGE_POPULARITY: 2.6171304, RATIO_NOVELTY: 0.0264531,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 38.7440
# Function value obtained: -0.2493
# Current minimum: -0.2514
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.8390415906812541}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.64 sec. Users per second: 353
# SearchBayesianSkopt: New best config found. Config 5: {'norm': 1.0, 'alpha': 0.8390415906812541} - results: PRECISION: 0.4054302, PRECISION_RECALL_MIN_DEN: 0.4071910, RECALL: 0.0727012, MAP: 0.2514701, MAP_MIN_DEN: 0.2522480, MRR: 0.6533127, NDCG: 0.4190211, F1: 0.1232936, HIT_RATE: 0.9742782, ARHR_ALL_HITS: 1.2580138, NOVELTY: 0.0055299, AVERAGE_POPULARITY: 0.5423283, DIVERSITY_MEAN_INTER_LIST: 0.9103311, DIVERSITY_HERFINDAHL: 0.9910264, COVERAGE_ITEM: 0.0694944, COVERAGE_ITEM_CORRECT: 0.0516640, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9739927, DIVERSITY_GINI: 0.0106422, SHANNON_ENTROPY: 7.8359577, RATIO_DIVERSITY_HERFINDAHL: 0.9914027, RATIO_DIVERSITY_GINI: 0.0417260, RATIO_SHANNON_ENTROPY: 0.6307050, RATIO_AVERAGE_POPULARITY: 2.7196483, RATIO_NOVELTY: 0.0263020,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 38.8349
# Function value obtained: -0.2515
# Current minimum: -0.2515
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.56480073608577}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.84 min. Users per second: 123
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.56480073608577} - results: PRECISION: 0.4032537, PRECISION_RECALL_MIN_DEN: 0.4049447, RECALL: 0.0721933, MAP: 0.2504748, MAP_MIN_DEN: 0.2512393, MRR: 0.6523340, NDCG: 0.4174664, F1: 0.1224625, HIT_RATE: 0.9726660, ARHR_ALL_HITS: 1.2552189, NOVELTY: 0.0055488, AVERAGE_POPULARITY: 0.5300451, DIVERSITY_MEAN_INTER_LIST: 0.9199190, DIVERSITY_HERFINDAHL: 0.9919852, COVERAGE_ITEM: 0.0682762, COVERAGE_ITEM_CORRECT: 0.0527715, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9723810, DIVERSITY_GINI: 0.0115934, SHANNON_ENTROPY: 7.9794608, RATIO_DIVERSITY_HERFINDAHL: 0.9923617, RATIO_DIVERSITY_GINI: 0.0454555, RATIO_SHANNON_ENTROPY: 0.6422554, RATIO_AVERAGE_POPULARITY: 2.6580509, RATIO_NOVELTY: 0.0263917,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 110.7113
# Function value obtained: -0.2505
# Current minimum: -0.2515
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.5582439049267292}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.89 min. Users per second: 120
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.5582439049267292} - results: PRECISION: 0.4033563, PRECISION_RECALL_MIN_DEN: 0.4050546, RECALL: 0.0722346, MAP: 0.2505361, MAP_MIN_DEN: 0.2513016, MRR: 0.6523735, NDCG: 0.4175284, F1: 0.1225266, HIT_RATE: 0.9726660, ARHR_ALL_HITS: 1.2553023, NOVELTY: 0.0055496, AVERAGE_POPULARITY: 0.5295235, DIVERSITY_MEAN_INTER_LIST: 0.9203093, DIVERSITY_HERFINDAHL: 0.9920242, COVERAGE_ITEM: 0.0682208, COVERAGE_ITEM_CORRECT: 0.0527715, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9723810, DIVERSITY_GINI: 0.0116325, SHANNON_ENTROPY: 7.9852224, RATIO_DIVERSITY_HERFINDAHL: 0.9924008, RATIO_DIVERSITY_GINI: 0.0456086, RATIO_SHANNON_ENTROPY: 0.6427191, RATIO_AVERAGE_POPULARITY: 2.6554352, RATIO_NOVELTY: 0.0263957,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 113.4765
# Function value obtained: -0.2505
# Current minimum: -0.2515
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.5308270236186895}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.88 min. Users per second: 121
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.5308270236186895} - results: PRECISION: 0.4028726, PRECISION_RECALL_MIN_DEN: 0.4045701, RECALL: 0.0721589, MAP: 0.2501367, MAP_MIN_DEN: 0.2509001, MRR: 0.6520457, NDCG: 0.4170758, F1: 0.1223955, HIT_RATE: 0.9720797, ARHR_ALL_HITS: 1.2540757, NOVELTY: 0.0055524, AVERAGE_POPULARITY: 0.5276930, DIVERSITY_MEAN_INTER_LIST: 0.9216486, DIVERSITY_HERFINDAHL: 0.9921581, COVERAGE_ITEM: 0.0681101, COVERAGE_ITEM_CORRECT: 0.0531591, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9717949, DIVERSITY_GINI: 0.0117728, SHANNON_ENTROPY: 8.0056462, RATIO_DIVERSITY_HERFINDAHL: 0.9925348, RATIO_DIVERSITY_GINI: 0.0461588, RATIO_SHANNON_ENTROPY: 0.6443630, RATIO_AVERAGE_POPULARITY: 2.6462558, RATIO_NOVELTY: 0.0264091,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 113.1730
# Function value obtained: -0.2501
# Current minimum: -0.2515
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.9166544744875049}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.67 sec. Users per second: 353
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'norm': -inf, 'alpha': 0.9166544744875049} - results: PRECISION: 0.4042796, PRECISION_RECALL_MIN_DEN: 0.4060480, RECALL: 0.0725399, MAP: 0.2507167, MAP_MIN_DEN: 0.2514883, MRR: 0.6531548, NDCG: 0.4180888, F1: 0.1230085, HIT_RATE: 0.9741316, ARHR_ALL_HITS: 1.2558655, NOVELTY: 0.0055236, AVERAGE_POPULARITY: 0.5472720, DIVERSITY_MEAN_INTER_LIST: 0.9058852, DIVERSITY_HERFINDAHL: 0.9905819, COVERAGE_ITEM: 0.0724293, COVERAGE_ITEM_CORRECT: 0.0515532, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9738462, DIVERSITY_GINI: 0.0102907, SHANNON_ENTROPY: 7.7747287, RATIO_DIVERSITY_HERFINDAHL: 0.9909579, RATIO_DIVERSITY_GINI: 0.0403477, RATIO_SHANNON_ENTROPY: 0.6257768, RATIO_AVERAGE_POPULARITY: 2.7444398, RATIO_NOVELTY: 0.0262718,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 38.8626
# Function value obtained: -0.2507
# Current minimum: -0.2515
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.2689453676769363}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.86 min. Users per second: 122
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.2689453676769363} - results: PRECISION: 0.3962700, PRECISION_RECALL_MIN_DEN: 0.3979015, RECALL: 0.0707331, MAP: 0.2450747, MAP_MIN_DEN: 0.2458343, MRR: 0.6480689, NDCG: 0.4109913, F1: 0.1200395, HIT_RATE: 0.9709805, ARHR_ALL_HITS: 1.2379204, NOVELTY: 0.0055907, AVERAGE_POPULARITY: 0.5043339, DIVERSITY_MEAN_INTER_LIST: 0.9369516, DIVERSITY_HERFINDAHL: 0.9936883, COVERAGE_ITEM: 0.0684977, COVERAGE_ITEM_CORRECT: 0.0558724, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9706960, DIVERSITY_GINI: 0.0136738, SHANNON_ENTROPY: 8.2556694, RATIO_DIVERSITY_HERFINDAHL: 0.9940655, RATIO_DIVERSITY_GINI: 0.0536120, RATIO_SHANNON_ENTROPY: 0.6644870, RATIO_AVERAGE_POPULARITY: 2.5291156, RATIO_NOVELTY: 0.0265913,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 111.9933
# Function value obtained: -0.2451
# Current minimum: -0.2515
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.38500896796665357}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.60 sec. Users per second: 354
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.38500896796665357} - results: PRECISION: 0.3984391, PRECISION_RECALL_MIN_DEN: 0.4000766, RECALL: 0.0711346, MAP: 0.2464764, MAP_MIN_DEN: 0.2472404, MRR: 0.6477893, NDCG: 0.4126993, F1: 0.1207172, HIT_RATE: 0.9711271, ARHR_ALL_HITS: 1.2415755, NOVELTY: 0.0055816, AVERAGE_POPULARITY: 0.5098112, DIVERSITY_MEAN_INTER_LIST: 0.9336359, DIVERSITY_HERFINDAHL: 0.9933567, COVERAGE_ITEM: 0.0681101, COVERAGE_ITEM_CORRECT: 0.0549864, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9708425, DIVERSITY_GINI: 0.0132203, SHANNON_ENTROPY: 8.1990882, RATIO_DIVERSITY_HERFINDAHL: 0.9937338, RATIO_DIVERSITY_GINI: 0.0518338, RATIO_SHANNON_ENTROPY: 0.6599329, RATIO_AVERAGE_POPULARITY: 2.5565827, RATIO_NOVELTY: 0.0265480,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 38.7935
# Function value obtained: -0.2465
# Current minimum: -0.2515
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.9627069557531319}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.89 min. Users per second: 120
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.9627069557531319} - results: PRECISION: 0.4043383, PRECISION_RECALL_MIN_DEN: 0.4061084, RECALL: 0.0725680, MAP: 0.2507234, MAP_MIN_DEN: 0.2514937, MRR: 0.6534283, NDCG: 0.4181527, F1: 0.1230515, HIT_RATE: 0.9742782, ARHR_ALL_HITS: 1.2561120, NOVELTY: 0.0055234, AVERAGE_POPULARITY: 0.5473454, DIVERSITY_MEAN_INTER_LIST: 0.9058565, DIVERSITY_HERFINDAHL: 0.9905790, COVERAGE_ITEM: 0.0724846, COVERAGE_ITEM_CORRECT: 0.0516086, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9739927, DIVERSITY_GINI: 0.0102849, SHANNON_ENTROPY: 7.7740027, RATIO_DIVERSITY_HERFINDAHL: 0.9909551, RATIO_DIVERSITY_GINI: 0.0403251, RATIO_SHANNON_ENTROPY: 0.6257183, RATIO_AVERAGE_POPULARITY: 2.7448079, RATIO_NOVELTY: 0.0262712,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 113.7324
# Function value obtained: -0.2507
# Current minimum: -0.2515
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.8702852677002657}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.89 min. Users per second: 120
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.8702852677002657} - results: PRECISION: 0.4047340, PRECISION_RECALL_MIN_DEN: 0.4064799, RECALL: 0.0725430, MAP: 0.2512310, MAP_MIN_DEN: 0.2520122, MRR: 0.6533206, NDCG: 0.4185812, F1: 0.1230339, HIT_RATE: 0.9740583, ARHR_ALL_HITS: 1.2573425, NOVELTY: 0.0055268, AVERAGE_POPULARITY: 0.5446521, DIVERSITY_MEAN_INTER_LIST: 0.9082588, DIVERSITY_HERFINDAHL: 0.9908192, COVERAGE_ITEM: 0.0709342, COVERAGE_ITEM_CORRECT: 0.0516086, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9737729, DIVERSITY_GINI: 0.0104736, SHANNON_ENTROPY: 7.8073152, RATIO_DIVERSITY_HERFINDAHL: 0.9911954, RATIO_DIVERSITY_GINI: 0.0410648, RATIO_SHANNON_ENTROPY: 0.6283996, RATIO_AVERAGE_POPULARITY: 2.7313014, RATIO_NOVELTY: 0.0262873,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 113.7677
# Function value obtained: -0.2512
# Current minimum: -0.2515
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.5803935829812624}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.52 sec. Users per second: 354
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.5803935829812624} - results: PRECISION: 0.4024989, PRECISION_RECALL_MIN_DEN: 0.4041927, RECALL: 0.0720838, MAP: 0.2498655, MAP_MIN_DEN: 0.2506286, MRR: 0.6511890, NDCG: 0.4166652, F1: 0.1222702, HIT_RATE: 0.9720064, ARHR_ALL_HITS: 1.2527584, NOVELTY: 0.0055543, AVERAGE_POPULARITY: 0.5264640, DIVERSITY_MEAN_INTER_LIST: 0.9225824, DIVERSITY_HERFINDAHL: 0.9922515, COVERAGE_ITEM: 0.0683316, COVERAGE_ITEM_CORRECT: 0.0532698, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9717216, DIVERSITY_GINI: 0.0118778, SHANNON_ENTROPY: 8.0201285, RATIO_DIVERSITY_HERFINDAHL: 0.9926282, RATIO_DIVERSITY_GINI: 0.0465705, RATIO_SHANNON_ENTROPY: 0.6455287, RATIO_AVERAGE_POPULARITY: 2.6400924, RATIO_NOVELTY: 0.0264181,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 39.1094
# Function value obtained: -0.2499
# Current minimum: -0.2515
# Iteration No: 16 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.001}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.36 sec. Users per second: 356
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'norm': -inf, 'alpha': 0.001} - results: PRECISION: 0.3833504, PRECISION_RECALL_MIN_DEN: 0.3848537, RECALL: 0.0681456, MAP: 0.2339757, MAP_MIN_DEN: 0.2346846, MRR: 0.6344470, NDCG: 0.3976190, F1: 0.1157204, HIT_RATE: 0.9658508, ARHR_ALL_HITS: 1.1977470, NOVELTY: 0.0056403, AVERAGE_POPULARITY: 0.4759085, DIVERSITY_MEAN_INTER_LIST: 0.9514688, DIVERSITY_HERFINDAHL: 0.9951399, COVERAGE_ITEM: 0.0733706, COVERAGE_ITEM_CORRECT: 0.0608561, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9655678, DIVERSITY_GINI: 0.0162808, SHANNON_ENTROPY: 8.5432057, RATIO_DIVERSITY_HERFINDAHL: 0.9955177, RATIO_DIVERSITY_GINI: 0.0638334, RATIO_SHANNON_ENTROPY: 0.6876304, RATIO_AVERAGE_POPULARITY: 2.3865685, RATIO_NOVELTY: 0.0268269,
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 38.9309
# Function value obtained: -0.2340
# Current minimum: -0.2515
# Iteration No: 17 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.7929521487919424}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.79 sec. Users per second: 352
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'norm': inf, 'alpha': 0.7929521487919424} - results: PRECISION: 0.4050784, PRECISION_RECALL_MIN_DEN: 0.4068345, RECALL: 0.0726061, MAP: 0.2513194, MAP_MIN_DEN: 0.2520939, MRR: 0.6531185, NDCG: 0.4187544, F1: 0.1231406, HIT_RATE: 0.9743515, ARHR_ALL_HITS: 1.2574214, NOVELTY: 0.0055313, AVERAGE_POPULARITY: 0.5415451, DIVERSITY_MEAN_INTER_LIST: 0.9108865, DIVERSITY_HERFINDAHL: 0.9910820, COVERAGE_ITEM: 0.0695498, COVERAGE_ITEM_CORRECT: 0.0516640, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9740659, DIVERSITY_GINI: 0.0107086, SHANNON_ENTROPY: 7.8454484, RATIO_DIVERSITY_HERFINDAHL: 0.9914582, RATIO_DIVERSITY_GINI: 0.0419860, RATIO_SHANNON_ENTROPY: 0.6314689, RATIO_AVERAGE_POPULARITY: 2.7157210, RATIO_NOVELTY: 0.0263084,
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 39.3972
# Function value obtained: -0.2513
# Current minimum: -0.2515
# Iteration No: 18 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.09787701143340895}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.55 sec. Users per second: 354
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'norm': inf, 'alpha': 0.09787701143340895} - results: PRECISION: 0.3879305, PRECISION_RECALL_MIN_DEN: 0.3894346, RECALL: 0.0690086, MAP: 0.2379524, MAP_MIN_DEN: 0.2386765, MRR: 0.6395420, NDCG: 0.4024886, F1: 0.1171733, HIT_RATE: 0.9673897, ARHR_ALL_HITS: 1.2126951, NOVELTY: 0.0056224, AVERAGE_POPULARITY: 0.4859084, DIVERSITY_MEAN_INTER_LIST: 0.9468403, DIVERSITY_HERFINDAHL: 0.9946771, COVERAGE_ITEM: 0.0707680, COVERAGE_ITEM_CORRECT: 0.0583643, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9671062, DIVERSITY_GINI: 0.0153070, SHANNON_ENTROPY: 8.4427447, RATIO_DIVERSITY_HERFINDAHL: 0.9950547, RATIO_DIVERSITY_GINI: 0.0600155, RATIO_SHANNON_ENTROPY: 0.6795444, RATIO_AVERAGE_POPULARITY: 2.4367160, RATIO_NOVELTY: 0.0267419,
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 39.1066
# Function value obtained: -0.2380
# Current minimum: -0.2515
# Iteration No: 19 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.7756293692535797}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.52 sec. Users per second: 354
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'norm': -inf, 'alpha': 0.7756293692535797} - results: PRECISION: 0.4046167, PRECISION_RECALL_MIN_DEN: 0.4063700, RECALL: 0.0725214, MAP: 0.2510834, MAP_MIN_DEN: 0.2518494, MRR: 0.6537048, NDCG: 0.4184940, F1: 0.1229974, HIT_RATE: 0.9739851, ARHR_ALL_HITS: 1.2572842, NOVELTY: 0.0055266, AVERAGE_POPULARITY: 0.5449781, DIVERSITY_MEAN_INTER_LIST: 0.9079206, DIVERSITY_HERFINDAHL: 0.9907854, COVERAGE_ITEM: 0.0712664, COVERAGE_ITEM_CORRECT: 0.0517747, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9736996, DIVERSITY_GINI: 0.0104574, SHANNON_ENTROPY: 7.8034495, RATIO_DIVERSITY_HERFINDAHL: 0.9911615, RATIO_DIVERSITY_GINI: 0.0410014, RATIO_SHANNON_ENTROPY: 0.6280885, RATIO_AVERAGE_POPULARITY: 2.7329366, RATIO_NOVELTY: 0.0262860,
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 39.1173
# Function value obtained: -0.2511
# Current minimum: -0.2515
# Iteration No: 20 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.662921287697189}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.58 sec. Users per second: 354
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'norm': inf, 'alpha': 0.662921287697189} - results: PRECISION: 0.4043822, PRECISION_RECALL_MIN_DEN: 0.4060939, RECALL: 0.0724132, MAP: 0.2512396, MAP_MIN_DEN: 0.2520193, MRR: 0.6542304, NDCG: 0.4186183, F1: 0.1228309, HIT_RATE: 0.9738385, ARHR_ALL_HITS: 1.2586758, NOVELTY: 0.0055401, AVERAGE_POPULARITY: 0.5355447, DIVERSITY_MEAN_INTER_LIST: 0.9157231, DIVERSITY_HERFINDAHL: 0.9915656, COVERAGE_ITEM: 0.0683316, COVERAGE_ITEM_CORRECT: 0.0518301, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9735531, DIVERSITY_GINI: 0.0111665, SHANNON_ENTROPY: 7.9165682, RATIO_DIVERSITY_HERFINDAHL: 0.9919420, RATIO_DIVERSITY_GINI: 0.0437813, RATIO_SHANNON_ENTROPY: 0.6371932, RATIO_AVERAGE_POPULARITY: 2.6856303, RATIO_NOVELTY: 0.0263506,
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 39.1721
# Function value obtained: -0.2512
# Current minimum: -0.2515
# Iteration No: 21 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.9989533231788795}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.46 sec. Users per second: 355
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'norm': -inf, 'alpha': 0.9989533231788795} - results: PRECISION: 0.4039499, PRECISION_RECALL_MIN_DEN: 0.4057200, RECALL: 0.0724734, MAP: 0.2506040, MAP_MIN_DEN: 0.2513753, MRR: 0.6529966, NDCG: 0.4178464, F1: 0.1228976, HIT_RATE: 0.9740583, ARHR_ALL_HITS: 1.2553665, NOVELTY: 0.0055227, AVERAGE_POPULARITY: 0.5480992, DIVERSITY_MEAN_INTER_LIST: 0.9051237, DIVERSITY_HERFINDAHL: 0.9905057, COVERAGE_ITEM: 0.0738690, COVERAGE_ITEM_CORRECT: 0.0521070, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9737729, DIVERSITY_GINI: 0.0102463, SHANNON_ENTROPY: 7.7650967, RATIO_DIVERSITY_HERFINDAHL: 0.9908818, RATIO_DIVERSITY_GINI: 0.0401736, RATIO_SHANNON_ENTROPY: 0.6250015, RATIO_AVERAGE_POPULARITY: 2.7485882, RATIO_NOVELTY: 0.0262675,
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 39.0552
# Function value obtained: -0.2506
# Current minimum: -0.2515
# Iteration No: 22 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.7086972461150531}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.41 sec. Users per second: 355
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'norm': inf, 'alpha': 0.7086972461150531} - results: PRECISION: 0.4049831, PRECISION_RECALL_MIN_DEN: 0.4067105, RECALL: 0.0725619, MAP: 0.2513921, MAP_MIN_DEN: 0.2521682, MRR: 0.6530060, NDCG: 0.4187978, F1: 0.1230726, HIT_RATE: 0.9741316, ARHR_ALL_HITS: 1.2579774, NOVELTY: 0.0055367, AVERAGE_POPULARITY: 0.5378735, DIVERSITY_MEAN_INTER_LIST: 0.9139036, DIVERSITY_HERFINDAHL: 0.9913837, COVERAGE_ITEM: 0.0690514, COVERAGE_ITEM_CORRECT: 0.0519409, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9738462, DIVERSITY_GINI: 0.0109829, SHANNON_ENTROPY: 7.8889569, RATIO_DIVERSITY_HERFINDAHL: 0.9917600, RATIO_DIVERSITY_GINI: 0.0430616, RATIO_SHANNON_ENTROPY: 0.6349708, RATIO_AVERAGE_POPULARITY: 2.6973087, RATIO_NOVELTY: 0.0263342,
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 39.0022
# Function value obtained: -0.2514
# Current minimum: -0.2515
# Iteration No: 23 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.439662104589718}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.34 sec. Users per second: 356
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'norm': inf, 'alpha': 0.439662104589718} - results: PRECISION: 0.4008134, PRECISION_RECALL_MIN_DEN: 0.4024496, RECALL: 0.0715897, MAP: 0.2485592, MAP_MIN_DEN: 0.2493175, MRR: 0.6501196, NDCG: 0.4151842, F1: 0.1214815, HIT_RATE: 0.9719332, ARHR_ALL_HITS: 1.2491139, NOVELTY: 0.0055657, AVERAGE_POPULARITY: 0.5194036, DIVERSITY_MEAN_INTER_LIST: 0.9275126, DIVERSITY_HERFINDAHL: 0.9927445, COVERAGE_ITEM: 0.0675563, COVERAGE_ITEM_CORRECT: 0.0538790, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9716484, DIVERSITY_GINI: 0.0124300, SHANNON_ENTROPY: 8.0967873, RATIO_DIVERSITY_HERFINDAHL: 0.9931213, RATIO_DIVERSITY_GINI: 0.0487354, RATIO_SHANNON_ENTROPY: 0.6516988, RATIO_AVERAGE_POPULARITY: 2.6046866, RATIO_NOVELTY: 0.0264720,
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 38.9328
# Function value obtained: -0.2486
# Current minimum: -0.2515
# Iteration No: 24 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.7482833666843607}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.39 sec. Users per second: 355
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'norm': inf, 'alpha': 0.7482833666843607} - results: PRECISION: 0.4051077, PRECISION_RECALL_MIN_DEN: 0.4068618, RECALL: 0.0726032, MAP: 0.2514078, MAP_MIN_DEN: 0.2521858, MRR: 0.6533202, NDCG: 0.4188839, F1: 0.1231377, HIT_RATE: 0.9739118, ARHR_ALL_HITS: 1.2580994, NOVELTY: 0.0055337, AVERAGE_POPULARITY: 0.5397976, DIVERSITY_MEAN_INTER_LIST: 0.9124103, DIVERSITY_HERFINDAHL: 0.9912343, COVERAGE_ITEM: 0.0695498, COVERAGE_ITEM_CORRECT: 0.0519962, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9736264, DIVERSITY_GINI: 0.0108430, SHANNON_ENTROPY: 7.8669331, RATIO_DIVERSITY_HERFINDAHL: 0.9916106, RATIO_DIVERSITY_GINI: 0.0425131, RATIO_SHANNON_ENTROPY: 0.6331982, RATIO_AVERAGE_POPULARITY: 2.7069573, RATIO_NOVELTY: 0.0263201,
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 39.1870
# Function value obtained: -0.2514
# Current minimum: -0.2515
# Iteration No: 25 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.13451245236875936}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.14 sec. Users per second: 358
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'norm': -inf, 'alpha': 0.13451245236875936} - results: PRECISION: 0.3965851, PRECISION_RECALL_MIN_DEN: 0.3981896, RECALL: 0.0708003, MAP: 0.2450398, MAP_MIN_DEN: 0.2457947, MRR: 0.6469922, NDCG: 0.4109798, F1: 0.1201507, HIT_RATE: 0.9704675, ARHR_ALL_HITS: 1.2370159, NOVELTY: 0.0055908, AVERAGE_POPULARITY: 0.5043103, DIVERSITY_MEAN_INTER_LIST: 0.9369545, DIVERSITY_HERFINDAHL: 0.9936886, COVERAGE_ITEM: 0.0686085, COVERAGE_ITEM_CORRECT: 0.0560385, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9701832, DIVERSITY_GINI: 0.0136949, SHANNON_ENTROPY: 8.2572419, RATIO_DIVERSITY_HERFINDAHL: 0.9940658, RATIO_DIVERSITY_GINI: 0.0536949, RATIO_SHANNON_ENTROPY: 0.6646136, RATIO_AVERAGE_POPULARITY: 2.5289971, RATIO_NOVELTY: 0.0265915,
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 38.7716
# Function value obtained: -0.2450
# Current minimum: -0.2515
# Iteration No: 26 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.999}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.75 sec. Users per second: 352
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'norm': inf, 'alpha': 0.999} - results: PRECISION: 0.4039425, PRECISION_RECALL_MIN_DEN: 0.4057127, RECALL: 0.0724712, MAP: 0.2505953, MAP_MIN_DEN: 0.2513664, MRR: 0.6529207, NDCG: 0.4178334, F1: 0.1228941, HIT_RATE: 0.9740583, ARHR_ALL_HITS: 1.2553085, NOVELTY: 0.0055227, AVERAGE_POPULARITY: 0.5480922, DIVERSITY_MEAN_INTER_LIST: 0.9051300, DIVERSITY_HERFINDAHL: 0.9905064, COVERAGE_ITEM: 0.0738690, COVERAGE_ITEM_CORRECT: 0.0521070, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9737729, DIVERSITY_GINI: 0.0102467, SHANNON_ENTROPY: 7.7652144, RATIO_DIVERSITY_HERFINDAHL: 0.9908824, RATIO_DIVERSITY_GINI: 0.0401751, RATIO_SHANNON_ENTROPY: 0.6250110, RATIO_AVERAGE_POPULARITY: 2.7485530, RATIO_NOVELTY: 0.0262675,
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 39.4179
# Function value obtained: -0.2506
# Current minimum: -0.2515
# Iteration No: 27 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.7005234216940933}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.60 sec. Users per second: 354
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'norm': -inf, 'alpha': 0.7005234216940933} - results: PRECISION: 0.4050125, PRECISION_RECALL_MIN_DEN: 0.4067654, RECALL: 0.0726190, MAP: 0.2513848, MAP_MIN_DEN: 0.2521498, MRR: 0.6539263, NDCG: 0.4188440, F1: 0.1231561, HIT_RATE: 0.9742049, ARHR_ALL_HITS: 1.2582288, NOVELTY: 0.0055282, AVERAGE_POPULARITY: 0.5436866, DIVERSITY_MEAN_INTER_LIST: 0.9090954, DIVERSITY_HERFINDAHL: 0.9909029, COVERAGE_ITEM: 0.0701589, COVERAGE_ITEM_CORRECT: 0.0517747, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9739194, DIVERSITY_GINI: 0.0105485, SHANNON_ENTROPY: 7.8194056, RATIO_DIVERSITY_HERFINDAHL: 0.9912790, RATIO_DIVERSITY_GINI: 0.0413583, RATIO_SHANNON_ENTROPY: 0.6293728, RATIO_AVERAGE_POPULARITY: 2.7264597, RATIO_NOVELTY: 0.0262940,
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 39.2571
# Function value obtained: -0.2514
# Current minimum: -0.2515
# Iteration No: 28 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.8349601274672788}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.40 sec. Users per second: 355
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'norm': inf, 'alpha': 0.8349601274672788} - results: PRECISION: 0.4049099, PRECISION_RECALL_MIN_DEN: 0.4066549, RECALL: 0.0726145, MAP: 0.2512857, MAP_MIN_DEN: 0.2520605, MRR: 0.6533087, NDCG: 0.4187115, F1: 0.1231449, HIT_RATE: 0.9739118, ARHR_ALL_HITS: 1.2576171, NOVELTY: 0.0055286, AVERAGE_POPULARITY: 0.5433353, DIVERSITY_MEAN_INTER_LIST: 0.9094368, DIVERSITY_HERFINDAHL: 0.9909370, COVERAGE_ITEM: 0.0698267, COVERAGE_ITEM_CORRECT: 0.0514979, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9736264, DIVERSITY_GINI: 0.0105655, SHANNON_ENTROPY: 7.8233853, RATIO_DIVERSITY_HERFINDAHL: 0.9913132, RATIO_DIVERSITY_GINI: 0.0414250, RATIO_SHANNON_ENTROPY: 0.6296931, RATIO_AVERAGE_POPULARITY: 2.7246984, RATIO_NOVELTY: 0.0262957,
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 39.0616
# Function value obtained: -0.2513
# Current minimum: -0.2515
# Iteration No: 29 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.8419007451804548}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.61 sec. Users per second: 353
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'norm': -inf, 'alpha': 0.8419007451804548} - results: PRECISION: 0.4047999, PRECISION_RECALL_MIN_DEN: 0.4065723, RECALL: 0.0725879, MAP: 0.2511276, MAP_MIN_DEN: 0.2518966, MRR: 0.6536456, NDCG: 0.4185923, F1: 0.1231015, HIT_RATE: 0.9742049, ARHR_ALL_HITS: 1.2573650, NOVELTY: 0.0055249, AVERAGE_POPULARITY: 0.5461962, DIVERSITY_MEAN_INTER_LIST: 0.9068602, DIVERSITY_HERFINDAHL: 0.9906794, COVERAGE_ITEM: 0.0720970, COVERAGE_ITEM_CORRECT: 0.0517747, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9739194, DIVERSITY_GINI: 0.0103658, SHANNON_ENTROPY: 7.7880938, RATIO_DIVERSITY_HERFINDAHL: 0.9910555, RATIO_DIVERSITY_GINI: 0.0406421, RATIO_SHANNON_ENTROPY: 0.6268525, RATIO_AVERAGE_POPULARITY: 2.7390449, RATIO_NOVELTY: 0.0262781,
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 39.3266
# Function value obtained: -0.2511
# Current minimum: -0.2515
# Iteration No: 30 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.4032032262649646}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.32 sec. Users per second: 356
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'norm': -inf, 'alpha': 0.4032032262649646} - results: PRECISION: 0.4038400, PRECISION_RECALL_MIN_DEN: 0.4055191, RECALL: 0.0723066, MAP: 0.2508339, MAP_MIN_DEN: 0.2516060, MRR: 0.6529101, NDCG: 0.4180478, F1: 0.1226526, HIT_RATE: 0.9731057, ARHR_ALL_HITS: 1.2568632, NOVELTY: 0.0055449, AVERAGE_POPULARITY: 0.5326029, DIVERSITY_MEAN_INTER_LIST: 0.9179360, DIVERSITY_HERFINDAHL: 0.9917869, COVERAGE_ITEM: 0.0687192, COVERAGE_ITEM_CORRECT: 0.0524392, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9728205, DIVERSITY_GINI: 0.0114019, SHANNON_ENTROPY: 7.9504591, RATIO_DIVERSITY_HERFINDAHL: 0.9921634, RATIO_DIVERSITY_GINI: 0.0447044, RATIO_SHANNON_ENTROPY: 0.6399211, RATIO_AVERAGE_POPULARITY: 2.6708778, RATIO_NOVELTY: 0.0263733,
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 38.9829
# Function value obtained: -0.2508
# Current minimum: -0.2515
# Iteration No: 31 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.27301183216636066}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.38 sec. Users per second: 356
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'norm': -inf, 'alpha': 0.27301183216636066} - results: PRECISION: 0.4020079, PRECISION_RECALL_MIN_DEN: 0.4037160, RECALL: 0.0719561, MAP: 0.2493204, MAP_MIN_DEN: 0.2500962, MRR: 0.6503445, NDCG: 0.4160966, F1: 0.1220637, HIT_RATE: 0.9722263, ARHR_ALL_HITS: 1.2508459, NOVELTY: 0.0055608, AVERAGE_POPULARITY: 0.5225087, DIVERSITY_MEAN_INTER_LIST: 0.9253508, DIVERSITY_HERFINDAHL: 0.9925283, COVERAGE_ITEM: 0.0678886, COVERAGE_ITEM_CORRECT: 0.0543219, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9719414, DIVERSITY_GINI: 0.0121959, SHANNON_ENTROPY: 8.0638072, RATIO_DIVERSITY_HERFINDAHL: 0.9929051, RATIO_DIVERSITY_GINI: 0.0478176, RATIO_SHANNON_ENTROPY: 0.6490443, RATIO_AVERAGE_POPULARITY: 2.6202576, RATIO_NOVELTY: 0.0264488,
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 39.0303
# Function value obtained: -0.2493
# Current minimum: -0.2515
# Iteration No: 32 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.5543369821468104}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.42 sec. Users per second: 355
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'norm': -inf, 'alpha': 0.5543369821468104} - results: PRECISION: 0.4050051, PRECISION_RECALL_MIN_DEN: 0.4067358, RECALL: 0.0725838, MAP: 0.2512834, MAP_MIN_DEN: 0.2520659, MRR: 0.6528956, NDCG: 0.4187068, F1: 0.1231051, HIT_RATE: 0.9741316, ARHR_ALL_HITS: 1.2573131, NOVELTY: 0.0055342, AVERAGE_POPULARITY: 0.5396202, DIVERSITY_MEAN_INTER_LIST: 0.9124712, DIVERSITY_HERFINDAHL: 0.9912404, COVERAGE_ITEM: 0.0691068, COVERAGE_ITEM_CORRECT: 0.0517194, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9738462, DIVERSITY_GINI: 0.0108563, SHANNON_ENTROPY: 7.8685252, RATIO_DIVERSITY_HERFINDAHL: 0.9916167, RATIO_DIVERSITY_GINI: 0.0425653, RATIO_SHANNON_ENTROPY: 0.6333263, RATIO_AVERAGE_POPULARITY: 2.7060678, RATIO_NOVELTY: 0.0263225,
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 39.1961
# Function value obtained: -0.2513
# Current minimum: -0.2515
# Iteration No: 33 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.0021202936587565707}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.30 sec. Users per second: 356
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'norm': inf, 'alpha': 0.0021202936587565707} - results: PRECISION: 0.3833871, PRECISION_RECALL_MIN_DEN: 0.3848903, RECALL: 0.0681516, MAP: 0.2339678, MAP_MIN_DEN: 0.2346768, MRR: 0.6343009, NDCG: 0.3976094, F1: 0.1157306, HIT_RATE: 0.9658508, ARHR_ALL_HITS: 1.1975891, NOVELTY: 0.0056403, AVERAGE_POPULARITY: 0.4758730, DIVERSITY_MEAN_INTER_LIST: 0.9514827, DIVERSITY_HERFINDAHL: 0.9951413, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0609668, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9655678, DIVERSITY_GINI: 0.0162865, SHANNON_ENTROPY: 8.5436923, RATIO_DIVERSITY_HERFINDAHL: 0.9955191, RATIO_DIVERSITY_GINI: 0.0638561, RATIO_SHANNON_ENTROPY: 0.6876696, RATIO_AVERAGE_POPULARITY: 2.3863907, RATIO_NOVELTY: 0.0268272,
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 39.1339
# Function value obtained: -0.2340
# Current minimum: -0.2515
# Iteration No: 34 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.5557148690589057}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.48 sec. Users per second: 355
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'norm': inf, 'alpha': 0.5557148690589057} - results: PRECISION: 0.4029899, PRECISION_RECALL_MIN_DEN: 0.4046874, RECALL: 0.0721711, MAP: 0.2502019, MAP_MIN_DEN: 0.2509668, MRR: 0.6522800, NDCG: 0.4171839, F1: 0.1224184, HIT_RATE: 0.9721530, ARHR_ALL_HITS: 1.2543585, NOVELTY: 0.0055510, AVERAGE_POPULARITY: 0.5286156, DIVERSITY_MEAN_INTER_LIST: 0.9209951, DIVERSITY_HERFINDAHL: 0.9920928, COVERAGE_ITEM: 0.0683316, COVERAGE_ITEM_CORRECT: 0.0531037, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9718681, DIVERSITY_GINI: 0.0117055, SHANNON_ENTROPY: 7.9958027, RATIO_DIVERSITY_HERFINDAHL: 0.9924694, RATIO_DIVERSITY_GINI: 0.0458947, RATIO_SHANNON_ENTROPY: 0.6435707, RATIO_AVERAGE_POPULARITY: 2.6508822, RATIO_NOVELTY: 0.0264022,
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 39.3420
# Function value obtained: -0.2502
# Current minimum: -0.2515
# Iteration No: 35 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.28052701417242454}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.47 sec. Users per second: 355
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'norm': inf, 'alpha': 0.28052701417242454} - results: PRECISION: 0.3962553, PRECISION_RECALL_MIN_DEN: 0.3978868, RECALL: 0.0707378, MAP: 0.2450981, MAP_MIN_DEN: 0.2458602, MRR: 0.6483643, NDCG: 0.4110557, F1: 0.1200455, HIT_RATE: 0.9709072, ARHR_ALL_HITS: 1.2383037, NOVELTY: 0.0055904, AVERAGE_POPULARITY: 0.5045390, DIVERSITY_MEAN_INTER_LIST: 0.9368610, DIVERSITY_HERFINDAHL: 0.9936792, COVERAGE_ITEM: 0.0687746, COVERAGE_ITEM_CORRECT: 0.0559278, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9706227, DIVERSITY_GINI: 0.0136618, SHANNON_ENTROPY: 8.2541421, RATIO_DIVERSITY_HERFINDAHL: 0.9940565, RATIO_DIVERSITY_GINI: 0.0535649, RATIO_SHANNON_ENTROPY: 0.6643641, RATIO_AVERAGE_POPULARITY: 2.5301442, RATIO_NOVELTY: 0.0265895,
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 39.3972
# Function value obtained: -0.2451
# Current minimum: -0.2515
# Iteration No: 36 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.7645699994214924}
# EvaluatorHoldout: Processed 13646 (100.0%) in 39.03 sec. Users per second: 350
# SearchBayesianSkopt: Config 35 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.7645699994214924} - results: PRECISION: 0.4051151, PRECISION_RECALL_MIN_DEN: 0.4068479, RECALL: 0.0725887, MAP: 0.2514438, MAP_MIN_DEN: 0.2522230, MRR: 0.6536786, NDCG: 0.4189305, F1: 0.1231172, HIT_RATE: 0.9739118, ARHR_ALL_HITS: 1.2584203, NOVELTY: 0.0055357, AVERAGE_POPULARITY: 0.5385383, DIVERSITY_MEAN_INTER_LIST: 0.9133813, DIVERSITY_HERFINDAHL: 0.9913314, COVERAGE_ITEM: 0.0688853, COVERAGE_ITEM_CORRECT: 0.0519409, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9736264, DIVERSITY_GINI: 0.0109284, SHANNON_ENTROPY: 7.8807596, RATIO_DIVERSITY_HERFINDAHL: 0.9917078, RATIO_DIVERSITY_GINI: 0.0428478, RATIO_SHANNON_ENTROPY: 0.6343111, RATIO_AVERAGE_POPULARITY: 2.7006422, RATIO_NOVELTY: 0.0263294,
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 39.9887
# Function value obtained: -0.2514
# Current minimum: -0.2515
# Iteration No: 37 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.998275976097642}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.68 sec. Users per second: 353
# SearchBayesianSkopt: Config 36 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.998275976097642} - results: PRECISION: 0.4039645, PRECISION_RECALL_MIN_DEN: 0.4057396, RECALL: 0.0724953, MAP: 0.2505530, MAP_MIN_DEN: 0.2513246, MRR: 0.6527973, NDCG: 0.4178050, F1: 0.1229297, HIT_RATE: 0.9742049, ARHR_ALL_HITS: 1.2550782, NOVELTY: 0.0055226, AVERAGE_POPULARITY: 0.5480907, DIVERSITY_MEAN_INTER_LIST: 0.9051446, DIVERSITY_HERFINDAHL: 0.9905078, COVERAGE_ITEM: 0.0738690, COVERAGE_ITEM_CORRECT: 0.0521070, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9739194, DIVERSITY_GINI: 0.0102464, SHANNON_ENTROPY: 7.7653142, RATIO_DIVERSITY_HERFINDAHL: 0.9908838, RATIO_DIVERSITY_GINI: 0.0401741, RATIO_SHANNON_ENTROPY: 0.6250190, RATIO_AVERAGE_POPULARITY: 2.7485455, RATIO_NOVELTY: 0.0262674,
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 39.5316
# Function value obtained: -0.2506
# Current minimum: -0.2515
# Iteration No: 38 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.4371281677342193}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.99 sec. Users per second: 350
# SearchBayesianSkopt: Config 37 is suboptimal. Config: {'norm': -inf, 'alpha': 0.4371281677342193} - results: PRECISION: 0.4039938, PRECISION_RECALL_MIN_DEN: 0.4056698, RECALL: 0.0722789, MAP: 0.2508633, MAP_MIN_DEN: 0.2516333, MRR: 0.6531149, NDCG: 0.4181355, F1: 0.1226197, HIT_RATE: 0.9734721, ARHR_ALL_HITS: 1.2569627, NOVELTY: 0.0055417, AVERAGE_POPULARITY: 0.5346264, DIVERSITY_MEAN_INTER_LIST: 0.9164416, DIVERSITY_HERFINDAHL: 0.9916374, COVERAGE_ITEM: 0.0687746, COVERAGE_ITEM_CORRECT: 0.0521070, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9731868, DIVERSITY_GINI: 0.0112374, SHANNON_ENTROPY: 7.9269548, RATIO_DIVERSITY_HERFINDAHL: 0.9920139, RATIO_DIVERSITY_GINI: 0.0440595, RATIO_SHANNON_ENTROPY: 0.6380292, RATIO_AVERAGE_POPULARITY: 2.6810253, RATIO_NOVELTY: 0.0263580,
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 39.8991
# Function value obtained: -0.2509
# Current minimum: -0.2515
# Iteration No: 39 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.001}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.48 sec. Users per second: 355
# SearchBayesianSkopt: Config 38 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.001} - results: PRECISION: 0.3833797, PRECISION_RECALL_MIN_DEN: 0.3848830, RECALL: 0.0681413, MAP: 0.2339875, MAP_MIN_DEN: 0.2346965, MRR: 0.6345254, NDCG: 0.3976338, F1: 0.1157155, HIT_RATE: 0.9659241, ARHR_ALL_HITS: 1.1977747, NOVELTY: 0.0056406, AVERAGE_POPULARITY: 0.4757473, DIVERSITY_MEAN_INTER_LIST: 0.9515333, DIVERSITY_HERFINDAHL: 0.9951464, COVERAGE_ITEM: 0.0734260, COVERAGE_ITEM_CORRECT: 0.0609668, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9656410, DIVERSITY_GINI: 0.0162979, SHANNON_ENTROPY: 8.5448442, RATIO_DIVERSITY_HERFINDAHL: 0.9955241, RATIO_DIVERSITY_GINI: 0.0639005, RATIO_SHANNON_ENTROPY: 0.6877623, RATIO_AVERAGE_POPULARITY: 2.3857605, RATIO_NOVELTY: 0.0268282,
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 39.3807
# Function value obtained: -0.2340
# Current minimum: -0.2515
# Iteration No: 40 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.6299347994528249}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.42 sec. Users per second: 355
# SearchBayesianSkopt: Config 39 is suboptimal. Config: {'norm': -inf, 'alpha': 0.6299347994528249} - results: PRECISION: 0.4049099, PRECISION_RECALL_MIN_DEN: 0.4066748, RECALL: 0.0726172, MAP: 0.2513002, MAP_MIN_DEN: 0.2520848, MRR: 0.6535971, NDCG: 0.4187199, F1: 0.1231488, HIT_RATE: 0.9741316, ARHR_ALL_HITS: 1.2576463, NOVELTY: 0.0055305, AVERAGE_POPULARITY: 0.5420778, DIVERSITY_MEAN_INTER_LIST: 0.9104507, DIVERSITY_HERFINDAHL: 0.9910384, COVERAGE_ITEM: 0.0696606, COVERAGE_ITEM_CORRECT: 0.0516086, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9738462, DIVERSITY_GINI: 0.0106669, SHANNON_ENTROPY: 7.8389124, RATIO_DIVERSITY_HERFINDAHL: 0.9914146, RATIO_DIVERSITY_GINI: 0.0418228, RATIO_SHANNON_ENTROPY: 0.6309428, RATIO_AVERAGE_POPULARITY: 2.7183919, RATIO_NOVELTY: 0.0263047,
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 39.3534
# Function value obtained: -0.2513
# Current minimum: -0.2515
# Iteration No: 41 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.7986323968943104}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.88 min. Users per second: 121
# SearchBayesianSkopt: Config 40 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.7986323968943104} - results: PRECISION: 0.4053642, PRECISION_RECALL_MIN_DEN: 0.4071219, RECALL: 0.0726840, MAP: 0.2514134, MAP_MIN_DEN: 0.2521903, MRR: 0.6531976, NDCG: 0.4189510, F1: 0.1232658, HIT_RATE: 0.9742782, ARHR_ALL_HITS: 1.2577970, NOVELTY: 0.0055300, AVERAGE_POPULARITY: 0.5422844, DIVERSITY_MEAN_INTER_LIST: 0.9103660, DIVERSITY_HERFINDAHL: 0.9910299, COVERAGE_ITEM: 0.0694944, COVERAGE_ITEM_CORRECT: 0.0516640, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9739927, DIVERSITY_GINI: 0.0106461, SHANNON_ENTROPY: 7.8365264, RATIO_DIVERSITY_HERFINDAHL: 0.9914061, RATIO_DIVERSITY_GINI: 0.0417412, RATIO_SHANNON_ENTROPY: 0.6307508, RATIO_AVERAGE_POPULARITY: 2.7194282, RATIO_NOVELTY: 0.0263024,
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 113.4532
# Function value obtained: -0.2514
# Current minimum: -0.2515
# Iteration No: 42 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.9135954006357926}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.59 sec. Users per second: 354
# SearchBayesianSkopt: Config 41 is suboptimal. Config: {'norm': inf, 'alpha': 0.9135954006357926} - results: PRECISION: 0.4046680, PRECISION_RECALL_MIN_DEN: 0.4064353, RECALL: 0.0725537, MAP: 0.2510973, MAP_MIN_DEN: 0.2518658, MRR: 0.6534407, NDCG: 0.4184852, F1: 0.1230463, HIT_RATE: 0.9740583, ARHR_ALL_HITS: 1.2570739, NOVELTY: 0.0055255, AVERAGE_POPULARITY: 0.5457725, DIVERSITY_MEAN_INTER_LIST: 0.9072673, DIVERSITY_HERFINDAHL: 0.9907201, COVERAGE_ITEM: 0.0713218, COVERAGE_ITEM_CORRECT: 0.0517747, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9737729, DIVERSITY_GINI: 0.0104010, SHANNON_ENTROPY: 7.7940585, RATIO_DIVERSITY_HERFINDAHL: 0.9910962, RATIO_DIVERSITY_GINI: 0.0407801, RATIO_SHANNON_ENTROPY: 0.6273326, RATIO_AVERAGE_POPULARITY: 2.7369200, RATIO_NOVELTY: 0.0262808,
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 39.6662
# Function value obtained: -0.2511
# Current minimum: -0.2515
# Iteration No: 43 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.21731456530073714}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.48 sec. Users per second: 355
# SearchBayesianSkopt: Config 42 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.21731456530073714} - results: PRECISION: 0.3918584, PRECISION_RECALL_MIN_DEN: 0.3934036, RECALL: 0.0697997, MAP: 0.2415223, MAP_MIN_DEN: 0.2422489, MRR: 0.6435738, NDCG: 0.4066264, F1: 0.1184928, HIT_RATE: 0.9693683, ARHR_ALL_HITS: 1.2253252, NOVELTY: 0.0056072, AVERAGE_POPULARITY: 0.4946619, DIVERSITY_MEAN_INTER_LIST: 0.9423971, DIVERSITY_HERFINDAHL: 0.9942328, COVERAGE_ITEM: 0.0696606, COVERAGE_ITEM_CORRECT: 0.0569799, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9690842, DIVERSITY_GINI: 0.0145161, SHANNON_ENTROPY: 8.3552557, RATIO_DIVERSITY_HERFINDAHL: 0.9946102, RATIO_DIVERSITY_GINI: 0.0569145, RATIO_SHANNON_ENTROPY: 0.6725026, RATIO_AVERAGE_POPULARITY: 2.4806127, RATIO_NOVELTY: 0.0266694,
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 39.4475
# Function value obtained: -0.2415
# Current minimum: -0.2515
# Iteration No: 44 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.001128271413381764}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.89 min. Users per second: 120
# SearchBayesianSkopt: Config 43 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.001128271413381764} - results: PRECISION: 0.3833651, PRECISION_RECALL_MIN_DEN: 0.3848683, RECALL: 0.0681386, MAP: 0.2339917, MAP_MIN_DEN: 0.2347007, MRR: 0.6344819, NDCG: 0.3976264, F1: 0.1157110, HIT_RATE: 0.9659241, ARHR_ALL_HITS: 1.1977568, NOVELTY: 0.0056405, AVERAGE_POPULARITY: 0.4757743, DIVERSITY_MEAN_INTER_LIST: 0.9515262, DIVERSITY_HERFINDAHL: 0.9951457, COVERAGE_ITEM: 0.0734814, COVERAGE_ITEM_CORRECT: 0.0610222, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9656410, DIVERSITY_GINI: 0.0162952, SHANNON_ENTROPY: 8.5446163, RATIO_DIVERSITY_HERFINDAHL: 0.9955234, RATIO_DIVERSITY_GINI: 0.0638900, RATIO_SHANNON_ENTROPY: 0.6877439, RATIO_AVERAGE_POPULARITY: 2.3858959, RATIO_NOVELTY: 0.0268280,
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 114.2924
# Function value obtained: -0.2340
# Current minimum: -0.2515
# Iteration No: 45 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.4006115408231683}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.91 min. Users per second: 119
# SearchBayesianSkopt: Config 44 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.4006115408231683} - results: PRECISION: 0.4001832, PRECISION_RECALL_MIN_DEN: 0.4018118, RECALL: 0.0714818, MAP: 0.2480494, MAP_MIN_DEN: 0.2488144, MRR: 0.6497224, NDCG: 0.4146019, F1: 0.1212971, HIT_RATE: 0.9718599, ARHR_ALL_HITS: 1.2475434, NOVELTY: 0.0055694, AVERAGE_POPULARITY: 0.5171101, DIVERSITY_MEAN_INTER_LIST: 0.9290470, DIVERSITY_HERFINDAHL: 0.9928979, COVERAGE_ITEM: 0.0677225, COVERAGE_ITEM_CORRECT: 0.0543773, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9715751, DIVERSITY_GINI: 0.0126221, SHANNON_ENTROPY: 8.1219343, RATIO_DIVERSITY_HERFINDAHL: 0.9932748, RATIO_DIVERSITY_GINI: 0.0494885, RATIO_SHANNON_ENTROPY: 0.6537229, RATIO_AVERAGE_POPULARITY: 2.5931851, RATIO_NOVELTY: 0.0264898,
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 115.5613
# Function value obtained: -0.2480
# Current minimum: -0.2515
# Iteration No: 46 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.6916336882798994}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.54 sec. Users per second: 354
# SearchBayesianSkopt: Config 45 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.6916336882798994} - results: PRECISION: 0.4041184, PRECISION_RECALL_MIN_DEN: 0.4058227, RECALL: 0.0723583, MAP: 0.2511573, MAP_MIN_DEN: 0.2519336, MRR: 0.6543627, NDCG: 0.4184769, F1: 0.1227398, HIT_RATE: 0.9736186, ARHR_ALL_HITS: 1.2586174, NOVELTY: 0.0055418, AVERAGE_POPULARITY: 0.5343849, DIVERSITY_MEAN_INTER_LIST: 0.9166641, DIVERSITY_HERFINDAHL: 0.9916597, COVERAGE_ITEM: 0.0682208, COVERAGE_ITEM_CORRECT: 0.0519962, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9733333, DIVERSITY_GINI: 0.0112569, SHANNON_ENTROPY: 7.9302264, RATIO_DIVERSITY_HERFINDAHL: 0.9920361, RATIO_DIVERSITY_GINI: 0.0441359, RATIO_SHANNON_ENTROPY: 0.6382926, RATIO_AVERAGE_POPULARITY: 2.6798139, RATIO_NOVELTY: 0.0263587,
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 39.6422
# Function value obtained: -0.2512
# Current minimum: -0.2515
# Iteration No: 47 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 2.0, 'alpha': 0.5048638394569461}
# EvaluatorHoldout: Processed 13646 (100.0%) in 1.87 min. Users per second: 122
# SearchBayesianSkopt: Config 46 is suboptimal. Config: {'norm': 2.0, 'alpha': 0.5048638394569461} - results: PRECISION: 0.4023743, PRECISION_RECALL_MIN_DEN: 0.4040722, RECALL: 0.0720380, MAP: 0.2498563, MAP_MIN_DEN: 0.2506221, MRR: 0.6516041, NDCG: 0.4166528, F1: 0.1221985, HIT_RATE: 0.9718599, ARHR_ALL_HITS: 1.2530373, NOVELTY: 0.0055554, AVERAGE_POPULARITY: 0.5257804, DIVERSITY_MEAN_INTER_LIST: 0.9230700, DIVERSITY_HERFINDAHL: 0.9923002, COVERAGE_ITEM: 0.0681101, COVERAGE_ITEM_CORRECT: 0.0533252, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9715751, DIVERSITY_GINI: 0.0119333, SHANNON_ENTROPY: 8.0278302, RATIO_DIVERSITY_HERFINDAHL: 0.9926769, RATIO_DIVERSITY_GINI: 0.0467880, RATIO_SHANNON_ENTROPY: 0.6461486, RATIO_AVERAGE_POPULARITY: 2.6366646, RATIO_NOVELTY: 0.0264234,
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 113.0991
# Function value obtained: -0.2499
# Current minimum: -0.2515
# Iteration No: 48 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': inf, 'alpha': 0.5300127750788806}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.39 sec. Users per second: 355
# SearchBayesianSkopt: Config 47 is suboptimal. Config: {'norm': inf, 'alpha': 0.5300127750788806} - results: PRECISION: 0.4026674, PRECISION_RECALL_MIN_DEN: 0.4043572, RECALL: 0.0720946, MAP: 0.2499853, MAP_MIN_DEN: 0.2507491, MRR: 0.6517146, NDCG: 0.4168673, F1: 0.1222935, HIT_RATE: 0.9720797, ARHR_ALL_HITS: 1.2534828, NOVELTY: 0.0055540, AVERAGE_POPULARITY: 0.5267064, DIVERSITY_MEAN_INTER_LIST: 0.9223979, DIVERSITY_HERFINDAHL: 0.9922330, COVERAGE_ITEM: 0.0683316, COVERAGE_ITEM_CORRECT: 0.0533252, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9717949, DIVERSITY_GINI: 0.0118565, SHANNON_ENTROPY: 8.0173215, RATIO_DIVERSITY_HERFINDAHL: 0.9926097, RATIO_DIVERSITY_GINI: 0.0464869, RATIO_SHANNON_ENTROPY: 0.6453027, RATIO_AVERAGE_POPULARITY: 2.6413081, RATIO_NOVELTY: 0.0264164,
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 39.4478
# Function value obtained: -0.2500
# Current minimum: -0.2515
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': 1.0, 'alpha': 0.999}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.74 sec. Users per second: 352
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'norm': 1.0, 'alpha': 0.999} - results: PRECISION: 0.4039425, PRECISION_RECALL_MIN_DEN: 0.4057127, RECALL: 0.0724715, MAP: 0.2505914, MAP_MIN_DEN: 0.2513625, MRR: 0.6529194, NDCG: 0.4178298, F1: 0.1228944, HIT_RATE: 0.9740583, ARHR_ALL_HITS: 1.2552905, NOVELTY: 0.0055227, AVERAGE_POPULARITY: 0.5480850, DIVERSITY_MEAN_INTER_LIST: 0.9051376, DIVERSITY_HERFINDAHL: 0.9905071, COVERAGE_ITEM: 0.0738690, COVERAGE_ITEM_CORRECT: 0.0521070, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9737729, DIVERSITY_GINI: 0.0102471, SHANNON_ENTROPY: 7.7653012, RATIO_DIVERSITY_HERFINDAHL: 0.9908831, RATIO_DIVERSITY_GINI: 0.0401768, RATIO_SHANNON_ENTROPY: 0.6250180, RATIO_AVERAGE_POPULARITY: 2.7485168, RATIO_NOVELTY: 0.0262676,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 39.7587
# Function value obtained: -0.2506
# Current minimum: -0.2515
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'norm': -inf, 'alpha': 0.23907287016986017}
# EvaluatorHoldout: Processed 13646 (100.0%) in 38.64 sec. Users per second: 353
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'norm': -inf, 'alpha': 0.23907287016986017} - results: PRECISION: 0.4008574, PRECISION_RECALL_MIN_DEN: 0.4025320, RECALL: 0.0716784, MAP: 0.2484417, MAP_MIN_DEN: 0.2492116, MRR: 0.6496062, NDCG: 0.4150785, F1: 0.1216112, HIT_RATE: 0.9719332, ARHR_ALL_HITS: 1.2483034, NOVELTY: 0.0055667, AVERAGE_POPULARITY: 0.5188429, DIVERSITY_MEAN_INTER_LIST: 0.9278222, DIVERSITY_HERFINDAHL: 0.9927754, COVERAGE_ITEM: 0.0676117, COVERAGE_ITEM_CORRECT: 0.0544327, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9716484, DIVERSITY_GINI: 0.0124965, SHANNON_ENTROPY: 8.1039577, RATIO_DIVERSITY_HERFINDAHL: 0.9931523, RATIO_DIVERSITY_GINI: 0.0489961, RATIO_SHANNON_ENTROPY: 0.6522759, RATIO_AVERAGE_POPULARITY: 2.6018749, RATIO_NOVELTY: 0.0264768,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 39.5906
# Function value obtained: -0.2484
# Current minimum: -0.2515
# SearchBayesianSkopt: Search complete. Best config is 5: {'norm': 1.0, 'alpha': 0.8390415906812541}
